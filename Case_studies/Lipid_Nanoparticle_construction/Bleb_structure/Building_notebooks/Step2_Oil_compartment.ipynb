# %%
import numpy as np
import os
import subprocess 
import MDAnalysis as md
from MDAnalysis.analysis.leaflet import LeafletFinder
import re

# %% [markdown]
# # Notebook for constructing oil compartment

# %% [markdown]
# ## Requirements
# ### - Define Paths bellow;

# %%
IL_name_NP = 'MC3H'
IL_name_N1 = 'MC3'
sterol_name = 'CHOL'
vesicle_radius = 25 # nm
no_N1_lipids = 14000 # number of ILs - can be adapted
no_CHOL_lipids = 7000 # number of Cholesterols - can be adapted

# %%
main_dir = '.'
mdp_loc_BL = 'MDPs/'
ILs_itp = 'ITP/MC3_KC2_DP_DT/_LI5_LI2_LI10_BMHB.itp'

PCG_path = '' #Define path to PCG/TS2CG instalation

RNA = 'PDBs/ssDNA.gro'
RNA_itp = 'ITP/ssDNA.itp'

    
itpDir   = "ITP/"
IL_itp   = 'ITP/MC3_KC2_DP_DT_LI5_LI2_LI10_BMHB.itp'
Sterols  = "ITP/martini_v3.0_sterols_v1.0.itp"    
ffbonded = "ITP/martini_v3.0_ffbonded.itp"

# %% [markdown]
# ####  functions

# %%
def get_radius (x,y,z):
    # Calculate the centroid of the cylinder (center axis)
    centroid_x = np.mean(x)
    centroid_y = np.mean(y)
    centroid_z = np.mean(z)

    # Calculate the distances from the centroid to each point
    distances = np.sqrt((x - centroid_x)**2 + (y - centroid_y)**2 + (z - centroid_z)**2)

    # Find the minimum distance, which represents the internal radius of the cylinder
    internal_radius = np.min(distances)

    return internal_radius

def write_packmol_input(channel_radius, noW=1, noCL=1):
    f = open('solvate_channel.inp', 'w') 
    f.write(f'tolerance 3.0\nfiletype pdb\n\n')

    f.write(f'structure PDBs/MC3.pdb\n')
    f.write(f'  number {no_N1_lipids}\n') 
    f.write(f'  inside sphere 0. 0. 0. {int(channel_radius)}.\n')
    f.write(f'end structure\n')

    f.write(f'structure PDBs/CHOL.pdb\n')
    f.write(f'  number {no_CHOL_lipids}\n') 
    f.write(f'  inside sphere 0. 0. 0. {int(channel_radius)}.\n')
    f.write(f'end structure\n')
            
    f.write('output solvate_channel_rna2.pdb\n')
    f.close()
    return

def extract_lines(input_file, pattern):
    extracted_lines = []
    pattern_found = False

    with open(input_file, 'r') as f:
        for line in f:
            if pattern_found:
                extracted_lines.append(line)

            if pattern in line:
                pattern_found = True

    return extracted_lines

def write_topol (topol, noW, noCL):
    '''Writes out a topol.top file with the solvate channel times 4 including the correct itp files'''
    extracted_lines = extract_lines(topol, 'lower monolayer')


    with open('topol2.top', 'w') as topout:
        topout.write(f'#include "{itpDir}/martini_v3.0.0.itp"\n#include "{ffbonded}"\n#include "{RNA_itp}"\n\
#include "{itpDir}/martini_v3.0.0_phospholipids_v1.itp"\
\n#include "{IL_itp}"\n#include "{Sterols}"\n#include "{itpDir}/martini_v3.0.0_solvents_v1.itp"\n\
#include "{itpDir}/martini_v3.0.0_ions_v1.itp"\n')
        topout.write(f'[ system ]\n')
        topout.write('Compartment_Oil\n')
        topout.write(f'\n')
        topout.write(f'[ molecules ]\n')
        for i in range(1):
                topout.write(f'MC3    {no_N1_lipids}\n')
                topout.write(f'CHOL    {no_CHOL_lipids}\n')

    return

# %% [markdown]
# ## Create oil compartment

# %%
write_packmol_input((vesicle_radius*100)-5, noW=0, noCL=0)

# %% [markdown]
# ##### Run packmol

# %%
# !/projects/DAMM/packmol-20.14.3/packmol < solvate_channel.inp
# Out:
# ################################################################################
#
#  PACKMOL - Packing optimization for the automated generation of
#  starting configurations for molecular dynamics simulations.
#
#                                                               Version 20.14.3
#
# ################################################################################
#
#   Packmol must be run with: packmol < inputfile.inp
#
#   Userguide at: http://m3g.iqm.unicamp.br/packmol
#
#   Reading input file... (Control-C aborts)
#   Types of coordinate files specified: pdb
#   Seed for random number generator:      1234567
#   Output file: solvate_channel_rna2.pdb
#   Reading coordinate file: PDBs/MC3.pdb
#   Reading coordinate file: PDBs/CHOL.pdb
#   Number of independent structures:            2
#   The structures are:
#   Structure            1 :PDBs/MC3.pdb(          12  atoms)
#   Structure            2 :PDBs/CHOL.pdb(           9  atoms)
#   Maximum number of GENCAN loops for all molecule packing:          400
#   Total number of restrictions:            2
#   Distance tolerance:    3.0000000000000000
#   Warning: Type of residue numbering not set for structure            1
#   Residue numbering set for structure            1 :           0
#   Swap chains of molecules of structure            1 : F
#   Warning: Type of residue numbering not set for structure            2
#   Residue numbering set for structure            2 :           0
#   Swap chains of molecules of structure            2 : F
#   Number of molecules of type            1 :        14000
#   Warning: There will be more than 9999 molecules of type            1
#            Residue numbering is reset after 9999.
#   Each set be will be assigned a different chain in the PDB output file.
#   Number of molecules of type            2 :         7000
#   Total number of atoms:       231000
#   Total number of molecules:        21000
#   Number of fixed molecules:            0
#   Number of free molecules:        21000
#   Number of variables:       126000
#   Total number of fixed atoms:            0
#   Maximum internal distance of type            1 :    12.162409300792341
#   Maximum internal distance of type            2 :    15.115882375832378
#   All atoms must be within these coordinates:
#    x: [   -1000.0000000000000      ,    1000.0000000000000       ]
#    y: [   -1000.0000000000000      ,    1000.0000000000000       ]
#    z: [   -1000.0000000000000      ,    1000.0000000000000       ]
#   If the system is larger than this, increase the sidemax parameter.
#
# ################################################################################
#
#   Building initial approximation ...
#
# ################################################################################
#
#   Adjusting initial point to fit the constraints
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#           |***********************************
#
#   Restraint-only function value:    1.5412756483434902E-005
#   Maximum violation of the restraints:    1.5412666513706600E-005
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            2
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#           |******************************************************************|
#
#
#   Restraint-only function value:    0.0000000000000000
#   Maximum violation of the restraints:    0.0000000000000000
#
# --------------------------------------------------------------------------------
#
#   Rescaling maximum and minimum coordinates...
#   Computing size of patches...
#   Add fixed molecules to permanent arrays...
#   Reseting center of mass...
#
# --------------------------------------------------------------------------------
#
#   Setting initial trial coordinates ...
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |*************************************************
#   Restraint-only function value:    0.0000000000000000
#   Maximum violation of the restraints:    0.0000000000000000
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            2
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |*******
#   Restraint-only function value:    0.0000000000000000
#   Maximum violation of the restraints:    0.0000000000000000
#
# ################################################################################
#
#   Objective function at initial point:    922425.95671129657
#
# ################################################################################
#
#   Packing molecules of type:            1
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#           |******************************************************************|
#
#   Function value from last GENCAN loop: f = .10888E+01
#   Best function value before: f = .47869E+06
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.816117
#   Maximum violation of the constraints: .11596E-01
#   All-type function value: .44566E+06
#
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            1
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |
#
#   Function value from last GENCAN loop: f = .95772E-02
#   Best function value before: f = .10888E+01
#   Improvement from best function value:    99.12 %
#   Improvement from last loop:    99.12 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .95772E-02
#   Current structure written to file: solvate_channel_rna2.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           1
#   Objective function value:    9.5772441492586683E-003
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    9.5772441492586683E-003
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing molecules of type:            2
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#           |******************************************************************|
#
#   Function value from last GENCAN loop: f = .38945E+02
#   Best function value before: f = .71925E+05
#   Improvement from best function value:    99.95 %
#   Improvement from last loop:    99.95 %
#   Maximum violation of target distance:     4.386119
#   Maximum violation of the constraints: .00000E+00
#   All-type function value: .37180E+06
#
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            1
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |*******
#
#   Function value from last GENCAN loop: f = .00000E+00
#   Best function value before: f = .38945E+02
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .00000E+00
#   Current structure written to file: solvate_channel_rna2.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           2
#   Objective function value:    0.0000000000000000
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    0.0000000000000000
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing all molecules together
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#           |******************************************************************|
#
#   Function value from last GENCAN loop: f = .49403E+04
#   Best function value before: f = .37178E+06
#   Improvement from best function value:    98.67 %
#   Improvement from last loop:    98.67 %
#   Maximum violation of target distance:     8.964711
#   Maximum violation of the constraints: .12319E+01
#
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            1
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#           |******************************************************************|
#
#   Function value from last GENCAN loop: f = .18214E+03
#   Best function value before: f = .49403E+04
#   Improvement from best function value:    96.31 %
#   Improvement from last loop:    96.31 %
#   Maximum violation of target distance:     4.920713
#   Maximum violation of the constraints: .00000E+00
#
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            2
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#           |******************************************************************|
#
#   Function value from last GENCAN loop: f = .18588E+03
#   Best function value before: f = .18214E+03
#   Improvement from best function value:    -2.05 %
#   Improvement from last loop:    -2.05 %
#   Maximum violation of target distance:     4.704968
#   Maximum violation of the constraints: .00000E+00
#
# --------------------------------------------------------------------------------
#
#   Moving worst molecules ...
#   Function value before moving molecules:   185.88168370969538
#   Type         1 molecules with non-zero contributions:    0.04%
#   Moving         5 molecules of type         1
#   New positions will be based on good molecules (movebadrandom is not set)
#    Moving:|0                                                             100%|
#           |******************************************************************|
#   Type         2 molecules with non-zero contributions:    0.07%
#   Moving         5 molecules of type         2
#   New positions will be based on good molecules (movebadrandom is not set)
#    Moving:|0                                                             100%|
#           |******************************************************************|
#   Function value after moving molecules:   5436.5743927441572
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            3
#   Scaling radii by:    1.0000000000000000
#
#   Packing:|0                                                             100%|
#           |******************************************
#
#   Function value from last GENCAN loop: f = .25577E-06
#   Best function value before: f = .18214E+03
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000506
#   Maximum violation of the constraints: .00000E+00
#
# ################################################################################
#
#                                  Success!
#               Final objective function value: .25577E-06
#               Maximum violation of target distance:   0.000506
#               Maximum violation of the constraints: .00000E+00
#
# --------------------------------------------------------------------------------
#
#               Please cite this work if Packmol was useful:
#
#            L. Martinez, R. Andrade, E. G. Birgin, J. M. Martinez,
#          PACKMOL: A package for building initial configurations for
#                    molecular dynamics simulations.
#           Journal of Computational Chemistry, 30:2157-2164,2009.
#
# ################################################################################
#
#   Solution written to file: solvate_channel_rna2.pdb
#
# --------------------------------------------------------------------------------
#
#    Running time:    130.494751      seconds.
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ##### Create box

# %%
os.system('gmx editconf -f solvate_channel_rna2.pdb -o channel_solvated_combined2.gro -box 70 70 70')
# Out:
#                      :-) GROMACS - gmx editconf, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/LNP_builder/Building_material/Bleb_particle
# Command line:
#   gmx editconf -f solvate_channel_rna2.pdb -o channel_solvated_combined2.gro -box 70 70 70
#
#
# Back Off! I just backed up channel_solvated_combined2.gro to ./#channel_solvated_combined2.gro.2#
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 231000 atoms
# No velocities found
#     system size : 48.258 48.627 48.693 (nm)
#     center      : -0.063  0.011 -0.055 (nm)
#     box vectors :  0.000  0.000  0.000 (nm)
#     box angles  :   0.00   0.00   0.00 (degrees)
#     box volume  :   0.00               (nm^3)
#     shift       : 35.063 34.989 35.055 (nm)
# new center      : 35.000 35.000 35.000 (nm)
# new box vectors : 70.000 70.000 70.000 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :343000.00               (nm^3)
# GROMACS reminds you: "I'd be Safe and Warm if I was in L.A." (The Mamas and the Papas)
# 0

# %% [markdown]
# ##### Write topol.top

# %%
write_topol('system2.top', noW=0, noCL=0)

# %% [markdown]
# ### Min and relax

# %%
os.system(f"gmx grompp -f {mdp_loc_BL}/min.mdp -c channel_solvated_combined2.gro -p topol2.top -o m2.tpr -maxwarn 1")
# Out:
#                       :-) GROMACS - gmx grompp, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/LNP_builder/Building_material/Bleb_particle
# Command line:
#   gmx grompp -f MDPs//min.mdp -c channel_solvated_combined2.gro -p topol2.top -o m2.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file MDPs//min.mdp]:
#   Setting tcoupl from 'V-rescale' to 'no'. Temperature coupling does not
#   apply to steep.
#
#
# NOTE 2 [file MDPs//min.mdp]:
#   Setting pcoupl from 'C-rescale' to 'no'. Pressure coupling does not apply
#   to steep.
# Setting the LD random seed to 2032820143
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'MC3'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are: 21000      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 30 Mb of data
# Number of degrees of freedom in T-Coupling group System is 566997.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# There were 2 NOTEs
#
# Back Off! I just backed up m2.tpr to ./#m2.tpr.2#
#
# GROMACS reminds you: "Fresh Air, Green Hair" (Frank Black)
# 0

# %%
os.system(f"gmx mdrun -v -deffnm m2 -ntomp 5 -ntmpi 2")
# Out:
#                       :-) GROMACS - gmx mdrun, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/LNP_builder/Building_material/Bleb_particle
# Command line:
#   gmx mdrun -v -deffnm m2 -ntomp 5 -ntmpi 2
#
#
# Back Off! I just backed up m2.log to ./#m2.log.3#
# Reading file m2.tpr, VERSION 2023.3 (single precision)
# Update groups can not be used for this system because an incompatible virtual site type is used
#
# On host ibcp22-085 1 GPU selected for this run.
# Mapping of GPU IDs to the 2 GPU tasks in the 2 ranks on this node:
#   PP:0,PP:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 2 MPI threads
# Using 5 OpenMP threads per tMPI thread
#
#
# NOTE: The number of threads is not equal to the number of (logical) cpus
#       and the -pin option is set to auto: will not pin threads to cpus.
#       This can lead to significant performance degradation.
#       Consider using -pin on (and -pinoffset in case you run multiple jobs).
#
# Back Off! I just backed up m2.trr to ./#m2.trr.3#
#
# Back Off! I just backed up m2.edr to ./#m2.edr.3#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+01
#    Number of steps    =         1000
# Step=    0, Dmax= 1.0e-02 nm, Epot=  5.48141e+10 Fmax= 2.84789e+08, atom= 33793
# Step=    1, Dmax= 1.0e-02 nm, Epot=  2.40795e+10 Fmax= 4.98451e+07, atom= 46261
# Step=    2, Dmax= 1.2e-02 nm, Epot=  1.08290e+10 Fmax= 1.16549e+07, atom= 142067
# Step=    3, Dmax= 1.4e-02 nm, Epot=  3.08917e+09 Fmax= 2.38742e+06, atom= 161710
# Step=    4, Dmax= 1.7e-02 nm, Epot=  7.37132e+08 Fmax= 7.42120e+05, atom= 62586
# Step=    5, Dmax= 2.1e-02 nm, Epot=  2.87392e+08 Fmax= 3.73275e+05, atom= 67087
# Step=    6, Dmax= 2.5e-02 nm, Epot=  1.53840e+08 Fmax= 2.35319e+05, atom= 113202
# Step=    7, Dmax= 3.0e-02 nm, Epot=  9.75879e+07 Fmax= 2.73400e+05, atom= 159432
# Step=    8, Dmax= 3.6e-02 nm, Epot=  7.84022e+07 Fmax= 1.76277e+05, atom= 165392
# Step=    9, Dmax= 4.3e-02 nm, Epot=  6.05597e+07 Fmax= 2.91899e+05, atom= 165392
# Step=   10, Dmax= 5.2e-02 nm, Epot=  5.42135e+07 Fmax= 1.49087e+05, atom= 165392
# Step=   11, Dmax= 6.2e-02 nm, Epot=  4.47762e+07 Fmax= 2.03721e+05, atom= 165392
# Step=   12, Dmax= 7.4e-02 nm, Epot=  4.03156e+07 Fmax= 1.01347e+05, atom= 165392
# Step=   13, Dmax= 8.9e-02 nm, Epot=  3.36863e+07 Fmax= 2.42051e+05, atom= 165392
# Step=   14, Dmax= 1.1e-01 nm, Epot=  3.18583e+07 Fmax= 7.24453e+04, atom= 71299
# Step=   15, Dmax= 1.3e-01 nm, Epot=  2.67646e+07 Fmax= 8.58863e+04, atom= 71299
# Step=   16, Dmax= 1.5e-01 nm, Epot=  2.41410e+07 Fmax= 1.05079e+06, atom= 165392
# Step=   17, Dmax= 1.8e-01 nm, Epot=  2.39375e+07 Fmax= 1.29866e+05, atom= 165396
# Step=   18, Dmax= 2.2e-01 nm, Epot=  2.23325e+07 Fmax= 1.61886e+06, atom= 165396
# Step=   19, Dmax= 2.7e-01 nm, Epot=  2.22493e+07 Fmax= 3.24488e+06, atom= 165394
# Step=   20, Dmax= 3.2e-01 nm, Epot=  2.21017e+07 Fmax= 5.78768e+04, atom= 165394
# Step=   21, Dmax= 3.8e-01 nm, Epot=  1.81148e+07 Fmax= 1.15364e+04, atom= 54372
# Step=   23, Dmax= 2.3e-01 nm, Epot=  1.32276e+07 Fmax= 1.83103e+06, atom= 54367
# Step=   24, Dmax= 2.8e-01 nm, Epot=  1.31502e+07 Fmax= 1.54953e+05, atom= 23789
# Step=   25, Dmax= 3.3e-01 nm, Epot=  1.28999e+07 Fmax= 2.58785e+04, atom= 23791
# Step=   27, Dmax= 2.0e-01 nm, Epot=  1.21088e+07 Fmax= 8.89238e+05, atom= 218391
# Step=   28, Dmax= 2.4e-01 nm, Epot=  1.20688e+07 Fmax= 2.82185e+05, atom= 23789
# Step=   29, Dmax= 2.9e-01 nm, Epot=  1.19671e+07 Fmax= 1.89643e+04, atom= 23793
# Step=   30, Dmax= 3.4e-01 nm, Epot=  1.08745e+07 Fmax= 2.72576e+07, atom= 54368
# Step=   31, Dmax= 4.1e-01 nm, Epot=  1.04315e+07 Fmax= 2.24707e+05, atom= 23793
# Step=   33, Dmax= 2.5e-01 nm, Epot=  1.03840e+07 Fmax= 1.53160e+06, atom= 237951
# Step=   36, Dmax= 7.4e-02 nm, Epot=  1.03586e+07 Fmax= 4.41188e+05, atom= 23793
# Step=   37, Dmax= 8.9e-02 nm, Epot=  1.03354e+07 Fmax= 3.71080e+04, atom= 23793
# Step=   38, Dmax= 1.1e-01 nm, Epot=  1.01416e+07 Fmax= 6.94741e+03, atom= 23793
# Step=   39, Dmax= 1.3e-01 nm, Epot=  9.00409e+06 Fmax= 1.65677e+03, atom= 46939
#
# Step 40, time 0.8 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000022, max 0.001379 (between atoms 199976 and 199971)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  199971 199970   30.0    0.3480   0.3480      0.3480
# Step=   40, Dmax= 1.5e-01 nm, Epot=  5.19968e+06 Fmax= 1.98469e+05, atom= 199971
#
# Step 41, time 0.82 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000069, max 0.004944 (between atoms 199976 and 199970)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  199971 199970   36.4    0.3480   0.3489      0.3480
# Step=   41, Dmax= 1.8e-01 nm, Epot=  5.14938e+06 Fmax= 2.67372e+04, atom= 200358
#
# Step 42, time 0.84 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000175, max 0.012958 (between atoms 200358 and 200357)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200363 200358   35.4    0.7507   0.7595      0.7501
#  200358 200357   38.0    0.3475   0.3435      0.3480
# Step=   42, Dmax= 2.2e-01 nm, Epot=  4.90082e+06 Fmax= 3.62667e+05, atom= 200358
#
# Step 43, time 0.86 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000219, max 0.022517 (between atoms 200358 and 200357)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200358 200357   39.8    0.3435   0.3558      0.3480
# Step=   43, Dmax= 2.7e-01 nm, Epot=  4.87923e+06 Fmax= 2.83949e+05, atom= 199971
#
# Step 44, time 0.88 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000176, max 0.016394 (between atoms 199971 and 199970)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  199971 199970   57.4    0.3480   0.3537      0.3480
# Step=   44, Dmax= 3.2e-01 nm, Epot=  4.84204e+06 Fmax= 2.44065e+04, atom= 26885
#
# Step 45, time 0.9 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000911, max 0.085464 (between atoms 199971 and 199970)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200358 200357   45.8    0.3480   0.3526      0.3480
#  199971 199970   90.0    0.3537   0.3777      0.3480
# Step=   45, Dmax= 3.8e-01 nm, Epot=  4.75365e+06 Fmax= 9.26057e+06, atom= 26885
# Step=   47, Dmax= 2.3e-01 nm, Epot=  4.46861e+06 Fmax= 1.56986e+05, atom= 106230
#
# Step 48, time 0.96 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000193, max 0.016085 (between atoms 200358 and 200357)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200358 200357   40.6    0.3480   0.3536      0.3480
# Step=   49, Dmax= 1.4e-01 nm, Epot=  4.43862e+06 Fmax= 1.64677e+05, atom= 106230
# Step=   50, Dmax= 1.7e-01 nm, Epot=  4.40814e+06 Fmax= 2.25220e+04, atom= 18007
# Step=   52, Dmax= 9.9e-02 nm, Epot=  4.30596e+06 Fmax= 4.24586e+04, atom= 199970
# Step=   53, Dmax= 1.2e-01 nm, Epot=  4.24129e+06 Fmax= 1.12895e+04, atom= 106234
# Step=   54, Dmax= 1.4e-01 nm, Epot=  3.95796e+06 Fmax= 1.13934e+03, atom= 26885
# Step=   55, Dmax= 1.7e-01 nm, Epot=  1.48868e+06 Fmax= 1.33990e+05, atom= 200358
#
# Step 56, time 1.12 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000052, max 0.005287 (between atoms 200358 and 200357)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200358 200357   34.4    0.3486   0.3498      0.3480
# Step=   56, Dmax= 2.1e-01 nm, Epot=  1.44506e+06 Fmax= 8.54607e+03, atom= 200358
#
# Step 57, time 1.14 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.002750, max 0.281473 (between atoms 200358 and 200357)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200363 200358   31.7    0.7507   0.7683      0.7501
#  200358 200357   90.0    0.3498   0.4459      0.3480
# Step=   57, Dmax= 2.5e-01 nm, Epot=  1.16640e+06 Fmax= 7.96709e+05, atom= 106229
# Step=   58, Dmax= 3.0e-01 nm, Epot=  1.15892e+06 Fmax= 7.21439e+05, atom= 53575
# Step=   60, Dmax= 1.8e-01 nm, Epot=  1.14012e+06 Fmax= 9.60795e+04, atom= 20361
# Step=   61, Dmax= 2.1e-01 nm, Epot=  1.11616e+06 Fmax= 3.15820e+03, atom= 200363
#
# Step 62, time 1.24 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000152, max 0.009204 (between atoms 200363 and 200357)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200363 200357   30.2    0.7850   0.7778      0.7850
#  200363 200358   31.1    0.7501   0.7568      0.7501
#  200358 200357   38.9    0.3480   0.3493      0.3480
#  211941 211940   44.9    0.3480   0.3489      0.3480
# Step=   62, Dmax= 2.6e-01 nm, Epot=  6.15638e+05 Fmax= 1.58441e+06, atom= 164706
# Step=   63, Dmax= 3.1e-01 nm, Epot=  5.64140e+05 Fmax= 3.85338e+04, atom= 172718
#
# Step 64, time 1.28 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000735, max 0.052762 (between atoms 172719 and 172718)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  172724 172718   30.4    0.7850   0.8262      0.7850
#  172719 172718   90.0    0.3480   0.3663      0.3480
# Step=   64, Dmax= 3.7e-01 nm, Epot=  4.97142e+05 Fmax= 2.92494e+04, atom= 18007
# Step=   65, Dmax= 4.4e-01 nm, Epot=  4.20659e+05 Fmax= 5.39957e+03, atom= 26884
# Step=   67, Dmax= 2.7e-01 nm, Epot=  2.66510e+05 Fmax= 3.33889e+06, atom= 147856
# Step=   69, Dmax= 1.6e-01 nm, Epot=  2.11710e+05 Fmax= 1.15199e+04, atom= 147856
# Step=   70, Dmax= 1.9e-01 nm, Epot=  1.54065e+05 Fmax= 1.14830e+04, atom= 139291
# Step=   71, Dmax= 2.3e-01 nm, Epot=  9.00249e+04 Fmax= 6.86796e+02, atom= 20357
# Step=   72, Dmax= 2.8e-01 nm, Epot= -3.27150e+05 Fmax= 5.19678e+05, atom= 20357
# Step=   73, Dmax= 3.3e-01 nm, Epot= -3.41518e+05 Fmax= 8.65276e+05, atom= 200358
#
# Step 74, time 1.48 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000832, max 0.083789 (between atoms 200358 and 200357)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200363 200358   48.4    0.7501   0.7638      0.7501
#  200358 200357   57.1    0.3480   0.3771      0.3480
# Step=   76, Dmax= 9.9e-02 nm, Epot= -3.57648e+05 Fmax= 4.95336e+04, atom= 106233
# Step=   77, Dmax= 1.2e-01 nm, Epot= -3.80740e+05 Fmax= 1.64448e+04, atom= 106233
# Step=   78, Dmax= 1.4e-01 nm, Epot= -4.24674e+05 Fmax= 8.78110e+03, atom= 26890
# Step=   79, Dmax= 1.7e-01 nm, Epot= -4.78021e+05 Fmax= 1.43776e+03, atom= 139291
# Step=   80, Dmax= 2.1e-01 nm, Epot= -6.01218e+05 Fmax= 5.26964e+03, atom= 26890
# Step=   81, Dmax= 2.5e-01 nm, Epot= -6.24453e+05 Fmax= 1.45010e+05, atom= 18007
#
# Step 82, time 1.64 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000270, max 0.020655 (between atoms 199976 and 199970)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  199971 199970   68.6    0.3455   0.3542      0.3480
# Step=   82, Dmax= 3.0e-01 nm, Epot= -6.27729e+05 Fmax= 4.97816e+03, atom= 18007
#
# Step 83, time 1.66 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000219, max 0.022183 (between atoms 200363 and 200358)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200358 200357   72.4    0.3480   0.3480      0.3480
#  199971 199970   37.5    0.3542   0.3476      0.3480
# Step=   84, Dmax= 1.8e-01 nm, Epot= -6.39999e+05 Fmax= 3.44211e+04, atom= 159653
#
# Step 85, time 1.7 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000021, max 0.002162 (between atoms 210092 and 210087)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  210087 210086   34.9    0.3480   0.3480      0.3480
# Step=   85, Dmax= 2.1e-01 nm, Epot= -6.42447e+05 Fmax= 1.43140e+04, atom= 210086
#
# Step 86, time 1.72 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000236, max 0.020362 (between atoms 210092 and 210086)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  210087 210086   59.3    0.3480   0.3498      0.3480
# Step=   86, Dmax= 2.6e-01 nm, Epot= -6.48697e+05 Fmax= 9.88589e+02, atom= 210086
#
# Step 87, time 1.74 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000263, max 0.025416 (between atoms 210087 and 210086)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  210092 210086   32.0    0.8010   0.7925      0.7850
#  210087 210086   62.9    0.3498   0.3568      0.3480
# Step=   87, Dmax= 3.1e-01 nm, Epot= -7.20985e+05 Fmax= 2.64529e+05, atom= 18007
# Step=   89, Dmax= 1.8e-01 nm, Epot= -7.26438e+05 Fmax= 2.35813e+04, atom= 18007
#
# Step 90, time 1.8 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000051, max 0.003689 (between atoms 199971 and 199970)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  199971 199970   30.1    0.3480   0.3467      0.3480
# Step=   90, Dmax= 2.2e-01 nm, Epot= -7.29987e+05 Fmax= 5.85217e+03, atom= 199970
#
# Step 91, time 1.82 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000456, max 0.037079 (between atoms 199976 and 199970)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  199971 199970   87.7    0.3467   0.3579      0.3480
# Step=   91, Dmax= 2.6e-01 nm, Epot= -7.40280e+05 Fmax= 4.10392e+04, atom= 18006
# Step=   92, Dmax= 3.2e-01 nm, Epot= -7.41634e+05 Fmax= 2.04620e+04, atom= 18006
#
# Step 93, time 1.86 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000443, max 0.038209 (between atoms 199971 and 199970)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  199976 199971   34.6    0.7522   0.7680      0.7501
#  199971 199970   43.2    0.3462   0.3347      0.3480
# Step=   94, Dmax= 1.9e-01 nm, Epot= -7.43613e+05 Fmax= 2.13376e+04, atom= 18006
# Step=   95, Dmax= 2.3e-01 nm, Epot= -7.46758e+05 Fmax= 2.19143e+03, atom= 159652
# Step=   96, Dmax= 2.7e-01 nm, Epot= -7.69528e+05 Fmax= 1.70290e+04, atom= 159652
# Step=   97, Dmax= 3.3e-01 nm, Epot= -7.73226e+05 Fmax= 2.94342e+03, atom= 22724
# Step=   99, Dmax= 2.0e-01 nm, Epot= -7.85008e+05 Fmax= 3.89750e+03, atom= 22724
# Step=  100, Dmax= 2.4e-01 nm, Epot= -7.94156e+05 Fmax= 3.08976e+04, atom= 159657
# Step=  101, Dmax= 2.8e-01 nm, Epot= -7.95126e+05 Fmax= 3.69272e+04, atom= 159659
# Step=  102, Dmax= 3.4e-01 nm, Epot= -7.96654e+05 Fmax= 3.77439e+04, atom= 26886
# Step=  105, Dmax= 1.0e-01 nm, Epot= -7.98025e+05 Fmax= 4.64759e+03, atom= 147857
# Step=  106, Dmax= 1.2e-01 nm, Epot= -8.02277e+05 Fmax= 1.14682e+03, atom= 26886
# Step=  107, Dmax= 1.5e-01 nm, Epot= -8.21627e+05 Fmax= 1.52390e+03, atom= 64720
# Step=  108, Dmax= 1.8e-01 nm, Epot= -8.37747e+05 Fmax= 1.22601e+03, atom= 64720
# Step=  109, Dmax= 2.1e-01 nm, Epot= -8.60089e+05 Fmax= 3.34564e+03, atom= 64721
# Step=  110, Dmax= 2.6e-01 nm, Epot= -8.69159e+05 Fmax= 1.65318e+04, atom= 88248
#
# Step 111, time 2.22 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000159, max 0.015436 (between atoms 186624 and 186623)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  186624 186623   52.4    0.3480   0.3533      0.3480
# Step=  111, Dmax= 3.1e-01 nm, Epot= -8.71011e+05 Fmax= 1.83995e+04, atom= 186624
#
# Step 112, time 2.24 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.005051, max 0.518855 (between atoms 186624 and 186623)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  186629 186624   42.2    0.7539   0.7377      0.7501
#  186624 186623   90.0    0.3533   0.5285      0.3480
# Wrote pdb files with previous and current coordinates
# Step=  112, Dmax= 3.7e-01 nm, Epot=          inf Fmax= 1.65318e+04, atom= 88248
# Step 113, time 2.26 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000211, max 0.020730 (between atoms 186624 and 186623)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  186624 186623   43.1    0.3533   0.3552      0.3480
# Step=  113, Dmax= 1.8e-01 nm, Epot= -8.72803e+05 Fmax= 2.02490e+03, atom= 102799
#
# Step 114, time 2.28 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000016, max 0.001274 (between atoms 173156 and 173151)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  173151 173150   38.8    0.3483   0.3480      0.3480
# Step=  114, Dmax= 2.2e-01 nm, Epot= -8.84981e+05 Fmax= 8.33450e+03, atom= 102803
# Step=  115, Dmax= 2.6e-01 nm, Epot= -8.88744e+05 Fmax= 7.13125e+03, atom= 64719
# Step=  117, Dmax= 1.6e-01 nm, Epot= -8.91219e+05 Fmax= 8.25644e+03, atom= 139292
# Step=  118, Dmax= 1.9e-01 nm, Epot= -8.93947e+05 Fmax= 6.66345e+02, atom= 147855
# Step=  119, Dmax= 2.3e-01 nm, Epot= -9.28586e+05 Fmax= 1.97131e+04, atom= 88244
# Step=  121, Dmax= 1.4e-01 nm, Epot= -9.29863e+05 Fmax= 6.19499e+03, atom= 64719
# Step=  122, Dmax= 1.6e-01 nm, Epot= -9.32732e+05 Fmax= 8.61197e+02, atom= 147856
# Step=  123, Dmax= 2.0e-01 nm, Epot= -9.53315e+05 Fmax= 2.18634e+03, atom= 147856
# Step=  124, Dmax= 2.4e-01 nm, Epot= -9.62290e+05 Fmax= 1.09800e+04, atom= 139289
# Step=  125, Dmax= 2.8e-01 nm, Epot= -9.64997e+05 Fmax= 1.52015e+03, atom= 139289
# Step=  126, Dmax= 3.4e-01 nm, Epot= -9.80319e+05 Fmax= 5.19740e+04, atom= 186630
# Step=  127, Dmax= 4.1e-01 nm, Epot= -9.83118e+05 Fmax= 2.00287e+03, atom= 147858
# Step=  128, Dmax= 4.9e-01 nm, Epot= -9.83544e+05 Fmax= 3.04519e+05, atom= 147863
# Step=  129, Dmax= 5.9e-01 nm, Epot= -9.95100e+05 Fmax= 4.88016e+04, atom= 31026
#
# Step 130, time 2.6 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.012560, max 1.294192 (between atoms 170532 and 170531)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  170537 170532   65.5    0.7486   0.7723      0.7501
#  170532 170531   90.0    0.3520   0.7983      0.3480
# Wrote pdb files with previous and current coordinates
# Step=  130, Dmax= 7.1e-01 nm, Epot=          inf Fmax= 3.04519e+05, atom= 147863
# Step 131, time 2.62 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000464, max 0.044090 (between atoms 170532 and 170531)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  170532 170531   75.3    0.3520   0.3633      0.3480
# Step=  132, Dmax= 1.8e-01 nm, Epot= -9.97150e+05 Fmax= 8.62705e+03, atom= 31026
# Step=  133, Dmax= 2.1e-01 nm, Epot= -1.00273e+06 Fmax= 2.63988e+03, atom= 225537
# Step=  134, Dmax= 2.5e-01 nm, Epot= -1.00488e+06 Fmax= 2.75016e+05, atom= 147857
# Step=  135, Dmax= 3.1e-01 nm, Epot= -1.01077e+06 Fmax= 5.77564e+03, atom= 147857
# Step=  136, Dmax= 3.7e-01 nm, Epot= -1.01620e+06 Fmax= 1.07370e+03, atom= 139289
# Step=  137, Dmax= 4.4e-01 nm, Epot= -1.03078e+06 Fmax= 5.10922e+05, atom= 147856
# Step=  139, Dmax= 2.6e-01 nm, Epot= -1.03961e+06 Fmax= 7.89905e+03, atom= 147857
# Step=  140, Dmax= 3.2e-01 nm, Epot= -1.04459e+06 Fmax= 3.05402e+04, atom= 186629
# Step=  141, Dmax= 3.8e-01 nm, Epot= -1.04628e+06 Fmax= 2.36855e+04, atom= 159659
# Step=  143, Dmax= 2.3e-01 nm, Epot= -1.04628e+06 Fmax= 6.76900e+04, atom= 159654
# Step=  144, Dmax= 2.7e-01 nm, Epot= -1.04795e+06 Fmax= 1.81974e+03, atom= 22728
# Step=  145, Dmax= 3.3e-01 nm, Epot= -1.05803e+06 Fmax= 1.41863e+04, atom= 159660
# Step=  147, Dmax= 2.0e-01 nm, Epot= -1.06007e+06 Fmax= 1.59840e+03, atom= 102794
# Step=  148, Dmax= 2.4e-01 nm, Epot= -1.06800e+06 Fmax= 4.38871e+03, atom= 102794
# Step=  149, Dmax= 2.8e-01 nm, Epot= -1.07027e+06 Fmax= 1.22319e+05, atom= 147856
# Step=  150, Dmax= 3.4e-01 nm, Epot= -1.07304e+06 Fmax= 1.56238e+03, atom= 139291
# Step=  151, Dmax= 4.1e-01 nm, Epot= -1.08506e+06 Fmax= 1.67848e+04, atom= 139296
# Step=  152, Dmax= 4.9e-01 nm, Epot= -1.08891e+06 Fmax= 9.75050e+03, atom= 64726
# Step=  154, Dmax= 2.9e-01 nm, Epot= -1.08912e+06 Fmax= 4.12885e+04, atom= 64726
# Step=  156, Dmax= 1.8e-01 nm, Epot= -1.09124e+06 Fmax= 4.42210e+03, atom= 64723
# Step=  157, Dmax= 2.1e-01 nm, Epot= -1.09392e+06 Fmax= 7.19677e+03, atom= 64723
# Step=  158, Dmax= 2.5e-01 nm, Epot= -1.09597e+06 Fmax= 3.59179e+03, atom= 64723
# Step=  159, Dmax= 3.1e-01 nm, Epot= -1.09962e+06 Fmax= 3.92455e+04, atom= 64727
# Step=  161, Dmax= 1.8e-01 nm, Epot= -1.10022e+06 Fmax= 2.20247e+04, atom= 139294
# Step=  162, Dmax= 2.2e-01 nm, Epot= -1.10131e+06 Fmax= 8.38670e+02, atom= 64727
# Step=  163, Dmax= 2.6e-01 nm, Epot= -1.11689e+06 Fmax= 2.00511e+04, atom= 64728
# Step=  164, Dmax= 3.2e-01 nm, Epot= -1.11819e+06 Fmax= 1.59333e+03, atom= 176091
# Step=  165, Dmax= 3.8e-01 nm, Epot= -1.12886e+06 Fmax= 4.04174e+03, atom= 176091
#
# Step 166, time 3.32 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000027, max 0.002706 (between atoms 176085 and 176084)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  176090 176085   30.3    0.7489   0.7503      0.7501
#  176090 176084   30.6    0.7856   0.7849      0.7850
#  176085 176084   30.2    0.3505   0.3470      0.3480
# Step=  168, Dmax= 1.1e-01 nm, Epot= -1.13110e+06 Fmax= 3.12109e+03, atom= 141885
# Step=  169, Dmax= 1.4e-01 nm, Epot= -1.13333e+06 Fmax= 1.95017e+03, atom= 176091
# Step=  170, Dmax= 1.6e-01 nm, Epot= -1.13728e+06 Fmax= 4.79092e+03, atom= 176091
# Step=  171, Dmax= 2.0e-01 nm, Epot= -1.13931e+06 Fmax= 2.39345e+03, atom= 176091
# Step=  172, Dmax= 2.4e-01 nm, Epot= -1.14353e+06 Fmax= 5.59971e+03, atom= 176091
# Step=  173, Dmax= 2.8e-01 nm, Epot= -1.14601e+06 Fmax= 3.33298e+03, atom= 176091
# Step=  174, Dmax= 3.4e-01 nm, Epot= -1.14800e+06 Fmax= 7.01285e+04, atom= 176090
#
# Step 175, time 3.5 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000055, max 0.004068 (between atoms 176090 and 176084)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  176090 176085   32.8    0.7522   0.7478      0.7501
#  176090 176084   31.4    0.7839   0.7882      0.7850
# Step=  175, Dmax= 4.1e-01 nm, Epot= -1.15098e+06 Fmax= 1.85661e+03, atom= 176090
#
# Step 176, time 3.52 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.001721, max 0.122935 (between atoms 176090 and 176085)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  176090 176085   50.6    0.7478   0.8423      0.7501
#  176085 176084   85.3    0.3472   0.3076      0.3480
# Step=  176, Dmax= 4.9e-01 nm, Epot= -1.15466e+06 Fmax= 3.63224e+05, atom= 176085
#
# Step 177, time 3.54 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.008982, max 0.915383 (between atoms 176085 and 176084)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  176090 176084   39.7    0.7430   0.8200      0.7850
#  176090 176085   90.0    0.8423   0.8485      0.7501
#  176085 176084   90.1    0.3076   0.6665      0.3480
# Wrote pdb files with previous and current coordinates
# Step=  177, Dmax= 5.9e-01 nm, Epot=          inf Fmax= 1.85661e+03, atom= 176090
# Step 178, time 3.56 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000397, max 0.040127 (between atoms 176085 and 176084)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  176090 176085   33.2    0.8423   0.7550      0.7501
#  176085 176084   44.6    0.3076   0.3619      0.3480
# Step=  178, Dmax= 2.9e-01 nm, Epot= -1.15607e+06 Fmax= 3.13589e+05, atom= 50886
# Step=  179, Dmax= 3.5e-01 nm, Epot= -1.16239e+06 Fmax= 3.40413e+03, atom= 88242
# Step=  181, Dmax= 2.1e-01 nm, Epot= -1.16550e+06 Fmax= 3.24039e+03, atom= 88242
# Step=  182, Dmax= 2.5e-01 nm, Epot= -1.16871e+06 Fmax= 4.62476e+03, atom= 64723
# Step=  183, Dmax= 3.0e-01 nm, Epot= -1.17122e+06 Fmax= 1.74512e+04, atom= 88247
#
# Step 184, time 3.68 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000042, max 0.004269 (between atoms 186629 and 186623)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  186624 186623   44.9    0.3480   0.3480      0.3480
# Step=  184, Dmax= 3.7e-01 nm, Epot= -1.17261e+06 Fmax= 2.02019e+03, atom= 88247
# Step=  186, Dmax= 2.2e-01 nm, Epot= -1.17695e+06 Fmax= 1.06734e+04, atom= 88244
# Step=  187, Dmax= 2.6e-01 nm, Epot= -1.17815e+06 Fmax= 5.32074e+03, atom= 158669
# Step=  188, Dmax= 3.2e-01 nm, Epot= -1.17878e+06 Fmax= 7.78644e+04, atom= 158667
#
# Step 189, time 3.78 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000394, max 0.039786 (between atoms 173156 and 173151)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  173156 173151   31.1    0.7501   0.7800      0.7501
#  173151 173150   72.3    0.3480   0.3482      0.3480
# Step=  189, Dmax= 3.8e-01 nm, Epot= -1.17945e+06 Fmax= 2.65507e+04, atom= 158667
# Step=  191, Dmax= 2.3e-01 nm, Epot= -1.18061e+06 Fmax= 1.29004e+04, atom= 158667
# Step=  192, Dmax= 2.7e-01 nm, Epot= -1.18170e+06 Fmax= 2.79935e+03, atom= 102797
# Step=  194, Dmax= 1.6e-01 nm, Epot= -1.18414e+06 Fmax= 1.04784e+04, atom= 102797
# Step=  195, Dmax= 2.0e-01 nm, Epot= -1.18512e+06 Fmax= 7.56842e+02, atom= 102795
# Step=  196, Dmax= 2.4e-01 nm, Epot= -1.19712e+06 Fmax= 1.61175e+03, atom= 64719
# Step=  197, Dmax= 2.8e-01 nm, Epot= -1.20381e+06 Fmax= 1.18792e+03, atom= 102795
# Step=  198, Dmax= 3.4e-01 nm, Epot= -1.20946e+06 Fmax= 1.39235e+04, atom= 176091
#
# Step 199, time 3.98 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000060, max 0.005602 (between atoms 173151 and 173150)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  173151 173150   31.0    0.3480   0.3499      0.3480
# Step=  199, Dmax= 4.1e-01 nm, Epot= -1.21459e+06 Fmax= 1.65238e+04, atom= 64725
# Step=  201, Dmax= 2.4e-01 nm, Epot= -1.21592e+06 Fmax= 1.12028e+03, atom= 158666
# Step=  202, Dmax= 2.9e-01 nm, Epot= -1.22273e+06 Fmax= 1.57406e+04, atom= 41464
# Step=  203, Dmax= 3.5e-01 nm, Epot= -1.22501e+06 Fmax= 1.24236e+04, atom= 147861
# Step=  205, Dmax= 2.1e-01 nm, Epot= -1.22534e+06 Fmax= 4.85640e+04, atom= 26884
#
# Step 206, time 4.12 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000103, max 0.009141 (between atoms 199976 and 199971)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  199971 199970   43.6    0.3480   0.3465      0.3480
# Step=  207, Dmax= 1.3e-01 nm, Epot= -1.22642e+06 Fmax= 3.79078e+03, atom= 26884
# Step=  208, Dmax= 1.5e-01 nm, Epot= -1.22852e+06 Fmax= 8.62700e+02, atom= 64721
# Step=  209, Dmax= 1.8e-01 nm, Epot= -1.23578e+06 Fmax= 2.50098e+03, atom= 64717
# Step=  210, Dmax= 2.2e-01 nm, Epot= -1.23899e+06 Fmax= 4.47025e+03, atom= 147861
# Step=  212, Dmax= 1.3e-01 nm, Epot= -1.24008e+06 Fmax= 5.48239e+03, atom= 26884
# Step=  213, Dmax= 1.6e-01 nm, Epot= -1.24104e+06 Fmax= 2.48198e+03, atom= 199970
#
# Step 214, time 4.28 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000027, max 0.002599 (between atoms 199976 and 199971)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  199971 199970   39.6    0.3477   0.3482      0.3480
# Step=  214, Dmax= 1.9e-01 nm, Epot= -1.24349e+06 Fmax= 3.99020e+03, atom= 18006
# Step=  216, Dmax= 1.1e-01 nm, Epot= -1.24460e+06 Fmax= 2.54579e+03, atom= 159657
# Step=  217, Dmax= 1.4e-01 nm, Epot= -1.24640e+06 Fmax= 1.15184e+03, atom= 210092
# Step=  218, Dmax= 1.6e-01 nm, Epot= -1.25088e+06 Fmax= 2.32203e+03, atom= 210093
# Step=  219, Dmax= 2.0e-01 nm, Epot= -1.25367e+06 Fmax= 3.55326e+03, atom= 210093
# Step=  220, Dmax= 2.4e-01 nm, Epot= -1.25580e+06 Fmax= 2.37589e+03, atom= 210093
# Step=  221, Dmax= 2.8e-01 nm, Epot= -1.25929e+06 Fmax= 5.99427e+03, atom= 210093
# Step=  222, Dmax= 3.4e-01 nm, Epot= -1.26125e+06 Fmax= 5.70443e+03, atom= 5323
# Step=  223, Dmax= 4.1e-01 nm, Epot= -1.26350e+06 Fmax= 2.50874e+03, atom= 5323
# Step=  224, Dmax= 4.9e-01 nm, Epot= -1.26689e+06 Fmax= 6.44144e+04, atom= 22722
# Step=  226, Dmax= 2.9e-01 nm, Epot= -1.26872e+06 Fmax= 6.51471e+03, atom= 18006
# Step=  227, Dmax= 3.5e-01 nm, Epot= -1.27102e+06 Fmax= 1.35417e+03, atom= 18005
# Step=  228, Dmax= 4.2e-01 nm, Epot= -1.27811e+06 Fmax= 2.68838e+04, atom= 18006
#
# Step 229, time 4.58 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000328, max 0.033709 (between atoms 199971 and 199970)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  199971 199970   48.7    0.3480   0.3597      0.3480
# Step=  230, Dmax= 2.5e-01 nm, Epot= -1.27953e+06 Fmax= 1.97081e+04, atom= 199971
#
# Step 231, time 4.62 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000251, max 0.025866 (between atoms 199971 and 199970)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  199971 199970   39.8    0.3488   0.3570      0.3480
# Step=  232, Dmax= 1.5e-01 nm, Epot= -1.28054e+06 Fmax= 1.50085e+03, atom= 159659
# Step=  233, Dmax= 1.8e-01 nm, Epot= -1.28453e+06 Fmax= 2.27957e+03, atom= 39910
# Step=  234, Dmax= 2.2e-01 nm, Epot= -1.28733e+06 Fmax= 2.80694e+03, atom= 39906
# Step=  236, Dmax= 1.3e-01 nm, Epot= -1.28905e+06 Fmax= 3.67058e+02, atom= 39910
# Step=  237, Dmax= 1.6e-01 nm, Epot= -1.30049e+06 Fmax= 2.95725e+03, atom= 219983
# Step=  238, Dmax= 1.9e-01 nm, Epot= -1.30251e+06 Fmax= 3.63965e+03, atom= 219983
# Step=  239, Dmax= 2.3e-01 nm, Epot= -1.30420e+06 Fmax= 4.58335e+03, atom= 219983
# Step=  240, Dmax= 2.7e-01 nm, Epot= -1.30576e+06 Fmax= 3.69787e+03, atom= 219984
# Step=  241, Dmax= 3.3e-01 nm, Epot= -1.30712e+06 Fmax= 1.44760e+04, atom= 219983
#
# Step 242, time 4.84 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000109, max 0.006257 (between atoms 219983 and 219977)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  169956 169955   32.7    0.3480   0.3473      0.3480
#  219983 219978   32.4    0.7500   0.7546      0.7501
# Step=  242, Dmax= 3.9e-01 nm, Epot= -1.30882e+06 Fmax= 9.50306e+03, atom= 45728
#
# Step 243, time 4.86 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000130, max 0.012053 (between atoms 169961 and 169956)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  169961 169956   31.0    0.7528   0.7592      0.7501
#  169956 169955   40.8    0.3473   0.3462      0.3480
# Step=  244, Dmax= 2.4e-01 nm, Epot= -1.30948e+06 Fmax= 1.26146e+04, atom= 73063
# Step=  245, Dmax= 2.8e-01 nm, Epot= -1.31038e+06 Fmax= 1.10647e+03, atom= 73063
# Step=  247, Dmax= 1.7e-01 nm, Epot= -1.31445e+06 Fmax= 4.05006e+03, atom= 73067
# Step=  249, Dmax= 1.0e-01 nm, Epot= -1.31525e+06 Fmax= 2.38697e+03, atom= 45724
# Step=  250, Dmax= 1.2e-01 nm, Epot= -1.31664e+06 Fmax= 4.22987e+02, atom= 126312
# Step=  251, Dmax= 1.5e-01 nm, Epot= -1.32539e+06 Fmax= 2.08048e+03, atom= 45725
# Step=  252, Dmax= 1.8e-01 nm, Epot= -1.32761e+06 Fmax= 1.35864e+03, atom= 169962
# Step=  253, Dmax= 2.1e-01 nm, Epot= -1.33059e+06 Fmax= 8.02439e+03, atom= 169962
# Step=  254, Dmax= 2.5e-01 nm, Epot= -1.33229e+06 Fmax= 1.48132e+03, atom= 169962
# Step=  255, Dmax= 3.0e-01 nm, Epot= -1.33623e+06 Fmax= 9.35639e+03, atom= 169962
# Step=  256, Dmax= 3.6e-01 nm, Epot= -1.33823e+06 Fmax= 1.73206e+03, atom= 169962
# Step=  257, Dmax= 4.4e-01 nm, Epot= -1.34255e+06 Fmax= 1.15644e+04, atom= 169962
# Step=  258, Dmax= 5.2e-01 nm, Epot= -1.34507e+06 Fmax= 2.16908e+03, atom= 169962
#
# Step 259, time 5.18 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000166, max 0.016615 (between atoms 200376 and 200375)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200376 200375   42.4    0.3479   0.3538      0.3480
# Step=  261, Dmax= 1.6e-01 nm, Epot= -1.34696e+06 Fmax= 6.15930e+03, atom= 169962
# Step=  262, Dmax= 1.9e-01 nm, Epot= -1.34760e+06 Fmax= 6.50639e+03, atom= 73057
# Step=  263, Dmax= 2.3e-01 nm, Epot= -1.34863e+06 Fmax= 7.71997e+02, atom= 73057
# Step=  265, Dmax= 1.4e-01 nm, Epot= -1.35257e+06 Fmax= 8.03512e+03, atom= 73058
# Step=  266, Dmax= 1.6e-01 nm, Epot= -1.35329e+06 Fmax= 7.53221e+02, atom= 169962
# Step=  267, Dmax= 2.0e-01 nm, Epot= -1.35894e+06 Fmax= 3.05522e+03, atom= 169962
# Step=  268, Dmax= 2.3e-01 nm, Epot= -1.36089e+06 Fmax= 2.26530e+03, atom= 169962
# Step=  269, Dmax= 2.8e-01 nm, Epot= -1.36334e+06 Fmax= 3.35077e+03, atom= 169962
# Step=  270, Dmax= 3.4e-01 nm, Epot= -1.36504e+06 Fmax= 8.47478e+03, atom= 169962
# Step=  271, Dmax= 4.1e-01 nm, Epot= -1.36637e+06 Fmax= 1.09785e+04, atom= 169962
# Step=  272, Dmax= 4.9e-01 nm, Epot= -1.36718e+06 Fmax= 3.93492e+03, atom= 73058
# Step=  275, Dmax= 1.5e-01 nm, Epot= -1.36858e+06 Fmax= 1.40840e+03, atom= 457266
# Step=  276, Dmax= 1.8e-01 nm, Epot= -1.37152e+06 Fmax= 1.37298e+03, atom= 73057
# Step=  277, Dmax= 2.1e-01 nm, Epot= -1.37461e+06 Fmax= 9.05975e+03, atom= 124616
# Step=  278, Dmax= 2.5e-01 nm, Epot= -1.37499e+06 Fmax= 1.55842e+04, atom= 124616
# Step=  279, Dmax= 3.0e-01 nm, Epot= -1.37578e+06 Fmax= 8.51814e+02, atom= 158109
# Step=  280, Dmax= 3.6e-01 nm, Epot= -1.38414e+06 Fmax= 2.36108e+03, atom= 158110
# Step=  281, Dmax= 4.4e-01 nm, Epot= -1.38759e+06 Fmax= 1.32794e+04, atom= 158109
# Step=  283, Dmax= 2.6e-01 nm, Epot= -1.38840e+06 Fmax= 1.18014e+04, atom= 158105
# Step=  284, Dmax= 3.1e-01 nm, Epot= -1.38930e+06 Fmax= 1.87080e+03, atom= 79139
# Step=  285, Dmax= 3.8e-01 nm, Epot= -1.38947e+06 Fmax= 8.17954e+04, atom= 79134
# Step=  288, Dmax= 1.1e-01 nm, Epot= -1.39190e+06 Fmax= 5.19483e+04, atom= 200376
#
# Step 289, time 5.78 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000038, max 0.003337 (between atoms 200376 and 200375)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200376 200375   31.5    0.3480   0.3491      0.3480
# Step=  289, Dmax= 1.4e-01 nm, Epot= -1.39307e+06 Fmax= 3.48296e+03, atom= 200376
# Step=  290, Dmax= 1.6e-01 nm, Epot= -1.39454e+06 Fmax= 1.48661e+03, atom= 13265
# Step=  291, Dmax= 2.0e-01 nm, Epot= -1.39682e+06 Fmax= 3.99395e+03, atom= 13265
# Step=  292, Dmax= 2.3e-01 nm, Epot= -1.39753e+06 Fmax= 3.36988e+04, atom= 13263
# Step=  293, Dmax= 2.8e-01 nm, Epot= -1.39776e+06 Fmax= 3.08959e+04, atom= 21237
# Step=  294, Dmax= 3.4e-01 nm, Epot= -1.39842e+06 Fmax= 2.83612e+03, atom= 21237
# Step=  295, Dmax= 4.0e-01 nm, Epot= -1.40066e+06 Fmax= 1.27362e+04, atom= 115233
# Step=  297, Dmax= 2.4e-01 nm, Epot= -1.40109e+06 Fmax= 2.51153e+04, atom= 115236
# Step=  298, Dmax= 2.9e-01 nm, Epot= -1.40147e+06 Fmax= 1.74517e+04, atom= 115232
# Step=  301, Dmax= 8.7e-02 nm, Epot= -1.40190e+06 Fmax= 7.70503e+03, atom= 515
# Step=  302, Dmax= 1.0e-01 nm, Epot= -1.40240e+06 Fmax= 8.11519e+02, atom= 21237
# Step=  303, Dmax= 1.3e-01 nm, Epot= -1.40542e+06 Fmax= 2.53152e+03, atom= 515
# Step=  304, Dmax= 1.5e-01 nm, Epot= -1.40672e+06 Fmax= 8.29442e+02, atom= 515
# Step=  305, Dmax= 1.8e-01 nm, Epot= -1.40960e+06 Fmax= 2.24943e+04, atom= 158107
#
# Step 306, time 6.12 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000067, max 0.005262 (between atoms 200381 and 200376)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200376 200375   49.6    0.3482   0.3495      0.3480
# Step=  306, Dmax= 2.2e-01 nm, Epot= -1.41024e+06 Fmax= 1.04725e+04, atom= 13265
# Step=  308, Dmax= 1.3e-01 nm, Epot= -1.41097e+06 Fmax= 2.78816e+03, atom= 13265
# Step=  309, Dmax= 1.6e-01 nm, Epot= -1.41207e+06 Fmax= 7.21444e+03, atom= 158107
# Step=  310, Dmax= 1.9e-01 nm, Epot= -1.41283e+06 Fmax= 1.40967e+03, atom= 158107
# Step=  311, Dmax= 2.3e-01 nm, Epot= -1.41543e+06 Fmax= 8.65519e+03, atom= 13265
#
# Step 312, time 6.24 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000084, max 0.006456 (between atoms 200381 and 200376)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200376 200375   35.6    0.3485   0.3463      0.3480
# Step=  312, Dmax= 2.7e-01 nm, Epot= -1.41632e+06 Fmax= 2.13701e+03, atom= 13265
# Step=  314, Dmax= 1.6e-01 nm, Epot= -1.41767e+06 Fmax= 7.26439e+03, atom= 13265
# Step=  315, Dmax= 1.9e-01 nm, Epot= -1.41833e+06 Fmax= 8.21132e+02, atom= 13265
# Step=  316, Dmax= 2.3e-01 nm, Epot= -1.42059e+06 Fmax= 1.24528e+05, atom= 13264
# Step=  317, Dmax= 2.8e-01 nm, Epot= -1.42257e+06 Fmax= 2.22019e+04, atom= 506
# Step=  319, Dmax= 1.7e-01 nm, Epot= -1.42264e+06 Fmax= 4.03889e+04, atom= 506
# Step=  320, Dmax= 2.0e-01 nm, Epot= -1.42361e+06 Fmax= 1.11624e+03, atom= 509
# Step=  321, Dmax= 2.4e-01 nm, Epot= -1.42644e+06 Fmax= 8.16008e+03, atom= 13268
#
# Step 322, time 6.44 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000158, max 0.015271 (between atoms 200376 and 200375)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200381 200375   34.2    0.7846   0.7889      0.7850
#  200381 200376   31.9    0.7502   0.7482      0.7501
#  200376 200375   35.1    0.3486   0.3427      0.3480
# Step=  323, Dmax= 1.5e-01 nm, Epot= -1.42775e+06 Fmax= 1.80632e+03, atom= 200382
# Step=  324, Dmax= 1.7e-01 nm, Epot= -1.42954e+06 Fmax= 5.72755e+03, atom= 82905
#
# Step 325, time 6.5 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000062, max 0.006005 (between atoms 219983 and 219978)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  219978 219977   42.2    0.3480   0.3475      0.3480
# Step=  325, Dmax= 2.1e-01 nm, Epot= -1.43036e+06 Fmax= 1.87060e+03, atom= 219978
#
# Step 326, time 6.52 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000089, max 0.008196 (between atoms 219983 and 219978)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  219983 219978   38.9    0.7546   0.7563      0.7501
#  219978 219977   34.3    0.3475   0.3468      0.3480
# Step=  326, Dmax= 2.5e-01 nm, Epot= -1.43148e+06 Fmax= 2.32043e+04, atom= 219978
#
# Step 327, time 6.54 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000414, max 0.042610 (between atoms 219978 and 219977)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  219983 219978   32.1    0.7563   0.7490      0.7501
#  219978 219977   38.3    0.3468   0.3628      0.3480
# Step=  327, Dmax= 3.0e-01 nm, Epot= -1.43273e+06 Fmax= 1.71449e+03, atom= 219984
# Step=  328, Dmax= 3.6e-01 nm, Epot= -1.43468e+06 Fmax= 1.13347e+04, atom= 124615
#
# Step 329, time 6.58 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.001753, max 0.178847 (between atoms 200376 and 200375)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  200381 200375   48.8    0.7849   0.7669      0.7850
#  200381 200376   36.3    0.7503   0.7449      0.7501
#  200376 200375   58.5    0.3479   0.4102      0.3480
# Step=  331, Dmax= 1.1e-01 nm, Epot= -1.43608e+06 Fmax= 3.45869e+03, atom= 219984
# Step=  332, Dmax= 1.3e-01 nm, Epot= -1.43727e+06 Fmax= 5.31495e+03, atom= 219983
# Step=  333, Dmax= 1.6e-01 nm, Epot= -1.43783e+06 Fmax= 2.12675e+03, atom= 219984
# Step=  334, Dmax= 1.9e-01 nm, Epot= -1.43908e+06 Fmax= 6.74914e+03, atom= 219983
# Step=  335, Dmax= 2.3e-01 nm, Epot= -1.44009e+06 Fmax= 1.60719e+03, atom= 219984
# Step=  336, Dmax= 2.7e-01 nm, Epot= -1.44163e+06 Fmax= 9.04828e+03, atom= 219984
# Step=  337, Dmax= 3.2e-01 nm, Epot= -1.44350e+06 Fmax= 2.25780e+03, atom= 219984
# Step=  339, Dmax= 1.9e-01 nm, Epot= -1.44471e+06 Fmax= 3.58844e+03, atom= 219984
# Step=  340, Dmax= 2.3e-01 nm, Epot= -1.44584e+06 Fmax= 3.57085e+03, atom= 219984
# Step=  341, Dmax= 2.8e-01 nm, Epot= -1.44675e+06 Fmax= 5.08350e+03, atom= 219983
# Step=  342, Dmax= 3.4e-01 nm, Epot= -1.44777e+06 Fmax= 5.32222e+03, atom= 219984
#
# Step 343, time 6.86 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000060, max 0.004148 (between atoms 219978 and 219977)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  219983 219978   31.7    0.7512   0.7482      0.7501
# Step=  343, Dmax= 4.0e-01 nm, Epot= -1.44828e+06 Fmax= 7.63717e+03, atom= 219983
#
# Step 344, time 6.88 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000103, max 0.010137 (between atoms 219978 and 219977)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  219983 219977   35.2    0.7880   0.7836      0.7850
#  219983 219978   41.4    0.7482   0.7520      0.7501
# Step=  344, Dmax= 4.8e-01 nm, Epot= -1.44956e+06 Fmax= 9.97076e+03, atom= 219984
# Step=  345, Dmax= 5.8e-01 nm, Epot= -1.45054e+06 Fmax= 2.64892e+04, atom= 219984
# Step=  347, Dmax= 3.5e-01 nm, Epot= -1.45200e+06 Fmax= 1.16279e+03, atom= 495455
# Step=  349, Dmax= 2.1e-01 nm, Epot= -1.45457e+06 Fmax= 3.60344e+03, atom= 219984
# Step=  350, Dmax= 2.5e-01 nm, Epot= -1.45617e+06 Fmax= 1.56476e+03, atom= 219984
# Step=  351, Dmax= 3.0e-01 nm, Epot= -1.45867e+06 Fmax= 4.49858e+03, atom= 219984
# Step=  352, Dmax= 3.6e-01 nm, Epot= -1.46034e+06 Fmax= 2.92920e+03, atom= 219984
# Step=  353, Dmax= 4.3e-01 nm, Epot= -1.46239e+06 Fmax= 4.12498e+03, atom= 219984
#
# Step 354, time 7.08 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000113, max 0.010641 (between atoms 219983 and 219978)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  219983 219977   47.2    0.7849   0.7823      0.7850
#  219983 219978   42.1    0.7513   0.7581      0.7501
# Step=  355, Dmax= 2.6e-01 nm, Epot= -1.46350e+06 Fmax= 3.88031e+03, atom= 219983
# Step=  356, Dmax= 3.1e-01 nm, Epot= -1.46421e+06 Fmax= 5.79325e+03, atom= 219984
# Step=  357, Dmax= 3.7e-01 nm, Epot= -1.46522e+06 Fmax= 6.04954e+03, atom= 219983
#
# Step 358, time 7.16 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000078, max 0.005682 (between atoms 219978 and 219977)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  219983 219977   32.6    0.7867   0.7820      0.7850
#  219983 219978   36.5    0.7487   0.7532      0.7501
# Step=  358, Dmax= 4.5e-01 nm, Epot= -1.46635e+06 Fmax= 5.44283e+03, atom= 219984
#
# Step 359, time 7.18 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000215, max 0.017847 (between atoms 219978 and 219977)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  219983 219977   33.7    0.7820   0.7768      0.7850
#  219983 219978   38.0    0.7532   0.7560      0.7501
# Step=  360, Dmax= 2.7e-01 nm, Epot= -1.46794e+06 Fmax= 2.24739e+03, atom= 219983
# Step=  361, Dmax= 3.2e-01 nm, Epot= -1.46963e+06 Fmax= 5.03106e+03, atom= 219984
# Step=  363, Dmax= 1.9e-01 nm, Epot= -1.47099e+06 Fmax= 6.89580e+02, atom= 219983
# Step=  364, Dmax= 2.3e-01 nm, Epot= -1.47525e+06 Fmax= 5.07765e+03, atom= 219984
# Step=  365, Dmax= 2.8e-01 nm, Epot= -1.47686e+06 Fmax= 1.46869e+03, atom= 219984
# Step=  366, Dmax= 3.4e-01 nm, Epot= -1.47978e+06 Fmax= 3.76984e+03, atom= 219984
# Step=  368, Dmax= 2.0e-01 nm, Epot= -1.48084e+06 Fmax= 4.46299e+03, atom= 219983
# Step=  369, Dmax= 2.4e-01 nm, Epot= -1.48167e+06 Fmax= 2.31544e+03, atom= 219984
# Step=  370, Dmax= 2.9e-01 nm, Epot= -1.48195e+06 Fmax= 8.13826e+03, atom= 219983
# Step=  371, Dmax= 3.5e-01 nm, Epot= -1.48411e+06 Fmax= 2.43805e+03, atom= 219984
# Step=  373, Dmax= 2.1e-01 nm, Epot= -1.48512e+06 Fmax= 4.64947e+03, atom= 219983
# Step=  374, Dmax= 2.5e-01 nm, Epot= -1.48616e+06 Fmax= 2.43037e+03, atom= 219984
# Step=  375, Dmax= 3.0e-01 nm, Epot= -1.48692e+06 Fmax= 4.88607e+03, atom= 219984
# Step=  376, Dmax= 3.6e-01 nm, Epot= -1.48795e+06 Fmax= 3.47601e+03, atom= 219984
#
# Step 377, time 7.54 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000227, max 0.021673 (between atoms 209502 and 209501)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  209507 209502   35.1    0.7499   0.7518      0.7501
# Step=  378, Dmax= 2.2e-01 nm, Epot= -1.48901e+06 Fmax= 3.45052e+03, atom= 209508
# Step=  379, Dmax= 2.6e-01 nm, Epot= -1.48922e+06 Fmax= 1.26908e+04, atom= 226017
#
# Step 380, time 7.6 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.001263, max 0.124105 (between atoms 226017 and 226016)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  226017 226016   90.0    0.3480   0.3912      0.3480
# Step=  380, Dmax= 3.1e-01 nm, Epot= -1.06725e+06 Fmax= 2.55209e+07, atom= 143482
# Step 381, time 7.62 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000038, max 0.003618 (between atoms 226017 and 226016)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  226017 226016   32.8    0.3480   0.3492      0.3480
# Step=  381, Dmax= 1.6e-01 nm, Epot= -1.49028e+06 Fmax= 1.52000e+04, atom= 226017
# Step=  382, Dmax= 1.9e-01 nm, Epot= -1.49123e+06 Fmax= 1.96683e+03, atom= 143482
# Step=  383, Dmax= 2.2e-01 nm, Epot= -1.49168e+06 Fmax= 1.36401e+04, atom= 143482
# Step=  385, Dmax= 1.3e-01 nm, Epot= -1.49265e+06 Fmax= 2.31045e+03, atom= 143478
# Step=  386, Dmax= 1.6e-01 nm, Epot= -1.49357e+06 Fmax= 3.40380e+03, atom= 111105
# Step=  387, Dmax= 1.9e-01 nm, Epot= -1.49464e+06 Fmax= 2.59139e+03, atom= 211614
# Step=  388, Dmax= 2.3e-01 nm, Epot= -1.49527e+06 Fmax= 6.30166e+03, atom= 211614
# Step=  389, Dmax= 2.8e-01 nm, Epot= -1.49653e+06 Fmax= 3.56518e+03, atom= 211614
# Step=  390, Dmax= 3.4e-01 nm, Epot= -1.49667e+06 Fmax= 1.22771e+04, atom= 211614
# Step=  391, Dmax= 4.0e-01 nm, Epot= -1.49790e+06 Fmax= 1.70194e+04, atom= 101776
# Step=  393, Dmax= 2.4e-01 nm, Epot= -1.49850e+06 Fmax= 7.51211e+03, atom= 722904
# Step=  396, Dmax= 7.2e-02 nm, Epot= -1.49877e+06 Fmax= 3.11893e+03, atom= 101776
# Step=  397, Dmax= 8.7e-02 nm, Epot= -1.49933e+06 Fmax= 5.46608e+02, atom= 101776
# Step=  398, Dmax= 1.0e-01 nm, Epot= -1.50196e+06 Fmax= 6.30443e+02, atom= 211613
# Step=  399, Dmax= 1.3e-01 nm, Epot= -1.50422e+06 Fmax= 2.86297e+03, atom= 211614
# Step=  400, Dmax= 1.5e-01 nm, Epot= -1.50535e+06 Fmax= 1.57248e+03, atom= 211614
# Step=  401, Dmax= 1.8e-01 nm, Epot= -1.50648e+06 Fmax= 3.75609e+03, atom= 211614
# Step=  402, Dmax= 2.2e-01 nm, Epot= -1.50756e+06 Fmax= 2.64044e+03, atom= 211614
# Step=  403, Dmax= 2.6e-01 nm, Epot= -1.50830e+06 Fmax= 4.76087e+03, atom= 211614
# Step=  404, Dmax= 3.1e-01 nm, Epot= -1.50949e+06 Fmax= 4.64539e+03, atom= 211614
# Step=  405, Dmax= 3.7e-01 nm, Epot= -1.50994e+06 Fmax= 5.03725e+03, atom= 211614
#
# Step 406, time 8.12 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000125, max 0.007078 (between atoms 211770 and 211769)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  211775 211770   31.0    0.7500   0.7536      0.7501
# Step=  407, Dmax= 2.2e-01 nm, Epot= -1.51086e+06 Fmax= 1.45327e+04, atom= 211614
# Step=  409, Dmax= 1.3e-01 nm, Epot= -1.51153e+06 Fmax= 1.10775e+03, atom= 101781
# Step=  410, Dmax= 1.6e-01 nm, Epot= -1.51318e+06 Fmax= 4.67160e+03, atom= 211614
# Step=  411, Dmax= 1.9e-01 nm, Epot= -1.51407e+06 Fmax= 1.23832e+03, atom= 211614
# Step=  412, Dmax= 2.3e-01 nm, Epot= -1.51573e+06 Fmax= 7.03300e+03, atom= 211614
# Step=  413, Dmax= 2.8e-01 nm, Epot= -1.51696e+06 Fmax= 1.63476e+03, atom= 211614
# Step=  415, Dmax= 1.7e-01 nm, Epot= -1.51804e+06 Fmax= 2.96808e+03, atom= 211614
# Step=  416, Dmax= 2.0e-01 nm, Epot= -1.51902e+06 Fmax= 2.82151e+03, atom= 211614
# Step=  417, Dmax= 2.4e-01 nm, Epot= -1.52002e+06 Fmax= 3.70588e+03, atom= 211614
# Step=  418, Dmax= 2.9e-01 nm, Epot= -1.52087e+06 Fmax= 3.89452e+03, atom= 211614
# ...
# Step=  778, Dmax= 1.2e-01 nm, Epot= -1.71939e+06 Fmax= 2.63071e+03, atom= 197547
# Step=  779, Dmax= 1.4e-01 nm, Epot= -1.72012e+06 Fmax= 1.65196e+03, atom= 197547
# Step=  781, Dmax= 8.5e-02 nm, Epot= -1.72063e+06 Fmax= 9.40843e+02, atom= 197547
# Step=  782, Dmax= 1.0e-01 nm, Epot= -1.72076e+06 Fmax= 2.20547e+03, atom= 180132
# Step=  783, Dmax= 1.2e-01 nm, Epot= -1.72131e+06 Fmax= 1.59577e+03, atom= 180132
# Step=  785, Dmax= 7.3e-02 nm, Epot= -1.72186e+06 Fmax= 6.47664e+02, atom= 180131
# Step=  786, Dmax= 8.8e-02 nm, Epot= -1.72216e+06 Fmax= 2.02922e+03, atom= 180131
# Step=  787, Dmax= 1.1e-01 nm, Epot= -1.72277e+06 Fmax= 1.24961e+03, atom= 180132
# Step=  789, Dmax= 6.3e-02 nm, Epot= -1.72318e+06 Fmax= 7.27332e+02, atom= 180132
# Step=  790, Dmax= 7.6e-02 nm, Epot= -1.72353e+06 Fmax= 1.62343e+03, atom= 180132
# Step=  791, Dmax= 9.1e-02 nm, Epot= -1.72396e+06 Fmax= 1.20272e+03, atom= 180132
# Step=  792, Dmax= 1.1e-01 nm, Epot= -1.72407e+06 Fmax= 2.29976e+03, atom= 180132
# Step=  793, Dmax= 1.3e-01 nm, Epot= -1.72457e+06 Fmax= 1.76648e+03, atom= 180132
# Step=  795, Dmax= 7.9e-02 nm, Epot= -1.72515e+06 Fmax= 6.23109e+02, atom= 180131
# Step=  796, Dmax= 9.4e-02 nm, Epot= -1.72542e+06 Fmax= 2.24090e+03, atom= 180131
# Step=  797, Dmax= 1.1e-01 nm, Epot= -1.72611e+06 Fmax= 1.26750e+03, atom= 180132
# Step=  799, Dmax= 6.8e-02 nm, Epot= -1.72652e+06 Fmax= 8.45005e+02, atom= 180132
# Step=  800, Dmax= 8.2e-02 nm, Epot= -1.72680e+06 Fmax= 1.66340e+03, atom= 180132
# Step=  801, Dmax= 9.8e-02 nm, Epot= -1.72720e+06 Fmax= 1.35376e+03, atom= 180132
# Step=  802, Dmax= 1.2e-01 nm, Epot= -1.72723e+06 Fmax= 2.38233e+03, atom= 180132
# Step=  803, Dmax= 1.4e-01 nm, Epot= -1.72768e+06 Fmax= 1.95628e+03, atom= 180132
# Step=  805, Dmax= 8.5e-02 nm, Epot= -1.72843e+06 Fmax= 5.81941e+02, atom= 180131
# Step=  807, Dmax= 5.1e-02 nm, Epot= -1.72881e+06 Fmax= 9.56141e+02, atom= 180132
# Step=  808, Dmax= 6.1e-02 nm, Epot= -1.72917e+06 Fmax= 8.91067e+02, atom= 180132
# Step=  809, Dmax= 7.3e-02 nm, Epot= -1.72941e+06 Fmax= 1.34753e+03, atom= 180132
# Step=  810, Dmax= 8.8e-02 nm, Epot= -1.72974e+06 Fmax= 1.47290e+03, atom= 191328
# Step=  811, Dmax= 1.1e-01 nm, Epot= -1.72992e+06 Fmax= 1.95059e+03, atom= 191328
# Step=  812, Dmax= 1.3e-01 nm, Epot= -1.73024e+06 Fmax= 2.15117e+03, atom= 191328
# Step=  813, Dmax= 1.5e-01 nm, Epot= -1.73033e+06 Fmax= 2.76188e+03, atom= 191328
# Step=  814, Dmax= 1.8e-01 nm, Epot= -1.73056e+06 Fmax= 3.11773e+03, atom= 191328
# Step=  816, Dmax= 1.1e-01 nm, Epot= -1.73173e+06 Fmax= 4.71587e+02, atom= 171177
# Step=  817, Dmax= 1.3e-01 nm, Epot= -1.73219e+06 Fmax= 1.25238e+04, atom= 171177
# Step=  818, Dmax= 1.6e-01 nm, Epot= -1.73311e+06 Fmax= 1.35278e+03, atom= 91713
# Step=  820, Dmax= 9.4e-02 nm, Epot= -1.73347e+06 Fmax= 1.13711e+03, atom= 205332
# Step=  822, Dmax= 5.7e-02 nm, Epot= -1.73389e+06 Fmax= 5.87323e+02, atom= 205332
# Step=  823, Dmax= 6.8e-02 nm, Epot= -1.73421e+06 Fmax= 1.47819e+03, atom= 205332
# Step=  824, Dmax= 8.1e-02 nm, Epot= -1.73467e+06 Fmax= 1.05999e+03, atom= 197547
# Step=  825, Dmax= 9.8e-02 nm, Epot= -1.73468e+06 Fmax= 2.01173e+03, atom= 191328
# Step=  826, Dmax= 1.2e-01 nm, Epot= -1.73514e+06 Fmax= 1.88922e+03, atom= 204768
# Step=  828, Dmax= 7.0e-02 nm, Epot= -1.73582e+06 Fmax= 3.60473e+02, atom= 117981
# Step=  829, Dmax= 8.4e-02 nm, Epot= -1.73623e+06 Fmax= 4.25669e+03, atom= 204773
# Step=  830, Dmax= 1.0e-01 nm, Epot= -1.73707e+06 Fmax= 4.36608e+03, atom= 204768
# Step=  831, Dmax= 1.2e-01 nm, Epot= -1.73728e+06 Fmax= 1.09585e+03, atom= 204768
# Step=  833, Dmax= 7.3e-02 nm, Epot= -1.73766e+06 Fmax= 6.75076e+02, atom= 193218
# Step=  834, Dmax= 8.7e-02 nm, Epot= -1.73824e+06 Fmax= 1.54047e+03, atom= 193218
# Step=  835, Dmax= 1.0e-01 nm, Epot= -1.73864e+06 Fmax= 1.16633e+03, atom= 193218
# Step=  836, Dmax= 1.3e-01 nm, Epot= -1.73892e+06 Fmax= 2.80400e+03, atom= 204773
# Step=  837, Dmax= 1.5e-01 nm, Epot= -1.73928e+06 Fmax= 5.73040e+03, atom= 204768
#
# Step 838, time 16.76 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000115, max 0.011748 (between atoms 204768 and 204767)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  204768 204767   33.3    0.3477   0.3521      0.3480
# Step=  838, Dmax= 1.8e-01 nm, Epot= -1.73958e+06 Fmax= 2.69598e+03, atom= 204768
#
# Step 839, time 16.78 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000126, max 0.010777 (between atoms 204773 and 204768)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  204768 204767   43.2    0.3521   0.3458      0.3480
# Step=  839, Dmax= 2.2e-01 nm, Epot= -1.73993e+06 Fmax= 5.70108e+03, atom= 204768
#
# Step 840, time 16.8 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000345, max 0.035392 (between atoms 204768 and 204767)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  204768 204767   46.5    0.3458   0.3603      0.3480
# Step=  840, Dmax= 2.6e-01 nm, Epot= -1.73994e+06 Fmax= 5.86224e+03, atom= 117981
#
# Step 841, time 16.82 (ps)  LINCS WARNING
# relative constraint deviation after LINCS:
# rms 0.000488, max 0.045490 (between atoms 204768 and 204767)
# bonds that rotated more than 30 degrees:
#  atom 1 atom 2  angle  previous, current, constraint length
#  204773 204768   33.6    0.7488   0.7658      0.7501
#  204768 204767   38.4    0.3603   0.3321      0.3480
# Step=  842, Dmax= 1.6e-01 nm, Epot= -1.74032e+06 Fmax= 1.18279e+03, atom= 117981
# Step=  843, Dmax= 1.9e-01 nm, Epot= -1.74113e+06 Fmax= 1.57799e+03, atom= 204774
# Step=  844, Dmax= 2.3e-01 nm, Epot= -1.74131e+06 Fmax= 3.76037e+03, atom= 204774
# Step=  845, Dmax= 2.7e-01 nm, Epot= -1.74214e+06 Fmax= 1.97977e+03, atom= 204774
# Step=  847, Dmax= 1.6e-01 nm, Epot= -1.74263e+06 Fmax= 1.95263e+03, atom= 204774
# Step=  848, Dmax= 1.9e-01 nm, Epot= -1.74310e+06 Fmax= 2.27456e+03, atom= 204774
# Step=  849, Dmax= 2.3e-01 nm, Epot= -1.74346e+06 Fmax= 2.75489e+03, atom= 204774
# Step=  850, Dmax= 2.8e-01 nm, Epot= -1.74383e+06 Fmax= 3.16949e+03, atom= 204774
# Step=  851, Dmax= 3.4e-01 nm, Epot= -1.74389e+06 Fmax= 3.84618e+03, atom= 204774
# Step=  853, Dmax= 2.0e-01 nm, Epot= -1.74517e+06 Fmax= 7.65927e+02, atom= 191327
# Step=  855, Dmax= 1.2e-01 nm, Epot= -1.74556e+06 Fmax= 3.08978e+03, atom= 191328
# Step=  856, Dmax= 1.5e-01 nm, Epot= -1.74619e+06 Fmax= 1.47091e+03, atom= 191327
# Step=  857, Dmax= 1.7e-01 nm, Epot= -1.74620e+06 Fmax= 4.07426e+03, atom= 191328
# Step=  858, Dmax= 2.1e-01 nm, Epot= -1.74692e+06 Fmax= 2.39733e+03, atom= 191328
# Step=  860, Dmax= 1.3e-01 nm, Epot= -1.74729e+06 Fmax= 1.64619e+03, atom= 191328
# Step=  861, Dmax= 1.5e-01 nm, Epot= -1.74746e+06 Fmax= 3.40697e+03, atom= 191328
# Step=  862, Dmax= 1.8e-01 nm, Epot= -1.74787e+06 Fmax= 2.51114e+03, atom= 191328
# Step=  864, Dmax= 1.1e-01 nm, Epot= -1.74832e+06 Fmax= 7.68990e+02, atom= 191328
# Step=  865, Dmax= 1.3e-01 nm, Epot= -1.74876e+06 Fmax= 3.05161e+03, atom= 191328
# Step=  866, Dmax= 1.6e-01 nm, Epot= -1.74930e+06 Fmax= 1.95554e+03, atom= 191328
# Step=  868, Dmax= 9.4e-02 nm, Epot= -1.74964e+06 Fmax= 1.05267e+03, atom= 191328
# Step=  869, Dmax= 1.1e-01 nm, Epot= -1.74992e+06 Fmax= 2.65360e+03, atom= 191328
# Step=  870, Dmax= 1.4e-01 nm, Epot= -1.75033e+06 Fmax= 1.73702e+03, atom= 191328
# Step=  871, Dmax= 1.6e-01 nm, Epot= -1.75036e+06 Fmax= 3.58587e+03, atom= 191328
# Step=  872, Dmax= 1.9e-01 nm, Epot= -1.75078e+06 Fmax= 2.76967e+03, atom= 191328
# Step=  874, Dmax= 1.2e-01 nm, Epot= -1.75138e+06 Fmax= 7.27343e+02, atom= 191328
# Step=  875, Dmax= 1.4e-01 nm, Epot= -1.75166e+06 Fmax= 3.31741e+03, atom= 191328
# Step=  876, Dmax= 1.7e-01 nm, Epot= -1.75238e+06 Fmax= 2.07036e+03, atom= 191328
# Step=  878, Dmax= 1.0e-01 nm, Epot= -1.75277e+06 Fmax= 1.14053e+03, atom= 191328
# Step=  879, Dmax= 1.2e-01 nm, Epot= -1.75288e+06 Fmax= 2.80066e+03, atom= 191328
# Step=  880, Dmax= 1.5e-01 nm, Epot= -1.75332e+06 Fmax= 1.88083e+03, atom= 191328
# Step=  882, Dmax= 8.7e-02 nm, Epot= -1.75381e+06 Fmax= 7.62961e+02, atom= 191328
# Step=  883, Dmax= 1.0e-01 nm, Epot= -1.75403e+06 Fmax= 2.43784e+03, atom= 191328
# Step=  884, Dmax= 1.3e-01 nm, Epot= -1.75461e+06 Fmax= 1.41913e+03, atom= 191328
# Step=  886, Dmax= 7.5e-02 nm, Epot= -1.75495e+06 Fmax= 9.40384e+02, atom= 191328
# Step=  887, Dmax= 9.0e-02 nm, Epot= -1.75514e+06 Fmax= 1.98211e+03, atom= 195828
# Step=  888, Dmax= 1.1e-01 nm, Epot= -1.75550e+06 Fmax= 1.60082e+03, atom= 195828
# Step=  889, Dmax= 1.3e-01 nm, Epot= -1.75559e+06 Fmax= 2.81018e+03, atom= 195827
# Step=  890, Dmax= 1.6e-01 nm, Epot= -1.75596e+06 Fmax= 2.27960e+03, atom= 195828
# Step=  892, Dmax= 9.4e-02 nm, Epot= -1.75659e+06 Fmax= 4.33221e+02, atom= 191328
# Step=  893, Dmax= 1.1e-01 nm, Epot= -1.75690e+06 Fmax= 3.99238e+03, atom= 171177
# Step=  894, Dmax= 1.3e-01 nm, Epot= -1.75797e+06 Fmax= 1.16554e+03, atom= 171177
# Step=  895, Dmax= 1.6e-01 nm, Epot= -1.75807e+06 Fmax= 6.74779e+03, atom= 171177
# Step=  896, Dmax= 1.9e-01 nm, Epot= -1.75871e+06 Fmax= 1.74743e+03, atom= 171177
# Step=  898, Dmax= 1.2e-01 nm, Epot= -1.75903e+06 Fmax= 1.99085e+03, atom= 171176
# Step=  899, Dmax= 1.4e-01 nm, Epot= -1.75930e+06 Fmax= 2.29741e+03, atom= 171177
# Step=  900, Dmax= 1.7e-01 nm, Epot= -1.75959e+06 Fmax= 2.87904e+03, atom= 171176
# Step=  901, Dmax= 2.0e-01 nm, Epot= -1.75979e+06 Fmax= 3.25140e+03, atom= 171177
# Step=  902, Dmax= 2.4e-01 nm, Epot= -1.76006e+06 Fmax= 5.76624e+03, atom= 171177
# Step=  903, Dmax= 2.9e-01 nm, Epot= -1.76017e+06 Fmax= 5.50849e+03, atom= 91713
# Step=  905, Dmax= 1.7e-01 nm, Epot= -1.76035e+06 Fmax= 2.06595e+04, atom= 45548
# Step=  907, Dmax= 1.0e-01 nm, Epot= -1.76083e+06 Fmax= 1.75215e+03, atom= 995792
# Step=  908, Dmax= 1.3e-01 nm, Epot= -1.76120e+06 Fmax= 7.81340e+02, atom= 133832
# Step=  909, Dmax= 1.5e-01 nm, Epot= -1.76193e+06 Fmax= 2.21232e+03, atom= 171177
# Step=  910, Dmax= 1.8e-01 nm, Epot= -1.76219e+06 Fmax= 4.14058e+03, atom= 171177
# Step=  911, Dmax= 2.2e-01 nm, Epot= -1.76248e+06 Fmax= 2.94860e+03, atom= 171177
# Step=  913, Dmax= 1.3e-01 nm, Epot= -1.76298e+06 Fmax= 6.27668e+02, atom= 171176
# Step=  914, Dmax= 1.6e-01 nm, Epot= -1.76366e+06 Fmax= 3.67592e+03, atom= 171177
# Step=  915, Dmax= 1.9e-01 nm, Epot= -1.76430e+06 Fmax= 1.87181e+03, atom= 171177
# Step=  916, Dmax= 2.2e-01 nm, Epot= -1.76434e+06 Fmax= 4.11763e+03, atom= 171177
# Step=  917, Dmax= 2.7e-01 nm, Epot= -1.76506e+06 Fmax= 2.98451e+03, atom= 171177
# Step=  919, Dmax= 1.6e-01 nm, Epot= -1.76542e+06 Fmax= 1.53112e+03, atom= 171177
# Step=  920, Dmax= 1.9e-01 nm, Epot= -1.76565e+06 Fmax= 7.00030e+03, atom= 171177
# Step=  921, Dmax= 2.3e-01 nm, Epot= -1.76608e+06 Fmax= 2.03412e+03, atom= 91713
# Step=  923, Dmax= 1.4e-01 nm, Epot= -1.76643e+06 Fmax= 2.44252e+03, atom= 455487
# Step=  924, Dmax= 1.7e-01 nm, Epot= -1.76665e+06 Fmax= 5.96495e+03, atom= 133832
# Step=  925, Dmax= 2.0e-01 nm, Epot= -1.76690e+06 Fmax= 1.76769e+03, atom= 133832
# Step=  926, Dmax= 2.4e-01 nm, Epot= -1.76750e+06 Fmax= 1.45486e+03, atom= 148580
# Step=  927, Dmax= 2.9e-01 nm, Epot= -1.76802e+06 Fmax= 1.85369e+03, atom= 171177
# Step=  929, Dmax= 1.7e-01 nm, Epot= -1.76864e+06 Fmax= 4.20335e+03, atom= 171177
# Step=  930, Dmax= 2.1e-01 nm, Epot= -1.76899e+06 Fmax= 2.17988e+03, atom= 171177
# Step=  932, Dmax= 1.3e-01 nm, Epot= -1.76943e+06 Fmax= 7.64807e+02, atom= 171177
# Step=  933, Dmax= 1.5e-01 nm, Epot= -1.76999e+06 Fmax= 3.13785e+03, atom= 171177
# Step=  934, Dmax= 1.8e-01 nm, Epot= -1.77056e+06 Fmax= 1.15146e+03, atom= 171177
# Step=  936, Dmax= 1.1e-01 nm, Epot= -1.77088e+06 Fmax= 1.53423e+03, atom= 171177
# Step=  937, Dmax= 1.3e-01 nm, Epot= -1.77105e+06 Fmax= 3.96871e+03, atom= 195827
# Step=  938, Dmax= 1.6e-01 nm, Epot= -1.77140e+06 Fmax= 2.12001e+03, atom= 195828
# Step=  939, Dmax= 1.9e-01 nm, Epot= -1.77153e+06 Fmax= 5.05342e+03, atom= 195828
# Step=  940, Dmax= 2.2e-01 nm, Epot= -1.77184e+06 Fmax= 2.81111e+03, atom= 195828
# Step=  942, Dmax= 1.3e-01 nm, Epot= -1.77236e+06 Fmax= 9.37318e+02, atom= 195828
# Step=  943, Dmax= 1.6e-01 nm, Epot= -1.77299e+06 Fmax= 2.05105e+03, atom= 195828
# Step=  945, Dmax= 9.7e-02 nm, Epot= -1.77336e+06 Fmax= 9.14710e+02, atom= 195827
# Step=  946, Dmax= 1.2e-01 nm, Epot= -1.77370e+06 Fmax= 2.44506e+03, atom= 195828
# Step=  947, Dmax= 1.4e-01 nm, Epot= -1.77409e+06 Fmax= 1.78820e+03, atom= 195828
# Step=  948, Dmax= 1.7e-01 nm, Epot= -1.77411e+06 Fmax= 3.09315e+03, atom= 195828
# Step=  949, Dmax= 2.0e-01 nm, Epot= -1.77450e+06 Fmax= 2.63194e+03, atom= 195828
# Step=  951, Dmax= 1.2e-01 nm, Epot= -1.77503e+06 Fmax= 1.07539e+03, atom= 195828
# Step=  953, Dmax= 7.2e-02 nm, Epot= -1.77533e+06 Fmax= 1.24722e+03, atom= 174534
# Step=  954, Dmax= 8.7e-02 nm, Epot= -1.77561e+06 Fmax= 1.54459e+03, atom= 174534
# Step=  955, Dmax= 1.0e-01 nm, Epot= -1.77588e+06 Fmax= 1.77552e+03, atom= 174534
# Step=  956, Dmax= 1.2e-01 nm, Epot= -1.77610e+06 Fmax= 2.40162e+03, atom= 174534
# Step=  957, Dmax= 1.5e-01 nm, Epot= -1.77636e+06 Fmax= 2.33422e+03, atom= 174534
# Step=  958, Dmax= 1.8e-01 nm, Epot= -1.77641e+06 Fmax= 3.87617e+03, atom= 174534
# Step=  959, Dmax= 2.2e-01 nm, Epot= -1.77682e+06 Fmax= 2.92640e+03, atom= 174534
# Step=  961, Dmax= 1.3e-01 nm, Epot= -1.77734e+06 Fmax= 1.04875e+03, atom= 174533
# Step=  963, Dmax= 7.8e-02 nm, Epot= -1.77764e+06 Fmax= 1.35800e+03, atom= 174534
# Step=  964, Dmax= 9.3e-02 nm, Epot= -1.77791e+06 Fmax= 1.48121e+03, atom= 174534
# Step=  965, Dmax= 1.1e-01 nm, Epot= -1.77812e+06 Fmax= 2.07130e+03, atom= 174534
# Step=  966, Dmax= 1.3e-01 nm, Epot= -1.77836e+06 Fmax= 2.21852e+03, atom= 174534
# Step=  967, Dmax= 1.6e-01 nm, Epot= -1.77847e+06 Fmax= 2.80688e+03, atom= 174534
# Step=  968, Dmax= 1.9e-01 nm, Epot= -1.77853e+06 Fmax= 3.56207e+03, atom= 174534
# Step=  969, Dmax= 2.3e-01 nm, Epot= -1.77868e+06 Fmax= 3.58831e+03, atom= 174534
# Step=  971, Dmax= 1.4e-01 nm, Epot= -1.77967e+06 Fmax= 6.45546e+02, atom= 188106
# Step=  973, Dmax= 8.4e-02 nm, Epot= -1.77985e+06 Fmax= 2.22999e+03, atom= 230882
# Step=  974, Dmax= 1.0e-01 nm, Epot= -1.78037e+06 Fmax= 1.20397e+03, atom= 230883
# Step=  975, Dmax= 1.2e-01 nm, Epot= -1.78039e+06 Fmax= 3.08050e+03, atom= 230882
# Step=  976, Dmax= 1.4e-01 nm, Epot= -1.78092e+06 Fmax= 1.88654e+03, atom= 230883
# Step=  978, Dmax= 8.7e-02 nm, Epot= -1.78130e+06 Fmax= 7.44031e+02, atom= 230883
# Step=  979, Dmax= 1.0e-01 nm, Epot= -1.78158e+06 Fmax= 2.28410e+03, atom= 230883
# Step=  980, Dmax= 1.2e-01 nm, Epot= -1.78200e+06 Fmax= 1.62214e+03, atom= 230883
# Step=  982, Dmax= 7.5e-02 nm, Epot= -1.78233e+06 Fmax= 8.23205e+02, atom= 230883
# Step=  983, Dmax= 9.0e-02 nm, Epot= -1.78257e+06 Fmax= 2.17813e+03, atom= 230883
# Step=  984, Dmax= 1.1e-01 nm, Epot= -1.78294e+06 Fmax= 1.38264e+03, atom= 230883
# Step=  985, Dmax= 1.3e-01 nm, Epot= -1.78302e+06 Fmax= 3.01779e+03, atom= 230883
# Step=  986, Dmax= 1.6e-01 nm, Epot= -1.78343e+06 Fmax= 2.14678e+03, atom= 230883
# Step=  988, Dmax= 9.3e-02 nm, Epot= -1.78385e+06 Fmax= 6.02344e+02, atom= 230883
# Step=  989, Dmax= 1.1e-01 nm, Epot= -1.78412e+06 Fmax= 2.57237e+03, atom= 230883
# Step=  990, Dmax= 1.3e-01 nm, Epot= -1.78466e+06 Fmax= 1.55798e+03, atom= 230883
# Step=  992, Dmax= 8.0e-02 nm, Epot= -1.78501e+06 Fmax= 1.03923e+03, atom= 230883
# Step=  993, Dmax= 9.7e-02 nm, Epot= -1.78512e+06 Fmax= 2.08894e+03, atom= 230883
# Step=  994, Dmax= 1.2e-01 nm, Epot= -1.78548e+06 Fmax= 1.63757e+03, atom= 230883
# Step=  996, Dmax= 7.0e-02 nm, Epot= -1.78590e+06 Fmax= 5.14178e+02, atom= 180131
# Step=  997, Dmax= 8.3e-02 nm, Epot= -1.78614e+06 Fmax= 2.21681e+03, atom= 180131
# Step=  998, Dmax= 1.0e-01 nm, Epot= -1.78671e+06 Fmax= 1.03598e+03, atom= 180131
# Step= 1000, Dmax= 6.0e-02 nm, Epot= -1.78698e+06 Fmax= 8.53267e+02, atom= 180132
#
# Energy minimization reached the maximum number of steps before the forces
# reached the requested precision Fmax < 10.
#
# writing lowest energy coordinates.
#
# Back Off! I just backed up m2.gro to ./#m2.gro.3#
#
# Steepest Descents did not converge to Fmax < 10 in 1001 steps.
# Potential Energy  = -1.7869838e+06
# Maximum force     =  8.5326685e+02 on atom 180132
# Norm of force     =  6.2025781e+00
#
# GROMACS reminds you: "You always pass failure on the way to success." (Mickey Rooney)
# 0

# %%
### Create the index file
gro = 'm2.gro'
u = md.Universe(gro)
lipidsagg=u.select_atoms(f'resname {sterol_name} {IL_name_N1} {IL_name_NP} MC3H LI2H SITO CHOL A')
lipidsagg.write("index2.ndx", mode="w", name= 'Particle')
u.atoms.write("index2.ndx", mode="a", name= 'System')
