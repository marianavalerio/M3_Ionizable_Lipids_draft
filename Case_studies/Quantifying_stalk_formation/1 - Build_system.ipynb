# %% [markdown]
# ## Protocol to generate initial positions for PMF

# %%
import numpy as np
import MDAnalysis as md
from MDAnalysis.analysis import align
import subprocess
import networkx
import os
from MDAnalysis.analysis.leaflet import LeafletFinder

# %%
## Define paths to forcefield files, mdp files, insane script and an equilibrated water box
ff_loc  = 'ff_itp/'
mdp_loc = 'mdps/'
insane_loc = 'common_files'
water_loc = 'common_files'

IL_name = 'MC3H'

# %%
pin_cores = '-pin on -pinstride 1 -pinoffset 30'

# %% [markdown]
# ### Functions are hidden here
# ===============================================================================================

# %%
def build_system(comp1, comp2, hydration, forcefields, insane_loc):
    
    # ### Generate Comp1 membrane
    subprocess.call(f"python  {insane_loc}/python3_insane_M3_lipids.py  {comp1} -pbc cubic -o comp1_mem.gro -p topol_comp1.top", shell = True)
    
    ### Generate Comp2 membrane
    subprocess.call(f"python  {insane_loc}/python3_insane_M3_lipids.py {comp2} -pbc cubic -o comp2_mem.gro -p topol_comp2.top", shell = True)
    
        
    ##################################################
    ### Equilibrate both membranes separately
    ###################################################
    
    ############################# Comp1 membrane ##############
    #### Renumber and generate box
    subprocess.call('gmx editconf -f comp1_mem.gro -o comp1_mem.gro -resnr 1'.format(mdp_loc), shell=True)

    ############# Create topology file
    with open('topol_comp1.top') as topinput:
        top = topinput.readlines()

    top[0]= forcefields
    top[7]= ';membrane1   number\n'

    ## write the file
    with open("topol_comp1_W.top", "w") as f:
        top = "".join(top)
        f.write(top)

    ##### Solvate system
    subprocess.call('gmx solvate -cp comp1_mem.gro -cs {}/water.gro -p topol_comp1_W.top -o comp1_mem_W.gro -radius 0.21'.format(water_loc)
                   , shell=True)

    ##### Neutralize charge
    tpr = 'ions.tpr'
    out = 'comp1_mem_W_ion.gro'
    top = 'topol_comp1_W.top'
    # !touch empty.mdp

    subprocess.call('gmx grompp -f empty.mdp -c comp1_mem_W.gro -r comp1_mem_W.gro -p topol_comp1_W.top -o ions.tpr -renum -maxwarn 1', shell=True)

    p = subprocess.Popen(['gmx', 'genion', '-s', tpr, '-o', out, '-p', top, '-neutral'], stdin=subprocess.PIPE)
    p.communicate(b'W\n')
    p.wait()

    #### Water energy minimisation 
    subprocess.call('gmx grompp -f {}em_2.mdp -c comp1_mem_W_ion.gro -r comp1_mem_W_ion.gro -p topol_comp1_W.top -o em_comp1.tpr'.format(mdp_loc), shell=True)
    subprocess.call(f'gmx mdrun -v -deffnm em_comp1 -nt 10 {pin_cores}', shell=True)

    ## Remove trash
    # !rm *#

    ###Create new index file
    gro = 'comp1_mem_W_ion.gro'
    u = md.Universe(gro)

    Lipids = u.select_atoms('not name W')
    Water = u.select_atoms('name W')

    Lipids.write("index_comp1_mem.ndx", mode="w", name= 'Solute')
    Water.write("index_comp1_mem.ndx", mode="a", name= 'Solvent')

    u.atoms.write("index_comp1_mem.ndx", mode="a", name= 'System')

    #### Equilibration 
    subprocess.call('gmx grompp -f {}eq_3_20ns.mdp -c em_comp1.gro -r em_comp1.gro -p topol_comp1_W.top -n index_comp1_mem.ndx -o eq1_comp1.tpr -maxwarn 1'.format(mdp_loc), shell=True)
    subprocess.call(f'gmx mdrun -v -deffnm eq1_comp1 -nt 10 {pin_cores}', shell=True)

    ## Remove trash
    # !rm *#
    
    
    
    ############################### Comp2 membrane ##############
    #### Renumber and generate box
    subprocess.call('gmx editconf -f comp2_mem.gro -o comp2_mem.gro -resnr 1'.format(mdp_loc), shell=True)


    ############# Create topology file
    with open('topol_comp2.top') as topinput:
        top = topinput.readlines()

    top[0]= forcefields
    top[7]= ';membrane2\n'

    ## write the file
    with open("topol_comp2_W.top", "w") as f:
        top = "".join(top)
        f.write(top)


    ##### Solvate system
    subprocess.call('gmx solvate -cp comp2_mem.gro -cs {}/water.gro -p topol_comp2_W.top -o comp2_mem_W.gro -radius 0.21'.format(water_loc)
                   , shell=True)


    ##### Neutralize charge
    tpr = 'ions.tpr'
    out = 'comp2_mem_W_ion.gro'
    top = 'topol_comp2_W.top'
    # !touch empty.mdp

    subprocess.call('gmx grompp -f empty.mdp -c comp2_mem_W.gro -r comp2_mem_W.gro -p topol_comp2_W.top -o ions.tpr -renum -maxwarn 1', shell=True)

    p = subprocess.Popen(['gmx', 'genion', '-s', tpr, '-o', out, '-p', top, '-neutral'], stdin=subprocess.PIPE)
    p.communicate(b'W\n')
    p.wait()


    #### Water energy minimisation 
    subprocess.call('gmx grompp -f {}em_2.mdp -c comp2_mem_W_ion.gro -r comp2_mem_W_ion.gro -p topol_comp2_W.top -o em_comp2.tpr'.format(mdp_loc), shell=True)
    subprocess.call(f'gmx mdrun -v -deffnm em_comp2 -nt 10 {pin_cores}', shell=True)

    ## Remove trash
    # !rm *#


    ###Create new index file
    gro = 'comp2_mem_W_ion.gro'
    u = md.Universe(gro)

    Lipids = u.select_atoms('not name W')
    Water = u.select_atoms('name W')

    Lipids.write("index_comp2_mem.ndx", mode="w", name= 'Solute')
    Water.write("index_comp2_mem.ndx", mode="a", name= 'solvent')

    u.atoms.write("index_comp2_mem.ndx", mode="a", name= 'System')


    #### Equilibration 
    subprocess.call('gmx grompp -f {}eq_3_20ns.mdp -c em_comp2.gro -r em_comp2.gro -p topol_comp2_W.top -n index_comp2_mem.ndx -o eq1_comp2_in.tpr -maxwarn 1'.format(mdp_loc), shell=True)
    subprocess.call(f'gmx mdrun -v -deffnm eq1_comp2_in -nt 10 {pin_cores}', shell=True)

    
    #######################################
    ###### Define hydration level
    #######################################
    
    subprocess.call(f'gmx editconf -f eq1_comp2_in.gro -o eq1_comp2.gro -resnr 1 -box 10 10 {hydration}'.format(mdp_loc), shell=True)
    
    #######################################
    ###### Join both membranes  
    #######################################
    
    comp1_mem = md.Universe('eq1_comp1.gro')
    comp2_mem = md.Universe('eq1_comp2.gro')

    sys = md.Merge(comp1_mem.select_atoms('not name W NA CL'), comp2_mem.select_atoms('not name W NA CL'))

    ### write both membranes in one file 
    sys.atoms.write('stacked_membrane.gro')
    
    #### Renumber and generate box
    subprocess.call('gmx editconf -f stacked_membrane.gro -o stacked_membrane_renum.gro -resnr 1 -box 10 10 18'.format(mdp_loc), shell=True)
    
    ## Remove trash
    # !rm *#    
    
    return

# %%
def area_per_lipid(gro, xtc):#, lipids):
    #### Calculate area per lipid 
    u = md.Universe(gro,xtc)
    lipids = u.select_atoms('name PO4 NP N1')

    ## Determine area per lipid
    areas = []
    times = []

    for ts in u.trajectory[:]:
        APL = (u.dimensions[0]*u.dimensions[1])/(len(lipids)/2)
        areas.append(APL)
        #times.append(ts.time)

    ## Calculate average and standard deviation    
    avg = np.mean(areas)
    std = np.std(areas)
    return(avg,std,lipids)

# %%
def minimize_equilibrate():
    #### Water energy minimisation 
    subprocess.call(f'gmx grompp -f {mdp_loc}em_2.mdp -c mem_solvent_ions.gro -r restraint_reference.gro -p system_W.top -o em2.tpr', shell=True)
    subprocess.call(f'gmx mdrun -v -deffnm em2 -nt 10 {pin_cores}', shell=True)

    ## Remove trash
    # !rm *#
    
    ###Create new index file
    gro = 'em2.gro'
    u = md.Universe(gro)

    Lipids = u.select_atoms('not name W NA CL')
    Water = u.select_atoms('name W NA CL')

    Lipids.write("index_eq.ndx", mode="w", name= 'Solute')
    Water.write("index_eq.ndx", mode="a", name= 'solvent')

    u.atoms.write("index_eq.ndx", mode="a", name= 'System')
    
    #### Equilibration 
    subprocess.call(f'gmx grompp -f {mdp_loc}eq_3_20ns.mdp -c em2.gro -n index_eq.ndx -r restraint_reference.gro -p system_W.top -o eq1.tpr -maxwarn 1', shell=True)
    subprocess.call(f'gmx mdrun -v -deffnm eq1 -nt 10 {pin_cores}', shell=True)


    ## Remove trash
    # !rm *#
    
    return

# %%
def neutralize(neg_lipids, pos_lipids):          
    ##########################################
    ############## Neutralize lipid charge
    ##########################################

    ######## Find lower leaflet of upper membrane
    u_UpperMembrane = md.Universe('eq1_comp2.gro')
    L_up = LeafletFinder(u_UpperMembrane, 'name PO4 NP', cutoff = 20)
    UpperMembrane_leaflet0 = L_up.groups(0)  ### upper
    UpperMembrane_leaflet1 = L_up.groups(1)  ### lower
    
    ######## Find upper leaflet of lower membrane
    u_LowerMembrane = md.Universe('eq1_comp1.gro')
    L_low = LeafletFinder(u_LowerMembrane, 'name PO4 NP', cutoff = 18)
    LowerMembrane_leaflet0 = L_low.groups(0)  ### upper
    LowerMembrane_leaflet1 = L_low.groups(1)  ### lower
    
    print(L_up, L_low)
    
    ######## Get number of positive and negative leaflets facing the Middle waters
    num_neg_lipids = len(UpperMembrane_leaflet1.select_atoms(f'resname {" ".join(neg_lipids.keys())}').resids) + len(LowerMembrane_leaflet0.select_atoms(f'resname {" ".join(neg_lipids.keys())}').resids)
    num_pos_lipids = len(UpperMembrane_leaflet1.select_atoms(f'resname {" ".join(pos_lipids.keys())}').resids) + len(LowerMembrane_leaflet0.select_atoms(f'resname {" ".join(pos_lipids.keys())}').resids)
    
    lipid_sum = num_pos_lipids*sum(pos_lipids.values()) + num_neg_lipids*sum(neg_lipids.values())
                        
    print(lipid_sum)
    
    
    if lipid_sum > 0:
        #### Add CL- ions in middle compartment
        tpr = 'ions_2.tpr'
        out = 'mem_solvent_ions.gro'
        top = 'system_W.top'
        cl_fn = str(np.abs(lipid_sum))
        pname_fn = 'CL'
        index_fn = 'index.ndx'
        # !touch empty.mdp

        subprocess.call('gmx grompp -f empty.mdp -c stacked_membrane_renum_W_order.gro \
        -r stacked_membrane_renum_W_order.gro -p system_W.top -o ions_2.tpr -renum -maxwarn 2', shell=True)

        p = subprocess.Popen(['gmx', 'genion', '-s', tpr, '-o', out, '-p', top, '-nn', cl_fn, '-nname', pname_fn, '-n', index_fn], stdin=subprocess.PIPE)
        p.communicate(b'MiddleWater\n')
        p.wait()
    else:
        #### Add NA+ ions in middle compartment
        tpr = 'ions_2.tpr'
        out = 'mem_solvent_ions.gro'
        top = 'system_W.top'
        np_fn = str(np.abs(lipid_sum))
        pname_fn = 'NA'
        index_fn = 'index.ndx'
        # !touch empty.mdp

        subprocess.call('gmx grompp -f empty.mdp -c stacked_membrane_renum_W_order.gro -r stacked_membrane_renum_W_order.gro -p system_W.top -o ions_2.tpr -renum -maxwarn 1', shell=True)

        p = subprocess.Popen(['gmx', 'genion', '-s', tpr, '-o', out, '-p', top, '-np', np_fn, '-pname', pname_fn, '-n', index_fn], stdin=subprocess.PIPE)
        p.communicate(b'MiddleWater\n')
        p.wait()
    
                
    #### Add ions in outside compartment
    tpr = 'ions.tpr'
    out = 'mem_solvent_ions.gro'
    top = 'system_W.top'
    index_fn = 'index.ndx'
    # !touch empty.mdp

    subprocess.call('gmx grompp -f empty.mdp -c mem_solvent_ions.gro -r mem_solvent_ions.gro -p system_W.top\
    -o ions.tpr -renum -maxwarn 1', shell=True)

    p = subprocess.Popen(['gmx', 'genion', '-s', tpr, '-o', out, '-p', top, '-neutral', '-n', index_fn], stdin=subprocess.PIPE)
    p.communicate(b'OuterWater\n')
    p.wait()
    
    return

# %%
def solvate(not_tails):
    ############## Solvate system
    subprocess.call(f'gmx solvate -cp stacked_membrane_renum.gro -cs {water_loc}/water.gro -p system.top -o stacked_membrane_renum_W.gro -radius 0.21', shell=True)
    
    ##########################################
    ############## Assign Middle and Outter waters
    ##########################################
    u = md.Universe('stacked_membrane_renum_W.gro')
    #### Adapt topology file
    with open('system.top') as topinput:
        top = topinput.readlines()

    ### Select middle waters
    box_z = u.dimensions[2]
    top_leaflet = u.select_atoms('all and not name W and prop z > {}'.format(box_z/2))
    bot_leaflet = u.select_atoms('all and not name W and prop z < {}'.format(box_z/2))
    mem_top = top_leaflet.center_of_geometry()[2]-10
    mem_bot = bot_leaflet.center_of_geometry()[2]+10

    top[-1] = 'MiddleWater       {}\n'.format(len(u.select_atoms(f'name W and (prop z > {mem_bot} and prop z <= {mem_top})')))
    top.append('OuterWater       {}\n'.format(len(u.select_atoms(f'name W and (prop z > {mem_top} or prop z <= {mem_bot})'))))

    #### write the files
    with open("system_W.top", "w") as f:
        top = "".join(top)
        f.write(top)


    #### Re-order .gro file
    membrane = u.select_atoms('not name W')
    WNmiddle = u.select_atoms(f'name W and prop z <= {mem_top} and prop z > {mem_bot}')
    WNouter = u.select_atoms(f'name W and (prop z > {mem_top} or prop z <= {mem_bot})')

    outgoing = membrane + WNmiddle + WNouter
    outgoing.atoms.write('stacked_membrane_renum_W_order.gro')
    
       
    print (len(u.select_atoms(f'name W and (prop z > {mem_bot} and prop z < {mem_top})'))/330)
                              
    
    ##########################################
    ############## Create new index file
    ##########################################                          
    gro = 'stacked_membrane_renum_W_order.gro'
    u = md.Universe(gro)

    UpperMembrane = u.select_atoms(f'prop z > {box_z/2} and not name W NA CL')
    LowerMembrane = u.select_atoms(f'prop z < {box_z/2} and not name W NA CL')
    MiddleWater = u.select_atoms(f'name W NA and prop z < {mem_top} and prop z > {mem_bot}')
    OuterWater = u.select_atoms(f'name W NA and (prop z > {mem_top} or prop z < {mem_bot})')
    tails = u.select_atoms(f'not name {not_tails} W NA CL and not resname CHOL')
    water = u.select_atoms('name W')
    
    ##### Generate gro file for each membrane
    UpperMembrane.write('UpperMembrane.gro')
    LowerMembrane.write('LowerMembrane.gro')
    
    
    ##### Write new .ndx files
    LowerMembrane.write("index.ndx", mode="w", name= 'LowerMembrane')
    UpperMembrane.write("index.ndx", mode="a", name= 'UpperMembrane')
    MiddleWater.write("index.ndx", mode="a", name= 'MiddleWater')
    OuterWater.write("index.ndx", mode="a", name= 'OuterWater')
    tails.write("index.ndx", mode="a", name= 'tails')
    water.write("index.ndx", mode="a", name= 'water')

    u.atoms.write("index.ndx", mode="a", name= 'System')
    
    ############# Create flat bottom restraints for the water molecules
    #### Find COM of both leaflets
    LowerMembrane_com = LowerMembrane.center_of_geometry()/10
    UpperMembrane_com = UpperMembrane.center_of_geometry()/10
    
    print(LowerMembrane_com[2], UpperMembrane_com[2])

    zWNmiddle = (UpperMembrane_com[2]-LowerMembrane_com[2])/2-0.5 #atractive
    zWNouter = (UpperMembrane_com[2]-LowerMembrane_com[2])/2+0.5 #repulsive

    #### Adapt .itp file
    with open(f'{ff_loc}/WN_fbposres.itp') as topinput:
        top = topinput.readlines()

    top[7] = '[ position_restraints ]\n'
    top[8] = f'  1     2     5     {zWNmiddle}  50  ; attractive Z-layer\n'

    top[18] = '[ position_restraints ]\n'
    top[19] = f'  1     2     5     -{zWNouter}   50  ; repulsive Z-layer\n'

    #### write the files
    with open(f'{ff_loc}/WN_fbposres.itp', "w") as f:
        top = "".join(top)
        f.write(top)
        
    ###Create restraint reference at the center of the membrane
    tm = MiddleWater.positions
    tm[:,2]=np.full(MiddleWater.positions[:,2].shape, u.dimensions[2]/2)
    MiddleWater.positions = tm

    to = OuterWater.positions
    to[:,2]=np.full(OuterWater.positions[:,2].shape, u.dimensions[2]/2)
    OuterWater.positions = to

    u.atoms.write('restraint_reference.gro')
                                 
    return print('All done')

# %% [markdown]
# ### Build system with stacked membranes
# ===============================================================================================

# %%
hydration = '22' #(~5 waters per lipid)
comp1 = f'-u POPC:640 -u PAPS:264 -u PAPC:56 -u POPE:264 -u DIPE:160 -u DPSM:640 -u CHOL:826 \
-l POPC:373 -l PAPC:213 -l POPE:133 -l DIPE:426 -l DPSM:293 -l CHOL:746 -l PAPS:666 -l SAP6:53 -x 10 -y 10 -z 8'

comp2 = f'-l MC3H:50 -l DPPC:10 -l CHOL:40 -x 10 -y 10 -z 8' 

forcefields = f'#include "{ff_loc}/martini_v3.0.0.itp"\n\
#include "{ff_loc}/Martini_v1_tails-2.itp"\n\
#include "{ff_loc}/martini_v3.0.0_ions_v1.itp"\n\
#include "{ff_loc}/martini_v3.0.0_solvents_v1.itp"\n\
#include "{ff_loc}/martini_v3.0_phosphoinositides_v1.0.itp"\n\
#include "{ff_loc}/martini_v3.0.0_phospholipids_v1.itp"\n\
#include "{ff_loc}/martini_v3.0_CHOL_dev20.itp"\n\
#include "{ff_loc}/WN_fbposres.itp"\n\
#include "{ff_loc}/MC3_MC3H.itp"\n'

### Run
build_system(comp1, comp2, hydration, forcefields, insane_loc)
# Out:
# ; X: 10.000 (13 bins) Y: 10.000 (13 bins) in upper leaflet
# ; X: 10.000 (13 bins) Y: 10.000 (13 bins) in lower leaflet
# ; 169 lipids in upper leaflet, 169 lipids in lower leaflet
# ; NDX Solute 1 0
# ; Charge of protein: 0.000000
# ; NDX Membrane 1 3707
# ; Charge of membrane: -65.000000
# ; Total charge: -65.000000
# ; NDX Solvent 3708 0
# ; NDX System 1 3707
# ; "I mean, the good stuff is just INSANE" --Julia Ormond
# ; X: 10.000 (13 bins) Y: 10.000 (13 bins) in upper leaflet
# ; X: 10.000 (13 bins) Y: 10.000 (13 bins) in lower leaflet
# ; 169 lipids in upper leaflet, 169 lipids in lower leaflet
# ; NDX Solute 1 0
# ; Charge of protein: 0.000000
# ; NDX Membrane 1 3606
# ; Charge of membrane: 0.000000
# ; Total charge: 0.000000
# ; NDX Solvent 3607 0
# ; NDX System 1 3606
# ; "I mean, the good stuff is just INSANE" --Julia Ormond
#                      :-) GROMACS - gmx editconf, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx editconf -f comp1_mem.gro -o comp1_mem.gro -resnr 1
#
#
# Back Off! I just backed up comp1_mem.gro to ./#comp1_mem.gro.1#
#
# GROMACS reminds you: "The secret to getting ahead is getting started" (Mark Twain)
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 3707 atoms
# Volume: 800 nm^3, corresponds to roughly 360000 electrons
# No velocities found
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Adding line for 3593 solvent molecules with resname (W) to topology file (topol_comp1_W.top)
#                      :-) GROMACS - gmx solvate, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx solvate -cp comp1_mem.gro -cs /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/common_files/water.gro -p topol_comp1_W.top -o comp1_mem_W.gro -radius 0.21
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
# Generating solvent configuration
# Will generate new solvent configuration of 3x3x3 boxes
# Solvent box contains 8009 atoms in 8009 residues
# Removed 1783 solvent atoms due to solvent-solvent overlap
# Removed 2633 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#       W (   1 atoms):  3593 residues
# Generated solvent containing 3593 atoms in 3593 residues
# Writing generated configuration to comp1_mem_W.gro
#
# Output configuration contains 7300 atoms in 3922 residues
# Volume                 :         800 (nm^3)
# Density                :     1474.22 (g/l)
# Number of solvent molecules:   3593
#
# Processing topology
#
# Back Off! I just backed up topol_comp1_W.top to ./#topol_comp1_W.top.1#
#
# GROMACS reminds you: "The secret to getting ahead is getting started" (Mark Twain)
#
#                       :-) GROMACS - gmx grompp, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx grompp -f empty.mdp -c comp1_mem_W.gro -r comp1_mem_W.gro -p topol_comp1_W.top -o ions.tpr -renum -maxwarn 1
#
#
# NOTE 1 [file empty.mdp]:
#   For a correct single-point energy evaluation with nsteps = 0, use
#   continuation = yes to avoid constraining the input coordinates.
#
#
# NOTE 2 [file topol_comp1_W.top, line 32]:
#   System has non-zero total charge: -65.000000
#   Total charge should normally be an integer. See
#   http://www.gromacs.org/Documentation/Floating_Point_Arithmetic
#   for discussion on how close it should be to an integer.
#
#
#
#
# NOTE 3 [file topol_comp1_W.top, line 32]:
#   For energy conservation with LINCS, lincs_iter should be 2 or larger.
#
#
# Number of degrees of freedom in T-Coupling group rest is 20241.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# NOTE 4 [file empty.mdp]:
#   NVE simulation with an initial temperature of zero: will use a Verlet
#   buffer of 10%. Check your energy drift!
#
#
# NOTE 5 [file empty.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
#
# There were 5 NOTEs
#
# GROMACS reminds you: "I originally implemented PME to prove that you didn't need it..." (Erik Lindahl)
#
#                       :-) GROMACS - gmx genion, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx genion -s ions.tpr -o comp1_mem_W_ion.gro -p topol_comp1_W.top -neutral
#
# Reading file ions.tpr, VERSION 2023.3 (single precision)
# Reading file ions.tpr, VERSION 2023.3 (single precision)
# Group     0 (         System) has  7300 elements
# Group     1 (          Other) has  7300 elements
# Group     2 (           POPC) has   696 elements
# Group     3 (           PAPS) has   689 elements
# Group     4 (           PAPC) has   195 elements
# Group     5 (           POPE) has   264 elements
# Group     6 (           DIPE) has   396 elements
# Group     7 (           DPSM) has   594 elements
# Group     8 (           CHOL) has   819 elements
# Group     9 (           SAP6) has    54 elements
# Group    10 (              W) has  3593 elements
# Select a group: Number of (1-atomic) solvent molecules: 3593
#
# Back Off! I just backed up topol_comp1_W.top to ./#topol_comp1_W.top.2#
# Using random seed -134336277.
# Replacing solvent molecule 3248 (atom 6955) with NA
# Replacing solvent molecule 1843 (atom 5550) with NA
# Replacing solvent molecule 2643 (atom 6350) with NA
# Replacing solvent molecule 1526 (atom 5233) with NA
# Replacing solvent molecule 2405 (atom 6112) with NA
# Replacing solvent molecule 3299 (atom 7006) with NA
# Replacing solvent molecule 3440 (atom 7147) with NA
# Replacing solvent molecule 1747 (atom 5454) with NA
# Replacing solvent molecule 3392 (atom 7099) with NA
# Replacing solvent molecule 2708 (atom 6415) with NA
# Replacing solvent molecule 3185 (atom 6892) with NA
# Replacing solvent molecule 486 (atom 4193) with NA
# Replacing solvent molecule 3516 (atom 7223) with NA
# Replacing solvent molecule 2384 (atom 6091) with NA
# Replacing solvent molecule 3306 (atom 7013) with NA
# Replacing solvent molecule 1892 (atom 5599) with NA
# Replacing solvent molecule 2707 (atom 6414) with NA
# Replacing solvent molecule 606 (atom 4313) with NA
# Replacing solvent molecule 434 (atom 4141) with NA
# Replacing solvent molecule 2158 (atom 5865) with NA
# Replacing solvent molecule 325 (atom 4032) with NA
# Replacing solvent molecule 1046 (atom 4753) with NA
# Replacing solvent molecule 2879 (atom 6586) with NA
# Replacing solvent molecule 488 (atom 4195) with NA
# Replacing solvent molecule 86 (atom 3793) with NA
# Replacing solvent molecule 2286 (atom 5993) with NA
# Replacing solvent molecule 1345 (atom 5052) with NA
# Replacing solvent molecule 572 (atom 4279) with NA
# Replacing solvent molecule 1771 (atom 5478) with NA
# Replacing solvent molecule 2086 (atom 5793) with NA
# Replacing solvent molecule 1497 (atom 5204) with NA
# Replacing solvent molecule 462 (atom 4169) with NA
# Replacing solvent molecule 3453 (atom 7160) with NA
# Replacing solvent molecule 615 (atom 4322) with NA
# Replacing solvent molecule 3137 (atom 6844) with NA
# Replacing solvent molecule 59 (atom 3766) with NA
# Replacing solvent molecule 612 (atom 4319) with NA
# Replacing solvent molecule 1877 (atom 5584) with NA
# Replacing solvent molecule 2905 (atom 6612) with NA
# Replacing solvent molecule 1693 (atom 5400) with NA
# Replacing solvent molecule 1417 (atom 5124) with NA
# Replacing solvent molecule 3055 (atom 6762) with NA
# Replacing solvent molecule 1121 (atom 4828) with NA
# Replacing solvent molecule 1841 (atom 5548) with NA
# Replacing solvent molecule 1049 (atom 4756) with NA
# Replacing solvent molecule 2499 (atom 6206) with NA
# Replacing solvent molecule 1472 (atom 5179) with NA
# Replacing solvent molecule 584 (atom 4291) with NA
# Replacing solvent molecule 2120 (atom 5827) with NA
# Replacing solvent molecule 1713 (atom 5420) with NA
# Replacing solvent molecule 2659 (atom 6366) with NA
# Replacing solvent molecule 2375 (atom 6082) with NA
# Replacing solvent molecule 896 (atom 4603) with NA
# Replacing solvent molecule 1318 (atom 5025) with NA
# Replacing solvent molecule 3013 (atom 6720) with NA
# Replacing solvent molecule 3342 (atom 7049) with NA
# Replacing solvent molecule 335 (atom 4042) with NA
# Replacing solvent molecule 3082 (atom 6789) with NA
# Replacing solvent molecule 2955 (atom 6662) with NA
# Replacing solvent molecule 3379 (atom 7086) with NA
# Replacing solvent molecule 1016 (atom 4723) with NA
# Replacing solvent molecule 1925 (atom 5632) with NA
# Replacing solvent molecule 2463 (atom 6170) with NA
# Replacing solvent molecule 62 (atom 3769) with NA
# Replacing solvent molecule 694 (atom 4401) with NA
#
#
# GROMACS reminds you: "I originally implemented PME to prove that you didn't need it..." (Erik Lindahl)
#
#                       :-) GROMACS - gmx grompp, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx grompp -f /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/mdps/em_2.mdp -c comp1_mem_W_ion.gro -r comp1_mem_W_ion.gro -p topol_comp1_W.top -o em_comp1.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
# Setting the LD random seed to 1834844108
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'SAP6'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:  3922      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 1 Mb of data
# Will try to add 65 NA ions and 0 CL ions.
# Select a continuous group of solvent molecules
# Selected 10: 'W'
#
# Processing topology
# Replacing 65 solute molecules in topology file (topol_comp1_W.top)  by 65 NA and 0 CL ions.
# Number of degrees of freedom in T-Coupling group rest is 20523.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# GROMACS reminds you: "If Java had true garbage collection, most programs would delete themselves upon execution." (Robert Sewell)
#
#                       :-) GROMACS - gmx mdrun, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx mdrun -v -deffnm em_comp1 -nt 10 -pin on -pinstride 1 -pinoffset 30
# Setting the LD random seed to -1611399833
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'SAP6'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:  3922      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 1 Mb of data
# Reading file em_comp1.tpr, VERSION 2023.3 (single precision)
# Update groups can not be used for this system because an incompatible virtual site type is used
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 10 OpenMP threads
#
# Applying core pinning offset 30
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+01
#    Number of steps    =        10000
# Step=    0, Dmax= 1.0e-02 nm, Epot=  1.58270e+08 Fmax= 8.26826e+08, atom= 3470
# Step=    1, Dmax= 1.0e-02 nm, Epot=  1.19156e+08 Fmax= 1.91265e+08, atom= 271
# Step=    2, Dmax= 1.2e-02 nm, Epot=  7.71068e+07 Fmax= 4.14920e+07, atom= 1280
# Step=    3, Dmax= 1.4e-02 nm, Epot=  3.98859e+07 Fmax= 8.48306e+06, atom= 2568
# Step=    4, Dmax= 1.7e-02 nm, Epot=  1.61864e+07 Fmax= 1.64876e+06, atom= 113
# Step=    5, Dmax= 2.1e-02 nm, Epot=  5.61863e+06 Fmax= 3.21461e+05, atom= 2305
# Step=    6, Dmax= 2.5e-02 nm, Epot=  2.02206e+06 Fmax= 1.34936e+05, atom= 5498
# Step=    7, Dmax= 3.0e-02 nm, Epot=  1.14358e+06 Fmax= 6.37687e+04, atom= 3359
# Step=    8, Dmax= 3.6e-02 nm, Epot=  6.32413e+05 Fmax= 3.15293e+04, atom= 5498
# Step=    9, Dmax= 4.3e-02 nm, Epot=  3.45562e+05 Fmax= 1.96754e+04, atom= 854
# Step=   10, Dmax= 5.2e-02 nm, Epot=  2.06194e+05 Fmax= 2.77085e+04, atom= 7200
# Step=   11, Dmax= 6.2e-02 nm, Epot=  1.59573e+05 Fmax= 2.58711e+04, atom= 7200
# Step=   12, Dmax= 7.4e-02 nm, Epot=  1.20570e+05 Fmax= 1.70853e+04, atom= 854
# Step=   13, Dmax= 8.9e-02 nm, Epot=  7.79997e+04 Fmax= 8.23488e+03, atom= 858
# Step=   14, Dmax= 1.1e-01 nm, Epot=  3.72581e+04 Fmax= 1.82080e+04, atom= 854
# Step=   15, Dmax= 1.3e-01 nm, Epot=  2.55299e+04 Fmax= 8.04779e+03, atom= 1472
# Step=   16, Dmax= 1.5e-01 nm, Epot=  1.02513e+04 Fmax= 2.46285e+04, atom= 72
# Step=   17, Dmax= 1.8e-01 nm, Epot=  7.52186e+03 Fmax= 7.41614e+04, atom= 2829
# Step=   18, Dmax= 2.2e-01 nm, Epot=  1.07147e+03 Fmax= 3.22156e+04, atom= 2828
# Step=   19, Dmax= 2.7e-01 nm, Epot= -3.72301e+03 Fmax= 3.38023e+04, atom= 2834
# Step=   21, Dmax= 1.6e-01 nm, Epot= -1.05904e+04 Fmax= 1.56550e+04, atom= 2834
# Step=   22, Dmax= 1.9e-01 nm, Epot= -1.06138e+04 Fmax= 8.27154e+04, atom= 2829
# Step=   23, Dmax= 2.3e-01 nm, Epot= -1.86832e+04 Fmax= 1.71699e+04, atom= 2829
# Step=   25, Dmax= 1.4e-01 nm, Epot= -2.26590e+04 Fmax= 4.67830e+04, atom= 2828
# Step=   26, Dmax= 1.7e-01 nm, Epot= -2.54832e+04 Fmax= 8.56134e+03, atom= 2829
# Step=   27, Dmax= 2.0e-01 nm, Epot= -3.24953e+04 Fmax= 3.07169e+04, atom= 2828
# Step=   28, Dmax= 2.4e-01 nm, Epot= -3.64101e+04 Fmax= 2.32976e+04, atom= 2828
# Step=   30, Dmax= 1.4e-01 nm, Epot= -4.02954e+04 Fmax= 1.88806e+04, atom= 2834
# Step=   31, Dmax= 1.7e-01 nm, Epot= -4.11522e+04 Fmax= 3.46792e+04, atom= 2834
# Step=   32, Dmax= 2.1e-01 nm, Epot= -4.41542e+04 Fmax= 2.97539e+04, atom= 2834
# Step=   34, Dmax= 1.2e-01 nm, Epot= -4.76661e+04 Fmax= 8.26374e+03, atom= 2834
# Step=   35, Dmax= 1.5e-01 nm, Epot= -4.94333e+04 Fmax= 3.84514e+04, atom= 2834
# Step=   36, Dmax= 1.8e-01 nm, Epot= -5.39763e+04 Fmax= 1.64200e+04, atom= 2834
# Step=   38, Dmax= 1.1e-01 nm, Epot= -5.57651e+04 Fmax= 1.68596e+04, atom= 2834
# Step=   39, Dmax= 1.3e-01 nm, Epot= -5.71798e+04 Fmax= 2.24157e+04, atom= 2834
# Step=   40, Dmax= 1.5e-01 nm, Epot= -5.85987e+04 Fmax= 2.53845e+04, atom= 2834
# Step=   41, Dmax= 1.8e-01 nm, Epot= -5.94474e+04 Fmax= 3.13598e+04, atom= 2834
# Step=   42, Dmax= 2.2e-01 nm, Epot= -6.00732e+04 Fmax= 3.73171e+04, atom= 2834
# Step=   44, Dmax= 1.3e-01 nm, Epot= -6.46277e+04 Fmax= 3.65884e+03, atom= 2834
# Step=   45, Dmax= 1.6e-01 nm, Epot= -6.80287e+04 Fmax= 4.73262e+04, atom= 2834
# Step=   46, Dmax= 1.9e-01 nm, Epot= -7.44335e+04 Fmax= 1.18458e+04, atom= 2834
# Step=   48, Dmax= 1.1e-01 nm, Epot= -7.49868e+04 Fmax= 2.40035e+04, atom= 2834
# Step=   49, Dmax= 1.4e-01 nm, Epot= -7.65947e+04 Fmax= 1.83788e+04, atom= 2834
# Step=   51, Dmax= 8.3e-02 nm, Epot= -7.81415e+04 Fmax= 7.31846e+03, atom= 2834
# Step=   52, Dmax= 9.9e-02 nm, Epot= -7.90541e+04 Fmax= 2.28105e+04, atom= 2834
# Step=   53, Dmax= 1.2e-01 nm, Epot= -8.07667e+04 Fmax= 1.41283e+04, atom= 2834
# Step=   55, Dmax= 7.1e-02 nm, Epot= -8.19066e+04 Fmax= 7.75884e+03, atom= 2834
# Step=   56, Dmax= 8.6e-02 nm, Epot= -8.27268e+04 Fmax= 1.90962e+04, atom= 2834
# Step=   57, Dmax= 1.0e-01 nm, Epot= -8.40518e+04 Fmax= 1.24980e+04, atom= 2834
# Step=   59, Dmax= 6.2e-02 nm, Epot= -8.50623e+04 Fmax= 6.73002e+03, atom= 2834
# Step=   60, Dmax= 7.4e-02 nm, Epot= -8.59916e+04 Fmax= 1.57545e+04, atom= 2834
# Step=   61, Dmax= 8.9e-02 nm, Epot= -8.70485e+04 Fmax= 1.18698e+04, atom= 2834
# Step=   62, Dmax= 1.1e-01 nm, Epot= -8.73728e+04 Fmax= 2.07676e+04, atom= 2834
# Step=   63, Dmax= 1.3e-01 nm, Epot= -8.83631e+04 Fmax= 1.89303e+04, atom= 2834
# Step=   65, Dmax= 7.7e-02 nm, Epot= -8.97914e+04 Fmax= 4.66432e+03, atom= 2834
# Step=   66, Dmax= 9.2e-02 nm, Epot= -9.05119e+04 Fmax= 2.44246e+04, atom= 2834
# Step=   67, Dmax= 1.1e-01 nm, Epot= -9.24340e+04 Fmax= 9.62063e+03, atom= 2834
# Step=   69, Dmax= 6.6e-02 nm, Epot= -9.31133e+04 Fmax= 1.10855e+04, atom= 2834
# Step=   70, Dmax= 8.0e-02 nm, Epot= -9.37097e+04 Fmax= 1.32782e+04, atom= 2834
# Step=   71, Dmax= 9.6e-02 nm, Epot= -9.41966e+04 Fmax= 1.64287e+04, atom= 2834
# Step=   72, Dmax= 1.1e-01 nm, Epot= -9.46340e+04 Fmax= 1.87785e+04, atom= 2834
# Step=   73, Dmax= 1.4e-01 nm, Epot= -9.47125e+04 Fmax= 2.38888e+04, atom= 2834
# Step=   74, Dmax= 1.7e-01 nm, Epot= -9.48632e+04 Fmax= 2.69523e+04, atom= 2834
# Step=   76, Dmax= 9.9e-02 nm, Epot= -9.73935e+04 Fmax= 3.72850e+03, atom= 2834
# Step=   78, Dmax= 5.9e-02 nm, Epot= -9.82102e+04 Fmax= 1.41173e+04, atom= 2834
# Step=   79, Dmax= 7.1e-02 nm, Epot= -9.91275e+04 Fmax= 8.02739e+03, atom= 2834
# Step=   81, Dmax= 4.3e-02 nm, Epot= -9.97247e+04 Fmax= 5.03161e+03, atom= 2834
# Step=   82, Dmax= 5.1e-02 nm, Epot= -1.00212e+05 Fmax= 1.11052e+04, atom= 2834
# Step=   83, Dmax= 6.2e-02 nm, Epot= -1.00898e+05 Fmax= 7.76925e+03, atom= 2834
# Step=   84, Dmax= 7.4e-02 nm, Epot= -1.00930e+05 Fmax= 1.53121e+04, atom= 2834
# Step=   85, Dmax= 8.9e-02 nm, Epot= -1.01738e+05 Fmax= 1.19444e+04, atom= 2834
# Step=   87, Dmax= 5.3e-02 nm, Epot= -1.02617e+05 Fmax= 4.60816e+03, atom= 2834
# Step=   89, Dmax= 3.2e-02 nm, Epot= -1.03106e+05 Fmax= 5.06219e+03, atom= 2834
# Step=   90, Dmax= 3.8e-02 nm, Epot= -1.03543e+05 Fmax= 6.96893e+03, atom= 2834
# Step=   91, Dmax= 4.6e-02 nm, Epot= -1.03988e+05 Fmax= 7.55548e+03, atom= 3077
# Step=   92, Dmax= 5.5e-02 nm, Epot= -1.04298e+05 Fmax= 9.88629e+03, atom= 3077
# Step=   93, Dmax= 6.6e-02 nm, Epot= -1.04666e+05 Fmax= 1.12980e+04, atom= 3077
# Step=   94, Dmax= 7.9e-02 nm, Epot= -1.04832e+05 Fmax= 1.39293e+04, atom= 3077
# Step=   95, Dmax= 9.5e-02 nm, Epot= -1.05017e+05 Fmax= 1.67031e+04, atom= 3077
# Step=   97, Dmax= 5.7e-02 nm, Epot= -1.06409e+05 Fmax= 1.99928e+03, atom= 3077
# Step=   98, Dmax= 6.9e-02 nm, Epot= -1.07104e+05 Fmax= 2.25335e+04, atom= 3077
# Step=   99, Dmax= 8.2e-02 nm, Epot= -1.08684e+05 Fmax= 5.93058e+03, atom= 3077
# Step=  101, Dmax= 4.9e-02 nm, Epot= -1.08987e+05 Fmax= 9.97722e+03, atom= 3077
# Step=  102, Dmax= 5.9e-02 nm, Epot= -1.09380e+05 Fmax= 8.78285e+03, atom= 3077
# Step=  103, Dmax= 7.1e-02 nm, Epot= -1.09521e+05 Fmax= 1.38464e+04, atom= 3077
# Step=  104, Dmax= 8.5e-02 nm, Epot= -1.09882e+05 Fmax= 1.31463e+04, atom= 3077
# Step=  106, Dmax= 5.1e-02 nm, Epot= -1.10563e+05 Fmax= 2.88335e+03, atom= 3077
# Step=  107, Dmax= 6.2e-02 nm, Epot= -1.10984e+05 Fmax= 1.58916e+04, atom= 3077
# Step=  108, Dmax= 7.4e-02 nm, Epot= -1.11776e+05 Fmax= 7.07858e+03, atom= 3077
# Step=  110, Dmax= 4.4e-02 nm, Epot= -1.12088e+05 Fmax= 6.74041e+03, atom= 3077
# Step=  111, Dmax= 5.3e-02 nm, Epot= -1.12315e+05 Fmax= 1.00498e+04, atom= 3077
# Step=  112, Dmax= 6.4e-02 nm, Epot= -1.12608e+05 Fmax= 9.91989e+03, atom= 3077
# Step=  113, Dmax= 7.7e-02 nm, Epot= -1.12686e+05 Fmax= 1.42808e+04, atom= 3077
# Step=  114, Dmax= 9.2e-02 nm, Epot= -1.12923e+05 Fmax= 1.46091e+04, atom= 3077
# Step=  116, Dmax= 5.5e-02 nm, Epot= -1.13683e+05 Fmax= 2.58170e+03, atom= 3077
# Step=  117, Dmax= 6.6e-02 nm, Epot= -1.13965e+05 Fmax= 1.74713e+04, atom= 3077
# Step=  118, Dmax= 7.9e-02 nm, Epot= -1.14856e+05 Fmax= 7.14165e+03, atom= 3077
# Step=  120, Dmax= 4.8e-02 nm, Epot= -1.15099e+05 Fmax= 7.67572e+03, atom= 3077
# Step=  121, Dmax= 5.7e-02 nm, Epot= -1.15271e+05 Fmax= 1.02945e+04, atom= 3077
# Step=  122, Dmax= 6.9e-02 nm, Epot= -1.15473e+05 Fmax= 1.10962e+04, atom= 3077
# Step=  123, Dmax= 8.2e-02 nm, Epot= -1.15508e+05 Fmax= 1.47872e+04, atom= 3077
# Step=  124, Dmax= 9.9e-02 nm, Epot= -1.15617e+05 Fmax= 1.61483e+04, atom= 3077
# Step=  126, Dmax= 5.9e-02 nm, Epot= -1.16488e+05 Fmax= 2.28005e+03, atom= 3077
# Step=  127, Dmax= 7.1e-02 nm, Epot= -1.16611e+05 Fmax= 1.91615e+04, atom= 3077
# Step=  128, Dmax= 8.5e-02 nm, Epot= -1.17642e+05 Fmax= 7.21133e+03, atom= 3077
# Step=  130, Dmax= 5.1e-02 nm, Epot= -1.17812e+05 Fmax= 8.68739e+03, atom= 3077
# Step=  131, Dmax= 6.1e-02 nm, Epot= -1.17953e+05 Fmax= 1.05449e+04, atom= 3077
# Step=  132, Dmax= 7.4e-02 nm, Epot= -1.18052e+05 Fmax= 1.23792e+04, atom= 3077
# Step=  133, Dmax= 8.8e-02 nm, Epot= -1.18067e+05 Fmax= 1.53087e+04, atom= 3077
# Step=  135, Dmax= 5.3e-02 nm, Epot= -1.18833e+05 Fmax= 1.37670e+03, atom= 3077
# Step=  136, Dmax= 6.4e-02 nm, Epot= -1.19156e+05 Fmax= 1.95365e+04, atom= 3077
# Step=  137, Dmax= 7.6e-02 nm, Epot= -1.20312e+05 Fmax= 4.86983e+03, atom= 3077
# Step=  139, Dmax= 4.6e-02 nm, Epot= -1.20388e+05 Fmax= 9.53383e+03, atom= 3077
# Step=  140, Dmax= 5.5e-02 nm, Epot= -1.20641e+05 Fmax= 7.56333e+03, atom= 3077
# Step=  142, Dmax= 3.3e-02 nm, Epot= -1.20910e+05 Fmax= 2.72380e+03, atom= 3077
# Step=  143, Dmax= 4.0e-02 nm, Epot= -1.21064e+05 Fmax= 9.37712e+03, atom= 3077
# Step=  144, Dmax= 4.8e-02 nm, Epot= -1.21375e+05 Fmax= 5.40206e+03, atom= 3077
# Step=  146, Dmax= 2.9e-02 nm, Epot= -1.21563e+05 Fmax= 3.40519e+03, atom= 3077
# Step=  147, Dmax= 3.4e-02 nm, Epot= -1.21699e+05 Fmax= 7.34499e+03, atom= 3077
# Step=  148, Dmax= 4.1e-02 nm, Epot= -1.21913e+05 Fmax= 5.37652e+03, atom= 3077
# Step=  149, Dmax= 4.9e-02 nm, Epot= -1.21926e+05 Fmax= 1.00511e+04, atom= 3077
# Step=  150, Dmax= 5.9e-02 nm, Epot= -1.22163e+05 Fmax= 8.31396e+03, atom= 3077
# Step=  152, Dmax= 3.5e-02 nm, Epot= -1.22462e+05 Fmax= 2.72535e+03, atom= 3077
# Step=  153, Dmax= 4.3e-02 nm, Epot= -1.22524e+05 Fmax= 1.02899e+04, atom= 3077
# Step=  154, Dmax= 5.1e-02 nm, Epot= -1.22882e+05 Fmax= 5.57768e+03, atom= 3077
# Step=  156, Dmax= 3.1e-02 nm, Epot= -1.23060e+05 Fmax= 3.89104e+03, atom= 3077
# Step=  157, Dmax= 3.7e-02 nm, Epot= -1.23138e+05 Fmax= 7.63531e+03, atom= 3077
# Step=  158, Dmax= 4.4e-02 nm, Epot= -1.23337e+05 Fmax= 6.03892e+03, atom= 3077
# Step=  160, Dmax= 2.6e-02 nm, Epot= -1.23546e+05 Fmax= 2.21320e+03, atom= 3077
# Step=  161, Dmax= 3.2e-02 nm, Epot= -1.23683e+05 Fmax= 7.48624e+03, atom= 3077
# Step=  162, Dmax= 3.8e-02 nm, Epot= -1.23928e+05 Fmax= 4.37747e+03, atom= 3077
# Step=  164, Dmax= 2.3e-02 nm, Epot= -1.24083e+05 Fmax= 2.67833e+03, atom= 3077
# Step=  165, Dmax= 2.7e-02 nm, Epot= -1.24196e+05 Fmax= 5.95356e+03, atom= 3077
# Step=  166, Dmax= 3.3e-02 nm, Epot= -1.24376e+05 Fmax= 4.23660e+03, atom= 3077
# Step=  167, Dmax= 4.0e-02 nm, Epot= -1.24378e+05 Fmax= 8.14211e+03, atom= 3077
# Step=  168, Dmax= 4.7e-02 nm, Epot= -1.24581e+05 Fmax= 6.56625e+03, atom= 3077
# Step=  170, Dmax= 2.8e-02 nm, Epot= -1.24831e+05 Fmax= 2.29721e+03, atom= 3077
# Step=  171, Dmax= 3.4e-02 nm, Epot= -1.24853e+05 Fmax= 8.13747e+03, atom= 3077
# Step=  172, Dmax= 4.1e-02 nm, Epot= -1.25157e+05 Fmax= 4.60694e+03, atom= 3077
# Step=  174, Dmax= 2.5e-02 nm, Epot= -1.25316e+05 Fmax= 2.98152e+03, atom= 3077
# Step=  175, Dmax= 3.0e-02 nm, Epot= -1.25355e+05 Fmax= 6.28425e+03, atom= 3077
# Step=  176, Dmax= 3.5e-02 nm, Epot= -1.25543e+05 Fmax= 4.67418e+03, atom= 3077
# Step=  178, Dmax= 2.1e-02 nm, Epot= -1.25729e+05 Fmax= 2.03625e+03, atom= 1408
# Step=  179, Dmax= 2.6e-02 nm, Epot= -1.25803e+05 Fmax= 6.00747e+03, atom= 1408
# Step=  180, Dmax= 3.1e-02 nm, Epot= -1.26018e+05 Fmax= 3.67150e+03, atom= 1408
# Step=  182, Dmax= 1.8e-02 nm, Epot= -1.26153e+05 Fmax= 2.15632e+03, atom= 1408
# Step=  183, Dmax= 2.2e-02 nm, Epot= -1.26257e+05 Fmax= 4.86058e+03, atom= 1408
# Step=  184, Dmax= 2.6e-02 nm, Epot= -1.26406e+05 Fmax= 3.53966e+03, atom= 1408
# Step=  185, Dmax= 3.2e-02 nm, Epot= -1.26441e+05 Fmax= 6.57780e+03, atom= 1408
# Step=  186, Dmax= 3.8e-02 nm, Epot= -1.26598e+05 Fmax= 5.51880e+03, atom= 1408
# Step=  188, Dmax= 2.3e-02 nm, Epot= -1.26784e+05 Fmax= 1.70013e+03, atom= 1408
# Step=  189, Dmax= 2.7e-02 nm, Epot= -1.26893e+05 Fmax= 6.92720e+03, atom= 1408
# Step=  190, Dmax= 3.3e-02 nm, Epot= -1.27112e+05 Fmax= 3.45524e+03, atom= 1408
# Step=  192, Dmax= 2.0e-02 nm, Epot= -1.27224e+05 Fmax= 2.79920e+03, atom= 1408
# Step=  193, Dmax= 2.4e-02 nm, Epot= -1.27316e+05 Fmax= 4.72950e+03, atom= 1408
# Step=  194, Dmax= 2.8e-02 nm, Epot= -1.27430e+05 Fmax= 4.28394e+03, atom= 1408
# Step=  195, Dmax= 3.4e-02 nm, Epot= -1.27479e+05 Fmax= 6.57379e+03, atom= 1408
# Step=  196, Dmax= 4.1e-02 nm, Epot= -1.27586e+05 Fmax= 6.40769e+03, atom= 1408
# Step=  198, Dmax= 2.5e-02 nm, Epot= -1.27782e+05 Fmax= 1.33970e+03, atom= 1408
# Step=  199, Dmax= 2.9e-02 nm, Epot= -1.27937e+05 Fmax= 7.90939e+03, atom= 1408
# Step=  200, Dmax= 3.5e-02 nm, Epot= -1.28175e+05 Fmax= 3.22846e+03, atom= 1408
# Step=  202, Dmax= 2.1e-02 nm, Epot= -1.28271e+05 Fmax= 3.48677e+03, atom= 1408
# Step=  203, Dmax= 2.5e-02 nm, Epot= -1.28356e+05 Fmax= 4.59546e+03, atom= 1408
# Step=  204, Dmax= 3.1e-02 nm, Epot= -1.28442e+05 Fmax= 5.07771e+03, atom= 1408
# Step=  205, Dmax= 3.7e-02 nm, Epot= -1.28500e+05 Fmax= 6.57711e+03, atom= 1408
# Step=  206, Dmax= 4.4e-02 nm, Epot= -1.28564e+05 Fmax= 7.35560e+03, atom= 1408
# Step=  207, Dmax= 5.3e-02 nm, Epot= -1.28572e+05 Fmax= 9.46086e+03, atom= 1408
# Step=  208, Dmax= 6.3e-02 nm, Epot= -1.28592e+05 Fmax= 1.06147e+04, atom= 1408
# Step=  210, Dmax= 3.8e-02 nm, Epot= -1.28982e+05 Fmax= 1.33439e+03, atom= 1408
# Step=  211, Dmax= 4.6e-02 nm, Epot= -1.28995e+05 Fmax= 1.28772e+04, atom= 1408
# Step=  212, Dmax= 5.5e-02 nm, Epot= -1.29482e+05 Fmax= 4.26412e+03, atom= 1408
# Step=  214, Dmax= 3.3e-02 nm, Epot= -1.29530e+05 Fmax= 6.13045e+03, atom= 1408
# Step=  215, Dmax= 3.9e-02 nm, Epot= -1.29612e+05 Fmax= 6.37593e+03, atom= 1408
# Step=  216, Dmax= 4.7e-02 nm, Epot= -1.29614e+05 Fmax= 8.56871e+03, atom= 1408
# Step=  217, Dmax= 5.7e-02 nm, Epot= -1.29665e+05 Fmax= 9.46710e+03, atom= 1408
# Step=  219, Dmax= 3.4e-02 nm, Epot= -1.29960e+05 Fmax= 1.42083e+03, atom= 1408
# Step=  221, Dmax= 2.0e-02 nm, Epot= -1.30081e+05 Fmax= 5.12041e+03, atom= 1408
# Step=  222, Dmax= 2.5e-02 nm, Epot= -1.30198e+05 Fmax= 2.68687e+03, atom= 1408
# Step=  223, Dmax= 2.9e-02 nm, Epot= -1.30235e+05 Fmax= 6.68480e+03, atom= 1408
# Step=  224, Dmax= 3.5e-02 nm, Epot= -1.30369e+05 Fmax= 4.52256e+03, atom= 1408
# Step=  226, Dmax= 2.1e-02 nm, Epot= -1.30474e+05 Fmax= 2.17333e+03, atom= 1408
# Step=  227, Dmax= 2.5e-02 nm, Epot= -1.30539e+05 Fmax= 5.82805e+03, atom= 1408
# Step=  228, Dmax= 3.1e-02 nm, Epot= -1.30660e+05 Fmax= 3.80666e+03, atom= 1408
# Step=  230, Dmax= 1.8e-02 nm, Epot= -1.30748e+05 Fmax= 1.98840e+03, atom= 1408
# Step=  231, Dmax= 2.2e-02 nm, Epot= -1.30826e+05 Fmax= 4.99911e+03, atom= 1408
# Step=  232, Dmax= 2.6e-02 nm, Epot= -1.30928e+05 Fmax= 3.35665e+03, atom= 1408
# Step=  233, Dmax= 3.2e-02 nm, Epot= -1.30949e+05 Fmax= 6.71507e+03, atom= 1408
# Step=  234, Dmax= 3.8e-02 nm, Epot= -1.31061e+05 Fmax= 5.32000e+03, atom= 1408
# Step=  236, Dmax= 2.3e-02 nm, Epot= -1.31182e+05 Fmax= 1.87105e+03, atom= 1408
# Step=  237, Dmax= 2.7e-02 nm, Epot= -1.31239e+05 Fmax= 6.71063e+03, atom= 1408
# Step=  238, Dmax= 3.3e-02 nm, Epot= -1.31385e+05 Fmax= 3.63325e+03, atom= 1408
# Step=  240, Dmax= 2.0e-02 nm, Epot= -1.31465e+05 Fmax= 2.58869e+03, atom= 1408
# Step=  241, Dmax= 2.4e-02 nm, Epot= -1.31523e+05 Fmax= 4.91439e+03, atom= 1408
# Step=  242, Dmax= 2.8e-02 nm, Epot= -1.31609e+05 Fmax= 4.05555e+03, atom= 1408
# Step=  243, Dmax= 3.4e-02 nm, Epot= -1.31625e+05 Fmax= 6.76011e+03, atom= 1408
# Step=  244, Dmax= 4.1e-02 nm, Epot= -1.31711e+05 Fmax= 6.16232e+03, atom= 1408
# Step=  246, Dmax= 2.4e-02 nm, Epot= -1.31856e+05 Fmax= 1.55866e+03, atom= 1408
# Step=  247, Dmax= 2.9e-02 nm, Epot= -1.31909e+05 Fmax= 7.64190e+03, atom= 1408
# Step=  248, Dmax= 3.5e-02 nm, Epot= -1.32089e+05 Fmax= 3.45997e+03, atom= 1408
# Step=  250, Dmax= 2.1e-02 nm, Epot= -1.32159e+05 Fmax= 3.22064e+03, atom= 1408
# Step=  251, Dmax= 2.5e-02 nm, Epot= -1.32209e+05 Fmax= 4.83574e+03, atom= 1408
# Step=  252, Dmax= 3.0e-02 nm, Epot= -1.32276e+05 Fmax= 4.79433e+03, atom= 1408
# Step=  253, Dmax= 3.7e-02 nm, Epot= -1.32294e+05 Fmax= 6.81847e+03, atom= 1408
# Step=  254, Dmax= 4.4e-02 nm, Epot= -1.32349e+05 Fmax= 7.05630e+03, atom= 1408
# Step=  256, Dmax= 2.6e-02 nm, Epot= -1.32524e+05 Fmax= 1.23346e+03, atom= 1408
# Step=  257, Dmax= 3.2e-02 nm, Epot= -1.32588e+05 Fmax= 8.62278e+03, atom= 1408
# Step=  258, Dmax= 3.8e-02 nm, Epot= -1.32808e+05 Fmax= 3.28971e+03, atom= 1408
# Step=  260, Dmax= 2.3e-02 nm, Epot= -1.32866e+05 Fmax= 3.88605e+03, atom= 1408
# Step=  261, Dmax= 2.7e-02 nm, Epot= -1.32916e+05 Fmax= 4.76596e+03, atom= 1408
# Step=  262, Dmax= 3.3e-02 nm, Epot= -1.32960e+05 Fmax= 5.57357e+03, atom= 1408
# Step=  263, Dmax= 3.9e-02 nm, Epot= -1.32986e+05 Fmax= 6.89639e+03, atom= 1408
# Step=  264, Dmax= 4.7e-02 nm, Epot= -1.33004e+05 Fmax= 8.00185e+03, atom= 1408
# Step=  266, Dmax= 2.8e-02 nm, Epot= -1.33216e+05 Fmax= 8.98948e+02, atom= 1408
# Step=  267, Dmax= 3.4e-02 nm, Epot= -1.33327e+05 Fmax= 9.63925e+03, atom= 1408
# Step=  268, Dmax= 4.1e-02 nm, Epot= -1.33596e+05 Fmax= 3.13639e+03, atom= 1408
# Step=  270, Dmax= 2.4e-02 nm, Epot= -1.33637e+05 Fmax= 4.57829e+03, atom= 1408
# Step=  271, Dmax= 2.9e-02 nm, Epot= -1.33694e+05 Fmax= 4.71801e+03, atom= 1408
# Step=  272, Dmax= 3.5e-02 nm, Epot= -1.33709e+05 Fmax= 6.38561e+03, atom= 1408
# Step=  273, Dmax= 4.2e-02 nm, Epot= -1.33750e+05 Fmax= 7.00647e+03, atom= 1408
# Step=  275, Dmax= 2.5e-02 nm, Epot= -1.33914e+05 Fmax= 1.05474e+03, atom= 1408
# Step=  276, Dmax= 3.0e-02 nm, Epot= -1.33964e+05 Fmax= 8.76406e+03, atom= 1408
# Step=  277, Dmax= 3.6e-02 nm, Epot= -1.34190e+05 Fmax= 2.90125e+03, atom= 1408
# Step=  279, Dmax= 2.2e-02 nm, Epot= -1.34235e+05 Fmax= 4.05530e+03, atom= 1408
# Step=  280, Dmax= 2.6e-02 nm, Epot= -1.34286e+05 Fmax= 4.24508e+03, atom= 1408
# Step=  281, Dmax= 3.2e-02 nm, Epot= -1.34310e+05 Fmax= 5.75940e+03, atom= 1408
# Step=  282, Dmax= 3.8e-02 nm, Epot= -1.34350e+05 Fmax= 6.19340e+03, atom= 1408
# Step=  284, Dmax= 2.3e-02 nm, Epot= -1.34487e+05 Fmax= 9.59378e+02, atom= 1408
# Step=  285, Dmax= 2.7e-02 nm, Epot= -1.34574e+05 Fmax= 7.52074e+03, atom= 1408
# Step=  286, Dmax= 3.3e-02 nm, Epot= -1.34746e+05 Fmax= 2.75685e+03, atom= 1408
# Step=  288, Dmax= 2.0e-02 nm, Epot= -1.34793e+05 Fmax= 3.42586e+03, atom= 1408
# Step=  289, Dmax= 2.4e-02 nm, Epot= -1.34837e+05 Fmax= 4.03339e+03, atom= 1408
# Step=  290, Dmax= 2.8e-02 nm, Epot= -1.34873e+05 Fmax= 4.87650e+03, atom= 1408
# Step=  291, Dmax= 3.4e-02 nm, Epot= -1.34901e+05 Fmax= 5.86818e+03, atom= 1408
# Step=  292, Dmax= 4.1e-02 nm, Epot= -1.34915e+05 Fmax= 6.97157e+03, atom= 1408
# Step=  294, Dmax= 2.4e-02 nm, Epot= -1.35079e+05 Fmax= 7.10510e+02, atom= 1408
# Step=  295, Dmax= 2.9e-02 nm, Epot= -1.35215e+05 Fmax= 8.35481e+03, atom= 1408
# Step=  296, Dmax= 3.5e-02 nm, Epot= -1.35422e+05 Fmax= 2.67021e+03, atom= 1408
# Step=  298, Dmax= 2.1e-02 nm, Epot= -1.35458e+05 Fmax= 3.97927e+03, atom= 1408
# Step=  299, Dmax= 2.5e-02 nm, Epot= -1.35506e+05 Fmax= 4.03491e+03, atom= 1408
# Step=  300, Dmax= 3.0e-02 nm, Epot= -1.35522e+05 Fmax= 5.53766e+03, atom= 1408
# Step=  301, Dmax= 3.6e-02 nm, Epot= -1.35559e+05 Fmax= 6.00268e+03, atom= 1408
# Step=  303, Dmax= 2.2e-02 nm, Epot= -1.35684e+05 Fmax= 9.37166e+02, atom= 1408
# Step=  304, Dmax= 2.6e-02 nm, Epot= -1.35738e+05 Fmax= 7.50352e+03, atom= 1408
# Step=  305, Dmax= 3.1e-02 nm, Epot= -1.35909e+05 Fmax= 2.52845e+03, atom= 1408
# Step=  307, Dmax= 1.9e-02 nm, Epot= -1.35948e+05 Fmax= 3.46634e+03, atom= 1408
# Step=  308, Dmax= 2.3e-02 nm, Epot= -1.35991e+05 Fmax= 3.68805e+03, atom= 1408
# Step=  309, Dmax= 2.7e-02 nm, Epot= -1.36015e+05 Fmax= 4.93366e+03, atom= 1408
# Step=  310, Dmax= 3.3e-02 nm, Epot= -1.36049e+05 Fmax= 5.37088e+03, atom= 1408
# Step=  312, Dmax= 2.0e-02 nm, Epot= -1.36155e+05 Fmax= 8.00978e+02, atom= 1408
# Step=  313, Dmax= 2.3e-02 nm, Epot= -1.36247e+05 Fmax= 6.51197e+03, atom= 1408
# Step=  314, Dmax= 2.8e-02 nm, Epot= -1.36380e+05 Fmax= 2.35600e+03, atom= 1408
# Step=  316, Dmax= 1.7e-02 nm, Epot= -1.36421e+05 Fmax= 2.97491e+03, atom= 1408
# Step=  317, Dmax= 2.0e-02 nm, Epot= -1.36460e+05 Fmax= 3.45412e+03, atom= 1408
# Step=  318, Dmax= 2.4e-02 nm, Epot= -1.36491e+05 Fmax= 4.22897e+03, atom= 1408
# Step=  319, Dmax= 2.9e-02 nm, Epot= -1.36519e+05 Fmax= 5.02957e+03, atom= 1408
# Step=  320, Dmax= 3.5e-02 nm, Epot= -1.36533e+05 Fmax= 6.04209e+03, atom= 1408
# Step=  321, Dmax= 4.2e-02 nm, Epot= -1.36536e+05 Fmax= 7.29637e+03, atom= 1408
# Step=  323, Dmax= 2.5e-02 nm, Epot= -1.36706e+05 Fmax= 7.36552e+02, atom= 1408
# Step=  324, Dmax= 3.0e-02 nm, Epot= -1.36751e+05 Fmax= 9.07031e+03, atom= 1408
# Step=  325, Dmax= 3.6e-02 nm, Epot= -1.36991e+05 Fmax= 2.57315e+03, atom= 1408
# Step=  327, Dmax= 2.2e-02 nm, Epot= -1.37012e+05 Fmax= 4.35094e+03, atom= 1408
# Step=  328, Dmax= 2.6e-02 nm, Epot= -1.37060e+05 Fmax= 3.92540e+03, atom= 1408
# Step=  330, Dmax= 1.6e-02 nm, Epot= -1.37127e+05 Fmax= 1.03315e+03, atom= 1408
# Step=  331, Dmax= 1.9e-02 nm, Epot= -1.37181e+05 Fmax= 4.86912e+03, atom= 1408
# Step=  332, Dmax= 2.3e-02 nm, Epot= -1.37263e+05 Fmax= 2.25996e+03, atom= 1408
# Step=  334, Dmax= 1.4e-02 nm, Epot= -1.37303e+05 Fmax= 2.01952e+03, atom= 1408
# Step=  335, Dmax= 1.6e-02 nm, Epot= -1.37338e+05 Fmax= 3.14049e+03, atom= 1408
# Step=  336, Dmax= 2.0e-02 nm, Epot= -1.37379e+05 Fmax= 3.02921e+03, atom= 1408
# Step=  337, Dmax= 2.3e-02 nm, Epot= -1.37399e+05 Fmax= 4.40066e+03, atom= 1408
# Step=  338, Dmax= 2.8e-02 nm, Epot= -1.37436e+05 Fmax= 4.48862e+03, atom= 1408
# Step=  340, Dmax= 1.7e-02 nm, Epot= -1.37515e+05 Fmax= 8.36056e+02, atom= 1408
# Step=  341, Dmax= 2.0e-02 nm, Epot= -1.37581e+05 Fmax= 5.49733e+03, atom= 1408
# Step=  342, Dmax= 2.4e-02 nm, Epot= -1.37680e+05 Fmax= 2.15660e+03, atom= 1408
# Step=  344, Dmax= 1.5e-02 nm, Epot= -1.37717e+05 Fmax= 2.44330e+03, atom= 1408
# Step=  345, Dmax= 1.8e-02 nm, Epot= -1.37750e+05 Fmax= 3.09692e+03, atom= 1408
# Step=  346, Dmax= 2.1e-02 nm, Epot= -1.37782e+05 Fmax= 3.53300e+03, atom= 1408
# Step=  347, Dmax= 2.5e-02 nm, Epot= -1.37805e+05 Fmax= 4.44545e+03, atom= 1408
# Step=  348, Dmax= 3.0e-02 nm, Epot= -1.37827e+05 Fmax= 5.10649e+03, atom= 1408
# Step=  349, Dmax= 3.6e-02 nm, Epot= -1.37829e+05 Fmax= 6.38567e+03, atom= 1408
# Step=  351, Dmax= 2.2e-02 nm, Epot= -1.37963e+05 Fmax= 5.34566e+02, atom= 1408
# Step=  352, Dmax= 2.6e-02 nm, Epot= -1.38072e+05 Fmax= 7.88146e+03, atom= 1408
# Step=  353, Dmax= 3.1e-02 nm, Epot= -1.38259e+05 Fmax= 2.14324e+03, atom= 1408
# Step=  355, Dmax= 1.9e-02 nm, Epot= -1.38281e+05 Fmax= 3.81605e+03, atom= 1408
# Step=  356, Dmax= 2.3e-02 nm, Epot= -1.38324e+05 Fmax= 3.32210e+03, atom= 1408
# Step=  358, Dmax= 1.4e-02 nm, Epot= -1.38376e+05 Fmax= 9.52750e+02, atom= 1408
# Step=  359, Dmax= 1.6e-02 nm, Epot= -1.38426e+05 Fmax= 4.15299e+03, atom= 1408
# Step=  360, Dmax= 2.0e-02 nm, Epot= -1.38490e+05 Fmax= 1.99532e+03, atom= 1408
# Step=  362, Dmax= 1.2e-02 nm, Epot= -1.38525e+05 Fmax= 1.69903e+03, atom= 1408
# Step=  363, Dmax= 1.4e-02 nm, Epot= -1.38558e+05 Fmax= 2.74446e+03, atom= 1408
# Step=  364, Dmax= 1.7e-02 nm, Epot= -1.38594e+05 Fmax= 2.57941e+03, atom= 1408
# Step=  365, Dmax= 2.0e-02 nm, Epot= -1.38615e+05 Fmax= 3.81944e+03, atom= 1408
# Step=  366, Dmax= 2.4e-02 nm, Epot= -1.38649e+05 Fmax= 3.84956e+03, atom= 1408
# Step=  367, Dmax= 2.9e-02 nm, Epot= -1.38651e+05 Fmax= 5.36635e+03, atom= 1408
# Step=  368, Dmax= 3.5e-02 nm, Epot= -1.38675e+05 Fmax= 5.68063e+03, atom= 1408
# Step=  370, Dmax= 2.1e-02 nm, Epot= -1.38785e+05 Fmax= 9.20942e+02, atom= 1408
# Step=  371, Dmax= 2.5e-02 nm, Epot= -1.38797e+05 Fmax= 6.96095e+03, atom= 1408
# Step=  372, Dmax= 3.0e-02 nm, Epot= -1.38939e+05 Fmax= 2.52465e+03, atom= 1408
# Step=  374, Dmax= 1.8e-02 nm, Epot= -1.38966e+05 Fmax= 3.19380e+03, atom= 1408
# Step=  375, Dmax= 2.2e-02 nm, Epot= -1.38993e+05 Fmax= 3.67382e+03, atom= 1408
# Step=  376, Dmax= 2.6e-02 nm, Epot= -1.39008e+05 Fmax= 4.56332e+03, atom= 1408
# Step=  377, Dmax= 3.1e-02 nm, Epot= -1.39023e+05 Fmax= 5.32990e+03, atom= 1408
# Step=  379, Dmax= 1.9e-02 nm, Epot= -1.39121e+05 Fmax= 6.28990e+02, atom= 1408
# Step=  380, Dmax= 2.3e-02 nm, Epot= -1.39184e+05 Fmax= 6.55373e+03, atom= 1408
# Step=  381, Dmax= 2.7e-02 nm, Epot= -1.39316e+05 Fmax= 2.05660e+03, atom= 1408
# Step=  383, Dmax= 1.6e-02 nm, Epot= -1.39342e+05 Fmax= 3.07342e+03, atom= 1408
# Step=  384, Dmax= 1.9e-02 nm, Epot= -1.39373e+05 Fmax= 3.08189e+03, atom= 1408
# Step=  385, Dmax= 2.3e-02 nm, Epot= -1.39386e+05 Fmax= 4.30356e+03, atom= 1408
# Step=  386, Dmax= 2.8e-02 nm, Epot= -1.39412e+05 Fmax= 4.55868e+03, atom= 1408
# Step=  388, Dmax= 1.7e-02 nm, Epot= -1.39488e+05 Fmax= 7.38694e+02, atom= 1408
# Step=  389, Dmax= 2.0e-02 nm, Epot= -1.39536e+05 Fmax= 5.60365e+03, atom= 1408
# Step=  390, Dmax= 2.4e-02 nm, Epot= -1.39635e+05 Fmax= 2.01068e+03, atom= 1408
# Step=  392, Dmax= 1.5e-02 nm, Epot= -1.39663e+05 Fmax= 2.58019e+03, atom= 1408
# Step=  393, Dmax= 1.7e-02 nm, Epot= -1.39691e+05 Fmax= 2.92434e+03, atom= 1408
# Step=  394, Dmax= 2.1e-02 nm, Epot= -1.39711e+05 Fmax= 3.68694e+03, atom= 1408
# Step=  395, Dmax= 2.5e-02 nm, Epot= -1.39731e+05 Fmax= 4.24279e+03, atom= 1408
# Step=  396, Dmax= 3.0e-02 nm, Epot= -1.39737e+05 Fmax= 5.27818e+03, atom= 1408
# Step=  397, Dmax= 3.6e-02 nm, Epot= -1.39743e+05 Fmax= 6.14564e+03, atom= 1408
# Step=  399, Dmax= 2.2e-02 nm, Epot= -1.39865e+05 Fmax= 7.43616e+02, atom= 1408
# Step=  400, Dmax= 2.6e-02 nm, Epot= -1.39870e+05 Fmax= 7.54412e+03, atom= 1408
# Step=  401, Dmax= 3.1e-02 nm, Epot= -1.40036e+05 Fmax= 2.41390e+03, atom= 1408
# Step=  403, Dmax= 1.9e-02 nm, Epot= -1.40054e+05 Fmax= 3.50854e+03, atom= 1408
# Step=  404, Dmax= 2.3e-02 nm, Epot= -1.40082e+05 Fmax= 3.60537e+03, atom= 1408
# Step=  405, Dmax= 2.7e-02 nm, Epot= -1.40085e+05 Fmax= 4.92079e+03, atom= 1408
# Step=  406, Dmax= 3.2e-02 nm, Epot= -1.40103e+05 Fmax= 5.32005e+03, atom= 1408
# Step=  408, Dmax= 1.9e-02 nm, Epot= -1.40199e+05 Fmax= 7.94028e+02, atom= 1408
# Step=  409, Dmax= 2.3e-02 nm, Epot= -1.40214e+05 Fmax= 6.54111e+03, atom= 1408
# Step=  410, Dmax= 2.8e-02 nm, Epot= -1.40341e+05 Fmax= 2.24469e+03, atom= 1408
# Step=  412, Dmax= 1.7e-02 nm, Epot= -1.40362e+05 Fmax= 3.06150e+03, atom= 1408
# Step=  413, Dmax= 2.0e-02 nm, Epot= -1.40388e+05 Fmax= 3.29204e+03, atom= 1408
# Step=  414, Dmax= 2.4e-02 nm, Epot= -1.40397e+05 Fmax= 4.34665e+03, atom= 1408
# Step=  415, Dmax= 2.9e-02 nm, Epot= -1.40415e+05 Fmax= 4.80709e+03, atom= 1408
# Step=  417, Dmax= 1.7e-02 nm, Epot= -1.40496e+05 Fmax= 7.12541e+02, atom= 1408
# Step=  418, Dmax= 2.1e-02 nm, Epot= -1.40527e+05 Fmax= 5.89471e+03, atom= 1408
# Step=  419, Dmax= 2.5e-02 nm, Epot= -1.40634e+05 Fmax= 2.07196e+03, atom= 1408
# Step=  421, Dmax= 1.5e-02 nm, Epot= -1.40657e+05 Fmax= 2.67203e+03, atom= 1408
# Step=  422, Dmax= 1.8e-02 nm, Epot= -1.40681e+05 Fmax= 3.03603e+03, atom= 1408
# Step=  423, Dmax= 2.2e-02 nm, Epot= -1.40697e+05 Fmax= 3.79506e+03, atom= 1408
# Step=  424, Dmax= 2.6e-02 nm, Epot= -1.40712e+05 Fmax= 4.42030e+03, atom= 1408
# Step=  425, Dmax= 3.1e-02 nm, Epot= -1.40714e+05 Fmax= 5.42097e+03, atom= 1408
# Step=  427, Dmax= 1.9e-02 nm, Epot= -1.40813e+05 Fmax= 5.16741e+02, atom= 1408
# Step=  428, Dmax= 2.2e-02 nm, Epot= -1.40873e+05 Fmax= 6.57772e+03, atom= 1408
# Step=  429, Dmax= 2.7e-02 nm, Epot= -1.41004e+05 Fmax= 2.00319e+03, atom= 1408
# Step=  431, Dmax= 1.6e-02 nm, Epot= -1.41022e+05 Fmax= 3.09223e+03, atom= 1408
# Step=  432, Dmax= 1.9e-02 nm, Epot= -1.41049e+05 Fmax= 3.04566e+03, atom= 1408
# Step=  433, Dmax= 2.3e-02 nm, Epot= -1.41055e+05 Fmax= 4.29631e+03, atom= 1408
# Step=  434, Dmax= 2.8e-02 nm, Epot= -1.41075e+05 Fmax= 4.53790e+03, atom= 1408
# Step=  436, Dmax= 1.7e-02 nm, Epot= -1.41148e+05 Fmax= 7.33079e+02, atom= 1408
# Step=  437, Dmax= 2.0e-02 nm, Epot= -1.41172e+05 Fmax= 5.61997e+03, atom= 1408
# Step=  438, Dmax= 2.4e-02 nm, Epot= -1.41269e+05 Fmax= 1.95753e+03, atom= 1408
# Step=  440, Dmax= 1.4e-02 nm, Epot= -1.41290e+05 Fmax= 2.62340e+03, atom= 1408
# Step=  441, Dmax= 1.7e-02 nm, Epot= -1.41313e+05 Fmax= 2.84818e+03, atom= 1408
# Step=  442, Dmax= 2.1e-02 nm, Epot= -1.41326e+05 Fmax= 3.74446e+03, atom= 1408
# Step=  443, Dmax= 2.5e-02 nm, Epot= -1.41343e+05 Fmax= 4.14038e+03, atom= 1408
# Step=  445, Dmax= 1.5e-02 nm, Epot= -1.41407e+05 Fmax= 6.18502e+02, atom= 1408
# Step=  446, Dmax= 1.8e-02 nm, Epot= -1.41449e+05 Fmax= 5.04424e+03, atom= 1408
# Step=  447, Dmax= 2.2e-02 nm, Epot= -1.41531e+05 Fmax= 1.81997e+03, atom= 1408
# Step=  449, Dmax= 1.3e-02 nm, Epot= -1.41554e+05 Fmax= 2.26297e+03, atom= 1408
# Step=  450, Dmax= 1.6e-02 nm, Epot= -1.41575e+05 Fmax= 2.66363e+03, atom= 1408
# Step=  451, Dmax= 1.9e-02 nm, Epot= -1.41593e+05 Fmax= 3.21861e+03, atom= 1408
# Step=  452, Dmax= 2.2e-02 nm, Epot= -1.41607e+05 Fmax= 3.86969e+03, atom= 1408
# Step=  453, Dmax= 2.7e-02 nm, Epot= -1.41616e+05 Fmax= 4.60602e+03, atom= 1408
# Step=  455, Dmax= 1.6e-02 nm, Epot= -1.41690e+05 Fmax= 5.11473e+02, atom= 1408
# Step=  456, Dmax= 1.9e-02 nm, Epot= -1.41746e+05 Fmax= 5.56369e+03, atom= 1408
# Step=  457, Dmax= 2.3e-02 nm, Epot= -1.41843e+05 Fmax= 1.82261e+03, atom= 1408
# Step=  459, Dmax= 1.4e-02 nm, Epot= -1.41862e+05 Fmax= 2.56389e+03, atom= 1408
# Step=  460, Dmax= 1.7e-02 nm, Epot= -1.41884e+05 Fmax= 2.73223e+03, atom= 1408
# Step=  461, Dmax= 2.0e-02 nm, Epot= -1.41896e+05 Fmax= 3.58969e+03, atom= 1408
# Step=  462, Dmax= 2.4e-02 nm, Epot= -1.41911e+05 Fmax= 4.03052e+03, atom= 1408
# Step=  464, Dmax= 1.4e-02 nm, Epot= -1.41972e+05 Fmax= 5.12521e+02, atom= 1408
# Step=  465, Dmax= 1.7e-02 nm, Epot= -1.42026e+05 Fmax= 4.99677e+03, atom= 1408
# Step=  466, Dmax= 2.1e-02 nm, Epot= -1.42107e+05 Fmax= 1.53398e+03, atom= 1408
# Step=  468, Dmax= 1.3e-02 nm, Epot= -1.42127e+05 Fmax= 2.42349e+03, atom= 1408
# Step=  469, Dmax= 1.5e-02 nm, Epot= -1.42151e+05 Fmax= 2.28879e+03, atom= 1408
# Step=  470, Dmax= 1.8e-02 nm, Epot= -1.42161e+05 Fmax= 3.40133e+03, atom= 1408
# Step=  471, Dmax= 2.2e-02 nm, Epot= -1.42184e+05 Fmax= 3.38965e+03, atom= 1408
# Step=  473, Dmax= 1.3e-02 nm, Epot= -1.42230e+05 Fmax= 7.13142e+02, atom= 1408
# Step=  474, Dmax= 1.6e-02 nm, Epot= -1.42260e+05 Fmax= 4.15418e+03, atom= 1408
# Step=  475, Dmax= 1.9e-02 nm, Epot= -1.42318e+05 Fmax= 1.75869e+03, atom= 1408
# Step=  477, Dmax= 1.1e-02 nm, Epot= -1.42340e+05 Fmax= 1.75661e+03, atom= 1408
# Step=  478, Dmax= 1.3e-02 nm, Epot= -1.42358e+05 Fmax= 2.49632e+03, atom= 1408
# Step=  479, Dmax= 1.6e-02 nm, Epot= -1.42380e+05 Fmax= 2.56901e+03, atom= 1408
# Step=  480, Dmax= 1.9e-02 nm, Epot= -1.42389e+05 Fmax= 3.54711e+03, atom= 1408
# Step=  481, Dmax= 2.3e-02 nm, Epot= -1.42408e+05 Fmax= 3.75256e+03, atom= 1408
# Step=  483, Dmax= 1.4e-02 nm, Epot= -1.42461e+05 Fmax= 6.58189e+02, atom= 1408
# Step=  484, Dmax= 1.7e-02 nm, Epot= -1.42490e+05 Fmax= 4.56874e+03, atom= 1408
# Step=  485, Dmax= 2.0e-02 nm, Epot= -1.42558e+05 Fmax= 1.78991e+03, atom= 1408
# Step=  487, Dmax= 1.2e-02 nm, Epot= -1.42578e+05 Fmax= 1.98806e+03, atom= 1408
# Step=  488, Dmax= 1.4e-02 nm, Epot= -1.42596e+05 Fmax= 2.58283e+03, atom= 1408
# Step=  489, Dmax= 1.7e-02 nm, Epot= -1.42614e+05 Fmax= 2.86144e+03, atom= 1408
# Step=  490, Dmax= 2.1e-02 nm, Epot= -1.42623e+05 Fmax= 3.71214e+03, atom= 1408
# Step=  491, Dmax= 2.5e-02 nm, Epot= -1.42636e+05 Fmax= 4.13418e+03, atom= 1408
# Step=  493, Dmax= 1.5e-02 nm, Epot= -1.42698e+05 Fmax= 6.07938e+02, atom= 1408
# Step=  494, Dmax= 1.8e-02 nm, Epot= -1.42725e+05 Fmax= 5.00447e+03, atom= 1408
# Step=  495, Dmax= 2.2e-02 nm, Epot= -1.42804e+05 Fmax= 1.83400e+03, atom= 1408
# Step=  497, Dmax= 1.3e-02 nm, Epot= -1.42823e+05 Fmax= 2.22628e+03, atom= 1408
# Step=  498, Dmax= 1.6e-02 nm, Epot= -1.42840e+05 Fmax= 2.68607e+03, atom= 1408
# Step=  499, Dmax= 1.9e-02 nm, Epot= -1.42855e+05 Fmax= 3.16577e+03, atom= 1408
# Step=  500, Dmax= 2.2e-02 nm, Epot= -1.42863e+05 Fmax= 3.89962e+03, atom= 1408
# Step=  501, Dmax= 2.7e-02 nm, Epot= -1.42870e+05 Fmax= 4.53429e+03, atom= 1408
# Step=  503, Dmax= 1.6e-02 nm, Epot= -1.42942e+05 Fmax= 5.63833e+02, atom= 1408
# Step=  504, Dmax= 1.9e-02 nm, Epot= -1.42967e+05 Fmax= 5.46346e+03, atom= 1408
# Step=  505, Dmax= 2.3e-02 nm, Epot= -1.43060e+05 Fmax= 1.89155e+03, atom= 1408
# Step=  507, Dmax= 1.4e-02 nm, Epot= -1.43076e+05 Fmax= 2.47178e+03, atom= 1408
# Step=  508, Dmax= 1.7e-02 nm, Epot= -1.43092e+05 Fmax= 2.80772e+03, atom= 1408
# Step=  509, Dmax= 2.0e-02 nm, Epot= -1.43103e+05 Fmax= 3.48203e+03, atom= 1408
# Step=  510, Dmax= 2.4e-02 nm, Epot= -1.43111e+05 Fmax= 4.11223e+03, atom= 1408
# Step=  512, Dmax= 1.4e-02 nm, Epot= -1.43172e+05 Fmax= 4.09998e+02, atom= 1408
# Step=  513, Dmax= 1.7e-02 nm, Epot= -1.43231e+05 Fmax= 5.11873e+03, atom= 1408
# Step=  514, Dmax= 2.1e-02 nm, Epot= -1.43315e+05 Fmax= 1.37998e+03, atom= 1408
# Step=  516, Dmax= 1.2e-02 nm, Epot= -1.43330e+05 Fmax= 2.57125e+03, atom= 1408
# Step=  517, Dmax= 1.5e-02 nm, Epot= -1.43355e+05 Fmax= 2.11800e+03, atom= 1408
# Step=  518, Dmax= 1.8e-02 nm, Epot= -1.43357e+05 Fmax= 3.55589e+03, atom= 1408
# Step=  519, Dmax= 2.2e-02 nm, Epot= -1.43383e+05 Fmax= 3.20147e+03, atom= 1408
# Step=  521, Dmax= 1.3e-02 nm, Epot= -1.43424e+05 Fmax= 8.86462e+02, atom= 1408
# Step=  522, Dmax= 1.6e-02 nm, Epot= -1.43434e+05 Fmax= 3.95517e+03, atom= 1408
# Step=  523, Dmax= 1.9e-02 nm, Epot= -1.43484e+05 Fmax= 1.93393e+03, atom= 1408
# Step=  525, Dmax= 1.1e-02 nm, Epot= -1.43506e+05 Fmax= 1.56366e+03, atom= 1408
# Step=  526, Dmax= 1.3e-02 nm, Epot= -1.43518e+05 Fmax= 2.67848e+03, atom= 1408
# Step=  527, Dmax= 1.6e-02 nm, Epot= -1.43541e+05 Fmax= 2.36133e+03, atom= 1408
# Step=  528, Dmax= 1.9e-02 nm, Epot= -1.43541e+05 Fmax= 3.73563e+03, atom= 1408
# Step=  529, Dmax= 2.3e-02 nm, Epot= -1.43565e+05 Fmax= 3.52817e+03, atom= 1408
# Step=  531, Dmax= 1.4e-02 nm, Epot= -1.43612e+05 Fmax= 8.66004e+02, atom= 1408
# Step=  532, Dmax= 1.7e-02 nm, Epot= -1.43616e+05 Fmax= 4.33768e+03, atom= 1408
# Step=  533, Dmax= 2.0e-02 nm, Epot= -1.43674e+05 Fmax= 1.99377e+03, atom= 1408
# ...
# Step= 9881, Dmax= 2.9e-03 nm, Epot= -1.55481e+05 Fmax= 9.79772e+01, atom= 1244
# Step= 9882, Dmax= 3.4e-03 nm, Epot= -1.55481e+05 Fmax= 9.66879e+02, atom= 1244
# Step= 9883, Dmax= 4.1e-03 nm, Epot= -1.55484e+05 Fmax= 3.31467e+02, atom= 1244
# Step= 9885, Dmax= 2.5e-03 nm, Epot= -1.55484e+05 Fmax= 4.42393e+02, atom= 1244
# Step= 9886, Dmax= 3.0e-03 nm, Epot= -1.55484e+05 Fmax= 4.93356e+02, atom= 1244
# Step= 9887, Dmax= 3.6e-03 nm, Epot= -1.55485e+05 Fmax= 6.22575e+02, atom= 1244
# Step= 9888, Dmax= 4.3e-03 nm, Epot= -1.55485e+05 Fmax= 7.23520e+02, atom= 1244
# Step= 9890, Dmax= 2.6e-03 nm, Epot= -1.55487e+05 Fmax= 8.03899e+01, atom= 1244
# Step= 9891, Dmax= 3.1e-03 nm, Epot= -1.55487e+05 Fmax= 9.02651e+02, atom= 1244
# Step= 9892, Dmax= 3.7e-03 nm, Epot= -1.55490e+05 Fmax= 2.54969e+02, atom= 1244
# Step= 9894, Dmax= 2.2e-03 nm, Epot= -1.55490e+05 Fmax= 4.45142e+02, atom= 1244
# Step= 9895, Dmax= 2.7e-03 nm, Epot= -1.55491e+05 Fmax= 3.87534e+02, atom= 1244
# Step= 9897, Dmax= 1.6e-03 nm, Epot= -1.55491e+05 Fmax= 1.15729e+02, atom= 1244
# Step= 9898, Dmax= 1.9e-03 nm, Epot= -1.55492e+05 Fmax= 4.78462e+02, atom= 1244
# Step= 9899, Dmax= 2.3e-03 nm, Epot= -1.55493e+05 Fmax= 2.45793e+02, atom= 1244
# Step= 9900, Dmax= 2.8e-03 nm, Epot= -1.55493e+05 Fmax= 6.15519e+02, atom= 1244
# Step= 9901, Dmax= 3.3e-03 nm, Epot= -1.55494e+05 Fmax= 4.26666e+02, atom= 1244
# Step= 9903, Dmax= 2.0e-03 nm, Epot= -1.55495e+05 Fmax= 1.94738e+02, atom= 1244
# Step= 9904, Dmax= 2.4e-03 nm, Epot= -1.55495e+05 Fmax= 5.59101e+02, atom= 1244
# Step= 9905, Dmax= 2.9e-03 nm, Epot= -1.55496e+05 Fmax= 3.36400e+02, atom= 1244
# Step= 9907, Dmax= 1.7e-03 nm, Epot= -1.55496e+05 Fmax= 2.04904e+02, atom= 1244
# Step= 9908, Dmax= 2.1e-03 nm, Epot= -1.55497e+05 Fmax= 4.37114e+02, atom= 1244
# Step= 9909, Dmax= 2.5e-03 nm, Epot= -1.55498e+05 Fmax= 3.41552e+02, atom= 1244
# Step= 9910, Dmax= 3.0e-03 nm, Epot= -1.55498e+05 Fmax= 5.85745e+02, atom= 1244
# Step= 9911, Dmax= 3.5e-03 nm, Epot= -1.55498e+05 Fmax= 5.34610e+02, atom= 1244
# Step= 9913, Dmax= 2.1e-03 nm, Epot= -1.55499e+05 Fmax= 1.33754e+02, atom= 1244
# Step= 9914, Dmax= 2.6e-03 nm, Epot= -1.55499e+05 Fmax= 6.79088e+02, atom= 1244
# Step= 9915, Dmax= 3.1e-03 nm, Epot= -1.55501e+05 Fmax= 2.83819e+02, atom= 1244
# Step= 9917, Dmax= 1.8e-03 nm, Epot= -1.55501e+05 Fmax= 2.98389e+02, atom= 1244
# Step= 9918, Dmax= 2.2e-03 nm, Epot= -1.55502e+05 Fmax= 3.93264e+02, atom= 1244
# Step= 9919, Dmax= 2.6e-03 nm, Epot= -1.55502e+05 Fmax= 4.43971e+02, atom= 1244
# Step= 9920, Dmax= 3.2e-03 nm, Epot= -1.55502e+05 Fmax= 5.53589e+02, atom= 1244
# Step= 9921, Dmax= 3.8e-03 nm, Epot= -1.55503e+05 Fmax= 6.50840e+02, atom= 1244
# Step= 9922, Dmax= 4.6e-03 nm, Epot= -1.55503e+05 Fmax= 7.87164e+02, atom= 1244
# Step= 9924, Dmax= 2.7e-03 nm, Epot= -1.55505e+05 Fmax= 7.97469e+01, atom= 1244
# Step= 9925, Dmax= 3.3e-03 nm, Epot= -1.55506e+05 Fmax= 9.39505e+02, atom= 1244
# Step= 9926, Dmax= 4.0e-03 nm, Epot= -1.55508e+05 Fmax= 3.08761e+02, atom= 1244
# Step= 9928, Dmax= 2.4e-03 nm, Epot= -1.55508e+05 Fmax= 4.34785e+02, atom= 1244
# Step= 9929, Dmax= 2.8e-03 nm, Epot= -1.55509e+05 Fmax= 4.64960e+02, atom= 1244
# Step= 9930, Dmax= 3.4e-03 nm, Epot= -1.55509e+05 Fmax= 6.07376e+02, atom= 1244
# Step= 9931, Dmax= 4.1e-03 nm, Epot= -1.55509e+05 Fmax= 6.86981e+02, atom= 1244
# Step= 9933, Dmax= 2.5e-03 nm, Epot= -1.55511e+05 Fmax= 8.55948e+01, atom= 1244
# Step= 9934, Dmax= 3.0e-03 nm, Epot= -1.55511e+05 Fmax= 8.59456e+02, atom= 1244
# Step= 9935, Dmax= 3.5e-03 nm, Epot= -1.55514e+05 Fmax= 2.53325e+02, atom= 1244
# Step= 9937, Dmax= 2.1e-03 nm, Epot= -1.55514e+05 Fmax= 4.19923e+02, atom= 1244
# Step= 9938, Dmax= 2.6e-03 nm, Epot= -1.55515e+05 Fmax= 3.80159e+02, atom= 1244
# Step= 9939, Dmax= 3.1e-03 nm, Epot= -1.55515e+05 Fmax= 5.87450e+02, atom= 1244
# Step= 9940, Dmax= 3.7e-03 nm, Epot= -1.55515e+05 Fmax= 5.65908e+02, atom= 1244
# Step= 9942, Dmax= 2.2e-03 nm, Epot= -1.55516e+05 Fmax= 1.30134e+02, atom= 1244
# Step= 9943, Dmax= 2.6e-03 nm, Epot= -1.55517e+05 Fmax= 6.92977e+02, atom= 1244
# Step= 9944, Dmax= 3.2e-03 nm, Epot= -1.55518e+05 Fmax= 3.08898e+02, atom= 1244
# Step= 9946, Dmax= 1.9e-03 nm, Epot= -1.55519e+05 Fmax= 2.87617e+02, atom= 1244
# Step= 9947, Dmax= 2.3e-03 nm, Epot= -1.55519e+05 Fmax= 4.35775e+02, atom= 1244
# Step= 9948, Dmax= 2.7e-03 nm, Epot= -1.55519e+05 Fmax= 4.24457e+02, atom= 1244
# Step= 9949, Dmax= 3.3e-03 nm, Epot= -1.55520e+05 Fmax= 6.15373e+02, atom= 1244
# Step= 9950, Dmax= 3.9e-03 nm, Epot= -1.55520e+05 Fmax= 6.24603e+02, atom= 1244
# Step= 9952, Dmax= 2.4e-03 nm, Epot= -1.55521e+05 Fmax= 1.23465e+02, atom= 1244
# Step= 9953, Dmax= 2.8e-03 nm, Epot= -1.55521e+05 Fmax= 7.60789e+02, atom= 1244
# Step= 9954, Dmax= 3.4e-03 nm, Epot= -1.55523e+05 Fmax= 3.16023e+02, atom= 1244
# Step= 9956, Dmax= 2.0e-03 nm, Epot= -1.55524e+05 Fmax= 3.25276e+02, atom= 1244
# Step= 9957, Dmax= 2.5e-03 nm, Epot= -1.55524e+05 Fmax= 4.51823e+02, atom= 1244
# Step= 9958, Dmax= 2.9e-03 nm, Epot= -1.55524e+05 Fmax= 4.72974e+02, atom= 1244
# Step= 9959, Dmax= 3.5e-03 nm, Epot= -1.55524e+05 Fmax= 6.44406e+02, atom= 1244
# Step= 9960, Dmax= 4.2e-03 nm, Epot= -1.55525e+05 Fmax= 6.88613e+02, atom= 1244
# Step= 9962, Dmax= 2.5e-03 nm, Epot= -1.55526e+05 Fmax= 1.15423e+02, atom= 1244
# Step= 9963, Dmax= 3.1e-03 nm, Epot= -1.55527e+05 Fmax= 8.34257e+02, atom= 1244
# Step= 9964, Dmax= 3.7e-03 nm, Epot= -1.55529e+05 Fmax= 3.23305e+02, atom= 1244
# Step= 9966, Dmax= 2.2e-03 nm, Epot= -1.55529e+05 Fmax= 3.66137e+02, atom= 1244
# Step= 9967, Dmax= 2.6e-03 nm, Epot= -1.55529e+05 Fmax= 4.68793e+02, atom= 1244
# Step= 9968, Dmax= 3.2e-03 nm, Epot= -1.55530e+05 Fmax= 5.25421e+02, atom= 1244
# Step= 9969, Dmax= 3.8e-03 nm, Epot= -1.55530e+05 Fmax= 6.75365e+02, atom= 1244
# Step= 9970, Dmax= 4.6e-03 nm, Epot= -1.55530e+05 Fmax= 7.57695e+02, atom= 1244
# Step= 9972, Dmax= 2.7e-03 nm, Epot= -1.55532e+05 Fmax= 1.06549e+02, atom= 1244
# Step= 9973, Dmax= 3.3e-03 nm, Epot= -1.55532e+05 Fmax= 9.13061e+02, atom= 1244
# Step= 9974, Dmax= 3.9e-03 nm, Epot= -1.55534e+05 Fmax= 3.31195e+02, atom= 1244
# Step= 9976, Dmax= 2.4e-03 nm, Epot= -1.55535e+05 Fmax= 4.09940e+02, atom= 1244
# Step= 9977, Dmax= 2.8e-03 nm, Epot= -1.55535e+05 Fmax= 4.87291e+02, atom= 1244
# Step= 9978, Dmax= 3.4e-03 nm, Epot= -1.55535e+05 Fmax= 5.81612e+02, atom= 1244
# Step= 9979, Dmax= 4.1e-03 nm, Epot= -1.55535e+05 Fmax= 7.08965e+02, atom= 1244
# Step= 9981, Dmax= 2.5e-03 nm, Epot= -1.55537e+05 Fmax= 6.11115e+01, atom= 1244
# Step= 9982, Dmax= 2.9e-03 nm, Epot= -1.55539e+05 Fmax= 8.88595e+02, atom= 1244
# Step= 9983, Dmax= 3.5e-03 nm, Epot= -1.55541e+05 Fmax= 2.20413e+02, atom= 1244
# Step= 9985, Dmax= 2.1e-03 nm, Epot= -1.55541e+05 Fmax= 4.51624e+02, atom= 1244
# Step= 9986, Dmax= 2.5e-03 nm, Epot= -1.55542e+05 Fmax= 3.45887e+02, atom= 1244
# Step= 9987, Dmax= 3.1e-03 nm, Epot= -1.55542e+05 Fmax= 6.19208e+02, atom= 1244
# Step= 9988, Dmax= 3.7e-03 nm, Epot= -1.55543e+05 Fmax= 5.30348e+02, atom= 1244
# Step= 9990, Dmax= 2.2e-03 nm, Epot= -1.55544e+05 Fmax= 1.63687e+02, atom= 1244
# Step= 9991, Dmax= 2.6e-03 nm, Epot= -1.55544e+05 Fmax= 6.58331e+02, atom= 1244
# Step= 9992, Dmax= 3.2e-03 nm, Epot= -1.55545e+05 Fmax= 3.40575e+02, atom= 1244
# Step= 9994, Dmax= 1.9e-03 nm, Epot= -1.55545e+05 Fmax= 2.54053e+02, atom= 1244
# Step= 9995, Dmax= 2.3e-03 nm, Epot= -1.55546e+05 Fmax= 4.67626e+02, atom= 1244
# Step= 9996, Dmax= 2.7e-03 nm, Epot= -1.55546e+05 Fmax= 3.89727e+02, atom= 1244
# Step= 9997, Dmax= 3.3e-03 nm, Epot= -1.55546e+05 Fmax= 6.47228e+02, atom= 1244
# Step= 9998, Dmax= 3.9e-03 nm, Epot= -1.55547e+05 Fmax= 5.88539e+02, atom= 1244
# Step=10000, Dmax= 2.4e-03 nm, Epot= -1.55548e+05 Fmax= 1.57374e+02, atom= 1244
#
# Energy minimization reached the maximum number of steps before the forces
# reached the requested precision Fmax < 10.
#
# writing lowest energy coordinates.
#
# Steepest Descents did not converge to Fmax < 10 in 10001 steps.
# Potential Energy  = -1.5554827e+05
# Maximum force     =  1.5737404e+02 on atom 1244
# Norm of force     =  4.1006827e+00
#
# GROMACS reminds you: "Perfect is the enemy of good." (Voltaire)
#
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: D
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: G
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: R
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
#                       :-) GROMACS - gmx grompp, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx grompp -f /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/mdps/eq_3_20ns.mdp -c em_comp2.gro -r em_comp2.gro -p topol_comp2_W.top -n index_comp2_mem.ndx -o eq1_comp2_in.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'ns_type'
#
# WARNING 1 [file /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/mdps/eq_3_20ns.mdp]:
#   The Berendsen barostat does not generate any strictly correct ensemble,
#   and should not be used for new production simulations (in our opinion).
#   We recommend using the C-rescale barostat instead.
#
# Number of degrees of freedom in T-Coupling group Solute is 8908.59
# Number of degrees of freedom in T-Coupling group solvent is 9991.41
#
# NOTE 1 [file /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/mdps/eq_3_20ns.mdp]:
#   There are 670 non-linear virtual site constructions. Their contribution
#   to the energy error is approximated. In most cases this does not affect
#   the error significantly.
#
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "Apologies to the astrophysics student I met at a party years ago. When you told me how many hours a day you used 4chan and how much you love it, I gave you a funny look and walked away. Now, a decade later, I realize you were talking about Fortran." (Anonymous)
#
#                       :-) GROMACS - gmx mdrun, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx mdrun -v -deffnm eq1_comp2_in -nt 10 -pin on -pinstride 1 -pinoffset 30
# Setting the LD random seed to 1176353711
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'MC3H'
#
# Excluding 1 bonded neighbours molecule type 'DPPC'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'MC3H'
#
# Excluding 1 bonded neighbours molecule type 'DPPC'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 310 K
#
# Calculated rlist for 1x1 atom pair-list as 1.306 nm, buffer size 0.206 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.215 nm, buffer size 0.115 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 8 Mb of data
# Reading file eq1_comp2_in.tpr, VERSION 2023.3 (single precision)
# Changing nstlist from 20 to 25, rlist from 1.215 to 1.269
#
# Update groups can not be used for this system because an incompatible virtual site type is used
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 10 OpenMP threads
#
# Applying core pinning offset 30
# starting mdrun 'INSANE! Membrane UpperLeaflet>MC3H:DPPC:CHOL=50.0:10.0:40.0 LowerLeaflet>MC3H:DPPC:CHOL=50.0:10.0:40.0 in water'
# 1000000 steps,  20000.0 ps.
#
# Step 0  Warning: pressure scaling more than 1%, mu: 0.984893 0.984893 0.99067
# step 0
# Step 75  Warning: pressure scaling more than 1%, mu: 1.00475 1.00475 1.01206
#
# Step 100  Warning: pressure scaling more than 1%, mu: 1.00444 1.00444 1.01188
# step 999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 1000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     2242.828      224.283     1000.0
#                  (ns/day)    (hour/ns)
# Performance:     7704.561        0.003
#
# GROMACS reminds you: "Computer science is no more about computers than astronomy is about telescopes" (Edsger Dijkstra)
#
#                      :-) GROMACS - gmx editconf, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx editconf -f eq1_comp2_in.gro -o eq1_comp2.gro -resnr 1 -box 10 10 22
#
#
# GROMACS reminds you: "Computer science is no more about computers than astronomy is about telescopes" (Edsger Dijkstra)
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 7105 atoms
# Volume: 703.345 nm^3, corresponds to roughly 316500 electrons
# Velocities found
#     system size : 11.887 12.947  8.410 (nm)
#     center      :  4.558  4.592  4.186 (nm)
#     box vectors :  9.144  9.144  8.412 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  : 703.34               (nm^3)
#     shift       :  0.442  0.408  6.814 (nm)
# new center      :  5.000  5.000 11.000 (nm)
# new box vectors : 10.000 10.000 22.000 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :2200.00               (nm^3)
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: T
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/coordinates/GRO.py:479: UserWarning: missing dimension - setting unit cell to zeroed box [0., 0., 0.]
#   warnings.warn(wmsg)
#                      :-) GROMACS - gmx editconf, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx editconf -f stacked_membrane.gro -o stacked_membrane_renum.gro -resnr 1 -box 10 10 18
#
#
# GROMACS reminds you: "Computer science is no more about computers than astronomy is about telescopes" (Edsger Dijkstra)
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 7313 atoms
# Volume: 0 nm^3, corresponds to roughly 0 electrons
# No velocities found
#     system size : 11.887 13.072 12.390 (nm)
#     center      :  4.936  4.842  7.708 (nm)
#     box vectors :  0.000  0.000  0.000 (nm)
#     box angles  :   0.00   0.00   0.00 (degrees)
#     box volume  :   0.00               (nm^3)
#     shift       :  0.064  0.158  1.292 (nm)
# new center      :  5.000  5.000  9.000 (nm)
# new box vectors : 10.000 10.000 18.000 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :1800.00               (nm^3)
# rm: cannot remove '*#': No such file or directory

# %%
## Calculate the inconsistency in terms of membrane size to scale the bilayers
scaling_factor = area_per_lipid('eq1_comp2_in.gro', 'eq1_comp2_in.xtc')[0]/area_per_lipid('eq1_comp1.gro', 'eq1_comp1.xtc')[0]
scaling_factor
# Out:
# 1.1155922794412363

# %%
#### Obtain new box size
scaled_x = 10 + scaling_factor
scaled_y = 10 + scaling_factor

#### Re-run with scaling factor
hydration = '22' #(~5 waters per lipid)
comp1 = f'-u POPC:640 -u PAPS:264 -u PAPC:56 -u POPE:264 -u DIPE:160 -u DPSM:640 -u CHOL:826 \
-l POPC:373 -l PAPC:213 -l POPE:133 -l DIPE:426 -l DPSM:293 -l CHOL:746 -l PAPS:666 -l SAP6:53 -x 10 -y 10 -z 8'

comp2 = f'-l MC3H:50 -l DPPC:10 -l CHOL:40 -x {scaled_x} -y {scaled_y} -z 8' 

forcefields = f'#include "{ff_loc}/martini_v3.0.0.itp"\n\
#include "{ff_loc}/Martini_v1_tails-2.itp"\n\
#include "{ff_loc}/martini_v3.0.0_ions_v1.itp"\n\
#include "{ff_loc}/martini_v3.0.0_solvents_v1.itp"\n\
#include "{ff_loc}/martini_v3.0_phosphoinositides_v1.0.itp"\n\
#include "{ff_loc}/martini_v3.0.0_phospholipids_v1.itp"\n\
#include "{ff_loc}/martini_v3.0_CHOL_dev20.itp"\n\
#include "{ff_loc}/WN_fbposres.itp"\n\
#include "{ff_loc}/MC3_MC3H.itp"\n'

### Run
build_system(comp1, comp2, hydration, forcefields, insane_loc)
# Out:
# ; X: 10.000 (13 bins) Y: 10.000 (13 bins) in upper leaflet
# ; X: 10.000 (13 bins) Y: 10.000 (13 bins) in lower leaflet
# ; 169 lipids in upper leaflet, 169 lipids in lower leaflet
# ; NDX Solute 1 0
# ; Charge of protein: 0.000000
# ; NDX Membrane 1 3707
# ; Charge of membrane: -65.000000
# ; Total charge: -65.000000
# ; NDX Solvent 3708 0
# ; NDX System 1 3707
# ; "I mean, the good stuff is just INSANE" --Julia Ormond
# ; X: 11.116 (14 bins) Y: 11.116 (14 bins) in upper leaflet
# ; X: 11.116 (14 bins) Y: 11.116 (14 bins) in lower leaflet
# ; 196 lipids in upper leaflet, 196 lipids in lower leaflet
# ; NDX Solute 1 0
# ; Charge of protein: 0.000000
# ; NDX Membrane 1 4212
# ; Charge of membrane: 0.000000
# ; Total charge: 0.000000
# ; NDX Solvent 4213 0
# ; NDX System 1 4212
# ; "I mean, the good stuff is just INSANE" --Julia Ormond
#                      :-) GROMACS - gmx editconf, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx editconf -f comp1_mem.gro -o comp1_mem.gro -resnr 1
#
#
# Back Off! I just backed up comp1_mem.gro to ./#comp1_mem.gro.1#
#
# GROMACS reminds you: "It seemed a good idea at first" (Gerrit Groenhof)
#
#                      :-) GROMACS - gmx solvate, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx solvate -cp comp1_mem.gro -cs /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/common_files/water.gro -p topol_comp1_W.top -o comp1_mem_W.gro -radius 0.21
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
# Generating solvent configuration
# Will generate new solvent configuration of 3x3x3 boxes
# Solvent box contains 8009 atoms in 8009 residues
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 3707 atoms
# Volume: 800 nm^3, corresponds to roughly 360000 electrons
# No velocities found
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Adding line for 3619 solvent molecules with resname (W) to topology file (topol_comp1_W.top)
# Removed 1783 solvent atoms due to solvent-solvent overlap
# Removed 2607 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#       W (   1 atoms):  3619 residues
# Generated solvent containing 3619 atoms in 3619 residues
# Writing generated configuration to comp1_mem_W.gro
#
# Back Off! I just backed up comp1_mem_W.gro to ./#comp1_mem_W.gro.1#
#
# Output configuration contains 7326 atoms in 3948 residues
# Volume                 :         800 (nm^3)
# Density                :     1484.14 (g/l)
# Number of solvent molecules:   3619
#
# Processing topology
#
# Back Off! I just backed up topol_comp1_W.top to ./#topol_comp1_W.top.1#
#
# GROMACS reminds you: "It seemed a good idea at first" (Gerrit Groenhof)
#
#                       :-) GROMACS - gmx grompp, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx grompp -f empty.mdp -c comp1_mem_W.gro -r comp1_mem_W.gro -p topol_comp1_W.top -o ions.tpr -renum -maxwarn 1
#
#
# NOTE 1 [file empty.mdp]:
#   For a correct single-point energy evaluation with nsteps = 0, use
#   continuation = yes to avoid constraining the input coordinates.
#
#
# NOTE 2 [file topol_comp1_W.top, line 32]:
#   System has non-zero total charge: -65.000000
#   Total charge should normally be an integer. See
#   http://www.gromacs.org/Documentation/Floating_Point_Arithmetic
#   for discussion on how close it should be to an integer.
#
#
#
#
# NOTE 3 [file topol_comp1_W.top, line 32]:
#   For energy conservation with LINCS, lincs_iter should be 2 or larger.
#
#
# Number of degrees of freedom in T-Coupling group rest is 20319.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# NOTE 4 [file empty.mdp]:
#   NVE simulation with an initial temperature of zero: will use a Verlet
#   buffer of 10%. Check your energy drift!
#
#
# NOTE 5 [file empty.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
#
# There were 5 NOTEs
#
# Back Off! I just backed up ions.tpr to ./#ions.tpr.1#
#
# GROMACS reminds you: "This is Tense !" (Star Wars Episode I The Phantom Menace)
#
#                       :-) GROMACS - gmx genion, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx genion -s ions.tpr -o comp1_mem_W_ion.gro -p topol_comp1_W.top -neutral
#
# Reading file ions.tpr, VERSION 2023.3 (single precision)
# Reading file ions.tpr, VERSION 2023.3 (single precision)
# Group     0 (         System) has  7326 elements
# Group     1 (          Other) has  7326 elements
# Group     2 (           POPC) has   696 elements
# Group     3 (           PAPS) has   689 elements
# Group     4 (           PAPC) has   195 elements
# Group     5 (           POPE) has   264 elements
# Group     6 (           DIPE) has   396 elements
# Group     7 (           DPSM) has   594 elements
# Group     8 (           CHOL) has   819 elements
# Group     9 (           SAP6) has    54 elements
# Group    10 (              W) has  3619 elements
# Select a group: Number of (1-atomic) solvent molecules: 3619
#
# Back Off! I just backed up topol_comp1_W.top to ./#topol_comp1_W.top.2#
# Using random seed -445190181.
# Replacing solvent molecule 374 (atom 4081) with NA
# Replacing solvent molecule 2782 (atom 6489) with NA
# Replacing solvent molecule 1821 (atom 5528) with NA
# Replacing solvent molecule 2479 (atom 6186) with NA
# Replacing solvent molecule 3360 (atom 7067) with NA
# Replacing solvent molecule 1791 (atom 5498) with NA
# Replacing solvent molecule 93 (atom 3800) with NA
# Replacing solvent molecule 2504 (atom 6211) with NA
# Replacing solvent molecule 933 (atom 4640) with NA
# Replacing solvent molecule 1743 (atom 5450) with NA
# Replacing solvent molecule 2390 (atom 6097) with NA
# Replacing solvent molecule 2658 (atom 6365) with NA
# Replacing solvent molecule 2821 (atom 6528) with NA
# Replacing solvent molecule 2721 (atom 6428) with NA
# Replacing solvent molecule 928 (atom 4635) with NA
# Replacing solvent molecule 277 (atom 3984) with NA
# Replacing solvent molecule 413 (atom 4120) with NA
# Replacing solvent molecule 1772 (atom 5479) with NA
# Replacing solvent molecule 2302 (atom 6009) with NA
# Replacing solvent molecule 2681 (atom 6388) with NA
# Replacing solvent molecule 1399 (atom 5106) with NA
# Replacing solvent molecule 1320 (atom 5027) with NA
# Replacing solvent molecule 3123 (atom 6830) with NA
# Replacing solvent molecule 3462 (atom 7169) with NA
# Replacing solvent molecule 2333 (atom 6040) with NA
# Replacing solvent molecule 478 (atom 4185) with NA
# Replacing solvent molecule 2880 (atom 6587) with NA
# Replacing solvent molecule 1060 (atom 4767) with NA
# Replacing solvent molecule 2798 (atom 6505) with NA
# Replacing solvent molecule 411 (atom 4118) with NA
# Replacing solvent molecule 2671 (atom 6378) with NA
# Replacing solvent molecule 128 (atom 3835) with NA
# Replacing solvent molecule 1068 (atom 4775) with NA
# Replacing solvent molecule 1897 (atom 5604) with NA
# Replacing solvent molecule 3353 (atom 7060) with NA
# Replacing solvent molecule 37 (atom 3744) with NA
# Replacing solvent molecule 2197 (atom 5904) with NA
# Replacing solvent molecule 1219 (atom 4926) with NA
# Replacing solvent molecule 3141 (atom 6848) with NA
# Replacing solvent molecule 2338 (atom 6045) with NA
# Replacing solvent molecule 2002 (atom 5709) with NA
# Replacing solvent molecule 512 (atom 4219) with NA
# Replacing solvent molecule 921 (atom 4628) with NA
# Replacing solvent molecule 2077 (atom 5784) with NA
# Replacing solvent molecule 1391 (atom 5098) with NA
# Replacing solvent molecule 1414 (atom 5121) with NA
# Replacing solvent molecule 732 (atom 4439) with NA
# Replacing solvent molecule 1319 (atom 5026) with NA
# Replacing solvent molecule 3130 (atom 6837) with NA
# Replacing solvent molecule 477 (atom 4184) with NA
# Replacing solvent molecule 3473 (atom 7180) with NA
# Replacing solvent molecule 1899 (atom 5606) with NA
# Replacing solvent molecule 1469 (atom 5176) with NA
# Replacing solvent molecule 3211 (atom 6918) with NA
# Replacing solvent molecule 2308 (atom 6015) with NA
# Replacing solvent molecule 174 (atom 3881) with NA
# Replacing solvent molecule 3070 (atom 6777) with NA
# Replacing solvent molecule 2096 (atom 5803) with NA
# Replacing solvent molecule 2358 (atom 6065) with NA
# Replacing solvent molecule 1166 (atom 4873) with NA
# Replacing solvent molecule 3024 (atom 6731) with NA
# Replacing solvent molecule 520 (atom 4227) with NA
# Replacing solvent molecule 1603 (atom 5310) with NA
# Replacing solvent molecule 767 (atom 4474) with NA
# Replacing solvent molecule 1690 (atom 5397) with NA
#
#
# Back Off! I just backed up comp1_mem_W_ion.gro to ./#comp1_mem_W_ion.gro.1#
#
# GROMACS reminds you: "This is Tense !" (Star Wars Episode I The Phantom Menace)
#
#                       :-) GROMACS - gmx grompp, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx grompp -f /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/mdps/em_2.mdp -c comp1_mem_W_ion.gro -r comp1_mem_W_ion.gro -p topol_comp1_W.top -o em_comp1.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
# Setting the LD random seed to -21020681
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'SAP6'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:  3948      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 1 Mb of data
# Will try to add 65 NA ions and 0 CL ions.
# Select a continuous group of solvent molecules
# Selected 10: 'W'
#
# Processing topology
# Replacing 65 solute molecules in topology file (topol_comp1_W.top)  by 65 NA and 0 CL ions.
# Number of degrees of freedom in T-Coupling group rest is 20601.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# Back Off! I just backed up em_comp1.tpr to ./#em_comp1.tpr.1#
#
# GROMACS reminds you: "A tidy laboratory means a lazy chemist." (J.J. Berzelius)
#
#                       :-) GROMACS - gmx mdrun, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx mdrun -v -deffnm em_comp1 -nt 10 -pin on -pinstride 1 -pinoffset 30
# Setting the LD random seed to -1145049743
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'SAP6'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:  3948      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 1 Mb of data
# Back Off! I just backed up em_comp1.log to ./#em_comp1.log.1#
# Reading file em_comp1.tpr, VERSION 2023.3 (single precision)
# Update groups can not be used for this system because an incompatible virtual site type is used
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 10 OpenMP threads
#
# Applying core pinning offset 30
#
# Back Off! I just backed up em_comp1.trr to ./#em_comp1.trr.1#
#
# Back Off! I just backed up em_comp1.edr to ./#em_comp1.edr.1#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+01
#    Number of steps    =        10000
# Step=    0, Dmax= 1.0e-02 nm, Epot=  2.22516e+08 Fmax= 2.05016e+09, atom= 3432
# Step=    1, Dmax= 1.0e-02 nm, Epot=  1.62951e+08 Fmax= 4.43105e+08, atom= 1894
# Step=    2, Dmax= 1.2e-02 nm, Epot=  1.05275e+08 Fmax= 9.05452e+07, atom= 175
# Step=    3, Dmax= 1.4e-02 nm, Epot=  5.72600e+07 Fmax= 1.74894e+07, atom= 1870
# Step=    4, Dmax= 1.7e-02 nm, Epot=  2.39616e+07 Fmax= 3.21810e+06, atom= 889
# Step=    5, Dmax= 2.1e-02 nm, Epot=  8.13554e+06 Fmax= 5.76285e+05, atom= 2362
# Step=    6, Dmax= 2.5e-02 nm, Epot=  2.69525e+06 Fmax= 2.23910e+05, atom= 6467
# Step=    7, Dmax= 3.0e-02 nm, Epot=  1.52735e+06 Fmax= 1.03899e+05, atom= 139
# Step=    8, Dmax= 3.6e-02 nm, Epot=  8.58028e+05 Fmax= 7.31692e+04, atom= 5841
# Step=    9, Dmax= 4.3e-02 nm, Epot=  5.63758e+05 Fmax= 3.02858e+04, atom= 139
# Step=   10, Dmax= 5.2e-02 nm, Epot=  2.91886e+05 Fmax= 3.42971e+04, atom= 4506
# Step=   11, Dmax= 6.2e-02 nm, Epot=  2.15016e+05 Fmax= 3.67830e+04, atom= 4506
# Step=   12, Dmax= 7.4e-02 nm, Epot=  1.67381e+05 Fmax= 1.67519e+04, atom= 4587
# Step=   13, Dmax= 8.9e-02 nm, Epot=  9.70908e+04 Fmax= 2.08711e+04, atom= 984
# Step=   14, Dmax= 1.1e-01 nm, Epot=  6.76801e+04 Fmax= 2.13277e+04, atom= 4942
# Step=   15, Dmax= 1.3e-01 nm, Epot=  5.44131e+04 Fmax= 2.79985e+05, atom= 4942
# Step=   16, Dmax= 1.5e-01 nm, Epot=  4.77658e+04 Fmax= 1.11325e+04, atom= 1239
# Step=   17, Dmax= 1.8e-01 nm, Epot=  2.44253e+04 Fmax= 8.29387e+04, atom= 4874
# Step=   19, Dmax= 1.1e-01 nm, Epot=  1.95758e+04 Fmax= 6.79212e+04, atom= 4942
# Step=   20, Dmax= 1.3e-01 nm, Epot=  1.55541e+04 Fmax= 2.26133e+04, atom= 4942
# Step=   21, Dmax= 1.6e-01 nm, Epot=  9.45383e+03 Fmax= 3.48837e+04, atom= 4942
# Step=   22, Dmax= 1.9e-01 nm, Epot=  4.00347e+03 Fmax= 1.06827e+04, atom= 4942
# Step=   24, Dmax= 1.2e-01 nm, Epot= -3.11794e+03 Fmax= 1.93154e+04, atom= 1624
# Step=   25, Dmax= 1.4e-01 nm, Epot= -7.46371e+03 Fmax= 2.77551e+04, atom= 1624
# Step=   26, Dmax= 1.7e-01 nm, Epot= -1.12522e+04 Fmax= 2.56873e+04, atom= 1624
# Step=   27, Dmax= 2.0e-01 nm, Epot= -1.35958e+04 Fmax= 3.71522e+04, atom= 1624
# Step=   28, Dmax= 2.4e-01 nm, Epot= -1.68050e+04 Fmax= 3.81298e+04, atom= 1624
# Step=   29, Dmax= 2.9e-01 nm, Epot= -1.70807e+04 Fmax= 5.09224e+04, atom= 1624
# Step=   30, Dmax= 3.4e-01 nm, Epot= -1.84821e+04 Fmax= 5.61135e+04, atom= 1624
# Step=   32, Dmax= 2.1e-01 nm, Epot= -2.97702e+04 Fmax= 8.18722e+03, atom= 1624
# Step=   34, Dmax= 1.2e-01 nm, Epot= -3.38220e+04 Fmax= 2.84347e+04, atom= 1624
# Step=   35, Dmax= 1.5e-01 nm, Epot= -3.74586e+04 Fmax= 1.69480e+04, atom= 1624
# Step=   37, Dmax= 8.9e-02 nm, Epot= -4.00366e+04 Fmax= 1.04939e+04, atom= 1624
# Step=   38, Dmax= 1.1e-01 nm, Epot= -4.22156e+04 Fmax= 2.29497e+04, atom= 1624
# Step=   39, Dmax= 1.3e-01 nm, Epot= -4.49883e+04 Fmax= 1.66397e+04, atom= 1624
# Step=   40, Dmax= 1.5e-01 nm, Epot= -4.53388e+04 Fmax= 3.12382e+04, atom= 1624
# Step=   41, Dmax= 1.8e-01 nm, Epot= -4.82520e+04 Fmax= 2.59589e+04, atom= 1624
# Step=   43, Dmax= 1.1e-01 nm, Epot= -5.19775e+04 Fmax= 8.55674e+03, atom= 1624
# Step=   44, Dmax= 1.3e-01 nm, Epot= -5.24407e+04 Fmax= 3.17126e+04, atom= 1624
# Step=   45, Dmax= 1.6e-01 nm, Epot= -5.67528e+04 Fmax= 1.75653e+04, atom= 1624
# Step=   47, Dmax= 9.6e-02 nm, Epot= -5.89525e+04 Fmax= 1.18816e+04, atom= 1624
# Step=   48, Dmax= 1.1e-01 nm, Epot= -5.92108e+04 Fmax= 2.39473e+04, atom= 1624
# Step=   49, Dmax= 1.4e-01 nm, Epot= -6.16764e+04 Fmax= 1.86371e+04, atom= 1624
# Step=   51, Dmax= 8.3e-02 nm, Epot= -6.43778e+04 Fmax= 7.13028e+03, atom= 1624
# Step=   52, Dmax= 9.9e-02 nm, Epot= -6.46405e+04 Fmax= 2.29454e+04, atom= 1624
# Step=   53, Dmax= 1.2e-01 nm, Epot= -6.77470e+04 Fmax= 1.39152e+04, atom= 1624
# Step=   55, Dmax= 7.1e-02 nm, Epot= -6.96690e+04 Fmax= 8.01027e+03, atom= 1624
# Step=   56, Dmax= 8.6e-02 nm, Epot= -6.96758e+04 Fmax= 1.88346e+04, atom= 1624
# Step=   57, Dmax= 1.0e-01 nm, Epot= -7.20469e+04 Fmax= 1.28953e+04, atom= 1624
# Step=   59, Dmax= 6.2e-02 nm, Epot= -7.40501e+04 Fmax= 6.36877e+03, atom= 1624
# Step=   60, Dmax= 7.4e-02 nm, Epot= -7.40704e+04 Fmax= 1.65214e+04, atom= 2987
# Step=   61, Dmax= 8.9e-02 nm, Epot= -7.63619e+04 Fmax= 1.14687e+04, atom= 2987
# Step=   63, Dmax= 5.3e-02 nm, Epot= -7.81353e+04 Fmax= 5.41715e+03, atom= 2987
# Step=   64, Dmax= 6.4e-02 nm, Epot= -7.84304e+04 Fmax= 1.42493e+04, atom= 2987
# Step=   65, Dmax= 7.7e-02 nm, Epot= -8.02646e+04 Fmax= 1.08416e+04, atom= 1768
# Step=   67, Dmax= 4.6e-02 nm, Epot= -8.18836e+04 Fmax= 3.89681e+03, atom= 1768
# Step=   68, Dmax= 5.5e-02 nm, Epot= -8.27955e+04 Fmax= 1.30915e+04, atom= 1768
# Step=   69, Dmax= 6.6e-02 nm, Epot= -8.44623e+04 Fmax= 7.93966e+03, atom= 1768
# Step=   71, Dmax= 4.0e-02 nm, Epot= -8.55170e+04 Fmax= 4.77445e+03, atom= 1768
# Step=   72, Dmax= 4.8e-02 nm, Epot= -8.62814e+04 Fmax= 1.08373e+04, atom= 1768
# Step=   73, Dmax= 5.7e-02 nm, Epot= -8.74313e+04 Fmax= 7.71952e+03, atom= 1768
# Step=   74, Dmax= 6.9e-02 nm, Epot= -8.77003e+04 Fmax= 1.47439e+04, atom= 1768
# Step=   75, Dmax= 8.3e-02 nm, Epot= -8.88651e+04 Fmax= 1.23190e+04, atom= 1768
# Step=   77, Dmax= 5.0e-02 nm, Epot= -9.01745e+04 Fmax= 3.41667e+03, atom= 1768
# Step=   78, Dmax= 5.9e-02 nm, Epot= -9.11637e+04 Fmax= 1.46463e+04, atom= 1768
# Step=   79, Dmax= 7.1e-02 nm, Epot= -9.25784e+04 Fmax= 7.81563e+03, atom= 1768
# Step=   81, Dmax= 4.3e-02 nm, Epot= -9.33478e+04 Fmax= 5.77852e+03, atom= 1768
# Step=   82, Dmax= 5.1e-02 nm, Epot= -9.39000e+04 Fmax= 1.08121e+04, atom= 1768
# Step=   83, Dmax= 6.2e-02 nm, Epot= -9.47029e+04 Fmax= 8.96152e+03, atom= 1768
# Step=   84, Dmax= 7.4e-02 nm, Epot= -9.48964e+04 Fmax= 1.49290e+04, atom= 1768
# Step=   85, Dmax= 8.9e-02 nm, Epot= -9.56562e+04 Fmax= 1.38817e+04, atom= 1768
# Step=   87, Dmax= 5.3e-02 nm, Epot= -9.69263e+04 Fmax= 2.92824e+03, atom= 1768
# Step=   88, Dmax= 6.4e-02 nm, Epot= -9.77489e+04 Fmax= 1.63281e+04, atom= 1768
# Step=   89, Dmax= 7.7e-02 nm, Epot= -9.91878e+04 Fmax= 7.68946e+03, atom= 1768
# Step=   91, Dmax= 4.6e-02 nm, Epot= -9.97724e+04 Fmax= 6.87687e+03, atom= 1768
# Step=   92, Dmax= 5.5e-02 nm, Epot= -1.00136e+05 Fmax= 1.07927e+04, atom= 1768
# Step=   93, Dmax= 6.6e-02 nm, Epot= -1.00697e+05 Fmax= 1.03273e+04, atom= 1768
# Step=   94, Dmax= 7.9e-02 nm, Epot= -1.00776e+05 Fmax= 1.51258e+04, atom= 1768
# Step=   95, Dmax= 9.5e-02 nm, Epot= -1.01211e+05 Fmax= 1.56074e+04, atom= 1768
# Step=   97, Dmax= 5.7e-02 nm, Epot= -1.02633e+05 Fmax= 2.36449e+03, atom= 1768
# Step=   98, Dmax= 6.9e-02 nm, Epot= -1.03154e+05 Fmax= 1.81326e+04, atom= 1768
# Step=   99, Dmax= 8.2e-02 nm, Epot= -1.04874e+05 Fmax= 7.56174e+03, atom= 1768
# Step=  101, Dmax= 4.9e-02 nm, Epot= -1.05278e+05 Fmax= 8.07725e+03, atom= 1768
# Step=  102, Dmax= 5.9e-02 nm, Epot= -1.05504e+05 Fmax= 1.07701e+04, atom= 1768
# Step=  103, Dmax= 7.1e-02 nm, Epot= -1.05803e+05 Fmax= 1.18201e+04, atom= 1768
# Step=  105, Dmax= 4.3e-02 nm, Epot= -1.06809e+05 Fmax= 1.58517e+03, atom= 1768
# Step=  106, Dmax= 5.1e-02 nm, Epot= -1.07612e+05 Fmax= 1.37392e+04, atom= 1768
# Step=  107, Dmax= 6.2e-02 nm, Epot= -1.08908e+05 Fmax= 5.48497e+03, atom= 1768
# Step=  109, Dmax= 3.7e-02 nm, Epot= -1.09235e+05 Fmax= 6.12523e+03, atom= 1768
# Step=  110, Dmax= 4.4e-02 nm, Epot= -1.09462e+05 Fmax= 7.90791e+03, atom= 1768
# Step=  111, Dmax= 5.3e-02 nm, Epot= -1.09707e+05 Fmax= 8.86547e+03, atom= 1768
# Step=  112, Dmax= 6.4e-02 nm, Epot= -1.09733e+05 Fmax= 1.13217e+04, atom= 1768
# Step=  113, Dmax= 7.7e-02 nm, Epot= -1.09794e+05 Fmax= 1.29759e+04, atom= 1768
# Step=  115, Dmax= 4.6e-02 nm, Epot= -1.11208e+05 Fmax= 1.52313e+03, atom= 2870
# Step=  117, Dmax= 2.8e-02 nm, Epot= -1.11752e+05 Fmax= 7.52244e+03, atom= 2870
# Step=  118, Dmax= 3.3e-02 nm, Epot= -1.12308e+05 Fmax= 3.12723e+03, atom= 2870
# Step=  119, Dmax= 4.0e-02 nm, Epot= -1.12417e+05 Fmax= 9.62858e+03, atom= 2870
# Step=  120, Dmax= 4.8e-02 nm, Epot= -1.13032e+05 Fmax= 5.59331e+03, atom= 2870
# Step=  122, Dmax= 2.9e-02 nm, Epot= -1.13387e+05 Fmax= 3.50008e+03, atom= 2870
# Step=  123, Dmax= 3.4e-02 nm, Epot= -1.13599e+05 Fmax= 7.27157e+03, atom= 2870
# Step=  124, Dmax= 4.1e-02 nm, Epot= -1.13970e+05 Fmax= 5.76287e+03, atom= 2870
# Step=  125, Dmax= 4.9e-02 nm, Epot= -1.13985e+05 Fmax= 9.80671e+03, atom= 2870
# Step=  126, Dmax= 5.9e-02 nm, Epot= -1.14345e+05 Fmax= 8.97190e+03, atom= 2870
# Step=  128, Dmax= 3.6e-02 nm, Epot= -1.14934e+05 Fmax= 2.35032e+03, atom= 2870
# Step=  129, Dmax= 4.3e-02 nm, Epot= -1.15044e+05 Fmax= 1.14770e+04, atom= 2870
# Step=  130, Dmax= 5.1e-02 nm, Epot= -1.15781e+05 Fmax= 4.99183e+03, atom= 2870
# Step=  132, Dmax= 3.1e-02 nm, Epot= -1.16041e+05 Fmax= 4.81036e+03, atom= 2870
# Step=  133, Dmax= 3.7e-02 nm, Epot= -1.16230e+05 Fmax= 6.81296e+03, atom= 2870
# Step=  134, Dmax= 4.4e-02 nm, Epot= -1.16460e+05 Fmax= 7.22666e+03, atom= 2870
# Step=  135, Dmax= 5.3e-02 nm, Epot= -1.16555e+05 Fmax= 9.54028e+03, atom= 2870
# Step=  136, Dmax= 6.4e-02 nm, Epot= -1.16712e+05 Fmax= 1.06815e+04, atom= 2870
# Step=  138, Dmax= 3.8e-02 nm, Epot= -1.17351e+05 Fmax= 1.52694e+03, atom= 2870
# Step=  139, Dmax= 4.6e-02 nm, Epot= -1.17685e+05 Fmax= 1.35771e+04, atom= 2870
# Step=  140, Dmax= 5.5e-02 nm, Epot= -1.18510e+05 Fmax= 4.32912e+03, atom= 2870
# Step=  142, Dmax= 3.3e-02 nm, Epot= -1.18697e+05 Fmax= 6.24749e+03, atom= 2870
# Step=  143, Dmax= 4.0e-02 nm, Epot= -1.18904e+05 Fmax= 6.28591e+03, atom= 2870
# Step=  144, Dmax= 4.8e-02 nm, Epot= -1.19019e+05 Fmax= 8.84073e+03, atom= 2870
# Step=  145, Dmax= 5.7e-02 nm, Epot= -1.19196e+05 Fmax= 9.21246e+03, atom= 2870
# Step=  147, Dmax= 3.4e-02 nm, Epot= -1.19618e+05 Fmax= 1.57936e+03, atom= 2870
# Step=  148, Dmax= 4.1e-02 nm, Epot= -1.19998e+05 Fmax= 1.10338e+04, atom= 2870
# Step=  149, Dmax= 4.9e-02 nm, Epot= -1.20502e+05 Fmax= 4.41840e+03, atom= 2870
# Step=  151, Dmax= 3.0e-02 nm, Epot= -1.20683e+05 Fmax= 4.88701e+03, atom= 2870
# Step=  152, Dmax= 3.5e-02 nm, Epot= -1.20836e+05 Fmax= 6.38727e+03, atom= 2870
# Step=  153, Dmax= 4.3e-02 nm, Epot= -1.20992e+05 Fmax= 7.04705e+03, atom= 2870
# Step=  154, Dmax= 5.1e-02 nm, Epot= -1.21079e+05 Fmax= 9.18969e+03, atom= 2870
# Step=  155, Dmax= 6.1e-02 nm, Epot= -1.21186e+05 Fmax= 1.02077e+04, atom= 2870
# Step=  157, Dmax= 3.7e-02 nm, Epot= -1.21664e+05 Fmax= 1.37845e+03, atom= 2870
# Step=  158, Dmax= 4.4e-02 nm, Epot= -1.22006e+05 Fmax= 1.20879e+04, atom= 2870
# Step=  159, Dmax= 5.3e-02 nm, Epot= -1.22579e+05 Fmax= 4.47909e+03, atom= 2870
# Step=  161, Dmax= 3.2e-02 nm, Epot= -1.22719e+05 Fmax= 5.52596e+03, atom= 2870
# Step=  162, Dmax= 3.8e-02 nm, Epot= -1.22850e+05 Fmax= 6.58589e+03, atom= 2870
# Step=  163, Dmax= 4.6e-02 nm, Epot= -1.22951e+05 Fmax= 7.84108e+03, atom= 2870
# Step=  164, Dmax= 5.5e-02 nm, Epot= -1.23019e+05 Fmax= 9.59934e+03, atom= 2870
# Step=  165, Dmax= 6.6e-02 nm, Epot= -1.23049e+05 Fmax= 1.12314e+04, atom= 2870
# Step=  167, Dmax= 4.0e-02 nm, Epot= -1.23604e+05 Fmax= 1.20677e+03, atom= 2870
# Step=  168, Dmax= 4.7e-02 nm, Epot= -1.23885e+05 Fmax= 1.31346e+04, atom= 2870
# Step=  169, Dmax= 5.7e-02 nm, Epot= -1.24547e+05 Fmax= 4.62351e+03, atom= 2870
# Step=  171, Dmax= 3.4e-02 nm, Epot= -1.24644e+05 Fmax= 6.13641e+03, atom= 2870
# Step=  172, Dmax= 4.1e-02 nm, Epot= -1.24757e+05 Fmax= 6.88074e+03, atom= 2870
# Step=  173, Dmax= 4.9e-02 nm, Epot= -1.24801e+05 Fmax= 8.61121e+03, atom= 2870
# Step=  174, Dmax= 5.9e-02 nm, Epot= -1.24849e+05 Fmax= 1.01263e+04, atom= 2870
# Step=  176, Dmax= 3.5e-02 nm, Epot= -1.25309e+05 Fmax= 1.15004e+03, atom= 2870
# Step=  177, Dmax= 4.3e-02 nm, Epot= -1.25471e+05 Fmax= 1.29843e+04, atom= 2870
# Step=  178, Dmax= 5.1e-02 nm, Epot= -1.26113e+05 Fmax= 3.54226e+03, atom= 2870
# Step=  180, Dmax= 3.1e-02 nm, Epot= -1.26196e+05 Fmax= 6.26553e+03, atom= 2870
# Step=  181, Dmax= 3.7e-02 nm, Epot= -1.26344e+05 Fmax= 5.30957e+03, atom= 2870
# Step=  182, Dmax= 4.4e-02 nm, Epot= -1.26350e+05 Fmax= 8.72420e+03, atom= 2870
# Step=  183, Dmax= 5.3e-02 nm, Epot= -1.26500e+05 Fmax= 7.95692e+03, atom= 2870
# Step=  185, Dmax= 3.2e-02 nm, Epot= -1.26774e+05 Fmax= 2.05144e+03, atom= 2870
# Step=  186, Dmax= 3.8e-02 nm, Epot= -1.26821e+05 Fmax= 9.65400e+03, atom= 2870
# Step=  187, Dmax= 4.6e-02 nm, Epot= -1.27144e+05 Fmax= 4.70525e+03, atom= 2870
# Step=  189, Dmax= 2.7e-02 nm, Epot= -1.27270e+05 Fmax= 3.87975e+03, atom= 2870
# Step=  190, Dmax= 3.3e-02 nm, Epot= -1.27329e+05 Fmax= 6.59648e+03, atom= 2870
# Step=  191, Dmax= 3.9e-02 nm, Epot= -1.27463e+05 Fmax= 5.81501e+03, atom= 2870
# Step=  193, Dmax= 2.4e-02 nm, Epot= -1.27640e+05 Fmax= 1.67093e+03, atom= 2870
# Step=  194, Dmax= 2.8e-02 nm, Epot= -1.27774e+05 Fmax= 7.05578e+03, atom= 2870
# Step=  195, Dmax= 3.4e-02 nm, Epot= -1.27979e+05 Fmax= 3.69471e+03, atom= 2870
# Step=  197, Dmax= 2.0e-02 nm, Epot= -1.28092e+05 Fmax= 2.69908e+03, atom= 2870
# Step=  198, Dmax= 2.5e-02 nm, Epot= -1.28181e+05 Fmax= 5.14815e+03, atom= 2870
# Step=  199, Dmax= 2.9e-02 nm, Epot= -1.28305e+05 Fmax= 4.09765e+03, atom= 2870
# Step=  200, Dmax= 3.5e-02 nm, Epot= -1.28333e+05 Fmax= 7.16969e+03, atom= 2870
# Step=  201, Dmax= 4.2e-02 nm, Epot= -1.28468e+05 Fmax= 6.18332e+03, atom= 2870
# Step=  203, Dmax= 2.5e-02 nm, Epot= -1.28654e+05 Fmax= 1.86211e+03, atom= 2870
# Step=  204, Dmax= 3.1e-02 nm, Epot= -1.28731e+05 Fmax= 7.52791e+03, atom= 2870
# Step=  205, Dmax= 3.7e-02 nm, Epot= -1.28947e+05 Fmax= 4.02250e+03, atom= 2870
# Step=  207, Dmax= 2.2e-02 nm, Epot= -1.29058e+05 Fmax= 2.85257e+03, atom= 2870
# Step=  208, Dmax= 2.6e-02 nm, Epot= -1.29123e+05 Fmax= 5.58023e+03, atom= 2870
# Step=  209, Dmax= 3.2e-02 nm, Epot= -1.29247e+05 Fmax= 4.36121e+03, atom= 2870
# Step=  211, Dmax= 1.9e-02 nm, Epot= -1.29371e+05 Fmax= 1.66218e+03, atom= 2870
# Step=  212, Dmax= 2.3e-02 nm, Epot= -1.29484e+05 Fmax= 5.34479e+03, atom= 2870
# Step=  213, Dmax= 2.7e-02 nm, Epot= -1.29623e+05 Fmax= 3.30624e+03, atom= 2870
# Step=  214, Dmax= 3.3e-02 nm, Epot= -1.29636e+05 Fmax= 6.90563e+03, atom= 2870
# Step=  215, Dmax= 3.9e-02 nm, Epot= -1.29781e+05 Fmax= 5.54931e+03, atom= 2870
# Step=  217, Dmax= 2.4e-02 nm, Epot= -1.29936e+05 Fmax= 1.87445e+03, atom= 2870
# Step=  218, Dmax= 2.8e-02 nm, Epot= -1.29979e+05 Fmax= 7.28471e+03, atom= 2870
# Step=  219, Dmax= 3.4e-02 nm, Epot= -1.30186e+05 Fmax= 3.45645e+03, atom= 2870
# Step=  221, Dmax= 2.0e-02 nm, Epot= -1.30280e+05 Fmax= 3.04817e+03, atom= 2870
# Step=  222, Dmax= 2.5e-02 nm, Epot= -1.30347e+05 Fmax= 4.57656e+03, atom= 2870
# Step=  223, Dmax= 2.9e-02 nm, Epot= -1.30432e+05 Fmax= 4.75473e+03, atom= 2870
# Step=  224, Dmax= 3.5e-02 nm, Epot= -1.30469e+05 Fmax= 6.27496e+03, atom= 2870
# Step=  225, Dmax= 4.2e-02 nm, Epot= -1.30523e+05 Fmax= 7.14567e+03, atom= 2870
# Step=  227, Dmax= 2.5e-02 nm, Epot= -1.30746e+05 Fmax= 8.65965e+02, atom= 2870
# Step=  228, Dmax= 3.1e-02 nm, Epot= -1.30911e+05 Fmax= 9.27675e+03, atom= 2870
# Step=  229, Dmax= 3.7e-02 nm, Epot= -1.31243e+05 Fmax= 2.36566e+03, atom= 2870
# Step=  231, Dmax= 2.2e-02 nm, Epot= -1.31307e+05 Fmax= 4.67465e+03, atom= 2870
# Step=  232, Dmax= 2.6e-02 nm, Epot= -1.31406e+05 Fmax= 3.57681e+03, atom= 2870
# Step=  233, Dmax= 3.2e-02 nm, Epot= -1.31419e+05 Fmax= 6.50069e+03, atom= 2870
# Step=  234, Dmax= 3.8e-02 nm, Epot= -1.31531e+05 Fmax= 5.40751e+03, atom= 2870
# Step=  236, Dmax= 2.3e-02 nm, Epot= -1.31674e+05 Fmax= 1.78941e+03, atom= 2870
# Step=  237, Dmax= 2.7e-02 nm, Epot= -1.31717e+05 Fmax= 6.59170e+03, atom= 2870
# Step=  238, Dmax= 3.3e-02 nm, Epot= -1.31882e+05 Fmax= 3.74219e+03, atom= 2870
# Step=  240, Dmax= 2.0e-02 nm, Epot= -1.31972e+05 Fmax= 2.39040e+03, atom= 2870
# Step=  241, Dmax= 2.4e-02 nm, Epot= -1.32016e+05 Fmax= 5.16226e+03, atom= 2870
# Step=  242, Dmax= 2.8e-02 nm, Epot= -1.32124e+05 Fmax= 3.70658e+03, atom= 2870
# Step=  244, Dmax= 1.7e-02 nm, Epot= -1.32218e+05 Fmax= 1.68544e+03, atom= 2870
# Step=  245, Dmax= 2.0e-02 nm, Epot= -1.32290e+05 Fmax= 4.57622e+03, atom= 2870
# Step=  246, Dmax= 2.4e-02 nm, Epot= -1.32393e+05 Fmax= 3.16661e+03, atom= 2870
# Step=  247, Dmax= 2.9e-02 nm, Epot= -1.32402e+05 Fmax= 5.95033e+03, atom= 2870
# Step=  248, Dmax= 3.5e-02 nm, Epot= -1.32503e+05 Fmax= 5.18858e+03, atom= 2870
# Step=  250, Dmax= 2.1e-02 nm, Epot= -1.32639e+05 Fmax= 1.43557e+03, atom= 2870
# Step=  251, Dmax= 2.5e-02 nm, Epot= -1.32672e+05 Fmax= 6.79382e+03, atom= 2870
# Step=  252, Dmax= 3.0e-02 nm, Epot= -1.32863e+05 Fmax= 2.79003e+03, atom= 2870
# Step=  254, Dmax= 1.8e-02 nm, Epot= -1.32930e+05 Fmax= 3.03648e+03, atom= 2870
# Step=  255, Dmax= 2.2e-02 nm, Epot= -1.32987e+05 Fmax= 3.77721e+03, atom= 2870
# Step=  256, Dmax= 2.6e-02 nm, Epot= -1.33039e+05 Fmax= 4.57584e+03, atom= 2870
# Step=  257, Dmax= 3.2e-02 nm, Epot= -1.33082e+05 Fmax= 5.27579e+03, atom= 2870
# Step=  258, Dmax= 3.8e-02 nm, Epot= -1.33095e+05 Fmax= 6.72799e+03, atom= 2870
# Step=  259, Dmax= 4.5e-02 nm, Epot= -1.33117e+05 Fmax= 7.50664e+03, atom= 2870
# Step=  261, Dmax= 2.7e-02 nm, Epot= -1.33372e+05 Fmax= 1.07658e+03, atom= 2870
# Step=  263, Dmax= 1.6e-02 nm, Epot= -1.33471e+05 Fmax= 3.85795e+03, atom= 2870
# Step=  264, Dmax= 2.0e-02 nm, Epot= -1.33563e+05 Fmax= 2.34426e+03, atom= 2870
# Step=  265, Dmax= 2.4e-02 nm, Epot= -1.33581e+05 Fmax= 4.93764e+03, atom= 2870
# Step=  266, Dmax= 2.8e-02 nm, Epot= -1.33677e+05 Fmax= 4.00258e+03, atom= 2870
# Step=  268, Dmax= 1.7e-02 nm, Epot= -1.33782e+05 Fmax= 1.29201e+03, atom= 2870
# Step=  269, Dmax= 2.0e-02 nm, Epot= -1.33822e+05 Fmax= 5.30931e+03, atom= 2870
# Step=  270, Dmax= 2.4e-02 nm, Epot= -1.33967e+05 Fmax= 2.34859e+03, atom= 2870
# Step=  272, Dmax= 1.5e-02 nm, Epot= -1.34030e+05 Fmax= 2.33175e+03, atom= 2870
# Step=  273, Dmax= 1.8e-02 nm, Epot= -1.34082e+05 Fmax= 3.11199e+03, atom= 2870
# Step=  274, Dmax= 2.1e-02 nm, Epot= -1.34134e+05 Fmax= 3.59729e+03, atom= 2870
# Step=  275, Dmax= 2.5e-02 nm, Epot= -1.34173e+05 Fmax= 4.28588e+03, atom= 2870
# Step=  276, Dmax= 3.0e-02 nm, Epot= -1.34195e+05 Fmax= 5.35001e+03, atom= 2870
# Step=  277, Dmax= 3.6e-02 nm, Epot= -1.34216e+05 Fmax= 6.04463e+03, atom= 2870
# Step=  279, Dmax= 2.2e-02 nm, Epot= -1.34424e+05 Fmax= 8.50828e+02, atom= 2870
# Step=  280, Dmax= 2.6e-02 nm, Epot= -1.34449e+05 Fmax= 6.99611e+03, atom= 2870
# Step=  281, Dmax= 3.2e-02 nm, Epot= -1.34710e+05 Fmax= 2.90060e+03, atom= 2870
# Step=  283, Dmax= 1.9e-02 nm, Epot= -1.34764e+05 Fmax= 2.97026e+03, atom= 2870
# Step=  284, Dmax= 2.3e-02 nm, Epot= -1.34780e+05 Fmax= 4.24646e+03, atom= 2870
# Step=  285, Dmax= 2.7e-02 nm, Epot= -1.34833e+05 Fmax= 4.29621e+03, atom= 3149
# Step=  287, Dmax= 1.6e-02 nm, Epot= -1.34973e+05 Fmax= 8.74245e+02, atom= 3149
# Step=  288, Dmax= 2.0e-02 nm, Epot= -1.35012e+05 Fmax= 5.52557e+03, atom= 3149
# Step=  289, Dmax= 2.4e-02 nm, Epot= -1.35195e+05 Fmax= 1.94701e+03, atom= 3149
# Step=  291, Dmax= 1.4e-02 nm, Epot= -1.35245e+05 Fmax= 2.57694e+03, atom= 3149
# Step=  292, Dmax= 1.7e-02 nm, Epot= -1.35296e+05 Fmax= 2.74722e+03, atom= 3149
# Step=  293, Dmax= 2.0e-02 nm, Epot= -1.35331e+05 Fmax= 3.74328e+03, atom= 3149
# Step=  294, Dmax= 2.4e-02 nm, Epot= -1.35378e+05 Fmax= 3.93997e+03, atom= 3149
# Step=  295, Dmax= 2.9e-02 nm, Epot= -1.35380e+05 Fmax= 5.39315e+03, atom= 3149
# Step=  296, Dmax= 3.5e-02 nm, Epot= -1.35418e+05 Fmax= 5.69207e+03, atom= 3149
# Step=  298, Dmax= 2.1e-02 nm, Epot= -1.35598e+05 Fmax= 9.77033e+02, atom= 3149
# Step=  299, Dmax= 2.5e-02 nm, Epot= -1.35602e+05 Fmax= 6.79574e+03, atom= 3149
# Step=  300, Dmax= 3.0e-02 nm, Epot= -1.35819e+05 Fmax= 2.77621e+03, atom= 3149
# Step=  302, Dmax= 1.8e-02 nm, Epot= -1.35868e+05 Fmax= 2.94323e+03, atom= 3149
# Step=  303, Dmax= 2.2e-02 nm, Epot= -1.35895e+05 Fmax= 4.02264e+03, atom= 3149
# Step=  304, Dmax= 2.6e-02 nm, Epot= -1.35938e+05 Fmax= 4.23547e+03, atom= 3149
# Step=  306, Dmax= 1.6e-02 nm, Epot= -1.36048e+05 Fmax= 7.50289e+02, atom= 3149
# Step=  307, Dmax= 1.9e-02 nm, Epot= -1.36137e+05 Fmax= 5.02842e+03, atom= 3149
# Step=  308, Dmax= 2.3e-02 nm, Epot= -1.36266e+05 Fmax= 2.13192e+03, atom= 3149
# Step=  310, Dmax= 1.4e-02 nm, Epot= -1.36315e+05 Fmax= 2.12828e+03, atom= 3149
# Step=  311, Dmax= 1.6e-02 nm, Epot= -1.36354e+05 Fmax= 3.07956e+03, atom= 3149
# Step=  312, Dmax= 2.0e-02 nm, Epot= -1.36402e+05 Fmax= 3.07525e+03, atom= 3149
# Step=  313, Dmax= 2.3e-02 nm, Epot= -1.36420e+05 Fmax= 4.41030e+03, atom= 3149
# Step=  314, Dmax= 2.8e-02 nm, Epot= -1.36465e+05 Fmax= 4.47135e+03, atom= 3149
# Step=  316, Dmax= 1.7e-02 nm, Epot= -1.36577e+05 Fmax= 8.84340e+02, atom= 3149
# Step=  317, Dmax= 2.0e-02 nm, Epot= -1.36632e+05 Fmax= 5.35654e+03, atom= 3149
# Step=  318, Dmax= 2.4e-02 nm, Epot= -1.36764e+05 Fmax= 2.33508e+03, atom= 3149
# Step=  320, Dmax= 1.5e-02 nm, Epot= -1.36811e+05 Fmax= 2.24743e+03, atom= 3149
# Step=  321, Dmax= 1.8e-02 nm, Epot= -1.36844e+05 Fmax= 3.34495e+03, atom= 3149
# Step=  322, Dmax= 2.1e-02 nm, Epot= -1.36892e+05 Fmax= 3.27379e+03, atom= 3149
# Step=  323, Dmax= 2.5e-02 nm, Epot= -1.36901e+05 Fmax= 4.76670e+03, atom= 3149
# Step=  324, Dmax= 3.0e-02 nm, Epot= -1.36945e+05 Fmax= 4.78266e+03, atom= 3149
# Step=  326, Dmax= 1.8e-02 nm, Epot= -1.37062e+05 Fmax= 9.69193e+02, atom= 3149
# Step=  327, Dmax= 2.2e-02 nm, Epot= -1.37094e+05 Fmax= 5.75278e+03, atom= 3149
# Step=  328, Dmax= 2.6e-02 nm, Epot= -1.37234e+05 Fmax= 2.50726e+03, atom= 3149
# Step=  330, Dmax= 1.6e-02 nm, Epot= -1.37279e+05 Fmax= 2.42077e+03, atom= 3149
# Step=  331, Dmax= 1.9e-02 nm, Epot= -1.37307e+05 Fmax= 3.58358e+03, atom= 3149
# Step=  332, Dmax= 2.3e-02 nm, Epot= -1.37351e+05 Fmax= 3.53251e+03, atom= 3149
# Step=  333, Dmax= 2.7e-02 nm, Epot= -1.37355e+05 Fmax= 5.10296e+03, atom= 3149
# Step=  334, Dmax= 3.3e-02 nm, Epot= -1.37394e+05 Fmax= 5.16252e+03, atom= 3149
# Step=  336, Dmax= 2.0e-02 nm, Epot= -1.37520e+05 Fmax= 1.01448e+03, atom= 3149
# Step=  337, Dmax= 2.3e-02 nm, Epot= -1.37534e+05 Fmax= 6.21579e+03, atom= 3149
# Step=  338, Dmax= 2.8e-02 nm, Epot= -1.37685e+05 Fmax= 2.65370e+03, atom= 3149
# Step=  340, Dmax= 1.7e-02 nm, Epot= -1.37727e+05 Fmax= 2.64467e+03, atom= 3149
# Step=  341, Dmax= 2.0e-02 nm, Epot= -1.37751e+05 Fmax= 3.80156e+03, atom= 3149
# Step=  342, Dmax= 2.4e-02 nm, Epot= -1.37791e+05 Fmax= 3.84775e+03, atom= 3149
# Step=  344, Dmax= 1.5e-02 nm, Epot= -1.37869e+05 Fmax= 7.69579e+02, atom= 3149
# Step=  345, Dmax= 1.8e-02 nm, Epot= -1.37941e+05 Fmax= 4.60788e+03, atom= 3149
# Step=  346, Dmax= 2.1e-02 nm, Epot= -1.38035e+05 Fmax= 2.02543e+03, atom= 3149
# Step=  348, Dmax= 1.3e-02 nm, Epot= -1.38076e+05 Fmax= 1.92207e+03, atom= 3149
# Step=  349, Dmax= 1.5e-02 nm, Epot= -1.38110e+05 Fmax= 2.89721e+03, atom= 3149
# Step=  350, Dmax= 1.8e-02 nm, Epot= -1.38151e+05 Fmax= 2.80446e+03, atom= 3149
# Step=  351, Dmax= 2.2e-02 nm, Epot= -1.38169e+05 Fmax= 4.12246e+03, atom= 3149
# Step=  352, Dmax= 2.6e-02 nm, Epot= -1.38208e+05 Fmax= 4.10362e+03, atom= 3149
# Step=  354, Dmax= 1.6e-02 nm, Epot= -1.38291e+05 Fmax= 8.56164e+02, atom= 3149
# Step=  355, Dmax= 1.9e-02 nm, Epot= -1.38343e+05 Fmax= 4.93929e+03, atom= 3149
# Step=  356, Dmax= 2.3e-02 nm, Epot= -1.38442e+05 Fmax= 2.18555e+03, atom= 3149
# Step=  358, Dmax= 1.4e-02 nm, Epot= -1.38481e+05 Fmax= 2.06026e+03, atom= 3149
# Step=  359, Dmax= 1.6e-02 nm, Epot= -1.38511e+05 Fmax= 3.11525e+03, atom= 3149
# Step=  360, Dmax= 2.0e-02 nm, Epot= -1.38551e+05 Fmax= 3.01569e+03, atom= 3149
# Step=  361, Dmax= 2.3e-02 nm, Epot= -1.38563e+05 Fmax= 4.42463e+03, atom= 3149
# Step=  362, Dmax= 2.8e-02 nm, Epot= -1.38600e+05 Fmax= 4.41936e+03, atom= 3149
# Step=  364, Dmax= 1.7e-02 nm, Epot= -1.38688e+05 Fmax= 9.07540e+02, atom= 3149
# Step=  365, Dmax= 2.0e-02 nm, Epot= -1.38726e+05 Fmax= 5.32952e+03, atom= 3149
# Step=  366, Dmax= 2.4e-02 nm, Epot= -1.38832e+05 Fmax= 2.32160e+03, atom= 3149
# Step=  368, Dmax= 1.5e-02 nm, Epot= -1.38870e+05 Fmax= 2.24384e+03, atom= 3149
# Step=  369, Dmax= 1.7e-02 nm, Epot= -1.38896e+05 Fmax= 3.31273e+03, atom= 3149
# Step=  370, Dmax= 2.1e-02 nm, Epot= -1.38933e+05 Fmax= 3.27847e+03, atom= 3149
# Step=  371, Dmax= 2.5e-02 nm, Epot= -1.38940e+05 Fmax= 4.71260e+03, atom= 3149
# Step=  372, Dmax= 3.0e-02 nm, Epot= -1.38973e+05 Fmax= 4.79396e+03, atom= 3149
# Step=  374, Dmax= 1.8e-02 nm, Epot= -1.39070e+05 Fmax= 9.26618e+02, atom= 3149
# Step=  375, Dmax= 2.2e-02 nm, Epot= -1.39095e+05 Fmax= 5.77889e+03, atom= 3149
# Step=  376, Dmax= 2.6e-02 nm, Epot= -1.39212e+05 Fmax= 2.43668e+03, atom= 3149
# Step=  378, Dmax= 1.6e-02 nm, Epot= -1.39247e+05 Fmax= 2.47152e+03, atom= 3149
# Step=  379, Dmax= 1.9e-02 nm, Epot= -1.39270e+05 Fmax= 3.49406e+03, atom= 3149
# Step=  380, Dmax= 2.3e-02 nm, Epot= -1.39303e+05 Fmax= 3.59044e+03, atom= 3149
# Step=  381, Dmax= 2.7e-02 nm, Epot= -1.39307e+05 Fmax= 4.99149e+03, atom= 3149
# Step=  382, Dmax= 3.2e-02 nm, Epot= -1.39333e+05 Fmax= 5.22595e+03, atom= 3149
# Step=  384, Dmax= 1.9e-02 nm, Epot= -1.39442e+05 Fmax= 9.17126e+02, atom= 3149
# Step=  385, Dmax= 2.3e-02 nm, Epot= -1.39454e+05 Fmax= 6.28650e+03, atom= 3149
# Step=  386, Dmax= 2.8e-02 nm, Epot= -1.39587e+05 Fmax= 2.53426e+03, atom= 3149
# Step=  388, Dmax= 1.7e-02 nm, Epot= -1.39618e+05 Fmax= 2.74192e+03, atom= 3149
# Step=  389, Dmax= 2.0e-02 nm, Epot= -1.39639e+05 Fmax= 3.66298e+03, atom= 3149
# Step=  390, Dmax= 2.4e-02 nm, Epot= -1.39666e+05 Fmax= 3.95116e+03, atom= 3149
# Step=  391, Dmax= 2.9e-02 nm, Epot= -1.39668e+05 Fmax= 5.26522e+03, atom= 3149
# Step=  392, Dmax= 3.5e-02 nm, Epot= -1.39685e+05 Fmax= 5.71479e+03, atom= 3149
# Step=  394, Dmax= 2.1e-02 nm, Epot= -1.39808e+05 Fmax= 8.82059e+02, atom= 3149
# Step=  395, Dmax= 2.5e-02 nm, Epot= -1.39809e+05 Fmax= 6.85073e+03, atom= 3149
# Step=  396, Dmax= 3.0e-02 nm, Epot= -1.39960e+05 Fmax= 2.61847e+03, atom= 3149
# Step=  398, Dmax= 1.8e-02 nm, Epot= -1.39987e+05 Fmax= 3.05282e+03, atom= 3149
# Step=  399, Dmax= 2.2e-02 nm, Epot= -1.40007e+05 Fmax= 3.82441e+03, atom= 3149
# Step=  400, Dmax= 2.6e-02 nm, Epot= -1.40027e+05 Fmax= 4.35814e+03, atom= 3149
# Step=  401, Dmax= 3.1e-02 nm, Epot= -1.40028e+05 Fmax= 5.53968e+03, atom= 3149
# Step=  402, Dmax= 3.8e-02 nm, Epot= -1.40033e+05 Fmax= 6.25965e+03, atom= 3149
# Step=  404, Dmax= 2.3e-02 nm, Epot= -1.40175e+05 Fmax= 8.24659e+02, atom= 3149
# Step=  406, Dmax= 1.4e-02 nm, Epot= -1.40224e+05 Fmax= 3.33195e+03, atom= 3149
# Step=  407, Dmax= 1.6e-02 nm, Epot= -1.40273e+05 Fmax= 1.77211e+03, atom= 3149
# Step=  408, Dmax= 1.9e-02 nm, Epot= -1.40278e+05 Fmax= 4.29867e+03, atom= 3149
# Step=  409, Dmax= 2.3e-02 nm, Epot= -1.40334e+05 Fmax= 3.06762e+03, atom= 3149
# Step=  411, Dmax= 1.4e-02 nm, Epot= -1.40380e+05 Fmax= 1.33082e+03, atom= 3149
# Step=  412, Dmax= 1.7e-02 nm, Epot= -1.40397e+05 Fmax= 4.02882e+03, atom= 3149
# Step=  413, Dmax= 2.0e-02 nm, Epot= -1.40455e+05 Fmax= 2.31851e+03, atom= 3149
# Step=  415, Dmax= 1.2e-02 nm, Epot= -1.40490e+05 Fmax= 1.51395e+03, atom= 3149
# Step=  416, Dmax= 1.5e-02 nm, Epot= -1.40515e+05 Fmax= 3.01475e+03, atom= 3149
# Step=  417, Dmax= 1.7e-02 nm, Epot= -1.40552e+05 Fmax= 2.49286e+03, atom= 3149
# Step=  418, Dmax= 2.1e-02 nm, Epot= -1.40560e+05 Fmax= 4.05125e+03, atom= 3149
# Step=  419, Dmax= 2.5e-02 nm, Epot= -1.40595e+05 Fmax= 3.87453e+03, atom= 3149
# Step=  421, Dmax= 1.5e-02 nm, Epot= -1.40656e+05 Fmax= 8.63962e+02, atom= 3149
# Step=  422, Dmax= 1.8e-02 nm, Epot= -1.40683e+05 Fmax= 4.93541e+03, atom= 3149
# Step=  423, Dmax= 2.2e-02 nm, Epot= -1.40767e+05 Fmax= 1.90561e+03, atom= 3149
# Step=  425, Dmax= 1.3e-02 nm, Epot= -1.40795e+05 Fmax= 2.22218e+03, atom= 3149
# Step=  426, Dmax= 1.6e-02 nm, Epot= -1.40820e+05 Fmax= 2.66612e+03, atom= 3149
# Step=  427, Dmax= 1.9e-02 nm, Epot= -1.40843e+05 Fmax= 3.26238e+03, atom= 3149
# Step=  428, Dmax= 2.2e-02 nm, Epot= -1.40862e+05 Fmax= 3.78786e+03, atom= 3149
# Step=  429, Dmax= 2.7e-02 nm, Epot= -1.40872e+05 Fmax= 4.74080e+03, atom= 3149
# Step=  430, Dmax= 3.2e-02 nm, Epot= -1.40880e+05 Fmax= 5.42492e+03, atom= 3149
# Step=  432, Dmax= 1.9e-02 nm, Epot= -1.40985e+05 Fmax= 6.84548e+02, atom= 3149
# Step=  433, Dmax= 2.3e-02 nm, Epot= -1.41015e+05 Fmax= 6.45663e+03, atom= 3149
# Step=  434, Dmax= 2.8e-02 nm, Epot= -1.41143e+05 Fmax= 2.31067e+03, atom= 3149
# Step=  436, Dmax= 1.7e-02 nm, Epot= -1.41165e+05 Fmax= 2.94244e+03, atom= 3149
# Step=  437, Dmax= 2.0e-02 nm, Epot= -1.41186e+05 Fmax= 3.42291e+03, atom= 3149
# Step=  438, Dmax= 2.4e-02 nm, Epot= -1.41200e+05 Fmax= 4.15408e+03, atom= 3149
# Step=  439, Dmax= 2.9e-02 nm, Epot= -1.41209e+05 Fmax= 5.00604e+03, atom= 3149
# Step=  441, Dmax= 1.7e-02 nm, Epot= -1.41297e+05 Fmax= 4.79251e+02, atom= 3149
# Step=  442, Dmax= 2.1e-02 nm, Epot= -1.41368e+05 Fmax= 6.31092e+03, atom= 3149
# Step=  443, Dmax= 2.5e-02 nm, Epot= -1.41496e+05 Fmax= 1.62949e+03, atom= 3149
# Step=  445, Dmax= 1.5e-02 nm, Epot= -1.41514e+05 Fmax= 3.14072e+03, atom= 3149
# Step=  446, Dmax= 1.8e-02 nm, Epot= -1.41548e+05 Fmax= 2.52008e+03, atom= 3149
# Step=  447, Dmax= 2.2e-02 nm, Epot= -1.41549e+05 Fmax= 4.33300e+03, atom= 3149
# Step=  448, Dmax= 2.6e-02 nm, Epot= -1.41585e+05 Fmax= 3.82665e+03, atom= 3149
# Step=  450, Dmax= 1.6e-02 nm, Epot= -1.41642e+05 Fmax= 1.08336e+03, atom= 3149
# Step=  451, Dmax= 1.9e-02 nm, Epot= -1.41652e+05 Fmax= 4.71397e+03, atom= 3149
# Step=  452, Dmax= 2.2e-02 nm, Epot= -1.41721e+05 Fmax= 2.34244e+03, atom= 3149
# Step=  454, Dmax= 1.3e-02 nm, Epot= -1.41750e+05 Fmax= 1.87228e+03, atom= 3149
# Step=  455, Dmax= 1.6e-02 nm, Epot= -1.41765e+05 Fmax= 3.24542e+03, atom= 3149
# Step=  456, Dmax= 1.9e-02 nm, Epot= -1.41796e+05 Fmax= 2.83644e+03, atom= 3149
# Step=  458, Dmax= 1.2e-02 nm, Epot= -1.41835e+05 Fmax= 8.32870e+02, atom= 3149
# Step=  459, Dmax= 1.4e-02 nm, Epot= -1.41869e+05 Fmax= 3.48494e+03, atom= 3149
# Step=  460, Dmax= 1.7e-02 nm, Epot= -1.41915e+05 Fmax= 1.78935e+03, atom= 3149
# Step=  462, Dmax= 1.0e-02 nm, Epot= -1.41941e+05 Fmax= 1.35222e+03, atom= 3149
# Step=  463, Dmax= 1.2e-02 nm, Epot= -1.41965e+05 Fmax= 2.47417e+03, atom= 3149
# Step=  464, Dmax= 1.4e-02 nm, Epot= -1.41993e+05 Fmax= 2.06031e+03, atom= 3149
# Step=  465, Dmax= 1.7e-02 nm, Epot= -1.42005e+05 Fmax= 3.43696e+03, atom= 3149
# Step=  466, Dmax= 2.1e-02 nm, Epot= -1.42035e+05 Fmax= 3.10158e+03, atom= 3149
# Step=  468, Dmax= 1.3e-02 nm, Epot= -1.42077e+05 Fmax= 8.39675e+02, atom= 3149
# Step=  469, Dmax= 1.5e-02 nm, Epot= -1.42108e+05 Fmax= 3.80130e+03, atom= 3149
# Step=  470, Dmax= 1.8e-02 nm, Epot= -1.42158e+05 Fmax= 1.86352e+03, atom= 3149
# Step=  472, Dmax= 1.1e-02 nm, Epot= -1.42184e+05 Fmax= 1.51376e+03, atom= 3149
# Step=  473, Dmax= 1.3e-02 nm, Epot= -1.42204e+05 Fmax= 2.59371e+03, atom= 3149
# Step=  474, Dmax= 1.6e-02 nm, Epot= -1.42232e+05 Fmax= 2.28046e+03, atom= 3149
# Step=  475, Dmax= 1.9e-02 nm, Epot= -1.42241e+05 Fmax= 3.62312e+03, atom= 3149
# Step=  476, Dmax= 2.2e-02 nm, Epot= -1.42268e+05 Fmax= 3.40499e+03, atom= 3149
# Step=  478, Dmax= 1.3e-02 nm, Epot= -1.42315e+05 Fmax= 8.28006e+02, atom= 3149
# Step=  479, Dmax= 1.6e-02 nm, Epot= -1.42341e+05 Fmax= 4.15853e+03, atom= 3149
# Step=  480, Dmax= 1.9e-02 nm, Epot= -1.42398e+05 Fmax= 1.92482e+03, atom= 3149
# Step=  482, Dmax= 1.2e-02 nm, Epot= -1.42423e+05 Fmax= 1.70560e+03, atom= 3149
# Step=  483, Dmax= 1.4e-02 nm, Epot= -1.42442e+05 Fmax= 2.70374e+03, atom= 3149
# Step=  484, Dmax= 1.7e-02 nm, Epot= -1.42467e+05 Fmax= 2.53522e+03, atom= 3149
# Step=  485, Dmax= 2.0e-02 nm, Epot= -1.42474e+05 Fmax= 3.80476e+03, atom= 3149
# Step=  486, Dmax= 2.4e-02 nm, Epot= -1.42498e+05 Fmax= 3.74880e+03, atom= 3149
# Step=  488, Dmax= 1.4e-02 nm, Epot= -1.42551e+05 Fmax= 7.97333e+02, atom= 3149
# Step=  489, Dmax= 1.7e-02 nm, Epot= -1.42573e+05 Fmax= 4.55791e+03, atom= 3149
# Step=  490, Dmax= 2.1e-02 nm, Epot= -1.42639e+05 Fmax= 1.97453e+03, atom= 3149
# Step=  492, Dmax= 1.2e-02 nm, Epot= -1.42662e+05 Fmax= 1.92764e+03, atom= 3149
# Step=  493, Dmax= 1.5e-02 nm, Epot= -1.42679e+05 Fmax= 2.80613e+03, atom= 3149
# Step=  494, Dmax= 1.8e-02 nm, Epot= -1.42701e+05 Fmax= 2.82450e+03, atom= 3149
# Step=  495, Dmax= 2.2e-02 nm, Epot= -1.42707e+05 Fmax= 3.98408e+03, atom= 3149
# Step=  496, Dmax= 2.6e-02 nm, Epot= -1.42726e+05 Fmax= 4.13375e+03, atom= 3149
# Step=  498, Dmax= 1.6e-02 nm, Epot= -1.42787e+05 Fmax= 7.48597e+02, atom= 3149
# Step=  499, Dmax= 1.9e-02 nm, Epot= -1.42806e+05 Fmax= 5.00004e+03, atom= 3149
# Step=  500, Dmax= 2.2e-02 nm, Epot= -1.42882e+05 Fmax= 2.01413e+03, atom= 3149
# Step=  502, Dmax= 1.3e-02 nm, Epot= -1.42904e+05 Fmax= 2.18022e+03, atom= 3149
# Step=  503, Dmax= 1.6e-02 nm, Epot= -1.42919e+05 Fmax= 2.90211e+03, atom= 3149
# Step=  504, Dmax= 1.9e-02 nm, Epot= -1.42938e+05 Fmax= 3.14900e+03, atom= 3149
# Step=  505, Dmax= 2.3e-02 nm, Epot= -1.42943e+05 Fmax= 4.16296e+03, atom= 3149
# Step=  506, Dmax= 2.8e-02 nm, Epot= -1.42955e+05 Fmax= 4.56090e+03, atom= 3149
# Step=  508, Dmax= 1.7e-02 nm, Epot= -1.43027e+05 Fmax= 6.82527e+02, atom= 3149
# Step=  509, Dmax= 2.0e-02 nm, Epot= -1.43043e+05 Fmax= 5.48404e+03, atom= 3149
# Step=  510, Dmax= 2.4e-02 nm, Epot= -1.43133e+05 Fmax= 2.04580e+03, atom= 3149
# Step=  512, Dmax= 1.4e-02 nm, Epot= -1.43151e+05 Fmax= 2.46251e+03, atom= 3149
# Step=  513, Dmax= 1.7e-02 nm, Epot= -1.43167e+05 Fmax= 2.99464e+03, atom= 3149
# Step=  514, Dmax= 2.1e-02 nm, Epot= -1.43180e+05 Fmax= 3.50818e+03, atom= 3149
# Step=  515, Dmax= 2.5e-02 nm, Epot= -1.43186e+05 Fmax= 4.34429e+03, atom= 3149
# Step=  516, Dmax= 3.0e-02 nm, Epot= -1.43189e+05 Fmax= 5.03043e+03, atom= 3149
# Step=  518, Dmax= 1.8e-02 nm, Epot= -1.43275e+05 Fmax= 6.00810e+02, atom= 3149
# Step=  519, Dmax= 2.2e-02 nm, Epot= -1.43291e+05 Fmax= 6.00892e+03, atom= 3149
# Step=  520, Dmax= 2.6e-02 nm, Epot= -1.43397e+05 Fmax= 2.07342e+03, atom= 3149
# Step=  522, Dmax= 1.6e-02 nm, Epot= -1.43412e+05 Fmax= 2.77346e+03, atom= 3149
# Step=  523, Dmax= 1.9e-02 nm, Epot= -1.43429e+05 Fmax= 3.08662e+03, atom= 3149
# Step=  524, Dmax= 2.2e-02 nm, Epot= -1.43435e+05 Fmax= 3.90165e+03, atom= 3149
# Step=  525, Dmax= 2.7e-02 nm, Epot= -1.43443e+05 Fmax= 4.53121e+03, atom= 3149
# Step=  527, Dmax= 1.6e-02 nm, Epot= -1.43513e+05 Fmax= 5.21536e+02, atom= 3149
# Step=  528, Dmax= 1.9e-02 nm, Epot= -1.43539e+05 Fmax= 5.67411e+03, atom= 3149
# ...
# Step= 9889, Dmax= 2.1e-03 nm, Epot= -1.87183e+05 Fmax= 2.37980e+02, atom= 4175
# Step= 9891, Dmax= 1.3e-03 nm, Epot= -1.87184e+05 Fmax= 1.63380e+02, atom= 4175
# Step= 9892, Dmax= 1.5e-03 nm, Epot= -1.87184e+05 Fmax= 3.25467e+02, atom= 4175
# Step= 9893, Dmax= 1.8e-03 nm, Epot= -1.87185e+05 Fmax= 2.53147e+02, atom= 4175
# Step= 9894, Dmax= 2.2e-03 nm, Epot= -1.87185e+05 Fmax= 4.48216e+02, atom= 4175
# Step= 9895, Dmax= 2.7e-03 nm, Epot= -1.87186e+05 Fmax= 3.86024e+02, atom= 4175
# Step= 9897, Dmax= 1.6e-03 nm, Epot= -1.87187e+05 Fmax= 1.18273e+02, atom= 4175
# Step= 9898, Dmax= 1.9e-03 nm, Epot= -1.87188e+05 Fmax= 4.77229e+02, atom= 4175
# Step= 9899, Dmax= 2.3e-03 nm, Epot= -1.87189e+05 Fmax= 2.48727e+02, atom= 4175
# Step= 9901, Dmax= 1.4e-03 nm, Epot= -1.87190e+05 Fmax= 1.82818e+02, atom= 4175
# Step= 9902, Dmax= 1.7e-03 nm, Epot= -1.87190e+05 Fmax= 3.42146e+02, atom= 4175
# Step= 9903, Dmax= 2.0e-03 nm, Epot= -1.87191e+05 Fmax= 2.80045e+02, atom= 4175
# Step= 9905, Dmax= 1.2e-03 nm, Epot= -1.87192e+05 Fmax= 9.68806e+01, atom= 4175
# Step= 9906, Dmax= 1.4e-03 nm, Epot= -1.87193e+05 Fmax= 3.46343e+02, atom= 4175
# Step= 9907, Dmax= 1.7e-03 nm, Epot= -1.87194e+05 Fmax= 1.96097e+02, atom= 4175
# Step= 9908, Dmax= 2.1e-03 nm, Epot= -1.87194e+05 Fmax= 4.47168e+02, atom= 4175
# Step= 9909, Dmax= 2.5e-03 nm, Epot= -1.87195e+05 Fmax= 3.33175e+02, atom= 4175
# Step= 9911, Dmax= 1.5e-03 nm, Epot= -1.87196e+05 Fmax= 1.31355e+02, atom= 4175
# Step= 9912, Dmax= 1.8e-03 nm, Epot= -1.87197e+05 Fmax= 4.34521e+02, atom= 4175
# Step= 9913, Dmax= 2.1e-03 nm, Epot= -1.87198e+05 Fmax= 2.34864e+02, atom= 4175
# Step= 9915, Dmax= 1.3e-03 nm, Epot= -1.87199e+05 Fmax= 1.70802e+02, atom= 4175
# Step= 9916, Dmax= 1.5e-03 nm, Epot= -1.87199e+05 Fmax= 3.08753e+02, atom= 4175
# Step= 9917, Dmax= 1.8e-03 nm, Epot= -1.87200e+05 Fmax= 2.74445e+02, atom= 4175
# Step= 9918, Dmax= 2.2e-03 nm, Epot= -1.87200e+05 Fmax= 4.18503e+02, atom= 4175
# Step= 9919, Dmax= 2.6e-03 nm, Epot= -1.87201e+05 Fmax= 4.20389e+02, atom= 4175
# Step= 9920, Dmax= 3.2e-03 nm, Epot= -1.87201e+05 Fmax= 5.79264e+02, atom= 4175
# Step= 9921, Dmax= 3.8e-03 nm, Epot= -1.87201e+05 Fmax= 6.27503e+02, atom= 4175
# Step= 9923, Dmax= 2.3e-03 nm, Epot= -1.87204e+05 Fmax= 9.26634e+01, atom= 4175
# Step= 9925, Dmax= 1.4e-03 nm, Epot= -1.87204e+05 Fmax= 3.46900e+02, atom= 4175
# Step= 9926, Dmax= 1.6e-03 nm, Epot= -1.87205e+05 Fmax= 1.70604e+02, atom= 4175
# Step= 9927, Dmax= 2.0e-03 nm, Epot= -1.87206e+05 Fmax= 4.58625e+02, atom= 4175
# Step= 9928, Dmax= 2.4e-03 nm, Epot= -1.87207e+05 Fmax= 2.87591e+02, atom= 4175
# Step= 9930, Dmax= 1.4e-03 nm, Epot= -1.87208e+05 Fmax= 1.64058e+02, atom= 4175
# Step= 9931, Dmax= 1.7e-03 nm, Epot= -1.87208e+05 Fmax= 3.70367e+02, atom= 4175
# Step= 9932, Dmax= 2.0e-03 nm, Epot= -1.87209e+05 Fmax= 2.79242e+02, atom= 4175
# Step= 9933, Dmax= 2.5e-03 nm, Epot= -1.87209e+05 Fmax= 4.93190e+02, atom= 4175
# Step= 9934, Dmax= 3.0e-03 nm, Epot= -1.87210e+05 Fmax= 4.41403e+02, atom= 4175
# Step= 9936, Dmax= 1.8e-03 nm, Epot= -1.87211e+05 Fmax= 1.15653e+02, atom= 4175
# Step= 9937, Dmax= 2.1e-03 nm, Epot= -1.87212e+05 Fmax= 5.62838e+02, atom= 4175
# Step= 9938, Dmax= 2.6e-03 nm, Epot= -1.87213e+05 Fmax= 2.39478e+02, atom= 4175
# Step= 9940, Dmax= 1.5e-03 nm, Epot= -1.87214e+05 Fmax= 2.46434e+02, atom= 4175
# Step= 9941, Dmax= 1.8e-03 nm, Epot= -1.87214e+05 Fmax= 3.29750e+02, atom= 4175
# Step= 9942, Dmax= 2.2e-03 nm, Epot= -1.87215e+05 Fmax= 3.68874e+02, atom= 4175
# Step= 9943, Dmax= 2.6e-03 nm, Epot= -1.87215e+05 Fmax= 4.62387e+02, atom= 4175
# Step= 9944, Dmax= 3.2e-03 nm, Epot= -1.87216e+05 Fmax= 5.42078e+02, atom= 4175
# Step= 9946, Dmax= 1.9e-03 nm, Epot= -1.87218e+05 Fmax= 5.69491e+01, atom= 4175
# Step= 9947, Dmax= 2.3e-03 nm, Epot= -1.87220e+05 Fmax= 6.80560e+02, atom= 4175
# Step= 9948, Dmax= 2.7e-03 nm, Epot= -1.87222e+05 Fmax= 1.81807e+02, atom= 4175
# Step= 9950, Dmax= 1.6e-03 nm, Epot= -1.87223e+05 Fmax= 3.41522e+02, atom= 4175
# Step= 9951, Dmax= 2.0e-03 nm, Epot= -1.87223e+05 Fmax= 2.78854e+02, atom= 4175
# Step= 9952, Dmax= 2.4e-03 nm, Epot= -1.87223e+05 Fmax= 4.72606e+02, atom= 4175
# Step= 9953, Dmax= 2.8e-03 nm, Epot= -1.87224e+05 Fmax= 4.21555e+02, atom= 4175
# Step= 9955, Dmax= 1.7e-03 nm, Epot= -1.87226e+05 Fmax= 1.18653e+02, atom= 4175
# Step= 9956, Dmax= 2.0e-03 nm, Epot= -1.87226e+05 Fmax= 5.19759e+02, atom= 4175
# Step= 9957, Dmax= 2.5e-03 nm, Epot= -1.87228e+05 Fmax= 2.57943e+02, atom= 4175
# Step= 9959, Dmax= 1.5e-03 nm, Epot= -1.87228e+05 Fmax= 2.04639e+02, atom= 4175
# Step= 9960, Dmax= 1.8e-03 nm, Epot= -1.87229e+05 Fmax= 3.57400e+02, atom= 4175
# Step= 9961, Dmax= 2.1e-03 nm, Epot= -1.87230e+05 Fmax= 3.09569e+02, atom= 4175
# Step= 9963, Dmax= 1.3e-03 nm, Epot= -1.87230e+05 Fmax= 9.43021e+01, atom= 4175
# Step= 9964, Dmax= 1.5e-03 nm, Epot= -1.87232e+05 Fmax= 3.80674e+02, atom= 4175
# Step= 9965, Dmax= 1.8e-03 nm, Epot= -1.87233e+05 Fmax= 2.00395e+02, atom= 4175
# Step= 9966, Dmax= 2.2e-03 nm, Epot= -1.87233e+05 Fmax= 4.89079e+02, atom= 4175
# Step= 9967, Dmax= 2.6e-03 nm, Epot= -1.87234e+05 Fmax= 3.46782e+02, atom= 4175
# Step= 9969, Dmax= 1.6e-03 nm, Epot= -1.87235e+05 Fmax= 1.51094e+02, atom= 4175
# Step= 9970, Dmax= 1.9e-03 nm, Epot= -1.87235e+05 Fmax= 4.54293e+02, atom= 4175
# Step= 9971, Dmax= 2.3e-03 nm, Epot= -1.87236e+05 Fmax= 2.63127e+02, atom= 4175
# Step= 9973, Dmax= 1.4e-03 nm, Epot= -1.87237e+05 Fmax= 1.71199e+02, atom= 4175
# Step= 9974, Dmax= 1.6e-03 nm, Epot= -1.87238e+05 Fmax= 3.42861e+02, atom= 4175
# Step= 9975, Dmax= 2.0e-03 nm, Epot= -1.87239e+05 Fmax= 2.81873e+02, atom= 4175
# Step= 9976, Dmax= 2.4e-03 nm, Epot= -1.87239e+05 Fmax= 4.60879e+02, atom= 4175
# Step= 9977, Dmax= 2.8e-03 nm, Epot= -1.87239e+05 Fmax= 4.37861e+02, atom= 4175
# Step= 9979, Dmax= 1.7e-03 nm, Epot= -1.87241e+05 Fmax= 9.76803e+01, atom= 4175
# Step= 9980, Dmax= 2.0e-03 nm, Epot= -1.87241e+05 Fmax= 5.55883e+02, atom= 4175
# Step= 9981, Dmax= 2.5e-03 nm, Epot= -1.87243e+05 Fmax= 2.15436e+02, atom= 4175
# Step= 9983, Dmax= 1.5e-03 nm, Epot= -1.87244e+05 Fmax= 2.51927e+02, atom= 4175
# Step= 9984, Dmax= 1.8e-03 nm, Epot= -1.87244e+05 Fmax= 3.02113e+02, atom= 4175
# Step= 9985, Dmax= 2.1e-03 nm, Epot= -1.87245e+05 Fmax= 3.69717e+02, atom= 4175
# Step= 9986, Dmax= 2.5e-03 nm, Epot= -1.87245e+05 Fmax= 4.29469e+02, atom= 4175
# Step= 9987, Dmax= 3.1e-03 nm, Epot= -1.87245e+05 Fmax= 5.36673e+02, atom= 4175
# Step= 9988, Dmax= 3.7e-03 nm, Epot= -1.87246e+05 Fmax= 6.15505e+02, atom= 4175
# Step= 9990, Dmax= 2.2e-03 nm, Epot= -1.87248e+05 Fmax= 7.96972e+01, atom= 4175
# Step= 9991, Dmax= 2.6e-03 nm, Epot= -1.87249e+05 Fmax= 7.38094e+02, atom= 4175
# Step= 9992, Dmax= 3.2e-03 nm, Epot= -1.87252e+05 Fmax= 2.63300e+02, atom= 4175
# Step= 9994, Dmax= 1.9e-03 nm, Epot= -1.87252e+05 Fmax= 3.32485e+02, atom= 4175
# Step= 9995, Dmax= 2.3e-03 nm, Epot= -1.87253e+05 Fmax= 3.89463e+02, atom= 4175
# Step= 9996, Dmax= 2.7e-03 nm, Epot= -1.87253e+05 Fmax= 4.69940e+02, atom= 4175
# Step= 9997, Dmax= 3.3e-03 nm, Epot= -1.87253e+05 Fmax= 5.68177e+02, atom= 4175
# Step= 9998, Dmax= 3.9e-03 nm, Epot= -1.87253e+05 Fmax= 6.70617e+02, atom= 4175
# Step=10000, Dmax= 2.4e-03 nm, Epot= -1.87256e+05 Fmax= 7.66069e+01, atom= 4175
#
# Energy minimization reached the maximum number of steps before the forces
# reached the requested precision Fmax < 10.
#
# writing lowest energy coordinates.
#
# Back Off! I just backed up em_comp2.gro to ./#em_comp2.gro.1#
#
# Steepest Descents did not converge to Fmax < 10 in 10001 steps.
# Potential Energy  = -1.8725594e+05
# Maximum force     =  7.6606895e+01 on atom 4175
# Norm of force     =  3.7643915e+00
#
# GROMACS reminds you: "We think there is color, we think there is sweet, we think there is bitter, but in reality there are atoms and a void." (Democritus)
#
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: D
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: G
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: R
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
#                       :-) GROMACS - gmx grompp, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx grompp -f /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/mdps/eq_3_20ns.mdp -c em_comp2.gro -r em_comp2.gro -p topol_comp2_W.top -n index_comp2_mem.ndx -o eq1_comp2_in.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'ns_type'
#
# WARNING 1 [file /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/mdps/eq_3_20ns.mdp]:
#   The Berendsen barostat does not generate any strictly correct ensemble,
#   and should not be used for new production simulations (in our opinion).
#   We recommend using the C-rescale barostat instead.
#
# Number of degrees of freedom in T-Coupling group Solute is 10414.64
# Number of degrees of freedom in T-Coupling group solvent is 12574.36
#
# NOTE 1 [file /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/mdps/eq_3_20ns.mdp]:
#   There are 780 non-linear virtual site constructions. Their contribution
#   to the energy error is approximated. In most cases this does not affect
#   the error significantly.
#
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# Back Off! I just backed up eq1_comp2_in.tpr to ./#eq1_comp2_in.tpr.1#
#
# GROMACS reminds you: "The farther the experiment is from theory, the closer it is to the Nobel Prize." (Irene Joliot-Curie)
#
#                       :-) GROMACS - gmx mdrun, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx mdrun -v -deffnm eq1_comp2_in -nt 10 -pin on -pinstride 1 -pinoffset 30
# Setting the LD random seed to -33820181
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'MC3H'
#
# Excluding 1 bonded neighbours molecule type 'DPPC'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'MC3H'
#
# Excluding 1 bonded neighbours molecule type 'DPPC'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 310 K
#
# Calculated rlist for 1x1 atom pair-list as 1.305 nm, buffer size 0.205 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.215 nm, buffer size 0.115 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 9 Mb of data
# Back Off! I just backed up eq1_comp2_in.log to ./#eq1_comp2_in.log.1#
# Reading file eq1_comp2_in.tpr, VERSION 2023.3 (single precision)
# Changing nstlist from 20 to 25, rlist from 1.215 to 1.269
#
# Update groups can not be used for this system because an incompatible virtual site type is used
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 10 OpenMP threads
#
# Applying core pinning offset 30
#
# Back Off! I just backed up eq1_comp2_in.xtc to ./#eq1_comp2_in.xtc.1#
#
# Back Off! I just backed up eq1_comp2_in.edr to ./#eq1_comp2_in.edr.1#
# starting mdrun 'INSANE! Membrane UpperLeaflet>MC3H:DPPC:CHOL=50.0:10.0:40.0 LowerLeaflet>MC3H:DPPC:CHOL=50.0:10.0:40.0 in water'
# 1000000 steps,  20000.0 ps.
#
# Step 0  Warning: pressure scaling more than 1%, mu: 0.985446 0.985446 0.990056
# step 0
# Step 100  Warning: pressure scaling more than 1%, mu: 1.00441 1.00441 1.01085
# step 999900, remaining wall clock time:     0 s
# Writing final coordinates.
#
# Back Off! I just backed up eq1_comp2_in.gro to ./#eq1_comp2_in.gro.1#
# step 1000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     2600.683      260.068     1000.0
#                  (ns/day)    (hour/ns)
# Performance:     6644.412        0.004
#
# GROMACS reminds you: "A computer would deserve to be called intelligent if it could deceive a human into believing that it was human." (Alan Turing)
#
#                      :-) GROMACS - gmx editconf, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx editconf -f eq1_comp2_in.gro -o eq1_comp2.gro -resnr 1 -box 10 10 22
#
#
# Back Off! I just backed up eq1_comp2.gro to ./#eq1_comp2.gro.1#
#
# GROMACS reminds you: "A computer would deserve to be called intelligent if it could deceive a human into believing that it was human." (Alan Turing)
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 8600 atoms
# Volume: 863.52 nm^3, corresponds to roughly 388500 electrons
# Velocities found
#     system size : 12.524 12.061  9.254 (nm)
#     center      :  4.762  4.855  4.620 (nm)
#     box vectors :  9.655  9.655  9.264 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  : 863.52               (nm^3)
#     shift       :  0.238  0.145  6.380 (nm)
# new center      :  5.000  5.000 11.000 (nm)
# new box vectors : 10.000 10.000 22.000 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :2200.00               (nm^3)
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: T
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/coordinates/GRO.py:479: UserWarning: missing dimension - setting unit cell to zeroed box [0., 0., 0.]
#   warnings.warn(wmsg)
#                      :-) GROMACS - gmx editconf, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx editconf -f stacked_membrane.gro -o stacked_membrane_renum.gro -resnr 1 -box 10 10 18
#
#
# Back Off! I just backed up stacked_membrane_renum.gro to ./#stacked_membrane_renum.gro.1#
#
# GROMACS reminds you: "A computer would deserve to be called intelligent if it could deceive a human into believing that it was human." (Alan Turing)
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 7919 atoms
# Volume: 0 nm^3, corresponds to roughly 0 electrons
# No velocities found
#     system size : 12.650 12.061 12.980 (nm)
#     center      :  4.794  4.929  7.912 (nm)
#     box vectors :  0.000  0.000  0.000 (nm)
#     box angles  :   0.00   0.00   0.00 (degrees)
#     box volume  :   0.00               (nm^3)
#     shift       :  0.206  0.071  1.088 (nm)
# new center      :  5.000  5.000  9.000 (nm)
# new box vectors : 10.000 10.000 18.000 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :1800.00               (nm^3)

# %%
## Check the box sizes match 
# !tail eq1_comp1.gro
# !tail eq1_comp2_in.gro
# Out:
#  3940ION     NA 7318   0.581   3.344   2.598 -0.2184 -0.0278 -0.0602
#  3941ION     NA 7319   1.649   1.259   1.983  0.0654  0.1726  0.3719
#  3942ION     NA 7320   2.528   7.726   7.846  0.0739 -0.2665  0.3699
#  3943ION     NA 7321   3.723   5.878   2.155  0.1507  0.3152  0.2357
#  3944ION     NA 7322   6.315   2.893   1.507  0.0639 -0.2550  0.1729
#  3945ION     NA 7323   4.270   3.482   6.193  0.2119  0.1128 -0.1714
#  3946ION     NA 7324   3.240   4.967   1.583  0.0397  0.1190  0.0400
#  3947ION     NA 7325   7.694   6.461   7.017 -0.0207  0.0629  0.0560
#  3948ION     NA 7326   6.919   9.101   1.758  0.0152 -0.1243  0.0954
#    9.57512   9.57512   8.56850
#  4770ION     CL 8592   4.030   5.354   1.962 -0.2684 -0.4282 -0.0721
#  4771ION     CL 8593   7.078   7.800   2.061  0.4847  0.1125 -0.1771
#  4772ION     CL 8594   9.200   3.273   2.280  0.4055  0.2888 -0.1975
#  4773ION     CL 8595   0.645   8.326   7.491  0.0976  0.3912 -0.1172
#  4774ION     CL 8596   0.092   6.035   1.672  0.0609  0.2755  0.3367
#  4775ION     CL 8597   8.183   7.556   7.664 -0.0597  0.0639 -0.3233
#  4776ION     CL 8598   2.892   7.652   8.851 -0.0608 -0.1896  0.3573
#  4777ION     CL 8599   2.207   7.024   8.424 -0.1493 -0.1065 -0.1157
#  4778ION     CL 8600   0.430   4.135   7.324 -0.2381 -0.1989  0.3793
#    9.65463   9.65463   9.26406

# %% [markdown]
# ## Create topology
# ===============================================================================================

# %%
############# Create topology file
with open('topol_comp1_W.top') as topinput:
    top = topinput.readlines()[:-2]

## write the file
with open("system.top", "w") as f:
    top = "".join(top)
    f.write(top)
    
############# Add Comp2 membrane lipids
with open('system.top') as topinput:
    sys = topinput.read()
    
## Find line were molecules start    
lookup = '[ molecules ]'    
with open('topol_comp2.top') as topinput:
    for num, line in enumerate(topinput,1):
        if lookup in line:
            mem2 = topinput.read()[num:]
    
sys += ';membrane2'
sys += mem2

with open("system.top", "w") as f:
    f.write(sys)

# %%
# !cat system.top
# Out:
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//martini_v3.0.0.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//Martini_v1_tails-2.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//martini_v3.0.0_ions_v1.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//martini_v3.0.0_solvents_v1.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//martini_v3.0_phosphoinositides_v1.0.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//martini_v3.0.0_phospholipids_v1.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//martini_v3.0_CHOL_dev20.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//WN_fbposres.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//MC3_MC3H.itp"
#
# [ system ]
# ; name
# INSANE! Membrane UpperLeaflet>POPC:PAPS:PAPC:POPE:DIPE:DPSM:CHOL=640.0:264.0:56.0:264.0:160.0:640.0:826.0 LowerLeaflet>POPC:PAPC:POPE:DIPE:DPSM:CHOL:PAPS:SAP6=373.0:213.0:133.0:426.0:293.0:746.0:666.0:53.0 in water
#
# [ molecules ]
# ;membrane1   number
# POPC            37
# PAPS            15
# PAPC             3
# POPE            15
# DIPE             9
# DPSM            37
# CHOL            48
# POPC            21
# PAPC            12
# POPE             7
# DIPE            24
# DPSM            17
# CHOL            43
# PAPS            38
# SAP6             3
# ;membrane2 number
# MC3H            98
# DPPC            19
# CHOL            78
# MC3H            98
# DPPC            19
# CHOL            78

# %% [markdown]
# ### Solvate and equilibrate system
# ===============================================================================================

# %%
not_tails = 'NP CN GLA CX NC3 NH3 CNO C1 C2 C3 C4 P4 P5 PO4 GL1 GL2 AM1 AM2 ROH BB SC1 SC2 SC3 SC4 SC5 CA' #### atoms belonging to the 'heads' of the lipids
neg_lipids = {'PAPS SAP6': -1}  ##### write the name of the lipid and the charge without + or -
pos_lipids = {f'{IL_name}': +1}

### Run
solvate(not_tails)
neutralize(neg_lipids, pos_lipids)
# Out:
#                      :-) GROMACS - gmx solvate, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx solvate -cp stacked_membrane_renum.gro -cs /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/common_files/water.gro -p system.top -o stacked_membrane_renum_W.gro -radius 0.21
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
# Generating solvent configuration
# Will generate new solvent configuration of 3x3x5 boxes
# Solvent box contains 17035 atoms in 17035 residues
# Removed 2792 solvent atoms due to solvent-solvent overlap
# Removed 6392 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#       W (   1 atoms):  7851 residues
# Generated solvent containing 7851 atoms in 7851 residues
# Writing generated configuration to stacked_membrane_renum_W.gro
#
# Back Off! I just backed up stacked_membrane_renum_W.gro to ./#stacked_membrane_renum_W.gro.2#
#
# Output configuration contains 15770 atoms in 8570 residues
# Volume                 :        1800 (nm^3)
# Density                :     1425.33 (g/l)
# Number of solvent molecules:   7851
#
# Processing topology
#
# Back Off! I just backed up system.top to ./#system.top.3#
#
# GROMACS reminds you: "Would you give it all up to live again?" (Bad Religion)
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Adding line for 7851 solvent molecules with resname (W) to topology file (system.top)
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: D
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: G
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: R
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: T
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# 5.618181818181818
# 5.530322004984884 12.05552527962827
# All done
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: D
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: G
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: R
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: T
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# <LeafletFinder('name PO4 NP', cutoff=20.0 A) with 234 atoms in 5 groups> <LeafletFinder('name PO4 NP', cutoff=18.0 A) with 238 atoms in 2 groups>
# -14
#                       :-) GROMACS - gmx grompp, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx grompp -f empty.mdp -c stacked_membrane_renum_W_order.gro -r stacked_membrane_renum_W_order.gro -p system_W.top -o ions_2.tpr -renum -maxwarn 1
#
#
# NOTE 1 [file empty.mdp]:
#   For a correct single-point energy evaluation with nsteps = 0, use
#   continuation = yes to avoid constraining the input coordinates.
#
#
# NOTE 2 [file system_W.top, line 40]:
#   System has non-zero total charge: 131.000000
#   Total charge should normally be an integer. See
#   http://www.gromacs.org/Documentation/Floating_Point_Arithmetic
#   for discussion on how close it should be to an integer.
#
#
#
# atom name 7920 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7921 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7922 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7923 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7924 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7925 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7926 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7927 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7928 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7929 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7930 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7931 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7932 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7933 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7934 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7935 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7936 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7937 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7938 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7939 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# (more than 20 non-matching atom names)
#
# WARNING 1 [file system_W.top, line 40]:
#   7851 non-matching atom names
#   atom names from system_W.top will be used
#   atom names from stacked_membrane_renum_W_order.gro will be ignored
#
#
#
# NOTE 3 [file system_W.top, line 40]:
#   For energy conservation with LINCS, lincs_iter should be 2 or larger.
#
#
# Number of degrees of freedom in T-Coupling group rest is 42843.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# NOTE 4 [file empty.mdp]:
#   NVE simulation with an initial temperature of zero: will use a Verlet
#   buffer of 10%. Check your energy drift!
#
#
# NOTE 5 [file empty.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
#
# There were 5 NOTEs
#
# There was 1 WARNING
#
# GROMACS reminds you: "Push It Real Good" (Salt 'n' Pepa)
#
#                       :-) GROMACS - gmx genion, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx genion -s ions_2.tpr -o mem_solvent_ions.gro -p system_W.top -np 14 -pname NA -n index.ndx
#
# Reading file ions_2.tpr, VERSION 2023.3 (single precision)
# Reading file ions_2.tpr, VERSION 2023.3 (single precision)
# Group     0 (  LowerMembrane) has  3708 elements
# Group     1 (  UpperMembrane) has  4211 elements
# Group     2 (    MiddleWater) has  1854 elements
# Group     3 (     OuterWater) has  5997 elements
# Group     4 (          tails) has  3793 elements
# Group     5 (          water) has  7851 elements
# Group     6 (         System) has 15770 elements
# Select a group: Number of (1-atomic) solvent molecules: 1854
#
# Back Off! I just backed up system_W.top to ./#system_W.top.1#
# Using random seed -1613365295.
# Replacing solvent molecule 173 (atom 8092) with NA
# Replacing solvent molecule 618 (atom 8537) with NA
# Replacing solvent molecule 1223 (atom 9142) with NA
# Replacing solvent molecule 479 (atom 8398) with NA
# Replacing solvent molecule 1492 (atom 9411) with NA
# Replacing solvent molecule 761 (atom 8680) with NA
# Replacing solvent molecule 209 (atom 8128) with NA
# Replacing solvent molecule 1007 (atom 8926) with NA
# Replacing solvent molecule 853 (atom 8772) with NA
# Replacing solvent molecule 1760 (atom 9679) with NA
# Replacing solvent molecule 1109 (atom 9028) with NA
# Replacing solvent molecule 1544 (atom 9463) with NA
# Replacing solvent molecule 1557 (atom 9476) with NA
# Replacing solvent molecule 740 (atom 8659) with NA
#
#
# GROMACS reminds you: "Push It Real Good" (Salt 'n' Pepa)
# Setting the LD random seed to 1052766199
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'SAP6'
#
# Excluding 1 bonded neighbours molecule type 'MC3H'
#
# Excluding 1 bonded neighbours molecule type 'DPPC'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'MC3H'
#
# Excluding 1 bonded neighbours molecule type 'DPPC'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'MiddleWater'
#
# Excluding 1 bonded neighbours molecule type 'OuterWater'
#
# atom name 7920 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7921 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7922 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7923 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7924 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7925 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7926 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7927 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7928 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7929 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7930 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7931 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7932 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7933 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7934 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7935 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7936 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7937 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7938 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# atom name 7939 in system_W.top and stacked_membrane_renum_W_order.gro does not match (WN - W)
#
# (more than 20 non-matching atom names)
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:  8570      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 1 Mb of data
# Will try to add 14 NA ions and 0 CL ions.
# Select a continuous group of solvent molecules
# Selected 2: 'MiddleWater'
#
# Processing topology
# Replacing 14 solute molecules in topology file (system_W.top)  by 14 NA and 0 CL ions.
#                       :-) GROMACS - gmx grompp, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx grompp -f empty.mdp -c mem_solvent_ions.gro -r mem_solvent_ions.gro -p system_W.top -o ions.tpr -renum -maxwarn 1
#
#
# NOTE 1 [file empty.mdp]:
#   For a correct single-point energy evaluation with nsteps = 0, use
#   continuation = yes to avoid constraining the input coordinates.
#
#
# NOTE 2 [file system_W.top, line 41]:
#   System has non-zero total charge: 145.000000
#   Total charge should normally be an integer. See
#   http://www.gromacs.org/Documentation/Floating_Point_Arithmetic
#   for discussion on how close it should be to an integer.
#
#
#
#
# NOTE 3 [file system_W.top, line 41]:
#   For energy conservation with LINCS, lincs_iter should be 2 or larger.
#
#
# Number of degrees of freedom in T-Coupling group rest is 42843.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# NOTE 4 [file empty.mdp]:
#   NVE simulation with an initial temperature of zero: will use a Verlet
#   buffer of 10%. Check your energy drift!
#
#
# NOTE 5 [file empty.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
#
# There were 5 NOTEs
#
# Back Off! I just backed up ions.tpr to ./#ions.tpr.1#
#
# GROMACS reminds you: "The scientific method is an integral part of human intelligence, and when it has once been set at work it can only be dismissed by dismissing the intelligence itself" (George H. Mead)
#
#                       :-) GROMACS - gmx genion, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx genion -s ions.tpr -o mem_solvent_ions.gro -p system_W.top -neutral -n index.ndx
#
# Reading file ions.tpr, VERSION 2023.3 (single precision)
# Reading file ions.tpr, VERSION 2023.3 (single precision)
# Group     0 (  LowerMembrane) has  3708 elements
# Group     1 (  UpperMembrane) has  4211 elements
# Group     2 (    MiddleWater) has  1854 elements
# Group     3 (     OuterWater) has  5997 elements
# Group     4 (          tails) has  3793 elements
# Group     5 (          water) has  7851 elements
# Group     6 (         System) has 15770 elements
# Select a group: Number of (1-atomic) solvent molecules: 5997
#
# Back Off! I just backed up system_W.top to ./#system_W.top.2#
# Using random seed -5399441.
# Replacing solvent molecule 3350 (atom 13123) with CL
# Replacing solvent molecule 1355 (atom 11128) with CL
# Replacing solvent molecule 2148 (atom 11921) with CL
# Replacing solvent molecule 4784 (atom 14557) with CL
# Replacing solvent molecule 348 (atom 10121) with CL
# Replacing solvent molecule 4735 (atom 14508) with CL
# Replacing solvent molecule 5925 (atom 15698) with CL
# Replacing solvent molecule 13 (atom 9786) with CL
# Replacing solvent molecule 2419 (atom 12192) with CL
# Replacing solvent molecule 757 (atom 10530) with CL
# Replacing solvent molecule 3212 (atom 12985) with CL
# Replacing solvent molecule 4203 (atom 13976) with CL
# Replacing solvent molecule 3567 (atom 13340) with CL
# Replacing solvent molecule 5058 (atom 14831) with CL
# Replacing solvent molecule 1489 (atom 11262) with CL
# Replacing solvent molecule 818 (atom 10591) with CL
# Replacing solvent molecule 640 (atom 10413) with CL
# Replacing solvent molecule 3550 (atom 13323) with CL
# Replacing solvent molecule 2290 (atom 12063) with CL
# Replacing solvent molecule 2061 (atom 11834) with CL
# Replacing solvent molecule 2732 (atom 12505) with CL
# Replacing solvent molecule 491 (atom 10264) with CL
# Replacing solvent molecule 3994 (atom 13767) with CL
# Replacing solvent molecule 4190 (atom 13963) with CL
# Replacing solvent molecule 5384 (atom 15157) with CL
# Replacing solvent molecule 3440 (atom 13213) with CL
# Replacing solvent molecule 2702 (atom 12475) with CL
# Replacing solvent molecule 3243 (atom 13016) with CL
# Replacing solvent molecule 4152 (atom 13925) with CL
# Replacing solvent molecule 4016 (atom 13789) with CL
# Replacing solvent molecule 5875 (atom 15648) with CL
# Replacing solvent molecule 719 (atom 10492) with CL
# Replacing solvent molecule 3187 (atom 12960) with CL
# Replacing solvent molecule 5466 (atom 15239) with CL
# Replacing solvent molecule 114 (atom 9887) with CL
# Replacing solvent molecule 313 (atom 10086) with CL
# Replacing solvent molecule 1287 (atom 11060) with CL
# Replacing solvent molecule 3899 (atom 13672) with CL
# Replacing solvent molecule 2861 (atom 12634) with CL
# Replacing solvent molecule 2889 (atom 12662) with CL
# Replacing solvent molecule 2492 (atom 12265) with CL
# Replacing solvent molecule 1593 (atom 11366) with CL
# Replacing solvent molecule 4468 (atom 14241) with CL
# Replacing solvent molecule 1391 (atom 11164) with CL
# Replacing solvent molecule 1665 (atom 11438) with CL
# Replacing solvent molecule 4928 (atom 14701) with CL
# Replacing solvent molecule 2680 (atom 12453) with CL
# Replacing solvent molecule 5589 (atom 15362) with CL
# Replacing solvent molecule 3794 (atom 13567) with CL
# Replacing solvent molecule 12 (atom 9785) with CL
# Replacing solvent molecule 1086 (atom 10859) with CL
# Replacing solvent molecule 5521 (atom 15294) with CL
# Replacing solvent molecule 5002 (atom 14775) with CL
# Replacing solvent molecule 214 (atom 9987) with CL
# Replacing solvent molecule 2747 (atom 12520) with CL
# Replacing solvent molecule 1515 (atom 11288) with CL
# Replacing solvent molecule 3604 (atom 13377) with CL
# Replacing solvent molecule 3133 (atom 12906) with CL
# Replacing solvent molecule 4322 (atom 14095) with CL
# Replacing solvent molecule 1091 (atom 10864) with CL
# Replacing solvent molecule 4001 (atom 13774) with CL
# Replacing solvent molecule 1041 (atom 10814) with CL
# Replacing solvent molecule 628 (atom 10401) with CL
# Replacing solvent molecule 726 (atom 10499) with CL
# Replacing solvent molecule 4950 (atom 14723) with CL
# Replacing solvent molecule 771 (atom 10544) with CL
# Replacing solvent molecule 2167 (atom 11940) with CL
# Replacing solvent molecule 4002 (atom 13775) with CL
# Replacing solvent molecule 5514 (atom 15287) with CL
# Replacing solvent molecule 564 (atom 10337) with CL
# Replacing solvent molecule 1607 (atom 11380) with CL
# Replacing solvent molecule 742 (atom 10515) with CL
# Replacing solvent molecule 4388 (atom 14161) with CL
# Replacing solvent molecule 1069 (atom 10842) with CL
# Replacing solvent molecule 917 (atom 10690) with CL
# Replacing solvent molecule 4918 (atom 14691) with CL
# Replacing solvent molecule 5977 (atom 15750) with CL
# Replacing solvent molecule 4998 (atom 14771) with CL
# Replacing solvent molecule 956 (atom 10729) with CL
# Replacing solvent molecule 2746 (atom 12519) with CL
# Replacing solvent molecule 1321 (atom 11094) with CL
# Replacing solvent molecule 644 (atom 10417) with CL
# Replacing solvent molecule 5896 (atom 15669) with CL
# Replacing solvent molecule 4616 (atom 14389) with CL
# Replacing solvent molecule 5047 (atom 14820) with CL
# Replacing solvent molecule 5646 (atom 15419) with CL
# Replacing solvent molecule 5746 (atom 15519) with CL
# Replacing solvent molecule 5874 (atom 15647) with CL
# Replacing solvent molecule 5825 (atom 15598) with CL
# Replacing solvent molecule 3466 (atom 13239) with CL
# Replacing solvent molecule 3654 (atom 13427) with CL
# Replacing solvent molecule 386 (atom 10159) with CL
# Replacing solvent molecule 4301 (atom 14074) with CL
# Replacing solvent molecule 4931 (atom 14704) with CL
# Replacing solvent molecule 4046 (atom 13819) with CL
# Replacing solvent molecule 1679 (atom 11452) with CL
# Replacing solvent molecule 2431 (atom 12204) with CL
# Replacing solvent molecule 1525 (atom 11298) with CL
# Replacing solvent molecule 3292 (atom 13065) with CL
# Replacing solvent molecule 3814 (atom 13587) with CL
# Replacing solvent molecule 851 (atom 10624) with CL
# Replacing solvent molecule 3547 (atom 13320) with CL
# Replacing solvent molecule 698 (atom 10471) with CL
# Replacing solvent molecule 3169 (atom 12942) with CL
# Replacing solvent molecule 5144 (atom 14917) with CL
# Replacing solvent molecule 5644 (atom 15417) with CL
# Replacing solvent molecule 417 (atom 10190) with CL
# Replacing solvent molecule 2179 (atom 11952) with CL
# Replacing solvent molecule 5909 (atom 15682) with CL
# Replacing solvent molecule 5288 (atom 15061) with CL
# Replacing solvent molecule 2977 (atom 12750) with CL
# Replacing solvent molecule 1591 (atom 11364) with CL
# Replacing solvent molecule 5114 (atom 14887) with CL
# Replacing solvent molecule 786 (atom 10559) with CL
# Replacing solvent molecule 3670 (atom 13443) with CL
# Replacing solvent molecule 3905 (atom 13678) with CL
# Replacing solvent molecule 1821 (atom 11594) with CL
# Replacing solvent molecule 3569 (atom 13342) with CL
# Replacing solvent molecule 5854 (atom 15627) with CL
# Replacing solvent molecule 517 (atom 10290) with CL
# Replacing solvent molecule 4285 (atom 14058) with CL
# Replacing solvent molecule 2649 (atom 12422) with CL
# Replacing solvent molecule 1293 (atom 11066) with CL
# Replacing solvent molecule 1302 (atom 11075) with CL
# Replacing solvent molecule 137 (atom 9910) with CL
# Replacing solvent molecule 507 (atom 10280) with CL
# Replacing solvent molecule 2881 (atom 12654) with CL
# Replacing solvent molecule 2510 (atom 12283) with CL
# Replacing solvent molecule 500 (atom 10273) with CL
# Replacing solvent molecule 276 (atom 10049) with CL
# Replacing solvent molecule 1358 (atom 11131) with CL
# Replacing solvent molecule 3141 (atom 12914) with CL
# Replacing solvent molecule 4540 (atom 14313) with CL
# Replacing solvent molecule 490 (atom 10263) with CL
# Replacing solvent molecule 4760 (atom 14533) with CL
# Replacing solvent molecule 4213 (atom 13986) with CL
# Replacing solvent molecule 1263 (atom 11036) with CL
# Replacing solvent molecule 2978 (atom 12751) with CL
# Replacing solvent molecule 1467 (atom 11240) with CL
# Replacing solvent molecule 5469 (atom 15242) with CL
# Replacing solvent molecule 639 (atom 10412) with CL
# Replacing solvent molecule 1506 (atom 11279) with CL
# Replacing solvent molecule 768 (atom 10541) with CL
# Replacing solvent molecule 4180 (atom 13953) with CL
# Replacing solvent molecule 2713 (atom 12486) with CL
#
#
# Back Off! I just backed up mem_solvent_ions.gro to ./#mem_solvent_ions.gro.1#
#
# GROMACS reminds you: "The scientific method is an integral part of human intelligence, and when it has once been set at work it can only be dismissed by dismissing the intelligence itself" (George H. Mead)
# Setting the LD random seed to -742426642
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'SAP6'
#
# Excluding 1 bonded neighbours molecule type 'MC3H'
#
# Excluding 1 bonded neighbours molecule type 'DPPC'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'MC3H'
#
# Excluding 1 bonded neighbours molecule type 'DPPC'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'MiddleWater'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Excluding 1 bonded neighbours molecule type 'OuterWater'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:  8570      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 1 Mb of data
# Will try to add 0 NA ions and 145 CL ions.
# Select a continuous group of solvent molecules
# Selected 3: 'OuterWater'
#
# Processing topology
# Replacing 145 solute molecules in topology file (system_W.top)  by 0 NA and 145 CL ions.

# %% [markdown]
# ### Minimize and equilibrate system with cell and viral membranes
# ===============================================================================================

# %%
### Minimize and equilibrate the double bilayer system
minimize_equilibrate()
# Out:
#                       :-) GROMACS - gmx grompp, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx grompp -f /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/mdps/em_2.mdp -c mem_solvent_ions.gro -r restraint_reference.gro -p system_W.top -o em2.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
# Number of degrees of freedom in T-Coupling group rest is 43593.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# GROMACS reminds you: "I'll Match Your DNA" (Red Hot Chili Peppers)
#
#                       :-) GROMACS - gmx mdrun, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx mdrun -v -deffnm em2 -nt 10 -pin on -pinstride 1 -pinoffset 30
# Setting the LD random seed to -755175562
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'SAP6'
#
# Excluding 1 bonded neighbours molecule type 'MC3H'
#
# Excluding 1 bonded neighbours molecule type 'DPPC'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'MC3H'
#
# Excluding 1 bonded neighbours molecule type 'DPPC'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'MiddleWater'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Excluding 1 bonded neighbours molecule type 'OuterWater'
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:  8570      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 2 Mb of data
# Reading file em2.tpr, VERSION 2023.3 (single precision)
# Update groups can not be used for this system because an incompatible virtual site type is used
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 10 OpenMP threads
#
# Applying core pinning offset 30
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+01
#    Number of steps    =        10000
# Step=    0, Dmax= 1.0e-02 nm, Epot=  2.46859e+08 Fmax= 9.53865e+09, atom= 2292
# Step=    1, Dmax= 1.0e-02 nm, Epot=  1.22168e+08 Fmax= 1.69977e+09, atom= 2292
# Step=    2, Dmax= 1.2e-02 nm, Epot=  3.94911e+07 Fmax= 3.43456e+08, atom= 2292
# Step=    3, Dmax= 1.4e-02 nm, Epot=  1.52630e+07 Fmax= 5.99876e+07, atom= 5931
# Step=    4, Dmax= 1.7e-02 nm, Epot=  4.41417e+06 Fmax= 1.17828e+07, atom= 6785
# Step=    5, Dmax= 2.1e-02 nm, Epot=  1.50216e+06 Fmax= 3.04863e+06, atom= 6835
# Step=    6, Dmax= 2.5e-02 nm, Epot=  7.06398e+05 Fmax= 9.79145e+05, atom= 6836
# Step=    7, Dmax= 3.0e-02 nm, Epot=  3.66032e+05 Fmax= 6.11025e+05, atom= 2292
# Step=    8, Dmax= 3.6e-02 nm, Epot=  2.20858e+05 Fmax= 4.72681e+05, atom= 2933
# Step=    9, Dmax= 4.3e-02 nm, Epot=  1.21213e+05 Fmax= 1.63234e+05, atom= 2292
# Step=   10, Dmax= 5.2e-02 nm, Epot= -1.83479e+04 Fmax= 4.15483e+04, atom= 2291
# Step=   11, Dmax= 6.2e-02 nm, Epot= -1.59860e+05 Fmax= 2.33223e+04, atom= 2933
# Step=   12, Dmax= 7.4e-02 nm, Epot= -2.05747e+05 Fmax= 1.21098e+04, atom= 4747
# Step=   13, Dmax= 8.9e-02 nm, Epot= -2.36359e+05 Fmax= 1.17533e+04, atom= 4824
# Step=   14, Dmax= 1.1e-01 nm, Epot= -2.46879e+05 Fmax= 3.67387e+04, atom= 12435
# Step=   15, Dmax= 1.3e-01 nm, Epot= -2.51987e+05 Fmax= 1.05769e+04, atom= 3900
# Step=   16, Dmax= 1.5e-01 nm, Epot= -2.61043e+05 Fmax= 2.67956e+04, atom= 3900
# Step=   17, Dmax= 1.8e-01 nm, Epot= -2.63557e+05 Fmax= 2.92873e+04, atom= 3900
# Step=   18, Dmax= 2.2e-01 nm, Epot= -2.63608e+05 Fmax= 9.59433e+04, atom= 12324
# Step=   19, Dmax= 2.7e-01 nm, Epot= -2.64831e+05 Fmax= 1.67217e+05, atom= 12431
# Step=   21, Dmax= 1.6e-01 nm, Epot= -2.69083e+05 Fmax= 1.81793e+03, atom= 12431
# Step=   22, Dmax= 1.9e-01 nm, Epot= -2.82722e+05 Fmax= 2.26178e+04, atom= 5695
# Step=   24, Dmax= 1.2e-01 nm, Epot= -2.86686e+05 Fmax= 1.43441e+04, atom= 5695
# Step=   26, Dmax= 6.9e-02 nm, Epot= -2.88454e+05 Fmax= 7.46734e+03, atom= 5695
# Step=   28, Dmax= 4.1e-02 nm, Epot= -2.89135e+05 Fmax= 5.39514e+03, atom= 5695
# Step=   29, Dmax= 5.0e-02 nm, Epot= -2.89203e+05 Fmax= 1.04479e+04, atom= 5695
# Step=   30, Dmax= 6.0e-02 nm, Epot= -2.89919e+05 Fmax= 8.29845e+03, atom= 5695
# Step=   32, Dmax= 3.6e-02 nm, Epot= -2.90722e+05 Fmax= 2.98205e+03, atom= 5695
# Step=   33, Dmax= 4.3e-02 nm, Epot= -2.90773e+05 Fmax= 1.02481e+04, atom= 5695
# Step=   34, Dmax= 5.2e-02 nm, Epot= -2.91670e+05 Fmax= 5.89996e+03, atom= 5695
# Step=   36, Dmax= 3.1e-02 nm, Epot= -2.92134e+05 Fmax= 3.80876e+03, atom= 5695
# Step=   37, Dmax= 3.7e-02 nm, Epot= -2.92212e+05 Fmax= 7.90262e+03, atom= 5695
# Step=   38, Dmax= 4.5e-02 nm, Epot= -2.92714e+05 Fmax= 6.14134e+03, atom= 5695
# Step=   40, Dmax= 2.7e-02 nm, Epot= -2.93230e+05 Fmax= 2.26634e+03, atom= 3077
# Step=   41, Dmax= 3.2e-02 nm, Epot= -2.93382e+05 Fmax= 7.86421e+03, atom= 3077
# Step=   42, Dmax= 3.8e-02 nm, Epot= -2.94002e+05 Fmax= 4.34712e+03, atom= 3077
# Step=   44, Dmax= 2.3e-02 nm, Epot= -2.94322e+05 Fmax= 3.01106e+03, atom= 3077
# Step=   45, Dmax= 2.8e-02 nm, Epot= -2.94519e+05 Fmax= 5.85512e+03, atom= 3077
# Step=   46, Dmax= 3.3e-02 nm, Epot= -2.94852e+05 Fmax= 4.75500e+03, atom= 3077
# Step=   47, Dmax= 4.0e-02 nm, Epot= -2.94898e+05 Fmax= 8.00936e+03, atom= 3077
# Step=   48, Dmax= 4.8e-02 nm, Epot= -2.95224e+05 Fmax= 7.27614e+03, atom= 3077
# Step=   50, Dmax= 2.9e-02 nm, Epot= -2.95725e+05 Fmax= 1.82351e+03, atom= 3077
# Step=   51, Dmax= 3.4e-02 nm, Epot= -2.95925e+05 Fmax= 9.01278e+03, atom= 3077
# Step=   52, Dmax= 4.1e-02 nm, Epot= -2.96510e+05 Fmax= 4.05551e+03, atom= 3077
# Step=   54, Dmax= 2.5e-02 nm, Epot= -2.96736e+05 Fmax= 3.82813e+03, atom= 3077
# Step=   55, Dmax= 3.0e-02 nm, Epot= -2.96901e+05 Fmax= 5.65446e+03, atom= 3077
# Step=   56, Dmax= 3.6e-02 nm, Epot= -2.97111e+05 Fmax= 5.70702e+03, atom= 3077
# Step=   57, Dmax= 4.3e-02 nm, Epot= -2.97192e+05 Fmax= 7.94972e+03, atom= 3077
# Step=   58, Dmax= 5.1e-02 nm, Epot= -2.97361e+05 Fmax= 8.42041e+03, atom= 3077
# Step=   60, Dmax= 3.1e-02 nm, Epot= -2.97857e+05 Fmax= 1.32723e+03, atom= 3077
# Step=   61, Dmax= 3.7e-02 nm, Epot= -2.98169e+05 Fmax= 1.02663e+04, atom= 3077
# Step=   62, Dmax= 4.4e-02 nm, Epot= -2.98767e+05 Fmax= 3.72330e+03, atom= 3077
# Step=   64, Dmax= 2.7e-02 nm, Epot= -2.98926e+05 Fmax= 4.73312e+03, atom= 3077
# Step=   65, Dmax= 3.2e-02 nm, Epot= -2.99082e+05 Fmax= 5.42002e+03, atom= 3077
# Step=   66, Dmax= 3.8e-02 nm, Epot= -2.99196e+05 Fmax= 6.75443e+03, atom= 3077
# Step=   67, Dmax= 4.6e-02 nm, Epot= -2.99307e+05 Fmax= 7.86666e+03, atom= 3077
# Step=   68, Dmax= 5.5e-02 nm, Epot= -2.99343e+05 Fmax= 9.67362e+03, atom= 3077
# Step=   69, Dmax= 6.6e-02 nm, Epot= -2.99369e+05 Fmax= 1.13911e+04, atom= 3077
# Step=   71, Dmax= 4.0e-02 nm, Epot= -3.00040e+05 Fmax= 1.36841e+03, atom= 3077
# Step=   72, Dmax= 4.8e-02 nm, Epot= -3.00137e+05 Fmax= 1.40804e+04, atom= 3077
# Step=   73, Dmax= 5.7e-02 nm, Epot= -3.00927e+05 Fmax= 4.43061e+03, atom= 3077
# Step=   75, Dmax= 3.4e-02 nm, Epot= -3.01025e+05 Fmax= 6.48171e+03, atom= 3077
# Step=   76, Dmax= 4.1e-02 nm, Epot= -3.01163e+05 Fmax= 6.59675e+03, atom= 3077
# Step=   77, Dmax= 5.0e-02 nm, Epot= -3.01195e+05 Fmax= 9.09471e+03, atom= 3077
# Step=   78, Dmax= 5.9e-02 nm, Epot= -3.01292e+05 Fmax= 9.73932e+03, atom= 3077
# Step=   80, Dmax= 3.6e-02 nm, Epot= -3.01696e+05 Fmax= 1.47411e+03, atom= 3077
# Step=   81, Dmax= 4.3e-02 nm, Epot= -3.01825e+05 Fmax= 1.18996e+04, atom= 3077
# Step=   82, Dmax= 5.1e-02 nm, Epot= -3.02336e+05 Fmax= 4.20286e+03, atom= 3077
# Step=   84, Dmax= 3.1e-02 nm, Epot= -3.02436e+05 Fmax= 5.53384e+03, atom= 3077
# Step=   85, Dmax= 3.7e-02 nm, Epot= -3.02543e+05 Fmax= 6.14333e+03, atom= 3077
# Step=   86, Dmax= 4.4e-02 nm, Epot= -3.02599e+05 Fmax= 7.87305e+03, atom= 3077
# Step=   87, Dmax= 5.3e-02 nm, Epot= -3.02670e+05 Fmax= 8.94616e+03, atom= 3077
# Step=   89, Dmax= 3.2e-02 nm, Epot= -3.02999e+05 Fmax= 1.21185e+03, atom= 3077
# Step=   90, Dmax= 3.8e-02 nm, Epot= -3.03194e+05 Fmax= 1.10223e+04, atom= 3077
# Step=   91, Dmax= 4.6e-02 nm, Epot= -3.03614e+05 Fmax= 3.66301e+03, atom= 3077
# Step=   93, Dmax= 2.8e-02 nm, Epot= -3.03707e+05 Fmax= 5.05696e+03, atom= 3077
# Step=   94, Dmax= 3.3e-02 nm, Epot= -3.03808e+05 Fmax= 5.40491e+03, atom= 3077
# Step=   95, Dmax= 4.0e-02 nm, Epot= -3.03866e+05 Fmax= 7.14202e+03, atom= 3077
# Step=   96, Dmax= 4.8e-02 nm, Epot= -3.03939e+05 Fmax= 7.92352e+03, atom= 3077
# Step=   98, Dmax= 2.9e-02 nm, Epot= -3.04190e+05 Fmax= 1.06511e+03, atom= 3077
# Step=   99, Dmax= 3.4e-02 nm, Epot= -3.04428e+05 Fmax= 9.68114e+03, atom= 3077
# Step=  100, Dmax= 4.1e-02 nm, Epot= -3.04748e+05 Fmax= 3.23385e+03, atom= 3077
# Step=  102, Dmax= 2.5e-02 nm, Epot= -3.04834e+05 Fmax= 4.56586e+03, atom= 3077
# Step=  103, Dmax= 3.0e-02 nm, Epot= -3.04927e+05 Fmax= 4.78230e+03, atom= 3077
# Step=  104, Dmax= 3.6e-02 nm, Epot= -3.04981e+05 Fmax= 6.44451e+03, atom= 3077
# Step=  105, Dmax= 4.3e-02 nm, Epot= -3.05057e+05 Fmax= 7.01859e+03, atom= 3077
# Step=  106, Dmax= 5.1e-02 nm, Epot= -3.05059e+05 Fmax= 9.15282e+03, atom= 3077
# Step=  107, Dmax= 6.2e-02 nm, Epot= -3.05096e+05 Fmax= 1.02421e+04, atom= 3077
# Step=  109, Dmax= 3.7e-02 nm, Epot= -3.05457e+05 Fmax= 1.47940e+03, atom= 3077
# Step=  111, Dmax= 2.2e-02 nm, Epot= -3.05585e+05 Fmax= 5.53217e+03, atom= 3077
# Step=  112, Dmax= 2.7e-02 nm, Epot= -3.05719e+05 Fmax= 2.87922e+03, atom= 3077
# Step=  113, Dmax= 3.2e-02 nm, Epot= -3.05745e+05 Fmax= 7.18565e+03, atom= 3077
# Step=  114, Dmax= 3.8e-02 nm, Epot= -3.05898e+05 Fmax= 4.90911e+03, atom= 3077
# Step=  116, Dmax= 2.3e-02 nm, Epot= -3.06017e+05 Fmax= 2.31092e+03, atom= 3077
# Step=  117, Dmax= 2.8e-02 nm, Epot= -3.06074e+05 Fmax= 6.35234e+03, atom= 3077
# Step=  118, Dmax= 3.3e-02 nm, Epot= -3.06214e+05 Fmax= 4.03644e+03, atom= 3077
# Step=  120, Dmax= 2.0e-02 nm, Epot= -3.06310e+05 Fmax= 2.22099e+03, atom= 3077
# Step=  121, Dmax= 2.4e-02 nm, Epot= -3.06384e+05 Fmax= 5.28192e+03, atom= 3077
# Step=  122, Dmax= 2.9e-02 nm, Epot= -3.06493e+05 Fmax= 3.73505e+03, atom= 3077
# Step=  123, Dmax= 3.4e-02 nm, Epot= -3.06507e+05 Fmax= 7.07295e+03, atom= 3077
# Step=  124, Dmax= 4.1e-02 nm, Epot= -3.06622e+05 Fmax= 5.91457e+03, atom= 3077
# Step=  126, Dmax= 2.5e-02 nm, Epot= -3.06766e+05 Fmax= 1.83711e+03, atom= 3077
# Step=  127, Dmax= 3.0e-02 nm, Epot= -3.06814e+05 Fmax= 7.46397e+03, atom= 3077
# Step=  128, Dmax= 3.6e-02 nm, Epot= -3.06993e+05 Fmax= 3.68790e+03, atom= 3077
# Step=  130, Dmax= 2.1e-02 nm, Epot= -3.07075e+05 Fmax= 3.03203e+03, atom= 3077
# Step=  131, Dmax= 2.6e-02 nm, Epot= -3.07130e+05 Fmax= 5.02283e+03, atom= 3077
# Step=  132, Dmax= 3.1e-02 nm, Epot= -3.07213e+05 Fmax= 4.65850e+03, atom= 3077
# Step=  133, Dmax= 3.7e-02 nm, Epot= -3.07230e+05 Fmax= 6.94533e+03, atom= 3077
# Step=  134, Dmax= 4.4e-02 nm, Epot= -3.07300e+05 Fmax= 6.99989e+03, atom= 3077
# Step=  136, Dmax= 2.7e-02 nm, Epot= -3.07480e+05 Fmax= 1.32282e+03, atom= 3077
# Step=  137, Dmax= 3.2e-02 nm, Epot= -3.07544e+05 Fmax= 8.66159e+03, atom= 3077
# Step=  138, Dmax= 3.8e-02 nm, Epot= -3.07777e+05 Fmax= 3.30754e+03, atom= 3077
# Step=  140, Dmax= 2.3e-02 nm, Epot= -3.07841e+05 Fmax= 3.91129e+03, atom= 3077
# Step=  141, Dmax= 2.8e-02 nm, Epot= -3.07898e+05 Fmax= 4.73721e+03, atom= 3077
# Step=  142, Dmax= 3.3e-02 nm, Epot= -3.07946e+05 Fmax= 5.65852e+03, atom= 3077
# Step=  143, Dmax= 4.0e-02 nm, Epot= -3.07981e+05 Fmax= 6.80020e+03, atom= 3077
# Step=  144, Dmax= 4.8e-02 nm, Epot= -3.07996e+05 Fmax= 8.17379e+03, atom= 3077
# Step=  146, Dmax= 2.9e-02 nm, Epot= -3.08223e+05 Fmax= 7.62561e+02, atom= 3077
# Step=  147, Dmax= 3.4e-02 nm, Epot= -3.08411e+05 Fmax= 9.95153e+03, atom= 3077
# Step=  148, Dmax= 4.1e-02 nm, Epot= -3.08710e+05 Fmax= 2.88717e+03, atom= 3077
# Step=  150, Dmax= 2.5e-02 nm, Epot= -3.08751e+05 Fmax= 4.87711e+03, atom= 3077
# Step=  151, Dmax= 3.0e-02 nm, Epot= -3.08824e+05 Fmax= 4.41241e+03, atom= 3077
# Step=  152, Dmax= 3.5e-02 nm, Epot= -3.08827e+05 Fmax= 6.75228e+03, atom= 3077
# Step=  153, Dmax= 4.3e-02 nm, Epot= -3.08894e+05 Fmax= 6.62454e+03, atom= 3077
# Step=  155, Dmax= 2.6e-02 nm, Epot= -3.09051e+05 Fmax= 1.44170e+03, atom= 3077
# Step=  156, Dmax= 3.1e-02 nm, Epot= -3.09068e+05 Fmax= 8.22297e+03, atom= 3077
# Step=  157, Dmax= 3.7e-02 nm, Epot= -3.09270e+05 Fmax= 3.40877e+03, atom= 3077
# Step=  159, Dmax= 2.2e-02 nm, Epot= -3.09328e+05 Fmax= 3.52637e+03, atom= 3077
# Step=  160, Dmax= 2.6e-02 nm, Epot= -3.09368e+05 Fmax= 4.80893e+03, atom= 3077
# Step=  161, Dmax= 3.2e-02 nm, Epot= -3.09419e+05 Fmax= 5.17433e+03, atom= 3077
# Step=  162, Dmax= 3.8e-02 nm, Epot= -3.09429e+05 Fmax= 6.82692e+03, atom= 3077
# Step=  163, Dmax= 4.6e-02 nm, Epot= -3.09462e+05 Fmax= 7.55304e+03, atom= 3077
# Step=  165, Dmax= 2.7e-02 nm, Epot= -3.09653e+05 Fmax= 1.12103e+03, atom= 3077
# Step=  166, Dmax= 3.3e-02 nm, Epot= -3.09675e+05 Fmax= 9.27354e+03, atom= 3077
# Step=  167, Dmax= 4.0e-02 nm, Epot= -3.09927e+05 Fmax= 3.24299e+03, atom= 3077
# Step=  169, Dmax= 2.4e-02 nm, Epot= -3.09971e+05 Fmax= 4.21083e+03, atom= 3077
# Step=  170, Dmax= 2.8e-02 nm, Epot= -3.10015e+05 Fmax= 4.74957e+03, atom= 3077
# Step=  171, Dmax= 3.4e-02 nm, Epot= -3.10041e+05 Fmax= 5.98225e+03, atom= 3077
# Step=  172, Dmax= 4.1e-02 nm, Epot= -3.10065e+05 Fmax= 6.91975e+03, atom= 3077
# Step=  174, Dmax= 2.5e-02 nm, Epot= -3.10228e+05 Fmax= 7.84238e+02, atom= 3077
# Step=  175, Dmax= 3.0e-02 nm, Epot= -3.10345e+05 Fmax= 8.47616e+03, atom= 3077
# Step=  176, Dmax= 3.5e-02 nm, Epot= -3.10562e+05 Fmax= 2.60040e+03, atom= 3077
# Step=  178, Dmax= 2.1e-02 nm, Epot= -3.10600e+05 Fmax= 4.08852e+03, atom= 3077
# Step=  179, Dmax= 2.6e-02 nm, Epot= -3.10655e+05 Fmax= 3.91375e+03, atom= 3077
# Step=  180, Dmax= 3.1e-02 nm, Epot= -3.10669e+05 Fmax= 5.71029e+03, atom= 3077
# Step=  181, Dmax= 3.7e-02 nm, Epot= -3.10717e+05 Fmax= 5.81540e+03, atom= 3077
# Step=  183, Dmax= 2.2e-02 nm, Epot= -3.10839e+05 Fmax= 1.13191e+03, atom= 3077
# Step=  184, Dmax= 2.6e-02 nm, Epot= -3.10881e+05 Fmax= 7.17975e+03, atom= 3077
# Step=  185, Dmax= 3.2e-02 nm, Epot= -3.11039e+05 Fmax= 2.83615e+03, atom= 3077
# Step=  187, Dmax= 1.9e-02 nm, Epot= -3.11086e+05 Fmax= 3.13742e+03, atom= 3077
# Step=  188, Dmax= 2.3e-02 nm, Epot= -3.11123e+05 Fmax= 4.04900e+03, atom= 3077
# Step=  189, Dmax= 2.7e-02 nm, Epot= -3.11163e+05 Fmax= 4.55275e+03, atom= 3077
# Step=  190, Dmax= 3.3e-02 nm, Epot= -3.11181e+05 Fmax= 5.79304e+03, atom= 3077
# Step=  191, Dmax= 3.9e-02 nm, Epot= -3.11205e+05 Fmax= 6.59744e+03, atom= 3077
# Step=  193, Dmax= 2.4e-02 nm, Epot= -3.11353e+05 Fmax= 8.73111e+02, atom= 3077
# Step=  194, Dmax= 2.8e-02 nm, Epot= -3.11415e+05 Fmax= 8.06100e+03, atom= 3077
# Step=  195, Dmax= 3.4e-02 nm, Epot= -3.11609e+05 Fmax= 2.71539e+03, atom= 3077
# Step=  197, Dmax= 2.0e-02 nm, Epot= -3.11645e+05 Fmax= 3.70434e+03, atom= 3077
# Step=  198, Dmax= 2.5e-02 nm, Epot= -3.11687e+05 Fmax= 4.02076e+03, atom= 3077
# Step=  199, Dmax= 2.9e-02 nm, Epot= -3.11709e+05 Fmax= 5.22552e+03, atom= 3077
# Step=  200, Dmax= 3.5e-02 nm, Epot= -3.11735e+05 Fmax= 5.89652e+03, atom= 3077
# Step=  202, Dmax= 2.1e-02 nm, Epot= -3.11858e+05 Fmax= 7.46135e+02, atom= 3077
# Step=  203, Dmax= 2.5e-02 nm, Epot= -3.11953e+05 Fmax= 7.25648e+03, atom= 3077
# Step=  204, Dmax= 3.1e-02 nm, Epot= -3.12115e+05 Fmax= 2.29760e+03, atom= 3077
# Step=  206, Dmax= 1.8e-02 nm, Epot= -3.12151e+05 Fmax= 3.46995e+03, atom= 3077
# Step=  207, Dmax= 2.2e-02 nm, Epot= -3.12196e+05 Fmax= 3.42520e+03, atom= 3077
# Step=  208, Dmax= 2.6e-02 nm, Epot= -3.12214e+05 Fmax= 4.87362e+03, atom= 3077
# Step=  209, Dmax= 3.2e-02 nm, Epot= -3.12254e+05 Fmax= 5.05899e+03, atom= 3077
# Step=  211, Dmax= 1.9e-02 nm, Epot= -3.12349e+05 Fmax= 9.27778e+02, atom= 3077
# Step=  212, Dmax= 2.3e-02 nm, Epot= -3.12408e+05 Fmax= 6.22105e+03, atom= 3077
# Step=  213, Dmax= 2.7e-02 nm, Epot= -3.12529e+05 Fmax= 2.40770e+03, atom= 3077
# Step=  215, Dmax= 1.6e-02 nm, Epot= -3.12570e+05 Fmax= 2.73841e+03, atom= 3077
# Step=  216, Dmax= 2.0e-02 nm, Epot= -3.12605e+05 Fmax= 3.45910e+03, atom= 3077
# Step=  217, Dmax= 2.4e-02 nm, Epot= -3.12639e+05 Fmax= 3.95300e+03, atom= 3077
# Step=  218, Dmax= 2.8e-02 nm, Epot= -3.12661e+05 Fmax= 4.96773e+03, atom= 3077
# Step=  219, Dmax= 3.4e-02 nm, Epot= -3.12683e+05 Fmax= 5.70999e+03, atom= 3077
# Step=  221, Dmax= 2.0e-02 nm, Epot= -3.12796e+05 Fmax= 7.27163e+02, atom= 3077
# Step=  222, Dmax= 2.5e-02 nm, Epot= -3.12877e+05 Fmax= 6.95220e+03, atom= 3077
# Step=  223, Dmax= 2.9e-02 nm, Epot= -3.13026e+05 Fmax= 2.32942e+03, atom= 3077
# Step=  225, Dmax= 1.8e-02 nm, Epot= -3.13060e+05 Fmax= 3.20090e+03, atom= 3077
# Step=  226, Dmax= 2.1e-02 nm, Epot= -3.13096e+05 Fmax= 3.46063e+03, atom= 3077
# Step=  227, Dmax= 2.5e-02 nm, Epot= -3.13118e+05 Fmax= 4.50682e+03, atom= 3077
# Step=  228, Dmax= 3.1e-02 nm, Epot= -3.13145e+05 Fmax= 5.08255e+03, atom= 3077
# Step=  229, Dmax= 3.7e-02 nm, Epot= -3.13147e+05 Fmax= 6.39597e+03, atom= 3077
# Step=  230, Dmax= 4.4e-02 nm, Epot= -3.13149e+05 Fmax= 7.41298e+03, atom= 3077
# Step=  232, Dmax= 2.6e-02 nm, Epot= -3.13324e+05 Fmax= 8.30112e+02, atom= 3077
# Step=  234, Dmax= 1.6e-02 nm, Epot= -3.13394e+05 Fmax= 4.13950e+03, atom= 3077
# Step=  235, Dmax= 1.9e-02 nm, Epot= -3.13460e+05 Fmax= 1.79301e+03, atom= 3077
# Step=  236, Dmax= 2.3e-02 nm, Epot= -3.13464e+05 Fmax= 5.36521e+03, atom= 3077
# Step=  237, Dmax= 2.7e-02 nm, Epot= -3.13547e+05 Fmax= 3.18959e+03, atom= 3077
# Step=  239, Dmax= 1.6e-02 nm, Epot= -3.13595e+05 Fmax= 1.96565e+03, atom= 3077
# Step=  240, Dmax= 2.0e-02 nm, Epot= -3.13616e+05 Fmax= 4.19668e+03, atom= 3077
# Step=  241, Dmax= 2.4e-02 nm, Epot= -3.13669e+05 Fmax= 3.22801e+03, atom= 3077
# Step=  243, Dmax= 1.4e-02 nm, Epot= -3.13720e+05 Fmax= 1.20557e+03, atom= 3077
# Step=  244, Dmax= 1.7e-02 nm, Epot= -3.13758e+05 Fmax= 4.14212e+03, atom= 3077
# Step=  245, Dmax= 2.0e-02 nm, Epot= -3.13821e+05 Fmax= 2.24141e+03, atom= 3077
# Step=  247, Dmax= 1.2e-02 nm, Epot= -3.13859e+05 Fmax= 1.60822e+03, atom= 3077
# Step=  248, Dmax= 1.5e-02 nm, Epot= -3.13894e+05 Fmax= 2.98664e+03, atom= 3077
# Step=  249, Dmax= 1.8e-02 nm, Epot= -3.13934e+05 Fmax= 2.55547e+03, atom= 3077
# Step=  250, Dmax= 2.1e-02 nm, Epot= -3.13953e+05 Fmax= 4.06835e+03, atom= 3077
# Step=  251, Dmax= 2.5e-02 nm, Epot= -3.13992e+05 Fmax= 3.90986e+03, atom= 3077
# Step=  253, Dmax= 1.5e-02 nm, Epot= -3.14055e+05 Fmax= 8.54575e+02, atom= 3077
# Step=  254, Dmax= 1.8e-02 nm, Epot= -3.14110e+05 Fmax= 4.89913e+03, atom= 3077
# Step=  255, Dmax= 2.2e-02 nm, Epot= -3.14192e+05 Fmax= 1.95907e+03, atom= 3077
# Step=  257, Dmax= 1.3e-02 nm, Epot= -3.14227e+05 Fmax= 2.17904e+03, atom= 3077
# Step=  258, Dmax= 1.6e-02 nm, Epot= -3.14258e+05 Fmax= 2.76111e+03, atom= 3077
# Step=  259, Dmax= 1.9e-02 nm, Epot= -3.14288e+05 Fmax= 3.19463e+03, atom= 3077
# Step=  260, Dmax= 2.3e-02 nm, Epot= -3.14313e+05 Fmax= 3.92446e+03, atom= 3077
# Step=  261, Dmax= 2.7e-02 nm, Epot= -3.14333e+05 Fmax= 4.64831e+03, atom= 3077
# Step=  262, Dmax= 3.3e-02 nm, Epot= -3.14343e+05 Fmax= 5.60883e+03, atom= 3077
# Step=  264, Dmax= 2.0e-02 nm, Epot= -3.14451e+05 Fmax= 5.75704e+02, atom= 3077
# Step=  265, Dmax= 2.4e-02 nm, Epot= -3.14540e+05 Fmax= 6.78200e+03, atom= 3077
# Step=  266, Dmax= 2.8e-02 nm, Epot= -3.14681e+05 Fmax= 2.13549e+03, atom= 3077
# Step=  268, Dmax= 1.7e-02 nm, Epot= -3.14707e+05 Fmax= 3.17493e+03, atom= 3077
# Step=  269, Dmax= 2.0e-02 nm, Epot= -3.14740e+05 Fmax= 3.22646e+03, atom= 3077
# Step=  270, Dmax= 2.4e-02 nm, Epot= -3.14753e+05 Fmax= 4.42659e+03, atom= 3077
# Step=  271, Dmax= 2.9e-02 nm, Epot= -3.14778e+05 Fmax= 4.78829e+03, atom= 3077
# Step=  273, Dmax= 1.8e-02 nm, Epot= -3.14861e+05 Fmax= 7.14500e+02, atom= 3077
# Step=  274, Dmax= 2.1e-02 nm, Epot= -3.14914e+05 Fmax= 5.93478e+03, atom= 3077
# Step=  275, Dmax= 2.5e-02 nm, Epot= -3.15025e+05 Fmax= 1.98391e+03, atom= 3077
# Step=  277, Dmax= 1.5e-02 nm, Epot= -3.15053e+05 Fmax= 2.79644e+03, atom= 3077
# Step=  278, Dmax= 1.8e-02 nm, Epot= -3.15084e+05 Fmax= 2.91151e+03, atom= 3077
# Step=  279, Dmax= 2.2e-02 nm, Epot= -3.15101e+05 Fmax= 3.96669e+03, atom= 3077
# Step=  280, Dmax= 2.6e-02 nm, Epot= -3.15127e+05 Fmax= 4.25726e+03, atom= 3077
# Step=  282, Dmax= 1.6e-02 nm, Epot= -3.15197e+05 Fmax= 7.01064e+02, atom= 3077
# Step=  283, Dmax= 1.9e-02 nm, Epot= -3.15254e+05 Fmax= 5.19828e+03, atom= 3077
# Step=  284, Dmax= 2.3e-02 nm, Epot= -3.15343e+05 Fmax= 1.94557e+03, atom= 3077
# Step=  286, Dmax= 1.4e-02 nm, Epot= -3.15373e+05 Fmax= 2.31291e+03, atom= 3077
# Step=  287, Dmax= 1.6e-02 nm, Epot= -3.15399e+05 Fmax= 2.82420e+03, atom= 3077
# Step=  288, Dmax= 2.0e-02 nm, Epot= -3.15425e+05 Fmax= 3.31200e+03, atom= 3077
# Step=  289, Dmax= 2.4e-02 nm, Epot= -3.15442e+05 Fmax= 4.08084e+03, atom= 3077
# Step=  290, Dmax= 2.8e-02 nm, Epot= -3.15458e+05 Fmax= 4.76013e+03, atom= 3077
# Step=  292, Dmax= 1.7e-02 nm, Epot= -3.15540e+05 Fmax= 5.70384e+02, atom= 3077
# Step=  293, Dmax= 2.0e-02 nm, Epot= -3.15615e+05 Fmax= 5.76314e+03, atom= 3077
# Step=  294, Dmax= 2.4e-02 nm, Epot= -3.15721e+05 Fmax= 1.91907e+03, atom= 3077
# Step=  296, Dmax= 1.5e-02 nm, Epot= -3.15747e+05 Fmax= 2.65786e+03, atom= 3077
# Step=  297, Dmax= 1.8e-02 nm, Epot= -3.15775e+05 Fmax= 2.86298e+03, atom= 3077
# Step=  298, Dmax= 2.1e-02 nm, Epot= -3.15792e+05 Fmax= 3.73328e+03, atom= 3077
# Step=  299, Dmax= 2.5e-02 nm, Epot= -3.15813e+05 Fmax= 4.21279e+03, atom= 3077
# Step=  300, Dmax= 3.0e-02 nm, Epot= -3.15817e+05 Fmax= 5.29108e+03, atom= 3077
# Step=  301, Dmax= 3.6e-02 nm, Epot= -3.15820e+05 Fmax= 6.14917e+03, atom= 3077
# Step=  303, Dmax= 2.2e-02 nm, Epot= -3.15945e+05 Fmax= 6.81355e+02, atom= 3077
# Step=  304, Dmax= 2.6e-02 nm, Epot= -3.15956e+05 Fmax= 7.56835e+03, atom= 3077
# Step=  305, Dmax= 3.1e-02 nm, Epot= -3.16127e+05 Fmax= 2.25711e+03, atom= 3077
# Step=  307, Dmax= 1.9e-02 nm, Epot= -3.16139e+05 Fmax= 3.67768e+03, atom= 3077
# Step=  308, Dmax= 2.3e-02 nm, Epot= -3.16172e+05 Fmax= 3.41143e+03, atom= 3077
# Step=  310, Dmax= 1.4e-02 nm, Epot= -3.16223e+05 Fmax= 8.62791e+02, atom= 3077
# Step=  311, Dmax= 1.6e-02 nm, Epot= -3.16256e+05 Fmax= 4.22606e+03, atom= 3077
# Step=  312, Dmax= 2.0e-02 nm, Epot= -3.16319e+05 Fmax= 1.92951e+03, atom= 3077
# Step=  314, Dmax= 1.2e-02 nm, Epot= -3.16348e+05 Fmax= 1.74153e+03, atom= 3077
# Step=  315, Dmax= 1.4e-02 nm, Epot= -3.16371e+05 Fmax= 2.68996e+03, atom= 3077
# Step=  316, Dmax= 1.7e-02 nm, Epot= -3.16400e+05 Fmax= 2.59917e+03, atom= 3077
# Step=  317, Dmax= 2.0e-02 nm, Epot= -3.16412e+05 Fmax= 3.77631e+03, atom= 3077
# Step=  318, Dmax= 2.4e-02 nm, Epot= -3.16438e+05 Fmax= 3.84401e+03, atom= 3077
# Step=  320, Dmax= 1.5e-02 nm, Epot= -3.16497e+05 Fmax= 7.50607e+02, atom= 3077
# Step=  321, Dmax= 1.8e-02 nm, Epot= -3.16534e+05 Fmax= 4.71652e+03, atom= 3077
# Step=  322, Dmax= 2.1e-02 nm, Epot= -3.16609e+05 Fmax= 1.90170e+03, atom= 3077
# Step=  324, Dmax= 1.3e-02 nm, Epot= -3.16635e+05 Fmax= 2.04446e+03, atom= 3077
# Step=  325, Dmax= 1.5e-02 nm, Epot= -3.16658e+05 Fmax= 2.71749e+03, atom= 3077
# Step=  326, Dmax= 1.8e-02 nm, Epot= -3.16682e+05 Fmax= 2.96844e+03, atom= 3077
# Step=  327, Dmax= 2.2e-02 nm, Epot= -3.16694e+05 Fmax= 3.88361e+03, atom= 3077
# Step=  328, Dmax= 2.6e-02 nm, Epot= -3.16712e+05 Fmax= 4.30846e+03, atom= 3077
# Step=  330, Dmax= 1.6e-02 nm, Epot= -3.16782e+05 Fmax= 6.30727e+02, atom= 3077
# Step=  331, Dmax= 1.9e-02 nm, Epot= -3.16826e+05 Fmax= 5.24083e+03, atom= 3077
# Step=  332, Dmax= 2.3e-02 nm, Epot= -3.16916e+05 Fmax= 1.87537e+03, atom= 3077
# Step=  334, Dmax= 1.4e-02 nm, Epot= -3.16940e+05 Fmax= 2.36636e+03, atom= 3077
# Step=  335, Dmax= 1.6e-02 nm, Epot= -3.16963e+05 Fmax= 2.75091e+03, atom= 3077
# Step=  336, Dmax= 2.0e-02 nm, Epot= -3.16981e+05 Fmax= 3.36140e+03, atom= 3077
# Step=  337, Dmax= 2.3e-02 nm, Epot= -3.16995e+05 Fmax= 4.00319e+03, atom= 3077
# Step=  338, Dmax= 2.8e-02 nm, Epot= -3.17002e+05 Fmax= 4.80379e+03, atom= 3077
# Step=  340, Dmax= 1.7e-02 nm, Epot= -3.17086e+05 Fmax= 5.06107e+02, atom= 3077
# Step=  341, Dmax= 2.0e-02 nm, Epot= -3.17147e+05 Fmax= 5.79703e+03, atom= 3077
# Step=  342, Dmax= 2.4e-02 nm, Epot= -3.17256e+05 Fmax= 1.85578e+03, atom= 3077
# Step=  344, Dmax= 1.5e-02 nm, Epot= -3.17276e+05 Fmax= 2.70293e+03, atom= 3077
# Step=  345, Dmax= 1.8e-02 nm, Epot= -3.17300e+05 Fmax= 2.79652e+03, atom= 3077
# Step=  346, Dmax= 2.1e-02 nm, Epot= -3.17310e+05 Fmax= 3.77434e+03, atom= 3077
# Step=  347, Dmax= 2.5e-02 nm, Epot= -3.17328e+05 Fmax= 4.14131e+03, atom= 3077
# Step=  349, Dmax= 1.5e-02 nm, Epot= -3.17394e+05 Fmax= 5.85597e+02, atom= 3077
# Step=  350, Dmax= 1.8e-02 nm, Epot= -3.17435e+05 Fmax= 5.13826e+03, atom= 3077
# Step=  351, Dmax= 2.2e-02 nm, Epot= -3.17525e+05 Fmax= 1.66497e+03, atom= 3077
# Step=  353, Dmax= 1.3e-02 nm, Epot= -3.17546e+05 Fmax= 2.44330e+03, atom= 3077
# Step=  354, Dmax= 1.6e-02 nm, Epot= -3.17570e+05 Fmax= 2.45833e+03, atom= 3077
# Step=  355, Dmax= 1.9e-02 nm, Epot= -3.17581e+05 Fmax= 3.45168e+03, atom= 3077
# Step=  356, Dmax= 2.3e-02 nm, Epot= -3.17603e+05 Fmax= 3.61096e+03, atom= 3077
# Step=  358, Dmax= 1.4e-02 nm, Epot= -3.17657e+05 Fmax= 6.47347e+02, atom= 3077
# Step=  359, Dmax= 1.6e-02 nm, Epot= -3.17694e+05 Fmax= 4.41477e+03, atom= 3077
# Step=  360, Dmax= 2.0e-02 nm, Epot= -3.17763e+05 Fmax= 1.71896e+03, atom= 3077
# Step=  362, Dmax= 1.2e-02 nm, Epot= -3.17786e+05 Fmax= 1.93756e+03, atom= 3077
# Step=  363, Dmax= 1.4e-02 nm, Epot= -3.17807e+05 Fmax= 2.47653e+03, atom= 3077
# Step=  364, Dmax= 1.7e-02 nm, Epot= -3.17827e+05 Fmax= 2.79304e+03, atom= 3077
# Step=  365, Dmax= 2.0e-02 nm, Epot= -3.17839e+05 Fmax= 3.55864e+03, atom= 3077
# Step=  366, Dmax= 2.4e-02 nm, Epot= -3.17853e+05 Fmax= 4.03424e+03, atom= 3077
# Step=  368, Dmax= 1.5e-02 nm, Epot= -3.17917e+05 Fmax= 5.43531e+02, atom= 3077
# Step=  369, Dmax= 1.7e-02 nm, Epot= -3.17962e+05 Fmax= 4.89227e+03, atom= 3077
# Step=  370, Dmax= 2.1e-02 nm, Epot= -3.18045e+05 Fmax= 1.70253e+03, atom= 3077
# Step=  372, Dmax= 1.3e-02 nm, Epot= -3.18066e+05 Fmax= 2.22817e+03, atom= 3077
# Step=  373, Dmax= 1.5e-02 nm, Epot= -3.18086e+05 Fmax= 2.51528e+03, atom= 3077
# Step=  374, Dmax= 1.8e-02 nm, Epot= -3.18101e+05 Fmax= 3.14989e+03, atom= 3077
# Step=  375, Dmax= 2.2e-02 nm, Epot= -3.18115e+05 Fmax= 3.67652e+03, atom= 3077
# Step=  376, Dmax= 2.6e-02 nm, Epot= -3.18119e+05 Fmax= 4.48601e+03, atom= 3077
# Step=  378, Dmax= 1.6e-02 nm, Epot= -3.18197e+05 Fmax= 4.35164e+02, atom= 3077
# Step=  379, Dmax= 1.9e-02 nm, Epot= -3.18259e+05 Fmax= 5.39845e+03, atom= 3077
# Step=  380, Dmax= 2.3e-02 nm, Epot= -3.18360e+05 Fmax= 1.69294e+03, atom= 3077
# Step=  382, Dmax= 1.4e-02 nm, Epot= -3.18377e+05 Fmax= 2.53192e+03, atom= 3077
# Step=  383, Dmax= 1.6e-02 nm, Epot= -3.18399e+05 Fmax= 2.56557e+03, atom= 3077
# Step=  384, Dmax= 1.9e-02 nm, Epot= -3.18407e+05 Fmax= 3.52470e+03, atom= 3077
# Step=  385, Dmax= 2.3e-02 nm, Epot= -3.18424e+05 Fmax= 3.81235e+03, atom= 3077
# Step=  387, Dmax= 1.4e-02 nm, Epot= -3.18483e+05 Fmax= 5.69102e+02, atom= 3077
# Step=  388, Dmax= 1.7e-02 nm, Epot= -3.18514e+05 Fmax= 4.73776e+03, atom= 3077
# Step=  389, Dmax= 2.0e-02 nm, Epot= -3.18596e+05 Fmax= 1.56946e+03, atom= 3077
# Step=  391, Dmax= 1.2e-02 nm, Epot= -3.18615e+05 Fmax= 2.23838e+03, atom= 3077
# Step=  392, Dmax= 1.5e-02 nm, Epot= -3.18636e+05 Fmax= 2.30503e+03, atom= 3077
# Step=  393, Dmax= 1.7e-02 nm, Epot= -3.18646e+05 Fmax= 3.17300e+03, atom= 3077
# Step=  394, Dmax= 2.1e-02 nm, Epot= -3.18664e+05 Fmax= 3.37330e+03, atom= 3077
# Step=  396, Dmax= 1.3e-02 nm, Epot= -3.18716e+05 Fmax= 5.73641e+02, atom= 3077
# Step=  397, Dmax= 1.5e-02 nm, Epot= -3.18748e+05 Fmax= 4.11555e+03, atom= 3077
# Step=  398, Dmax= 1.8e-02 nm, Epot= -3.18813e+05 Fmax= 1.56900e+03, atom= 3077
# Step=  400, Dmax= 1.1e-02 nm, Epot= -3.18834e+05 Fmax= 1.82019e+03, atom= 3077
# Step=  401, Dmax= 1.3e-02 nm, Epot= -3.18852e+05 Fmax= 2.27119e+03, atom= 3077
# Step=  402, Dmax= 1.6e-02 nm, Epot= -3.18870e+05 Fmax= 2.61304e+03, atom= 3077
# Step=  403, Dmax= 1.9e-02 nm, Epot= -3.18881e+05 Fmax= 3.27415e+03, atom= 3077
# Step=  404, Dmax= 2.3e-02 nm, Epot= -3.18891e+05 Fmax= 3.76333e+03, atom= 3077
# Step=  406, Dmax= 1.4e-02 nm, Epot= -3.18954e+05 Fmax= 4.79580e+02, atom= 3077
# Step=  407, Dmax= 1.6e-02 nm, Epot= -3.18993e+05 Fmax= 4.55546e+03, atom= 3077
# Step=  408, Dmax= 1.9e-02 nm, Epot= -3.19073e+05 Fmax= 1.55629e+03, atom= 3077
# Step=  410, Dmax= 1.2e-02 nm, Epot= -3.19091e+05 Fmax= 2.08713e+03, atom= 3077
# Step=  411, Dmax= 1.4e-02 nm, Epot= -3.19110e+05 Fmax= 2.30949e+03, atom= 3077
# Step=  412, Dmax= 1.7e-02 nm, Epot= -3.19121e+05 Fmax= 2.94152e+03, atom= 3077
# Step=  413, Dmax= 2.0e-02 nm, Epot= -3.19134e+05 Fmax= 3.38590e+03, atom= 3077
# Step=  414, Dmax= 2.4e-02 nm, Epot= -3.19135e+05 Fmax= 4.17980e+03, atom= 3077
# Step=  416, Dmax= 1.5e-02 nm, Epot= -3.19211e+05 Fmax= 3.81447e+02, atom= 3077
# Step=  417, Dmax= 1.7e-02 nm, Epot= -3.19264e+05 Fmax= 5.02207e+03, atom= 3077
# Step=  418, Dmax= 2.1e-02 nm, Epot= -3.19365e+05 Fmax= 1.54945e+03, atom= 3077
# Step=  420, Dmax= 1.3e-02 nm, Epot= -3.19379e+05 Fmax= 2.36652e+03, atom= 3077
# Step=  421, Dmax= 1.5e-02 nm, Epot= -3.19399e+05 Fmax= 2.35847e+03, atom= 3077
# Step=  422, Dmax= 1.8e-02 nm, Epot= -3.19404e+05 Fmax= 3.28636e+03, atom= 3077
# Step=  423, Dmax= 2.2e-02 nm, Epot= -3.19418e+05 Fmax= 3.51445e+03, atom= 3077
# Step=  425, Dmax= 1.3e-02 nm, Epot= -3.19477e+05 Fmax= 5.47083e+02, atom= 3077
# Step=  426, Dmax= 1.6e-02 nm, Epot= -3.19493e+05 Fmax= 4.37108e+03, atom= 3077
# Step=  427, Dmax= 1.9e-02 nm, Epot= -3.19574e+05 Fmax= 1.47662e+03, atom= 3077
# Step=  429, Dmax= 1.1e-02 nm, Epot= -3.19590e+05 Fmax= 2.05285e+03, atom= 3077
# Step=  430, Dmax= 1.3e-02 nm, Epot= -3.19609e+05 Fmax= 2.15878e+03, atom= 3077
# Step=  431, Dmax= 1.6e-02 nm, Epot= -3.19616e+05 Fmax= 2.91895e+03, atom= 3077
# Step=  432, Dmax= 1.9e-02 nm, Epot= -3.19630e+05 Fmax= 3.14898e+03, atom= 3077
# Step=  434, Dmax= 1.2e-02 nm, Epot= -3.19683e+05 Fmax= 5.09182e+02, atom= 3077
# Step=  435, Dmax= 1.4e-02 nm, Epot= -3.19706e+05 Fmax= 3.83603e+03, atom= 3077
# Step=  436, Dmax= 1.7e-02 nm, Epot= -3.19774e+05 Fmax= 1.43233e+03, atom= 3077
# Step=  438, Dmax= 1.0e-02 nm, Epot= -3.19792e+05 Fmax= 1.70911e+03, atom= 3077
# Step=  439, Dmax= 1.2e-02 nm, Epot= -3.19808e+05 Fmax= 2.08334e+03, atom= 3077
# Step=  440, Dmax= 1.4e-02 nm, Epot= -3.19822e+05 Fmax= 2.44393e+03, atom= 3077
# Step=  441, Dmax= 1.7e-02 nm, Epot= -3.19829e+05 Fmax= 3.01344e+03, atom= 3077
# Step=  442, Dmax= 2.1e-02 nm, Epot= -3.19835e+05 Fmax= 3.51034e+03, atom= 3077
# Step=  444, Dmax= 1.3e-02 nm, Epot= -3.19901e+05 Fmax= 4.21957e+02, atom= 3077
# Step=  445, Dmax= 1.5e-02 nm, Epot= -3.19925e+05 Fmax= 4.24291e+03, atom= 3077
# Step=  446, Dmax= 1.8e-02 nm, Epot= -3.20014e+05 Fmax= 1.42167e+03, atom= 3077
# Step=  448, Dmax= 1.1e-02 nm, Epot= -3.20027e+05 Fmax= 1.95524e+03, atom= 3077
# Step=  449, Dmax= 1.3e-02 nm, Epot= -3.20044e+05 Fmax= 2.12013e+03, atom= 3077
# Step=  450, Dmax= 1.6e-02 nm, Epot= -3.20051e+05 Fmax= 2.74718e+03, atom= 3077
# Step=  451, Dmax= 1.9e-02 nm, Epot= -3.20061e+05 Fmax= 3.11819e+03, atom= 3077
# Step=  453, Dmax= 1.1e-02 nm, Epot= -3.20118e+05 Fmax= 3.84653e+02, atom= 3077
# Step=  454, Dmax= 1.3e-02 nm, Epot= -3.20145e+05 Fmax= 3.86928e+03, atom= 3077
# Step=  455, Dmax= 1.6e-02 nm, Epot= -3.20228e+05 Fmax= 1.17413e+03, atom= 3077
# Step=  457, Dmax= 9.7e-03 nm, Epot= -3.20240e+05 Fmax= 1.87125e+03, atom= 3077
# Step=  458, Dmax= 1.2e-02 nm, Epot= -3.20260e+05 Fmax= 1.75993e+03, atom= 3077
# Step=  459, Dmax= 1.4e-02 nm, Epot= -3.20263e+05 Fmax= 2.62034e+03, atom= 3077
# Step=  460, Dmax= 1.7e-02 nm, Epot= -3.20281e+05 Fmax= 2.61235e+03, atom= 3077
# Step=  462, Dmax= 1.0e-02 nm, Epot= -3.20329e+05 Fmax= 5.42415e+02, atom= 3077
# Step=  463, Dmax= 1.2e-02 nm, Epot= -3.20336e+05 Fmax= 3.20700e+03, atom= 3077
# Step=  464, Dmax= 1.4e-02 nm, Epot= -3.20397e+05 Fmax= 1.33525e+03, atom= 3077
# Step=  466, Dmax= 8.7e-03 nm, Epot= -3.20416e+05 Fmax= 1.37339e+03, atom= 3077
# Step=  467, Dmax= 1.0e-02 nm, Epot= -3.20426e+05 Fmax= 1.89831e+03, atom= 3077
# Step=  468, Dmax= 1.3e-02 nm, Epot= -3.20442e+05 Fmax= 2.00577e+03, atom= 3077
# Step=  469, Dmax= 1.5e-02 nm, Epot= -3.20444e+05 Fmax= 2.70141e+03, atom= 3077
# Step=  470, Dmax= 1.8e-02 nm, Epot= -3.20454e+05 Fmax= 2.92408e+03, atom= 3077
# Step=  472, Dmax= 1.1e-02 nm, Epot= -3.20517e+05 Fmax= 4.66916e+02, atom= 3077
# Step=  474, Dmax= 6.5e-03 nm, Epot= -3.20542e+05 Fmax= 1.54524e+03, atom= 3077
# Step=  475, Dmax= 7.8e-03 nm, Epot= -3.20566e+05 Fmax= 8.97436e+02, atom= 3077
# Step=  476, Dmax= 9.3e-03 nm, Epot= -3.20573e+05 Fmax= 2.01094e+03, atom= 3077
# Step=  477, Dmax= 1.1e-02 nm, Epot= -3.20601e+05 Fmax= 1.50420e+03, atom= 3077
# Step=  479, Dmax= 6.7e-03 nm, Epot= -3.20626e+05 Fmax= 5.92422e+02, atom= 3077
# Step=  480, Dmax= 8.1e-03 nm, Epot= -3.20640e+05 Fmax= 1.94846e+03, atom= 3077
# Step=  481, Dmax= 9.7e-03 nm, Epot= -3.20672e+05 Fmax= 1.07220e+03, atom= 3077
# Step=  483, Dmax= 5.8e-03 nm, Epot= -3.20692e+05 Fmax= 7.52731e+02, atom= 3077
# Step=  484, Dmax= 7.0e-03 nm, Epot= -3.20707e+05 Fmax= 1.41597e+03, atom= 3077
# Step=  485, Dmax= 8.4e-03 nm, Epot= -3.20727e+05 Fmax= 1.20980e+03, atom= 3077
# Step=  486, Dmax= 1.0e-02 nm, Epot= -3.20733e+05 Fmax= 1.91978e+03, atom= 3077
# Step=  487, Dmax= 1.2e-02 nm, Epot= -3.20751e+05 Fmax= 1.85835e+03, atom= 3077
# Step=  489, Dmax= 7.2e-03 nm, Epot= -3.20788e+05 Fmax= 3.96130e+02, atom= 3077
# Step=  490, Dmax= 8.7e-03 nm, Epot= -3.20804e+05 Fmax= 2.34313e+03, atom= 3077
# Step=  491, Dmax= 1.0e-02 nm, Epot= -3.20854e+05 Fmax= 9.04253e+02, atom= 3077
# Step=  493, Dmax= 6.2e-03 nm, Epot= -3.20870e+05 Fmax= 1.05824e+03, atom= 3077
# Step=  494, Dmax= 7.5e-03 nm, Epot= -3.20885e+05 Fmax= 1.27649e+03, atom= 3077
# Step=  495, Dmax= 9.0e-03 nm, Epot= -3.20897e+05 Fmax= 1.54614e+03, atom= 3077
# Step=  496, Dmax= 1.1e-02 nm, Epot= -3.20907e+05 Fmax= 1.81994e+03, atom= 3077
# Step=  497, Dmax= 1.3e-02 nm, Epot= -3.20911e+05 Fmax= 2.24095e+03, atom= 3077
# Step=  498, Dmax= 1.6e-02 nm, Epot= -3.20912e+05 Fmax= 2.61035e+03, atom= 3077
# Step=  500, Dmax= 9.3e-03 nm, Epot= -3.20983e+05 Fmax= 3.17611e+02, atom= 7909
# Step=  502, Dmax= 5.6e-03 nm, Epot= -3.21012e+05 Fmax= 1.48029e+03, atom= 7909
# Step=  503, Dmax= 6.7e-03 nm, Epot= -3.21040e+05 Fmax= 6.28513e+02, atom= 7909
# Step=  504, Dmax= 8.1e-03 nm, Epot= -3.21045e+05 Fmax= 1.92970e+03, atom= 7909
# Step=  505, Dmax= 9.7e-03 nm, Epot= -3.21080e+05 Fmax= 1.10406e+03, atom= 7909
# Step=  507, Dmax= 5.8e-03 nm, Epot= -3.21100e+05 Fmax= 7.28800e+02, atom= 7909
# Step=  508, Dmax= 7.0e-03 nm, Epot= -3.21113e+05 Fmax= 1.44114e+03, atom= 7909
# Step=  509, Dmax= 8.3e-03 nm, Epot= -3.21133e+05 Fmax= 1.19357e+03, atom= 7909
# Step=  510, Dmax= 1.0e-02 nm, Epot= -3.21135e+05 Fmax= 1.94081e+03, atom= 7909
# Step=  511, Dmax= 1.2e-02 nm, Epot= -3.21154e+05 Fmax= 1.85030e+03, atom= 7909
# Step=  513, Dmax= 7.2e-03 nm, Epot= -3.21192e+05 Fmax= 4.13905e+02, atom= 7909
# Step=  514, Dmax= 8.7e-03 nm, Epot= -3.21202e+05 Fmax= 2.35270e+03, atom= 7909
# Step=  515, Dmax= 1.0e-02 nm, Epot= -3.21253e+05 Fmax= 9.14669e+02, atom= 7909
# Step=  517, Dmax= 6.2e-03 nm, Epot= -3.21268e+05 Fmax= 1.05829e+03, atom= 7909
# Step=  518, Dmax= 7.5e-03 nm, Epot= -3.21282e+05 Fmax= 1.28188e+03, atom= 7909
# Step=  519, Dmax= 9.0e-03 nm, Epot= -3.21294e+05 Fmax= 1.55298e+03, atom= 7909
# Step=  520, Dmax= 1.1e-02 nm, Epot= -3.21304e+05 Fmax= 1.82177e+03, atom= 7909
# Step=  521, Dmax= 1.3e-02 nm, Epot= -3.21308e+05 Fmax= 2.25611e+03, atom= 7909
# Step=  522, Dmax= 1.6e-02 nm, Epot= -3.21311e+05 Fmax= 2.60889e+03, atom= 7909
# Step=  524, Dmax= 9.3e-03 nm, Epot= -3.21377e+05 Fmax= 3.18391e+02, atom= 7909
# Step=  525, Dmax= 1.1e-02 nm, Epot= -3.21382e+05 Fmax= 3.11490e+03, atom= 7909
# Step=  526, Dmax= 1.3e-02 nm, Epot= -3.21468e+05 Fmax= 1.08888e+03, atom= 7909
# Step=  528, Dmax= 8.0e-03 nm, Epot= -3.21478e+05 Fmax= 1.42625e+03, atom= 7909
# Step=  529, Dmax= 9.6e-03 nm, Epot= -3.21490e+05 Fmax= 1.61841e+03, atom= 7909
# Step=  530, Dmax= 1.2e-02 nm, Epot= -3.21495e+05 Fmax= 2.00936e+03, atom= 7909
# Step=  531, Dmax= 1.4e-02 nm, Epot= -3.21498e+05 Fmax= 2.37132e+03, atom= 7909
# Step=  533, Dmax= 8.3e-03 nm, Epot= -3.21557e+05 Fmax= 2.48178e+02, atom= 7909
# Step=  534, Dmax= 1.0e-02 nm, Epot= -3.21580e+05 Fmax= 2.98144e+03, atom= 7909
# Step=  535, Dmax= 1.2e-02 nm, Epot= -3.21663e+05 Fmax= 8.04207e+02, atom= 7909
# Step=  537, Dmax= 7.2e-03 nm, Epot= -3.21673e+05 Fmax= 1.47561e+03, atom= 7909
# Step=  538, Dmax= 8.6e-03 nm, Epot= -3.21693e+05 Fmax= 1.23343e+03, atom= 7909
# Step=  540, Dmax= 5.2e-03 nm, Epot= -3.21715e+05 Fmax= 4.02777e+02, atom= 7909
# Step=  541, Dmax= 6.2e-03 nm, Epot= -3.21734e+05 Fmax= 1.52682e+03, atom= 7909
# Step=  542, Dmax= 7.5e-03 nm, Epot= -3.21760e+05 Fmax= 8.25387e+02, atom= 7909
# Step=  544, Dmax= 4.5e-03 nm, Epot= -3.21777e+05 Fmax= 5.83823e+02, atom= 5704
# Step=  545, Dmax= 5.4e-03 nm, Epot= -3.21791e+05 Fmax= 1.10252e+03, atom= 7909
# Step=  546, Dmax= 6.5e-03 nm, Epot= -3.21809e+05 Fmax= 9.41233e+02, atom= 5704
# Step=  547, Dmax= 7.7e-03 nm, Epot= -3.21817e+05 Fmax= 1.49168e+03, atom= 5704
# Step=  548, Dmax= 9.3e-03 nm, Epot= -3.21834e+05 Fmax= 1.45135e+03, atom= 5704
# Step=  549, Dmax= 1.1e-02 nm, Epot= -3.21834e+05 Fmax= 2.05880e+03, atom= 5704
# Step=  550, Dmax= 1.3e-02 nm, Epot= -3.21847e+05 Fmax= 2.17658e+03, atom= 5704
# Step=  552, Dmax= 8.0e-03 nm, Epot= -3.21895e+05 Fmax= 3.61004e+02, atom= 5704
# Step=  553, Dmax= 9.6e-03 nm, Epot= -3.21902e+05 Fmax= 2.73881e+03, atom= 5704
# Step=  554, Dmax= 1.2e-02 nm, Epot= -3.21964e+05 Fmax= 9.25997e+02, atom= 5704
# Step=  556, Dmax= 6.9e-03 nm, Epot= -3.21976e+05 Fmax= 1.27823e+03, atom= 5704
# Step=  557, Dmax= 8.3e-03 nm, Epot= -3.21991e+05 Fmax= 1.34329e+03, atom= 5704
# Step=  558, Dmax= 1.0e-02 nm, Epot= -3.21998e+05 Fmax= 1.82415e+03, atom= 5704
# Step=  559, Dmax= 1.2e-02 nm, Epot= -3.22010e+05 Fmax= 1.95446e+03, atom= 5704
# Step=  561, Dmax= 7.2e-03 nm, Epot= -3.22045e+05 Fmax= 3.18064e+02, atom= 5704
# Step=  562, Dmax= 8.6e-03 nm, Epot= -3.22073e+05 Fmax= 2.35624e+03, atom= 5704
# Step=  563, Dmax= 1.0e-02 nm, Epot= -3.22115e+05 Fmax= 9.09289e+02, atom= 5704
# Step=  565, Dmax= 6.2e-03 nm, Epot= -3.22130e+05 Fmax= 1.04306e+03, atom= 5704
# Step=  566, Dmax= 7.5e-03 nm, Epot= -3.22142e+05 Fmax= 1.32243e+03, atom= 5704
# Step=  567, Dmax= 8.9e-03 nm, Epot= -3.22155e+05 Fmax= 1.49482e+03, atom= 5704
# Step=  568, Dmax= 1.1e-02 nm, Epot= -3.22163e+05 Fmax= 1.90824e+03, atom= 5704
# Step=  569, Dmax= 1.3e-02 nm, Epot= -3.22173e+05 Fmax= 2.15390e+03, atom= 5704
# Step=  571, Dmax= 7.7e-03 nm, Epot= -3.22210e+05 Fmax= 2.87475e+02, atom= 5704
# Step=  572, Dmax= 9.3e-03 nm, Epot= -3.22244e+05 Fmax= 2.58129e+03, atom= 5704
# Step=  573, Dmax= 1.1e-02 nm, Epot= -3.22291e+05 Fmax= 9.26414e+02, atom= 5704
# Step=  575, Dmax= 6.7e-03 nm, Epot= -3.22304e+05 Fmax= 1.17298e+03, atom= 5704
# Step=  576, Dmax= 8.0e-03 nm, Epot= -3.22317e+05 Fmax= 1.36842e+03, atom= 5704
# Step=  577, Dmax= 9.6e-03 nm, Epot= -3.22328e+05 Fmax= 1.66009e+03, atom= 5704
# Step=  578, Dmax= 1.2e-02 nm, Epot= -3.22337e+05 Fmax= 1.99668e+03, atom= 5704
# Step=  579, Dmax= 1.4e-02 nm, Epot= -3.22343e+05 Fmax= 2.37049e+03, atom= 5704
# Step=  580, Dmax= 1.7e-02 nm, Epot= -3.22343e+05 Fmax= 2.89280e+03, atom= 5704
# Step=  582, Dmax= 1.0e-02 nm, Epot= -3.22401e+05 Fmax= 2.65833e+02, atom= 5704
# Step=  583, Dmax= 1.2e-02 nm, Epot= -3.22434e+05 Fmax= 3.62129e+03, atom= 5704
# Step=  584, Dmax= 1.4e-02 nm, Epot= -3.22509e+05 Fmax= 9.52938e+02, atom= 5704
# Step=  586, Dmax= 8.6e-03 nm, Epot= -3.22518e+05 Fmax= 1.78376e+03, atom= 5704
# Step=  587, Dmax= 1.0e-02 nm, Epot= -3.22536e+05 Fmax= 1.47749e+03, atom= 5704
# Step=  588, Dmax= 1.2e-02 nm, Epot= -3.22537e+05 Fmax= 2.45866e+03, atom= 5704
# Step=  589, Dmax= 1.5e-02 nm, Epot= -3.22555e+05 Fmax= 2.24232e+03, atom= 5704
# Step=  591, Dmax= 8.9e-03 nm, Epot= -3.22587e+05 Fmax= 5.79849e+02, atom= 5704
# Step=  592, Dmax= 1.1e-02 nm, Epot= -3.22593e+05 Fmax= 2.76663e+03, atom= 5704
# Step=  593, Dmax= 1.3e-02 nm, Epot= -3.22632e+05 Fmax= 1.28970e+03, atom= 5704
# Step=  595, Dmax= 7.7e-03 nm, Epot= -3.22648e+05 Fmax= 1.13913e+03, atom= 5704
# Step=  596, Dmax= 9.3e-03 nm, Epot= -3.22656e+05 Fmax= 1.79962e+03, atom= 5704
# Step=  597, Dmax= 1.1e-02 nm, Epot= -3.22672e+05 Fmax= 1.70501e+03, atom= 5704
# Step=  598, Dmax= 1.3e-02 nm, Epot= -3.22673e+05 Fmax= 2.52316e+03, atom= 5704
# Step=  599, Dmax= 1.6e-02 nm, Epot= -3.22687e+05 Fmax= 2.52911e+03, atom= 5704
# Step=  601, Dmax= 9.6e-03 nm, Epot= -3.22725e+05 Fmax= 5.02387e+02, atom= 5704
# Step=  602, Dmax= 1.2e-02 nm, Epot= -3.22732e+05 Fmax= 3.08675e+03, atom= 5704
# Step=  603, Dmax= 1.4e-02 nm, Epot= -3.22779e+05 Fmax= 1.26910e+03, atom= 5704
# Step=  605, Dmax= 8.3e-03 nm, Epot= -3.22792e+05 Fmax= 1.34144e+03, atom= 5704
# Step=  606, Dmax= 1.0e-02 nm, Epot= -3.22802e+05 Fmax= 1.81462e+03, atom= 5704
# Step=  607, Dmax= 1.2e-02 nm, Epot= -3.22814e+05 Fmax= 1.95178e+03, atom= 5704
# Step=  608, Dmax= 1.4e-02 nm, Epot= -3.22817e+05 Fmax= 2.59054e+03, atom= 5704
# Step=  609, Dmax= 1.7e-02 nm, Epot= -3.22825e+05 Fmax= 2.83923e+03, atom= 5704
# Step=  611, Dmax= 1.0e-02 nm, Epot= -3.22869e+05 Fmax= 4.17169e+02, atom= 5704
# Step=  612, Dmax= 1.2e-02 nm, Epot= -3.22881e+05 Fmax= 3.42789e+03, atom= 5704
# Step=  613, Dmax= 1.5e-02 nm, Epot= -3.22937e+05 Fmax= 1.24882e+03, atom= 5704
# Step=  615, Dmax= 8.9e-03 nm, Epot= -3.22949e+05 Fmax= 1.55763e+03, atom= 5704
# Step=  616, Dmax= 1.1e-02 nm, Epot= -3.22959e+05 Fmax= 1.83277e+03, atom= 5704
# Step=  617, Dmax= 1.3e-02 nm, Epot= -3.22968e+05 Fmax= 2.21519e+03, atom= 5704
# Step=  618, Dmax= 1.5e-02 nm, Epot= -3.22973e+05 Fmax= 2.66497e+03, atom= 5704
# Step=  619, Dmax= 1.8e-02 nm, Epot= -3.22974e+05 Fmax= 3.17076e+03, atom= 5704
# Step=  621, Dmax= 1.1e-02 nm, Epot= -3.23027e+05 Fmax= 3.27493e+02, atom= 5704
# Step=  622, Dmax= 1.3e-02 nm, Epot= -3.23050e+05 Fmax= 3.78426e+03, atom= 5704
# Step=  623, Dmax= 1.6e-02 nm, Epot= -3.23116e+05 Fmax= 1.23464e+03, atom= 5704
# Step=  625, Dmax= 9.6e-03 nm, Epot= -3.23126e+05 Fmax= 1.78434e+03, atom= 5704
# Step=  626, Dmax= 1.2e-02 nm, Epot= -3.23138e+05 Fmax= 1.85906e+03, atom= 5704
# Step=  627, Dmax= 1.4e-02 nm, Epot= -3.23141e+05 Fmax= 2.49195e+03, atom= 5704
# Step=  628, Dmax= 1.7e-02 nm, Epot= -3.23150e+05 Fmax= 2.75210e+03, atom= 5704
# Step=  630, Dmax= 9.9e-03 nm, Epot= -3.23191e+05 Fmax= 3.94930e+02, atom= 5704
# Step=  631, Dmax= 1.2e-02 nm, Epot= -3.23204e+05 Fmax= 3.44742e+03, atom= 5704
# Step=  632, Dmax= 1.4e-02 nm, Epot= -3.23259e+05 Fmax= 1.10238e+03, atom= 5704
# Step=  634, Dmax= 8.6e-03 nm, Epot= -3.23269e+05 Fmax= 1.62555e+03, atom= 5704
# Step=  635, Dmax= 1.0e-02 nm, Epot= -3.23282e+05 Fmax= 1.62451e+03, atom= 5704
# Step=  636, Dmax= 1.2e-02 nm, Epot= -3.23288e+05 Fmax= 2.29640e+03, atom= 5704
# Step=  637, Dmax= 1.5e-02 nm, Epot= -3.23299e+05 Fmax= 2.38717e+03, atom= 5704
# Step=  639, Dmax= 8.9e-03 nm, Epot= -3.23330e+05 Fmax= 4.24279e+02, atom= 5704
# Step=  640, Dmax= 1.1e-02 nm, Epot= -3.23349e+05 Fmax= 2.89876e+03, atom= 5704
# Step=  641, Dmax= 1.3e-02 nm, Epot= -3.23387e+05 Fmax= 1.14097e+03, atom= 5704
# Step=  643, Dmax= 7.7e-03 nm, Epot= -3.23399e+05 Fmax= 1.27951e+03, atom= 5704
# Step=  644, Dmax= 9.2e-03 nm, Epot= -3.23410e+05 Fmax= 1.64725e+03, atom= 5704
# Step=  645, Dmax= 1.1e-02 nm, Epot= -3.23421e+05 Fmax= 1.84431e+03, atom= 5704
# Step=  646, Dmax= 1.3e-02 nm, Epot= -3.23427e+05 Fmax= 2.36762e+03, atom= 5704
# Step=  647, Dmax= 1.6e-02 nm, Epot= -3.23435e+05 Fmax= 2.66628e+03, atom= 5704
# Step=  649, Dmax= 9.6e-03 nm, Epot= -3.23471e+05 Fmax= 3.54091e+02, atom= 5704
# Step=  650, Dmax= 1.1e-02 nm, Epot= -3.23496e+05 Fmax= 3.20620e+03, atom= 5704
# Step=  651, Dmax= 1.4e-02 nm, Epot= -3.23541e+05 Fmax= 1.13130e+03, atom= 5704
# Step=  653, Dmax= 8.3e-03 nm, Epot= -3.23552e+05 Fmax= 1.47098e+03, atom= 5704
# Step=  654, Dmax= 9.9e-03 nm, Epot= -3.23564e+05 Fmax= 1.67345e+03, atom= 5704
# Step=  655, Dmax= 1.2e-02 nm, Epot= -3.23572e+05 Fmax= 2.07961e+03, atom= 5704
# Step=  656, Dmax= 1.4e-02 nm, Epot= -3.23579e+05 Fmax= 2.44613e+03, atom= 5704
# Step=  657, Dmax= 1.7e-02 nm, Epot= -3.23582e+05 Fmax= 2.96469e+03, atom= 5704
# Step=  659, Dmax= 1.0e-02 nm, Epot= -3.23624e+05 Fmax= 2.80359e+02, atom= 5704
# Step=  660, Dmax= 1.2e-02 nm, Epot= -3.23664e+05 Fmax= 3.52632e+03, atom= 5704
# Step=  661, Dmax= 1.5e-02 nm, Epot= -3.23717e+05 Fmax= 1.12868e+03, atom= 5704
# Step=  663, Dmax= 8.9e-03 nm, Epot= -3.23726e+05 Fmax= 1.67094e+03, atom= 5704
# Step=  664, Dmax= 1.1e-02 nm, Epot= -3.23739e+05 Fmax= 1.70825e+03, atom= 5704
# Step=  665, Dmax= 1.3e-02 nm, Epot= -3.23744e+05 Fmax= 2.32617e+03, atom= 5704
# Step=  666, Dmax= 1.5e-02 nm, Epot= -3.23753e+05 Fmax= 2.53721e+03, atom= 5704
# Step=  668, Dmax= 9.2e-03 nm, Epot= -3.23786e+05 Fmax= 3.80360e+02, atom= 5704
# Step=  669, Dmax= 1.1e-02 nm, Epot= -3.23804e+05 Fmax= 3.18006e+03, atom= 5704
# Step=  670, Dmax= 1.3e-02 nm, Epot= -3.23848e+05 Fmax= 1.03644e+03, atom= 5704
# Step=  672, Dmax= 8.0e-03 nm, Epot= -3.23859e+05 Fmax= 1.49332e+03, atom= 5704
# Step=  673, Dmax= 9.6e-03 nm, Epot= -3.23871e+05 Fmax= 1.51988e+03, atom= 5704
# Step=  674, Dmax= 1.1e-02 nm, Epot= -3.23878e+05 Fmax= 2.11629e+03, atom= 5704
# Step=  675, Dmax= 1.4e-02 nm, Epot= -3.23889e+05 Fmax= 2.22631e+03, atom= 5704
# Step=  677, Dmax= 8.3e-03 nm, Epot= -3.23915e+05 Fmax= 3.81555e+02, atom= 5704
# Step=  678, Dmax= 9.9e-03 nm, Epot= -3.23938e+05 Fmax= 2.69897e+03, atom= 5704
# Step=  679, Dmax= 1.2e-02 nm, Epot= -3.23971e+05 Fmax= 1.04823e+03, atom= 5704
# Step=  681, Dmax= 7.1e-03 nm, Epot= -3.23983e+05 Fmax= 1.19644e+03, atom= 5704
# Step=  682, Dmax= 8.6e-03 nm, Epot= -3.23993e+05 Fmax= 1.51801e+03, atom= 5704
# Step=  683, Dmax= 1.0e-02 nm, Epot= -3.24004e+05 Fmax= 1.71923e+03, atom= 5704
# Step=  684, Dmax= 1.2e-02 nm, Epot= -3.24011e+05 Fmax= 2.18677e+03, atom= 5704
# Step=  685, Dmax= 1.5e-02 nm, Epot= -3.24019e+05 Fmax= 2.48083e+03, atom= 5704
# Step=  686, Dmax= 1.8e-02 nm, Epot= -3.24019e+05 Fmax= 3.14184e+03, atom= 5704
# Step=  687, Dmax= 2.1e-02 nm, Epot= -3.24021e+05 Fmax= 3.58604e+03, atom= 5704
# Step=  689, Dmax= 1.3e-02 nm, Epot= -3.24076e+05 Fmax= 4.42385e+02, atom= 5704
# Step=  691, Dmax= 7.7e-03 nm, Epot= -3.24096e+05 Fmax= 1.93931e+03, atom= 5704
# Step=  692, Dmax= 9.2e-03 nm, Epot= -3.24116e+05 Fmax= 9.60562e+02, atom= 5704
# Step=  693, Dmax= 1.1e-02 nm, Epot= -3.24117e+05 Fmax= 2.50790e+03, atom= 5704
# Step=  694, Dmax= 1.3e-02 nm, Epot= -3.24141e+05 Fmax= 1.67913e+03, atom= 5704
# Step=  696, Dmax= 7.9e-03 nm, Epot= -3.24158e+05 Fmax= 8.29188e+02, atom= 5704
# Step=  697, Dmax= 9.5e-03 nm, Epot= -3.24164e+05 Fmax= 2.20769e+03, atom= 5704
# Step=  698, Dmax= 1.1e-02 nm, Epot= -3.24185e+05 Fmax= 1.41151e+03, atom= 5704
# Step=  700, Dmax= 6.9e-03 nm, Epot= -3.24200e+05 Fmax= 7.64826e+02, atom= 5704
# Step=  701, Dmax= 8.2e-03 nm, Epot= -3.24210e+05 Fmax= 1.82132e+03, atom= 5704
# Step=  702, Dmax= 9.9e-03 nm, Epot= -3.24227e+05 Fmax= 1.30762e+03, atom= 5704
# Step=  703, Dmax= 1.2e-02 nm, Epot= -3.24228e+05 Fmax= 2.42655e+03, atom= 5704
# Step=  704, Dmax= 1.4e-02 nm, Epot= -3.24245e+05 Fmax= 2.07743e+03, atom= 5704
# Step=  706, Dmax= 8.5e-03 nm, Epot= -3.24268e+05 Fmax= 6.23142e+02, atom= 5704
# Step=  707, Dmax= 1.0e-02 nm, Epot= -3.24275e+05 Fmax= 2.65262e+03, atom= 5704
# Step=  708, Dmax= 1.2e-02 nm, Epot= -3.24304e+05 Fmax= 1.24531e+03, atom= 5704
# Step=  710, Dmax= 7.4e-03 nm, Epot= -3.24316e+05 Fmax= 1.09722e+03, atom= 5704
# Step=  711, Dmax= 8.9e-03 nm, Epot= -3.24326e+05 Fmax= 1.69105e+03, atom= 5704
# Step=  712, Dmax= 1.1e-02 nm, Epot= -3.24338e+05 Fmax= 1.67611e+03, atom= 5704
# ...
# Step= 9857, Dmax= 2.9e-03 nm, Epot= -3.54396e+05 Fmax= 1.16555e+02, atom= 5533
# Step= 9858, Dmax= 3.4e-03 nm, Epot= -3.54397e+05 Fmax= 9.76125e+02, atom= 5533
# Step= 9859, Dmax= 4.1e-03 nm, Epot= -3.54401e+05 Fmax= 3.30793e+02, atom= 5533
# Step= 9861, Dmax= 2.5e-03 nm, Epot= -3.54402e+05 Fmax= 4.55221e+02, atom= 5533
# Step= 9862, Dmax= 3.0e-03 nm, Epot= -3.54403e+05 Fmax= 4.86034e+02, atom= 5533
# Step= 9863, Dmax= 3.6e-03 nm, Epot= -3.54404e+05 Fmax= 6.45483e+02, atom= 5533
# Step= 9864, Dmax= 4.3e-03 nm, Epot= -3.54404e+05 Fmax= 7.10156e+02, atom= 5533
# Step= 9865, Dmax= 5.1e-03 nm, Epot= -3.54404e+05 Fmax= 9.18703e+02, atom= 5533
# Step= 9866, Dmax= 6.2e-03 nm, Epot= -3.54405e+05 Fmax= 1.03372e+03, atom= 5533
# Step= 9868, Dmax= 3.7e-03 nm, Epot= -3.54409e+05 Fmax= 1.40111e+02, atom= 5533
# Step= 9870, Dmax= 2.2e-03 nm, Epot= -3.54411e+05 Fmax= 5.61604e+02, atom= 5533
# Step= 9871, Dmax= 2.7e-03 nm, Epot= -3.54413e+05 Fmax= 2.83113e+02, atom= 5533
# Step= 9872, Dmax= 3.2e-03 nm, Epot= -3.54413e+05 Fmax= 7.28644e+02, atom= 5533
# Step= 9873, Dmax= 3.8e-03 nm, Epot= -3.54415e+05 Fmax= 4.87541e+02, atom= 5533
# Step= 9875, Dmax= 2.3e-03 nm, Epot= -3.54416e+05 Fmax= 2.40838e+02, atom= 5533
# Step= 9876, Dmax= 2.8e-03 nm, Epot= -3.54417e+05 Fmax= 6.34937e+02, atom= 5533
# Step= 9877, Dmax= 3.3e-03 nm, Epot= -3.54419e+05 Fmax= 4.13956e+02, atom= 5533
# Step= 9879, Dmax= 2.0e-03 nm, Epot= -3.54420e+05 Fmax= 2.16690e+02, atom= 5533
# Step= 9880, Dmax= 2.4e-03 nm, Epot= -3.54421e+05 Fmax= 5.38209e+02, atom= 5533
# Step= 9881, Dmax= 2.9e-03 nm, Epot= -3.54423e+05 Fmax= 3.69732e+02, atom= 5533
# Step= 9882, Dmax= 3.4e-03 nm, Epot= -3.54423e+05 Fmax= 7.17904e+02, atom= 5533
# Step= 9883, Dmax= 4.1e-03 nm, Epot= -3.54424e+05 Fmax= 5.89412e+02, atom= 5533
# Step= 9885, Dmax= 2.5e-03 nm, Epot= -3.54426e+05 Fmax= 1.93497e+02, atom= 5533
# Step= 9886, Dmax= 3.0e-03 nm, Epot= -3.54427e+05 Fmax= 7.48183e+02, atom= 5533
# Step= 9887, Dmax= 3.6e-03 nm, Epot= -3.54429e+05 Fmax= 3.79151e+02, atom= 5533
# Step= 9889, Dmax= 2.1e-03 nm, Epot= -3.54430e+05 Fmax= 2.98829e+02, atom= 5533
# Step= 9890, Dmax= 2.6e-03 nm, Epot= -3.54431e+05 Fmax= 5.12966e+02, atom= 5533
# Step= 9891, Dmax= 3.1e-03 nm, Epot= -3.54432e+05 Fmax= 4.62996e+02, atom= 5533
# Step= 9892, Dmax= 3.7e-03 nm, Epot= -3.54433e+05 Fmax= 7.06347e+02, atom= 5533
# Step= 9893, Dmax= 4.4e-03 nm, Epot= -3.54434e+05 Fmax= 6.98891e+02, atom= 5533
# Step= 9895, Dmax= 2.7e-03 nm, Epot= -3.54436e+05 Fmax= 1.42560e+02, atom= 5533
# Step= 9896, Dmax= 3.2e-03 nm, Epot= -3.54437e+05 Fmax= 8.70347e+02, atom= 5533
# Step= 9897, Dmax= 3.8e-03 nm, Epot= -3.54440e+05 Fmax= 3.41669e+02, atom= 5533
# Step= 9899, Dmax= 2.3e-03 nm, Epot= -3.54442e+05 Fmax= 3.86998e+02, atom= 5533
# Step= 9900, Dmax= 2.8e-03 nm, Epot= -3.54443e+05 Fmax= 4.85706e+02, atom= 5533
# Step= 9901, Dmax= 3.3e-03 nm, Epot= -3.54444e+05 Fmax= 5.63528e+02, atom= 5533
# Step= 9902, Dmax= 4.0e-03 nm, Epot= -3.54444e+05 Fmax= 6.93487e+02, atom= 5533
# Step= 9903, Dmax= 4.8e-03 nm, Epot= -3.54444e+05 Fmax= 8.16926e+02, atom= 5533
# Step= 9904, Dmax= 5.7e-03 nm, Epot= -3.54444e+05 Fmax= 9.93527e+02, atom= 5533
# Step= 9906, Dmax= 3.4e-03 nm, Epot= -3.54449e+05 Fmax= 9.51142e+01, atom= 5533
# Step= 9907, Dmax= 4.1e-03 nm, Epot= -3.54450e+05 Fmax= 1.20579e+03, atom= 5533
# Step= 9908, Dmax= 4.9e-03 nm, Epot= -3.54456e+05 Fmax= 3.61315e+02, atom= 5533
# Step= 9910, Dmax= 3.0e-03 nm, Epot= -3.54457e+05 Fmax= 5.76789e+02, atom= 5533
# Step= 9911, Dmax= 3.5e-03 nm, Epot= -3.54458e+05 Fmax= 5.50907e+02, atom= 5533
# Step= 9913, Dmax= 2.1e-03 nm, Epot= -3.54460e+05 Fmax= 1.24315e+02, atom= 5533
# Step= 9914, Dmax= 2.6e-03 nm, Epot= -3.54462e+05 Fmax= 6.88739e+02, atom= 5533
# Step= 9915, Dmax= 3.1e-03 nm, Epot= -3.54464e+05 Fmax= 2.83830e+02, atom= 5533
# Step= 9917, Dmax= 1.8e-03 nm, Epot= -3.54465e+05 Fmax= 3.00918e+02, atom= 5533
# Step= 9918, Dmax= 2.2e-03 nm, Epot= -3.54466e+05 Fmax= 3.99258e+02, atom= 5533
# Step= 9919, Dmax= 2.6e-03 nm, Epot= -3.54467e+05 Fmax= 4.42660e+02, atom= 5533
# Step= 9920, Dmax= 3.2e-03 nm, Epot= -3.54468e+05 Fmax= 5.65934e+02, atom= 5533
# Step= 9921, Dmax= 3.8e-03 nm, Epot= -3.54469e+05 Fmax= 6.46108e+02, atom= 5533
# Step= 9922, Dmax= 4.6e-03 nm, Epot= -3.54469e+05 Fmax= 8.06483e+02, atom= 5533
# Step= 9923, Dmax= 5.5e-03 nm, Epot= -3.54469e+05 Fmax= 9.38608e+02, atom= 5533
# Step= 9925, Dmax= 3.3e-03 nm, Epot= -3.54473e+05 Fmax= 1.06410e+02, atom= 5533
# Step= 9926, Dmax= 4.0e-03 nm, Epot= -3.54474e+05 Fmax= 1.15198e+03, atom= 5533
# Step= 9927, Dmax= 4.7e-03 nm, Epot= -3.54480e+05 Fmax= 3.53218e+02, atom= 5533
# Step= 9929, Dmax= 2.8e-03 nm, Epot= -3.54480e+05 Fmax= 5.51786e+02, atom= 5533
# Step= 9930, Dmax= 3.4e-03 nm, Epot= -3.54481e+05 Fmax= 5.32479e+02, atom= 5533
# Step= 9931, Dmax= 4.1e-03 nm, Epot= -3.54481e+05 Fmax= 7.70362e+02, atom= 5533
# Step= 9932, Dmax= 4.9e-03 nm, Epot= -3.54482e+05 Fmax= 7.91127e+02, atom= 5533
# Step= 9934, Dmax= 3.0e-03 nm, Epot= -3.54485e+05 Fmax= 1.47581e+02, atom= 5533
# Step= 9935, Dmax= 3.5e-03 nm, Epot= -3.54486e+05 Fmax= 9.76109e+02, atom= 5533
# Step= 9936, Dmax= 4.3e-03 nm, Epot= -3.54490e+05 Fmax= 3.75370e+02, atom= 5533
# Step= 9938, Dmax= 2.6e-03 nm, Epot= -3.54491e+05 Fmax= 4.33945e+02, atom= 5533
# Step= 9939, Dmax= 3.1e-03 nm, Epot= -3.54491e+05 Fmax= 5.38569e+02, atom= 5533
# Step= 9940, Dmax= 3.7e-03 nm, Epot= -3.54492e+05 Fmax= 6.26919e+02, atom= 5533
# Step= 9941, Dmax= 4.4e-03 nm, Epot= -3.54493e+05 Fmax= 7.73701e+02, atom= 5533
# Step= 9942, Dmax= 5.3e-03 nm, Epot= -3.54493e+05 Fmax= 9.04844e+02, atom= 5533
# Step= 9944, Dmax= 3.2e-03 nm, Epot= -3.54497e+05 Fmax= 1.04291e+02, atom= 5533
# Step= 9945, Dmax= 3.8e-03 nm, Epot= -3.54498e+05 Fmax= 1.10301e+03, atom= 5533
# Step= 9946, Dmax= 4.6e-03 nm, Epot= -3.54503e+05 Fmax= 3.49816e+02, atom= 5533
# Step= 9948, Dmax= 2.7e-03 nm, Epot= -3.54504e+05 Fmax= 5.20097e+02, atom= 5533
# Step= 9949, Dmax= 3.3e-03 nm, Epot= -3.54505e+05 Fmax= 5.25385e+02, atom= 5533
# Step= 9950, Dmax= 3.9e-03 nm, Epot= -3.54506e+05 Fmax= 7.27499e+02, atom= 5533
# Step= 9951, Dmax= 4.7e-03 nm, Epot= -3.54506e+05 Fmax= 7.77850e+02, atom= 5533
# Step= 9953, Dmax= 2.8e-03 nm, Epot= -3.54509e+05 Fmax= 1.23627e+02, atom= 5533
# Step= 9954, Dmax= 3.4e-03 nm, Epot= -3.54510e+05 Fmax= 9.61320e+02, atom= 5533
# Step= 9955, Dmax= 4.1e-03 nm, Epot= -3.54514e+05 Fmax= 3.37186e+02, atom= 5533
# Step= 9957, Dmax= 2.5e-03 nm, Epot= -3.54516e+05 Fmax= 4.43477e+02, atom= 5533
# Step= 9958, Dmax= 2.9e-03 nm, Epot= -3.54516e+05 Fmax= 4.91823e+02, atom= 5533
# Step= 9959, Dmax= 3.5e-03 nm, Epot= -3.54517e+05 Fmax= 6.31896e+02, atom= 5533
# Step= 9960, Dmax= 4.2e-03 nm, Epot= -3.54518e+05 Fmax= 7.15079e+02, atom= 5533
# Step= 9961, Dmax= 5.1e-03 nm, Epot= -3.54518e+05 Fmax= 9.03015e+02, atom= 5533
# Step= 9963, Dmax= 3.1e-03 nm, Epot= -3.54521e+05 Fmax= 6.60803e+01, atom= 5533
# Step= 9964, Dmax= 3.7e-03 nm, Epot= -3.54526e+05 Fmax= 1.10188e+03, atom= 5533
# Step= 9965, Dmax= 4.4e-03 nm, Epot= -3.54531e+05 Fmax= 2.94143e+02, atom= 5533
# Step= 9967, Dmax= 2.6e-03 nm, Epot= -3.54532e+05 Fmax= 5.45097e+02, atom= 5533
# Step= 9968, Dmax= 3.2e-03 nm, Epot= -3.54533e+05 Fmax= 4.60335e+02, atom= 5533
# Step= 9970, Dmax= 1.9e-03 nm, Epot= -3.54535e+05 Fmax= 1.44131e+02, atom= 5533
# Step= 9971, Dmax= 2.3e-03 nm, Epot= -3.54536e+05 Fmax= 5.79150e+02, atom= 5533
# Step= 9972, Dmax= 2.7e-03 nm, Epot= -3.54538e+05 Fmax= 2.90915e+02, atom= 5533
# Step= 9973, Dmax= 3.3e-03 nm, Epot= -3.54538e+05 Fmax= 7.51676e+02, atom= 5533
# Step= 9974, Dmax= 3.9e-03 nm, Epot= -3.54540e+05 Fmax= 5.01114e+02, atom= 5533
# Step= 9976, Dmax= 2.4e-03 nm, Epot= -3.54542e+05 Fmax= 2.49284e+02, atom= 5533
# Step= 9977, Dmax= 2.8e-03 nm, Epot= -3.54542e+05 Fmax= 6.52792e+02, atom= 5533
# Step= 9978, Dmax= 3.4e-03 nm, Epot= -3.54544e+05 Fmax= 4.27889e+02, atom= 5533
# Step= 9980, Dmax= 2.0e-03 nm, Epot= -3.54546e+05 Fmax= 2.21778e+02, atom= 5533
# Step= 9981, Dmax= 2.5e-03 nm, Epot= -3.54546e+05 Fmax= 5.56240e+02, atom= 5533
# Step= 9982, Dmax= 2.9e-03 nm, Epot= -3.54548e+05 Fmax= 3.79028e+02, atom= 5533
# Step= 9984, Dmax= 1.8e-03 nm, Epot= -3.54549e+05 Fmax= 1.81095e+02, atom= 5533
# Step= 9985, Dmax= 2.1e-03 nm, Epot= -3.54550e+05 Fmax= 4.92487e+02, atom= 5533
# Step= 9986, Dmax= 2.5e-03 nm, Epot= -3.54552e+05 Fmax= 3.14168e+02, atom= 5533
# Step= 9987, Dmax= 3.1e-03 nm, Epot= -3.54552e+05 Fmax= 6.55409e+02, atom= 5533
# Step= 9988, Dmax= 3.7e-03 nm, Epot= -3.54554e+05 Fmax= 5.06356e+02, atom= 5533
# Step= 9990, Dmax= 2.2e-03 nm, Epot= -3.54556e+05 Fmax= 1.92036e+02, atom= 5533
# Step= 9991, Dmax= 2.6e-03 nm, Epot= -3.54556e+05 Fmax= 6.44253e+02, atom= 5533
# Step= 9992, Dmax= 3.2e-03 nm, Epot= -3.54558e+05 Fmax= 3.60978e+02, atom= 5533
# Step= 9994, Dmax= 1.9e-03 nm, Epot= -3.54559e+05 Fmax= 2.41072e+02, atom= 5533
# Step= 9995, Dmax= 2.3e-03 nm, Epot= -3.54560e+05 Fmax= 4.82847e+02, atom= 5533
# Step= 9996, Dmax= 2.7e-03 nm, Epot= -3.54561e+05 Fmax= 3.84325e+02, atom= 5533
# Step= 9997, Dmax= 3.3e-03 nm, Epot= -3.54562e+05 Fmax= 6.57812e+02, atom= 5533
# Step= 9998, Dmax= 3.9e-03 nm, Epot= -3.54563e+05 Fmax= 5.91106e+02, atom= 5533
# Step=10000, Dmax= 2.4e-03 nm, Epot= -3.54565e+05 Fmax= 1.59529e+02, atom= 5533
#
# Energy minimization reached the maximum number of steps before the forces
# reached the requested precision Fmax < 10.
#
# writing lowest energy coordinates.
#
# Steepest Descents did not converge to Fmax < 10 in 10001 steps.
# Potential Energy  = -3.5456503e+05
# Maximum force     =  1.5952937e+02 on atom 5533
# Norm of force     =  3.8894492e+00
#
# GROMACS reminds you: "You're like them scientists on TV explaining black holes. More you talk, less I get" (Jess Walter)
#
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: D
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: G
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: R
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /DAMM/hosts/damm085/data1/mvalerio/my_env/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: T
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
#                       :-) GROMACS - gmx grompp, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx grompp -f /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/mdps/eq_3_20ns.mdp -c em2.gro -n index_eq.ndx -r restraint_reference.gro -p system_W.top -o eq1.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'ns_type'
#
# WARNING 1 [file /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/mdps/eq_3_20ns.mdp]:
#   The Berendsen barostat does not generate any strictly correct ensemble,
#   and should not be used for new production simulations (in our opinion).
#   We recommend using the C-rescale barostat instead.
#
# Number of degrees of freedom in T-Coupling group Solute is 42366.04
# Number of degrees of freedom in T-Coupling group solvent is 476.97
#
# NOTE 1 [file /DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/mdps/eq_3_20ns.mdp]:
#   There are 1235 non-linear virtual site constructions. Their contribution
#   to the energy error is approximated. In most cases this does not affect
#   the error significantly.
#
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "If Life Seems Jolly Rotten, There's Something You've Forgotten !" (Monty Python)
#
#                       :-) GROMACS - gmx mdrun, 2023.3 (-:
#
# Executable:   /projects/DAMM/gromacs/avx2256/gromacs-2023.3/bin/gmx
# Data prefix:  /projects/DAMM/gromacs/avx2256/gromacs-2023.3
# Working dir:  /local/mvalerio/LNP_Sanofi/5_Endossomal_fusion/PMFs/Scripts
# Command line:
#   gmx mdrun -v -deffnm eq1 -nt 10 -pin on -pinstride 1 -pinoffset 30
# Setting the LD random seed to -672208173
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'PAPC'
#
# Excluding 1 bonded neighbours molecule type 'POPE'
#
# Excluding 1 bonded neighbours molecule type 'DIPE'
#
# Excluding 1 bonded neighbours molecule type 'DPSM'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'PAPS'
#
# Excluding 1 bonded neighbours molecule type 'SAP6'
#
# Excluding 1 bonded neighbours molecule type 'MC3H'
#
# Excluding 1 bonded neighbours molecule type 'DPPC'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'MC3H'
#
# Excluding 1 bonded neighbours molecule type 'DPPC'
#
# Excluding 1 bonded neighbours molecule type 'CHOL'
#
# Excluding 1 bonded neighbours molecule type 'MiddleWater'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Excluding 1 bonded neighbours molecule type 'OuterWater'
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# Cleaning up constraints and constant bonded interactions with virtual sites
#
# The center of mass of the position restraint coord's is  0.084  3.595  9.000
#
# The center of mass of the position restraint coord's is  0.084  3.595  9.000
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 310 K
#
# Calculated rlist for 1x1 atom pair-list as 1.301 nm, buffer size 0.201 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.215 nm, buffer size 0.115 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 13 Mb of data
# Reading file eq1.tpr, VERSION 2023.3 (single precision)
# Changing nstlist from 20 to 25, rlist from 1.215 to 1.267
#
# Update groups can not be used for this system because an incompatible virtual site type is used
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 10 OpenMP threads
#
# Applying core pinning offset 30
# starting mdrun 'INSANE! Membrane UpperLeaflet>POPC:PAPS:PAPC:POPE:DIPE:DPSM:CHOL=640.0:264.0:56.0:264.0:160.0:640.0:826.0 LowerLeaflet>POPC:PAPC:POPE:DIPE:DPSM:CHOL:PAPS:SAP6=373.0:213.0:133.0:426.0:293.0:746.0:666.0:53.0 in water'
# 1000000 steps,  20000.0 ps.
#
# Step 0  Warning: pressure scaling more than 1%, mu: 0.983944 0.983944 0.987227
# step 999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 1000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     8510.273      851.027     1000.0
#                  (ns/day)    (hour/ns)
# Performance:     2030.489        0.012
#
# GROMACS reminds you: "If your experiment needs a statistician, you need a better experiment." (Ernest Rutherford)
# rm: cannot remove '*#': No such file or directory

# %%
## Calculate the number of waters in the midle compartmente. Expecting a number between 3 and 6, if not change "hydration".
u = md.Universe('eq1.gro')
print(len(np.unique(u.select_atoms('name WN').resids))/333)
# Out:
# 5.525525525525525

# %% [markdown]
# ===============================================================================

# %%
# !cat system_W.top
# Out:
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//martini_v3.0.0.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//Martini_v1_tails-2.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//martini_v3.0.0_ions_v1.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//martini_v3.0.0_solvents_v1.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//martini_v3.0_phosphoinositides_v1.0.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//martini_v3.0.0_phospholipids_v1.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//martini_v3.0_CHOL_dev20.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//WN_fbposres.itp"
# #include "/DAMM/hosts/damm085/data1/mvalerio/Lisbeth/PMFs/itp//MC3_MC3H.itp"
#
# [ system ]
# ; name
# INSANE! Membrane UpperLeaflet>POPC:PAPS:PAPC:POPE:DIPE:DPSM:CHOL=640.0:264.0:56.0:264.0:160.0:640.0:826.0 LowerLeaflet>POPC:PAPC:POPE:DIPE:DPSM:CHOL:PAPS:SAP6=373.0:213.0:133.0:426.0:293.0:746.0:666.0:53.0 in water
#
# [ molecules ]
# ;membrane1   number
# POPC            37
# PAPS            15
# PAPC             3
# POPE            15
# DIPE             9
# DPSM            37
# CHOL            48
# POPC            21
# PAPC            12
# POPE             7
# DIPE            24
# DPSM            17
# CHOL            43
# PAPS            38
# SAP6             3
# ;membrane2 number
# MC3H            98
# DPPC            19
# CHOL            78
# MC3H            98
# DPPC            19
# CHOL            78
# MiddleWater  1840
# NA               14
# OuterWater  5852
# CL               145
